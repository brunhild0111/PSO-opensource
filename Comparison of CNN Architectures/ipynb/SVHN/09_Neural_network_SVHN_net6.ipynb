# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-07-12 14:51:33.773233: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
import tensorflow as tf
import numpy as np
from scipy.io import loadmat

def load_svhn_grayscale(data_path):
    """加载SVHN数据集并转换为灰度图像"""
    # 加载原始.mat文件
    train_data = loadmat(data_path + 'train_32x32.mat')
    test_data = loadmat(data_path + 'test_32x32.mat')

    # 转换数据维度格式 [H, W, C, N] -> [N, H, W, C]
    x_train = np.moveaxis(train_data['X'], -1, 0).astype('float32')
    x_test = np.moveaxis(test_data['X'], -1, 0).astype('float32')

    # RGB转灰度（使用亮度公式）
    x_train = tf.image.rgb_to_grayscale(x_train).numpy()  # 输出形状 [N,32,32,1]
    x_test = tf.image.rgb_to_grayscale(x_test).numpy()

    # 标签处理（原标签中10表示数字0）
    y_train = (train_data['y'].flatten() % 10).astype('int64')  # 保持整数标签
    y_test = (test_data['y'].flatten() % 10).astype('int64')

    # 归一化
    x_train /= 255.0
    x_test /= 255.0

    return (x_train, y_train), (x_test, y_test)

# 数据集路径（需提前下载train_32x32.mat和test_32x32.mat）
data_path = '/workspace/examples/vision_transformer/data/svhn/'
(x_train, y_train), (x_test, y_test) = load_svhn_grayscale(data_path)
# Out:
# 2025-07-12 14:51:44.070291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:44.810115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:44.813165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:44.818994: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-12 14:51:44.872819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:44.875630: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:44.878206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:51.247031: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:51.248924: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:51.250568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-07-12 14:51:51.252194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %%
# 划分验证集
val_size = 5000
x_val = x_train[-val_size:]
y_val = y_train[-val_size:]
x_train = x_train[:-val_size]
y_train = y_train[:-val_size]

# 输入形状验证
input_shape = x_train[0].shape
print(f'Input shape: {input_shape}')  # 输出 (32,32,1)
print(f'Train samples: {len(x_train)}, Val samples: {len(x_val)}, Test samples: {len(x_test)}')
# Out:
# Input shape: (32, 32, 1)
# Train samples: 68257, Val samples: 5000, Test samples: 26032

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test11')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test11 of shape (26032, 32, 32, 1) in data/net_mnist/x_test11.h5
# Saving x_train of shape (68257, 32, 32, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (5000, 32, 32, 1) in data/net_mnist/x_val.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2


# 构建模型
model = Sequential()

# 卷积层1（保持输入形状(32,32,1)不变，其他参数不变）
# 输入(32,32,1) → 输出(28,28,6)（32-5+1=28，无填充）
model.add(Conv2D(6, kernel_size=5, input_shape=(32, 32, 1), kernel_regularizer=l2(0.0005)))
model.add(AvgPool2D(pool_size=2, strides=2))  # 输入(28,28,6) → 输出(14,14,6)

# 卷积层2（无修改，维度自动衔接）
# 输入(14,14,6) → 输出(10,10,16)（14-5+1=10，无填充）
model.add(Conv2D(16, kernel_size=5, kernel_regularizer=l2(0.0005)))
model.add(AvgPool2D(pool_size=2, strides=2))  # 输入(10,10,16) → 输出(5,5,16)

# 核心合并层（保持原有参数不变，维度衔接正常）
# 输入(5,5,16) → 输出(1,1,84)（5-5+1=1，无填充）
model.add(Conv2D(84, kernel_size=5, kernel_regularizer=l2(0.0005)))

# 后续层（无修改，保持原结构）
model.add(BatchNormalization())
model.add(ReLU())

# 关键修改1：通道数从20调整为10（对应10个分类类别）
# 输入(1,1,84) → 输出(1,1,10)（kernel_size=1仅调整通道数，不改变空间维度）
model.add(Conv2D(10, kernel_size=1, kernel_regularizer=l2(0.0005)))

# 平均池化层（输入(1,1,10)，输出仍为(1,1,10)，不改变尺寸）
model.add(AvgPool2D(pool_size=1, strides=1))

# 展平层：将(1,1,10)特征图展平为(10,)向量，对应10个分类类别
model.add(Flatten())
# 输出模型架构

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 20)        520
#
#  average_pooling2d (AverageP  (None, 14, 14, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 50)        25050
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 10)          12510
#
#  batch_normalization (BatchN  (None, 1, 1, 10)         40
#  ormalization)
#
#  re_lu (ReLU)                (None, 1, 1, 10)          0
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 38,120
# Trainable params: 38,100
# Non-trainable params: 20
# _________________________________________________________________

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=20,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-07-12 14:52:11.999665: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 67/67 - 14s - loss: 2.2248 - accuracy: 0.2425 - val_loss: 2.3066 - val_accuracy: 0.3186 - 14s/epoch - 214ms/step
# Epoch 2/4000
# 67/67 - 1s - loss: 2.0702 - accuracy: 0.3549 - val_loss: 2.2810 - val_accuracy: 0.3436 - 843ms/epoch - 13ms/step
# Epoch 3/4000
# 67/67 - 1s - loss: 2.0366 - accuracy: 0.3700 - val_loss: 2.2469 - val_accuracy: 0.3408 - 826ms/epoch - 12ms/step
# Epoch 4/4000
# 67/67 - 1s - loss: 2.0207 - accuracy: 0.3727 - val_loss: 2.2042 - val_accuracy: 0.3538 - 825ms/epoch - 12ms/step
# Epoch 5/4000
# 67/67 - 1s - loss: 2.0103 - accuracy: 0.3753 - val_loss: 2.1533 - val_accuracy: 0.3586 - 827ms/epoch - 12ms/step
# Epoch 6/4000
# 67/67 - 1s - loss: 2.0030 - accuracy: 0.3770 - val_loss: 2.1029 - val_accuracy: 0.3620 - 823ms/epoch - 12ms/step
# Epoch 7/4000
# 67/67 - 1s - loss: 1.9974 - accuracy: 0.3769 - val_loss: 2.0522 - val_accuracy: 0.3656 - 833ms/epoch - 12ms/step
# Epoch 8/4000
# 67/67 - 1s - loss: 1.9923 - accuracy: 0.3777 - val_loss: 2.0151 - val_accuracy: 0.3596 - 838ms/epoch - 13ms/step
# Epoch 9/4000
# 67/67 - 1s - loss: 1.9884 - accuracy: 0.3778 - val_loss: 2.0035 - val_accuracy: 0.3752 - 833ms/epoch - 12ms/step
# Epoch 10/4000
# 67/67 - 1s - loss: 1.9843 - accuracy: 0.3792 - val_loss: 1.9815 - val_accuracy: 0.3762 - 825ms/epoch - 12ms/step
# Epoch 11/4000
# 67/67 - 1s - loss: 1.9813 - accuracy: 0.3790 - val_loss: 1.9810 - val_accuracy: 0.3678 - 824ms/epoch - 12ms/step
# Epoch 12/4000
# 67/67 - 1s - loss: 1.9778 - accuracy: 0.3795 - val_loss: 1.9643 - val_accuracy: 0.3768 - 823ms/epoch - 12ms/step
# Epoch 13/4000
# 67/67 - 1s - loss: 1.9750 - accuracy: 0.3802 - val_loss: 1.9654 - val_accuracy: 0.3770 - 825ms/epoch - 12ms/step
# Epoch 14/4000
# 67/67 - 1s - loss: 1.9728 - accuracy: 0.3799 - val_loss: 1.9652 - val_accuracy: 0.3780 - 831ms/epoch - 12ms/step
# Epoch 15/4000
# 67/67 - 1s - loss: 1.9696 - accuracy: 0.3805 - val_loss: 1.9709 - val_accuracy: 0.3788 - 841ms/epoch - 13ms/step
# Epoch 16/4000
# 67/67 - 1s - loss: 1.9674 - accuracy: 0.3802 - val_loss: 1.9603 - val_accuracy: 0.3754 - 828ms/epoch - 12ms/step
# Epoch 17/4000
# 67/67 - 1s - loss: 1.9655 - accuracy: 0.3799 - val_loss: 1.9549 - val_accuracy: 0.3820 - 824ms/epoch - 12ms/step
# Epoch 18/4000
# 67/67 - 1s - loss: 1.9635 - accuracy: 0.3801 - val_loss: 1.9599 - val_accuracy: 0.3804 - 826ms/epoch - 12ms/step
# Epoch 19/4000
# 67/67 - 1s - loss: 1.9611 - accuracy: 0.3800 - val_loss: 1.9652 - val_accuracy: 0.3756 - 826ms/epoch - 12ms/step
# Epoch 20/4000
# 67/67 - 1s - loss: 1.9593 - accuracy: 0.3804 - val_loss: 1.9596 - val_accuracy: 0.3834 - 830ms/epoch - 12ms/step
# Epoch 21/4000
# 67/67 - 1s - loss: 1.9573 - accuracy: 0.3803 - val_loss: 1.9542 - val_accuracy: 0.3772 - 837ms/epoch - 12ms/step
# Epoch 22/4000
# 67/67 - 1s - loss: 1.9556 - accuracy: 0.3806 - val_loss: 1.9514 - val_accuracy: 0.3792 - 835ms/epoch - 12ms/step
# Epoch 23/4000
# 67/67 - 1s - loss: 1.9540 - accuracy: 0.3800 - val_loss: 1.9525 - val_accuracy: 0.3792 - 846ms/epoch - 13ms/step
# Epoch 24/4000
# 67/67 - 1s - loss: 1.9522 - accuracy: 0.3800 - val_loss: 1.9461 - val_accuracy: 0.3800 - 841ms/epoch - 13ms/step
# Epoch 25/4000
# 67/67 - 1s - loss: 1.9508 - accuracy: 0.3797 - val_loss: 1.9563 - val_accuracy: 0.3754 - 842ms/epoch - 13ms/step
# Epoch 26/4000
# 67/67 - 1s - loss: 1.9489 - accuracy: 0.3802 - val_loss: 1.9491 - val_accuracy: 0.3812 - 840ms/epoch - 13ms/step
# Epoch 27/4000
# 67/67 - 1s - loss: 1.9477 - accuracy: 0.3803 - val_loss: 1.9442 - val_accuracy: 0.3796 - 852ms/epoch - 13ms/step
# Epoch 28/4000
# 67/67 - 1s - loss: 1.9463 - accuracy: 0.3798 - val_loss: 1.9453 - val_accuracy: 0.3856 - 835ms/epoch - 12ms/step
# Epoch 29/4000
# 67/67 - 1s - loss: 1.9445 - accuracy: 0.3803 - val_loss: 1.9553 - val_accuracy: 0.3724 - 843ms/epoch - 13ms/step
# Epoch 30/4000
# 67/67 - 1s - loss: 1.9431 - accuracy: 0.3800 - val_loss: 1.9508 - val_accuracy: 0.3792 - 849ms/epoch - 13ms/step
# Epoch 31/4000
# 67/67 - 1s - loss: 1.9416 - accuracy: 0.3803 - val_loss: 1.9427 - val_accuracy: 0.3850 - 841ms/epoch - 13ms/step
# Epoch 32/4000
# 67/67 - 1s - loss: 1.9404 - accuracy: 0.3805 - val_loss: 1.9400 - val_accuracy: 0.3838 - 851ms/epoch - 13ms/step
# Epoch 33/4000
# 67/67 - 1s - loss: 1.9389 - accuracy: 0.3810 - val_loss: 1.9511 - val_accuracy: 0.3726 - 832ms/epoch - 12ms/step
# Epoch 34/4000
# 67/67 - 1s - loss: 1.9378 - accuracy: 0.3802 - val_loss: 1.9392 - val_accuracy: 0.3808 - 831ms/epoch - 12ms/step
# Epoch 35/4000
# 67/67 - 1s - loss: 1.9365 - accuracy: 0.3804 - val_loss: 1.9454 - val_accuracy: 0.3748 - 831ms/epoch - 12ms/step
# Epoch 36/4000
# 67/67 - 1s - loss: 1.9352 - accuracy: 0.3802 - val_loss: 1.9429 - val_accuracy: 0.3758 - 832ms/epoch - 12ms/step
# Epoch 37/4000
# 67/67 - 1s - loss: 1.9339 - accuracy: 0.3803 - val_loss: 1.9407 - val_accuracy: 0.3676 - 831ms/epoch - 12ms/step
# Epoch 38/4000
# 67/67 - 1s - loss: 1.9327 - accuracy: 0.3790 - val_loss: 1.9308 - val_accuracy: 0.3834 - 838ms/epoch - 13ms/step
# Epoch 39/4000
# 67/67 - 1s - loss: 1.9313 - accuracy: 0.3794 - val_loss: 1.9285 - val_accuracy: 0.3772 - 835ms/epoch - 12ms/step
# Epoch 40/4000
# 67/67 - 1s - loss: 1.9306 - accuracy: 0.3790 - val_loss: 1.9313 - val_accuracy: 0.3800 - 830ms/epoch - 12ms/step
# Epoch 59/4000
# 67/67 - 1s - loss: 1.9107 - accuracy: 0.3782 - val_loss: 1.9153 - val_accuracy: 0.3820 - 837ms/epoch - 12ms/step
# Epoch 60/4000
# 67/67 - 1s - loss: 1.9100 - accuracy: 0.3785 - val_loss: 1.9121 - val_accuracy: 0.3816 - 838ms/epoch - 13ms/step
# Epoch 61/4000
# 67/67 - 1s - loss: 1.9091 - accuracy: 0.3785 - val_loss: 1.9099 - val_accuracy: 0.3802 - 843ms/epoch - 13ms/step
# Epoch 62/4000
# 67/67 - 1s - loss: 1.9083 - accuracy: 0.3782 - val_loss: 1.9113 - val_accuracy: 0.3820 - 841ms/epoch - 13ms/step
# Epoch 63/4000
# 67/67 - 1s - loss: 1.9073 - accuracy: 0.3785 - val_loss: 1.9100 - val_accuracy: 0.3810 - 849ms/epoch - 13ms/step
# Epoch 64/4000
# 67/67 - 1s - loss: 1.9063 - accuracy: 0.3773 - val_loss: 1.9093 - val_accuracy: 0.3840 - 844ms/epoch - 13ms/step
# Epoch 65/4000
# 67/67 - 1s - loss: 1.9057 - accuracy: 0.3773 - val_loss: 1.9089 - val_accuracy: 0.3824 - 840ms/epoch - 13ms/step
# Epoch 66/4000
# 67/67 - 1s - loss: 1.9047 - accuracy: 0.3776 - val_loss: 1.9060 - val_accuracy: 0.3820 - 843ms/epoch - 13ms/step
# Epoch 67/4000
# 67/67 - 1s - loss: 1.9042 - accuracy: 0.3770 - val_loss: 1.9079 - val_accuracy: 0.3786 - 842ms/epoch - 13ms/step
# Epoch 68/4000
# 67/67 - 1s - loss: 1.9031 - accuracy: 0.3773 - val_loss: 1.9039 - val_accuracy: 0.3864 - 843ms/epoch - 13ms/step
# Epoch 69/4000
# 67/67 - 1s - loss: 1.9021 - accuracy: 0.3779 - val_loss: 1.9040 - val_accuracy: 0.3802 - 851ms/epoch - 13ms/step
# Epoch 70/4000
# 67/67 - 1s - loss: 1.9013 - accuracy: 0.3782 - val_loss: 1.9013 - val_accuracy: 0.3804 - 850ms/epoch - 13ms/step
# Epoch 71/4000
# 67/67 - 1s - loss: 1.9005 - accuracy: 0.3776 - val_loss: 1.8992 - val_accuracy: 0.3782 - 852ms/epoch - 13ms/step
# Epoch 72/4000
# 67/67 - 1s - loss: 1.8996 - accuracy: 0.3780 - val_loss: 1.9054 - val_accuracy: 0.3724 - 845ms/epoch - 13ms/step
# Epoch 73/4000
# 67/67 - 1s - loss: 1.8988 - accuracy: 0.3771 - val_loss: 1.8970 - val_accuracy: 0.3756 - 848ms/epoch - 13ms/step
# Epoch 74/4000
# 67/67 - 1s - loss: 1.8976 - accuracy: 0.3768 - val_loss: 1.8983 - val_accuracy: 0.3794 - 839ms/epoch - 13ms/step
# Epoch 75/4000
# 67/67 - 1s - loss: 1.8973 - accuracy: 0.3767 - val_loss: 1.8968 - val_accuracy: 0.3806 - 863ms/epoch - 13ms/step
# Epoch 76/4000
# 67/67 - 1s - loss: 1.8966 - accuracy: 0.3765 - val_loss: 1.8952 - val_accuracy: 0.3768 - 851ms/epoch - 13ms/step
# Epoch 77/4000
# 67/67 - 1s - loss: 1.8953 - accuracy: 0.3760 - val_loss: 1.8973 - val_accuracy: 0.3776 - 840ms/epoch - 13ms/step
# Epoch 78/4000
# 67/67 - 1s - loss: 1.8943 - accuracy: 0.3756 - val_loss: 1.8915 - val_accuracy: 0.3818 - 849ms/epoch - 13ms/step
# Epoch 79/4000
# 67/67 - 1s - loss: 1.8935 - accuracy: 0.3757 - val_loss: 1.8896 - val_accuracy: 0.3790 - 845ms/epoch - 13ms/step
# Epoch 80/4000
# 67/67 - 1s - loss: 1.8916 - accuracy: 0.3749 - val_loss: 1.8924 - val_accuracy: 0.3798 - 845ms/epoch - 13ms/step
# Epoch 81/4000
# 67/67 - 1s - loss: 1.8903 - accuracy: 0.3744 - val_loss: 1.8877 - val_accuracy: 0.3780 - 846ms/epoch - 13ms/step
# Epoch 82/4000
# 67/67 - 1s - loss: 1.8875 - accuracy: 0.3743 - val_loss: 1.8759 - val_accuracy: 0.3822 - 848ms/epoch - 13ms/step
# Epoch 83/4000
# 67/67 - 1s - loss: 1.8831 - accuracy: 0.3754 - val_loss: 1.8743 - val_accuracy: 0.3866 - 846ms/epoch - 13ms/step
# Epoch 84/4000
# 67/67 - 1s - loss: 1.8770 - accuracy: 0.3780 - val_loss: 1.8658 - val_accuracy: 0.3896 - 846ms/epoch - 13ms/step
# Epoch 85/4000
# 67/67 - 1s - loss: 1.8727 - accuracy: 0.3808 - val_loss: 1.8608 - val_accuracy: 0.3876 - 847ms/epoch - 13ms/step
# Epoch 86/4000
# 67/67 - 1s - loss: 1.8703 - accuracy: 0.3806 - val_loss: 1.8587 - val_accuracy: 0.3924 - 848ms/epoch - 13ms/step
# Epoch 87/4000
# 67/67 - 1s - loss: 1.8687 - accuracy: 0.3813 - val_loss: 1.8582 - val_accuracy: 0.3910 - 845ms/epoch - 13ms/step
# Epoch 88/4000
# 67/67 - 1s - loss: 1.8674 - accuracy: 0.3810 - val_loss: 1.8618 - val_accuracy: 0.3802 - 849ms/epoch - 13ms/step
# Epoch 89/4000
# 67/67 - 1s - loss: 1.8661 - accuracy: 0.3811 - val_loss: 1.8570 - val_accuracy: 0.3942 - 849ms/epoch - 13ms/step
# Epoch 90/4000
# 67/67 - 1s - loss: 1.8651 - accuracy: 0.3820 - val_loss: 1.8565 - val_accuracy: 0.3842 - 851ms/epoch - 13ms/step
# Epoch 91/4000
# 67/67 - 1s - loss: 1.8640 - accuracy: 0.3820 - val_loss: 1.8563 - val_accuracy: 0.3942 - 849ms/epoch - 13ms/step
# Epoch 92/4000
# 67/67 - 1s - loss: 1.8632 - accuracy: 0.3825 - val_loss: 1.8522 - val_accuracy: 0.3900 - 847ms/epoch - 13ms/step
# Epoch 93/4000
# 67/67 - 1s - loss: 1.8618 - accuracy: 0.3825 - val_loss: 1.8538 - val_accuracy: 0.3892 - 852ms/epoch - 13ms/step
# Epoch 94/4000
# 67/67 - 1s - loss: 1.8611 - accuracy: 0.3825 - val_loss: 1.8567 - val_accuracy: 0.3850 - 844ms/epoch - 13ms/step
# Epoch 95/4000
# 67/67 - 1s - loss: 1.8603 - accuracy: 0.3822 - val_loss: 1.8556 - val_accuracy: 0.3798 - 845ms/epoch - 13ms/step
# Epoch 96/4000
# 67/67 - 1s - loss: 1.8596 - accuracy: 0.3823 - val_loss: 1.8503 - val_accuracy: 0.3962 - 850ms/epoch - 13ms/step
# Epoch 97/4000
# 67/67 - 1s - loss: 1.8586 - accuracy: 0.3824 - val_loss: 1.8554 - val_accuracy: 0.3820 - 849ms/epoch - 13ms/step
# Epoch 98/4000
# 67/67 - 1s - loss: 1.8578 - accuracy: 0.3829 - val_loss: 1.8503 - val_accuracy: 0.3808 - 852ms/epoch - 13ms/step
# Epoch 99/4000
# 67/67 - 1s - loss: 1.8566 - accuracy: 0.3826 - val_loss: 1.8472 - val_accuracy: 0.3938 - 851ms/epoch - 13ms/step
# Epoch 100/4000
# 67/67 - 1s - loss: 1.8560 - accuracy: 0.3824 - val_loss: 1.8505 - val_accuracy: 0.3934 - 849ms/epoch - 13ms/step
# Epoch 101/4000
# 67/67 - 1s - loss: 1.8550 - accuracy: 0.3829 - val_loss: 1.8479 - val_accuracy: 0.3922 - 848ms/epoch - 13ms/step
# Epoch 102/4000
# 67/67 - 1s - loss: 1.8545 - accuracy: 0.3824 - val_loss: 1.8481 - val_accuracy: 0.3938 - 848ms/epoch - 13ms/step
# Epoch 103/4000
# 67/67 - 1s - loss: 1.8537 - accuracy: 0.3834 - val_loss: 1.8469 - val_accuracy: 0.3860 - 849ms/epoch - 13ms/step
# Epoch 104/4000
# 67/67 - 1s - loss: 1.8526 - accuracy: 0.3833 - val_loss: 1.8467 - val_accuracy: 0.3936 - 863ms/epoch - 13ms/step
# Epoch 105/4000
# 67/67 - 1s - loss: 1.8521 - accuracy: 0.3830 - val_loss: 1.8435 - val_accuracy: 0.3846 - 854ms/epoch - 13ms/step
# Epoch 106/4000
# 67/67 - 1s - loss: 1.8516 - accuracy: 0.3839 - val_loss: 1.8463 - val_accuracy: 0.3904 - 854ms/epoch - 13ms/step
# Epoch 107/4000
# 67/67 - 1s - loss: 1.8505 - accuracy: 0.3834 - val_loss: 1.8441 - val_accuracy: 0.3874 - 852ms/epoch - 13ms/step
# Epoch 108/4000
# 67/67 - 1s - loss: 1.8496 - accuracy: 0.3841 - val_loss: 1.8422 - val_accuracy: 0.3922 - 852ms/epoch - 13ms/step
# Epoch 109/4000
# 67/67 - 1s - loss: 1.8492 - accuracy: 0.3827 - val_loss: 1.8447 - val_accuracy: 0.3934 - 849ms/epoch - 13ms/step
# Epoch 110/4000
# 67/67 - 1s - loss: 1.8483 - accuracy: 0.3845 - val_loss: 1.8416 - val_accuracy: 0.3926 - 854ms/epoch - 13ms/step
# Epoch 111/4000
# 67/67 - 1s - loss: 1.8478 - accuracy: 0.3834 - val_loss: 1.8465 - val_accuracy: 0.3758 - 849ms/epoch - 13ms/step
# Epoch 112/4000
# 67/67 - 1s - loss: 1.8471 - accuracy: 0.3843 - val_loss: 1.8436 - val_accuracy: 0.3912 - 852ms/epoch - 13ms/step
# Epoch 113/4000
# 67/67 - 1s - loss: 1.8461 - accuracy: 0.3838 - val_loss: 1.8415 - val_accuracy: 0.3952 - 853ms/epoch - 13ms/step
# Epoch 114/4000
# 67/67 - 1s - loss: 1.8455 - accuracy: 0.3848 - val_loss: 1.8392 - val_accuracy: 0.3948 - 853ms/epoch - 13ms/step
# Epoch 115/4000
# 67/67 - 1s - loss: 1.8451 - accuracy: 0.3835 - val_loss: 1.8374 - val_accuracy: 0.3914 - 857ms/epoch - 13ms/step
# Epoch 116/4000
# 67/67 - 1s - loss: 1.8443 - accuracy: 0.3836 - val_loss: 1.8387 - val_accuracy: 0.3848 - 852ms/epoch - 13ms/step
# Epoch 117/4000
# 67/67 - 1s - loss: 1.8438 - accuracy: 0.3842 - val_loss: 1.8354 - val_accuracy: 0.3928 - 854ms/epoch - 13ms/step
# Epoch 118/4000
# 67/67 - 1s - loss: 1.8428 - accuracy: 0.3848 - val_loss: 1.8361 - val_accuracy: 0.3850 - 853ms/epoch - 13ms/step
# Epoch 119/4000
# 67/67 - 1s - loss: 1.8422 - accuracy: 0.3843 - val_loss: 1.8372 - val_accuracy: 0.3878 - 853ms/epoch - 13ms/step
# Epoch 120/4000
# 67/67 - 1s - loss: 1.8415 - accuracy: 0.3844 - val_loss: 1.8361 - val_accuracy: 0.3936 - 848ms/epoch - 13ms/step
# Epoch 121/4000
# 67/67 - 1s - loss: 1.8410 - accuracy: 0.3843 - val_loss: 1.8334 - val_accuracy: 0.3922 - 864ms/epoch - 13ms/step
# Epoch 122/4000
# 67/67 - 1s - loss: 1.8403 - accuracy: 0.3848 - val_loss: 1.8342 - val_accuracy: 0.3924 - 859ms/epoch - 13ms/step
# Epoch 123/4000
# 67/67 - 1s - loss: 1.8394 - accuracy: 0.3848 - val_loss: 1.8324 - val_accuracy: 0.3956 - 855ms/epoch - 13ms/step
# Epoch 124/4000
# 67/67 - 1s - loss: 1.8394 - accuracy: 0.3843 - val_loss: 1.8323 - val_accuracy: 0.3864 - 858ms/epoch - 13ms/step
# Epoch 125/4000
# 67/67 - 1s - loss: 1.8384 - accuracy: 0.3843 - val_loss: 1.8325 - val_accuracy: 0.3914 - 854ms/epoch - 13ms/step
# Epoch 126/4000
# 67/67 - 1s - loss: 1.8381 - accuracy: 0.3836 - val_loss: 1.8315 - val_accuracy: 0.3922 - 857ms/epoch - 13ms/step
# Epoch 127/4000
# 67/67 - 1s - loss: 1.8371 - accuracy: 0.3851 - val_loss: 1.8327 - val_accuracy: 0.3906 - 871ms/epoch - 13ms/step
# Epoch 128/4000
# 67/67 - 1s - loss: 1.8364 - accuracy: 0.3852 - val_loss: 1.8308 - val_accuracy: 0.3942 - 861ms/epoch - 13ms/step
# Epoch 129/4000
# 67/67 - 1s - loss: 1.8359 - accuracy: 0.3852 - val_loss: 1.8326 - val_accuracy: 0.3914 - 854ms/epoch - 13ms/step
# Epoch 130/4000
# 67/67 - 1s - loss: 1.8352 - accuracy: 0.3847 - val_loss: 1.8294 - val_accuracy: 0.3934 - 859ms/epoch - 13ms/step
# Epoch 131/4000
# 67/67 - 1s - loss: 1.8347 - accuracy: 0.3855 - val_loss: 1.8265 - val_accuracy: 0.3938 - 858ms/epoch - 13ms/step
# Epoch 132/4000
# 67/67 - 1s - loss: 1.8344 - accuracy: 0.3848 - val_loss: 1.8263 - val_accuracy: 0.3914 - 859ms/epoch - 13ms/step
# Epoch 133/4000
# 67/67 - 1s - loss: 1.8338 - accuracy: 0.3847 - val_loss: 1.8274 - val_accuracy: 0.3948 - 866ms/epoch - 13ms/step
# Epoch 134/4000
# 67/67 - 1s - loss: 1.8334 - accuracy: 0.3850 - val_loss: 1.8252 - val_accuracy: 0.3938 - 864ms/epoch - 13ms/step
# Epoch 135/4000
# 67/67 - 1s - loss: 1.8325 - accuracy: 0.3855 - val_loss: 1.8306 - val_accuracy: 0.3800 - 858ms/epoch - 13ms/step
# Epoch 136/4000
# 67/67 - 1s - loss: 1.8322 - accuracy: 0.3844 - val_loss: 1.8246 - val_accuracy: 0.3934 - 858ms/epoch - 13ms/step
# Epoch 137/4000
# 67/67 - 1s - loss: 1.8310 - accuracy: 0.3860 - val_loss: 1.8258 - val_accuracy: 0.3916 - 853ms/epoch - 13ms/step
# Epoch 138/4000
# 67/67 - 1s - loss: 1.8308 - accuracy: 0.3852 - val_loss: 1.8251 - val_accuracy: 0.3888 - 853ms/epoch - 13ms/step
# Epoch 139/4000
# 67/67 - 1s - loss: 1.8306 - accuracy: 0.3855 - val_loss: 1.8228 - val_accuracy: 0.3936 - 872ms/epoch - 13ms/step
# Epoch 140/4000
# 67/67 - 1s - loss: 1.8297 - accuracy: 0.3859 - val_loss: 1.8241 - val_accuracy: 0.3944 - 856ms/epoch - 13ms/step
# Epoch 141/4000
# 67/67 - 1s - loss: 1.8291 - accuracy: 0.3859 - val_loss: 1.8235 - val_accuracy: 0.3908 - 855ms/epoch - 13ms/step
# Epoch 142/4000
# 67/67 - 1s - loss: 1.8281 - accuracy: 0.3860 - val_loss: 1.8217 - val_accuracy: 0.3948 - 863ms/epoch - 13ms/step
# Epoch 143/4000
# 67/67 - 1s - loss: 1.8280 - accuracy: 0.3855 - val_loss: 1.8219 - val_accuracy: 0.4014 - 858ms/epoch - 13ms/step
# Epoch 144/4000
# 67/67 - 1s - loss: 1.8279 - accuracy: 0.3857 - val_loss: 1.8235 - val_accuracy: 0.3928 - 856ms/epoch - 13ms/step
# Epoch 145/4000
# 67/67 - 1s - loss: 1.8269 - accuracy: 0.3866 - val_loss: 1.8199 - val_accuracy: 0.3958 - 860ms/epoch - 13ms/step
# Epoch 146/4000
# 67/67 - 1s - loss: 1.8266 - accuracy: 0.3859 - val_loss: 1.8211 - val_accuracy: 0.3956 - 864ms/epoch - 13ms/step
# Epoch 147/4000
# 67/67 - 1s - loss: 1.8258 - accuracy: 0.3868 - val_loss: 1.8205 - val_accuracy: 0.3966 - 857ms/epoch - 13ms/step
# Epoch 148/4000
# 67/67 - 1s - loss: 1.8253 - accuracy: 0.3866 - val_loss: 1.8178 - val_accuracy: 0.3962 - 859ms/epoch - 13ms/step
# Epoch 149/4000
# 67/67 - 1s - loss: 1.8249 - accuracy: 0.3863 - val_loss: 1.8177 - val_accuracy: 0.3948 - 859ms/epoch - 13ms/step
# Epoch 150/4000
# 67/67 - 1s - loss: 1.8244 - accuracy: 0.3863 - val_loss: 1.8209 - val_accuracy: 0.3980 - 857ms/epoch - 13ms/step
# Epoch 151/4000
# 67/67 - 1s - loss: 1.8237 - accuracy: 0.3861 - val_loss: 1.8175 - val_accuracy: 0.3926 - 865ms/epoch - 13ms/step
# Epoch 152/4000
# 67/67 - 1s - loss: 1.8235 - accuracy: 0.3859 - val_loss: 1.8181 - val_accuracy: 0.3920 - 857ms/epoch - 13ms/step
# Epoch 153/4000
# 67/67 - 1s - loss: 1.8228 - accuracy: 0.3861 - val_loss: 1.8174 - val_accuracy: 0.3992 - 862ms/epoch - 13ms/step
# Epoch 154/4000
# 67/67 - 1s - loss: 1.8226 - accuracy: 0.3866 - val_loss: 1.8174 - val_accuracy: 0.3970 - 858ms/epoch - 13ms/step
# Epoch 155/4000
# 67/67 - 1s - loss: 1.8220 - accuracy: 0.3861 - val_loss: 1.8160 - val_accuracy: 0.3984 - 863ms/epoch - 13ms/step
# Epoch 156/4000
# 67/67 - 1s - loss: 1.8215 - accuracy: 0.3863 - val_loss: 1.8148 - val_accuracy: 0.3922 - 861ms/epoch - 13ms/step
# Epoch 157/4000
# 67/67 - 1s - loss: 1.8209 - accuracy: 0.3862 - val_loss: 1.8153 - val_accuracy: 0.3962 - 857ms/epoch - 13ms/step
# Epoch 158/4000
# 67/67 - 1s - loss: 1.8202 - accuracy: 0.3870 - val_loss: 1.8121 - val_accuracy: 0.3944 - 861ms/epoch - 13ms/step
# Epoch 159/4000
# 67/67 - 1s - loss: 1.8200 - accuracy: 0.3856 - val_loss: 1.8137 - val_accuracy: 0.3968 - 856ms/epoch - 13ms/step
# Epoch 160/4000
# 67/67 - 1s - loss: 1.8194 - accuracy: 0.3869 - val_loss: 1.8131 - val_accuracy: 0.3932 - 858ms/epoch - 13ms/step
# Epoch 161/4000
# 67/67 - 1s - loss: 1.8192 - accuracy: 0.3869 - val_loss: 1.8113 - val_accuracy: 0.3962 - 863ms/epoch - 13ms/step
# Epoch 162/4000
# 67/67 - 1s - loss: 1.8184 - accuracy: 0.3871 - val_loss: 1.8111 - val_accuracy: 0.3948 - 860ms/epoch - 13ms/step
# Epoch 163/4000
# 67/67 - 1s - loss: 1.8181 - accuracy: 0.3866 - val_loss: 1.8139 - val_accuracy: 0.3908 - 856ms/epoch - 13ms/step
# Epoch 164/4000
# 67/67 - 1s - loss: 1.8175 - accuracy: 0.3869 - val_loss: 1.8127 - val_accuracy: 0.3952 - 856ms/epoch - 13ms/step
# Epoch 165/4000
# 67/67 - 1s - loss: 1.8168 - accuracy: 0.3868 - val_loss: 1.8097 - val_accuracy: 0.3954 - 861ms/epoch - 13ms/step
# Epoch 166/4000
# 67/67 - 1s - loss: 1.8165 - accuracy: 0.3872 - val_loss: 1.8095 - val_accuracy: 0.3982 - 861ms/epoch - 13ms/step
# Epoch 185/4000
# 67/67 - 1s - loss: 1.8085 - accuracy: 0.3882 - val_loss: 1.8028 - val_accuracy: 0.3972 - 864ms/epoch - 13ms/step
# Epoch 186/4000
# 67/67 - 1s - loss: 1.8081 - accuracy: 0.3879 - val_loss: 1.8031 - val_accuracy: 0.3964 - 862ms/epoch - 13ms/step
# Epoch 187/4000
# 67/67 - 1s - loss: 1.8075 - accuracy: 0.3888 - val_loss: 1.8032 - val_accuracy: 0.3996 - 858ms/epoch - 13ms/step
# Epoch 188/4000
# 67/67 - 1s - loss: 1.8074 - accuracy: 0.3884 - val_loss: 1.8022 - val_accuracy: 0.3956 - 865ms/epoch - 13ms/step
# Epoch 189/4000
# 67/67 - 1s - loss: 1.8069 - accuracy: 0.3884 - val_loss: 1.8016 - val_accuracy: 0.3994 - 865ms/epoch - 13ms/step
# Epoch 190/4000
# 67/67 - 1s - loss: 1.8064 - accuracy: 0.3883 - val_loss: 1.8006 - val_accuracy: 0.3992 - 862ms/epoch - 13ms/step
# Epoch 191/4000
# 67/67 - 1s - loss: 1.8064 - accuracy: 0.3878 - val_loss: 1.8021 - val_accuracy: 0.3962 - 860ms/epoch - 13ms/step
# Epoch 192/4000
# 67/67 - 1s - loss: 1.8060 - accuracy: 0.3882 - val_loss: 1.8014 - val_accuracy: 0.3960 - 858ms/epoch - 13ms/step
# Epoch 193/4000
# 67/67 - 1s - loss: 1.8056 - accuracy: 0.3888 - val_loss: 1.8039 - val_accuracy: 0.3982 - 859ms/epoch - 13ms/step
# Epoch 194/4000
# 67/67 - 1s - loss: 1.8051 - accuracy: 0.3883 - val_loss: 1.7996 - val_accuracy: 0.4010 - 873ms/epoch - 13ms/step
# Epoch 195/4000
# 67/67 - 1s - loss: 1.8049 - accuracy: 0.3888 - val_loss: 1.8027 - val_accuracy: 0.4014 - 862ms/epoch - 13ms/step
# Epoch 196/4000
# 67/67 - 1s - loss: 1.8043 - accuracy: 0.3884 - val_loss: 1.7999 - val_accuracy: 0.3906 - 870ms/epoch - 13ms/step
# Epoch 197/4000
# 67/67 - 1s - loss: 1.8039 - accuracy: 0.3898 - val_loss: 1.7995 - val_accuracy: 0.3986 - 870ms/epoch - 13ms/step
# Epoch 198/4000
# 67/67 - 1s - loss: 1.8036 - accuracy: 0.3885 - val_loss: 1.7984 - val_accuracy: 0.3996 - 864ms/epoch - 13ms/step
# Epoch 199/4000
# 67/67 - 1s - loss: 1.8030 - accuracy: 0.3889 - val_loss: 1.7983 - val_accuracy: 0.3986 - 862ms/epoch - 13ms/step
# Epoch 200/4000
# 67/67 - 1s - loss: 1.8027 - accuracy: 0.3892 - val_loss: 1.7969 - val_accuracy: 0.3966 - 863ms/epoch - 13ms/step
# Epoch 201/4000
# 67/67 - 1s - loss: 1.8022 - accuracy: 0.3894 - val_loss: 1.7974 - val_accuracy: 0.3990 - 859ms/epoch - 13ms/step
# Epoch 202/4000
# 67/67 - 1s - loss: 1.8021 - accuracy: 0.3892 - val_loss: 1.7991 - val_accuracy: 0.3926 - 863ms/epoch - 13ms/step
# Epoch 583/4000
# 67/67 - 1s - loss: 1.7417 - accuracy: 0.3985 - val_loss: 1.7428 - val_accuracy: 0.4072 - 861ms/epoch - 13ms/step
# Epoch 584/4000
# 67/67 - 1s - loss: 1.7413 - accuracy: 0.3983 - val_loss: 1.7430 - val_accuracy: 0.4068 - 860ms/epoch - 13ms/step
# Epoch 585/4000
# 67/67 - 1s - loss: 1.7416 - accuracy: 0.3981 - val_loss: 1.7429 - val_accuracy: 0.4080 - 860ms/epoch - 13ms/step
# Epoch 586/4000
# 67/67 - 1s - loss: 1.7417 - accuracy: 0.3981 - val_loss: 1.7427 - val_accuracy: 0.4066 - 857ms/epoch - 13ms/step
# Epoch 587/4000
# 67/67 - 1s - loss: 1.7410 - accuracy: 0.3984 - val_loss: 1.7421 - val_accuracy: 0.4074 - 864ms/epoch - 13ms/step
# Epoch 588/4000
# 67/67 - 1s - loss: 1.7412 - accuracy: 0.3979 - val_loss: 1.7417 - val_accuracy: 0.4066 - 861ms/epoch - 13ms/step
# Epoch 589/4000
# 67/67 - 1s - loss: 1.7415 - accuracy: 0.3983 - val_loss: 1.7436 - val_accuracy: 0.4072 - 864ms/epoch - 13ms/step
# Epoch 590/4000
# 67/67 - 1s - loss: 1.7413 - accuracy: 0.3980 - val_loss: 1.7425 - val_accuracy: 0.4072 - 859ms/epoch - 13ms/step
# Epoch 591/4000
# 67/67 - 1s - loss: 1.7409 - accuracy: 0.3980 - val_loss: 1.7416 - val_accuracy: 0.4086 - 865ms/epoch - 13ms/step
# Epoch 592/4000
# 67/67 - 1s - loss: 1.7410 - accuracy: 0.3980 - val_loss: 1.7420 - val_accuracy: 0.4088 - 859ms/epoch - 13ms/step
# Epoch 593/4000
# 67/67 - 1s - loss: 1.7406 - accuracy: 0.3984 - val_loss: 1.7423 - val_accuracy: 0.4074 - 860ms/epoch - 13ms/step
# Epoch 594/4000
# 67/67 - 1s - loss: 1.7407 - accuracy: 0.3983 - val_loss: 1.7418 - val_accuracy: 0.4102 - 861ms/epoch - 13ms/step
# Epoch 595/4000
# 67/67 - 1s - loss: 1.7409 - accuracy: 0.3984 - val_loss: 1.7426 - val_accuracy: 0.4086 - 861ms/epoch - 13ms/step
# Epoch 596/4000
# 67/67 - 1s - loss: 1.7405 - accuracy: 0.3984 - val_loss: 1.7416 - val_accuracy: 0.4094 - 863ms/epoch - 13ms/step
# Epoch 597/4000
# 67/67 - 1s - loss: 1.7402 - accuracy: 0.3985 - val_loss: 1.7405 - val_accuracy: 0.4096 - 868ms/epoch - 13ms/step
# Epoch 598/4000
# 67/67 - 1s - loss: 1.7405 - accuracy: 0.3981 - val_loss: 1.7410 - val_accuracy: 0.4088 - 865ms/epoch - 13ms/step
# Epoch 599/4000
# 67/67 - 1s - loss: 1.7408 - accuracy: 0.3983 - val_loss: 1.7427 - val_accuracy: 0.4062 - 863ms/epoch - 13ms/step
# Epoch 600/4000
# 67/67 - 1s - loss: 1.7408 - accuracy: 0.3986 - val_loss: 1.7410 - val_accuracy: 0.4086 - 860ms/epoch - 13ms/step
# Epoch 601/4000
# 67/67 - 1s - loss: 1.7406 - accuracy: 0.3982 - val_loss: 1.7417 - val_accuracy: 0.4064 - 859ms/epoch - 13ms/step
# Epoch 602/4000
# 67/67 - 1s - loss: 1.7399 - accuracy: 0.3980 - val_loss: 1.7416 - val_accuracy: 0.4092 - 862ms/epoch - 13ms/step
# Epoch 603/4000
# 67/67 - 1s - loss: 1.7399 - accuracy: 0.3980 - val_loss: 1.7415 - val_accuracy: 0.4096 - 862ms/epoch - 13ms/step
# Epoch 604/4000
# 67/67 - 1s - loss: 1.7402 - accuracy: 0.3980 - val_loss: 1.7428 - val_accuracy: 0.4066 - 879ms/epoch - 13ms/step
# Epoch 605/4000
# 67/67 - 1s - loss: 1.7401 - accuracy: 0.3987 - val_loss: 1.7421 - val_accuracy: 0.4082 - 860ms/epoch - 13ms/step
# Epoch 606/4000
# 67/67 - 1s - loss: 1.7396 - accuracy: 0.3983 - val_loss: 1.7410 - val_accuracy: 0.4078 - 857ms/epoch - 13ms/step
# Epoch 607/4000
# 67/67 - 1s - loss: 1.7401 - accuracy: 0.3985 - val_loss: 1.7418 - val_accuracy: 0.4094 - 861ms/epoch - 13ms/step
# Epoch 608/4000
# 67/67 - 1s - loss: 1.7395 - accuracy: 0.3987 - val_loss: 1.7411 - val_accuracy: 0.4090 - 863ms/epoch - 13ms/step
# Epoch 609/4000
# 67/67 - 1s - loss: 1.7398 - accuracy: 0.3985 - val_loss: 1.7418 - val_accuracy: 0.4058 - 865ms/epoch - 13ms/step
# Epoch 610/4000
# 67/67 - 1s - loss: 1.7395 - accuracy: 0.3986 - val_loss: 1.7421 - val_accuracy: 0.4090 - 860ms/epoch - 13ms/step
# Epoch 611/4000
# 67/67 - 1s - loss: 1.7393 - accuracy: 0.3986 - val_loss: 1.7419 - val_accuracy: 0.4084 - 859ms/epoch - 13ms/step
# Epoch 612/4000
# 67/67 - 1s - loss: 1.7393 - accuracy: 0.3982 - val_loss: 1.7405 - val_accuracy: 0.4094 - 861ms/epoch - 13ms/step
# Epoch 613/4000
# 67/67 - 1s - loss: 1.7398 - accuracy: 0.3988 - val_loss: 1.7407 - val_accuracy: 0.4084 - 861ms/epoch - 13ms/step
# Epoch 614/4000
# 67/67 - 1s - loss: 1.7394 - accuracy: 0.3978 - val_loss: 1.7407 - val_accuracy: 0.4096 - 860ms/epoch - 13ms/step
# Epoch 615/4000
# 67/67 - 1s - loss: 1.7393 - accuracy: 0.3994 - val_loss: 1.7421 - val_accuracy: 0.4070 - 866ms/epoch - 13ms/step
# Epoch 616/4000
# 67/67 - 1s - loss: 1.7390 - accuracy: 0.3986 - val_loss: 1.7410 - val_accuracy: 0.4066 - 865ms/epoch - 13ms/step
# Epoch 617/4000
# 67/67 - 1s - loss: 1.7390 - accuracy: 0.3988 - val_loss: 1.7417 - val_accuracy: 0.4090 - 860ms/epoch - 13ms/step
# Epoch 618/4000
# 67/67 - 1s - loss: 1.7392 - accuracy: 0.3982 - val_loss: 1.7406 - val_accuracy: 0.4090 - 858ms/epoch - 13ms/step
# Epoch 619/4000
# 67/67 - 1s - loss: 1.7388 - accuracy: 0.3986 - val_loss: 1.7427 - val_accuracy: 0.4072 - 861ms/epoch - 13ms/step
# Epoch 620/4000
# 67/67 - 1s - loss: 1.7391 - accuracy: 0.3981 - val_loss: 1.7405 - val_accuracy: 0.4100 - 863ms/epoch - 13ms/step
# Epoch 621/4000
# 67/67 - 1s - loss: 1.7399 - accuracy: 0.3981 - val_loss: 1.7407 - val_accuracy: 0.4102 - 866ms/epoch - 13ms/step
# Epoch 622/4000
# 67/67 - 1s - loss: 1.7388 - accuracy: 0.3986 - val_loss: 1.7415 - val_accuracy: 0.4078 - 867ms/epoch - 13ms/step
# Epoch 623/4000
# 67/67 - 1s - loss: 1.7387 - accuracy: 0.3988 - val_loss: 1.7400 - val_accuracy: 0.4088 - 865ms/epoch - 13ms/step
# Epoch 624/4000
# 67/67 - 1s - loss: 1.7390 - accuracy: 0.3986 - val_loss: 1.7398 - val_accuracy: 0.4084 - 863ms/epoch - 13ms/step
# Epoch 625/4000
# 67/67 - 1s - loss: 1.7387 - accuracy: 0.3988 - val_loss: 1.7403 - val_accuracy: 0.4090 - 862ms/epoch - 13ms/step
# Epoch 626/4000
# 67/67 - 1s - loss: 1.7387 - accuracy: 0.3980 - val_loss: 1.7408 - val_accuracy: 0.4060 - 861ms/epoch - 13ms/step
# Epoch 627/4000
# 67/67 - 1s - loss: 1.7387 - accuracy: 0.3980 - val_loss: 1.7397 - val_accuracy: 0.4100 - 879ms/epoch - 13ms/step
# Epoch 628/4000
# 67/67 - 1s - loss: 1.7383 - accuracy: 0.3992 - val_loss: 1.7411 - val_accuracy: 0.4094 - 863ms/epoch - 13ms/step
# Epoch 629/4000
# 67/67 - 1s - loss: 1.7386 - accuracy: 0.3990 - val_loss: 1.7406 - val_accuracy: 0.4068 - 860ms/epoch - 13ms/step
# Epoch 630/4000
# 67/67 - 1s - loss: 1.7387 - accuracy: 0.3986 - val_loss: 1.7396 - val_accuracy: 0.4094 - 861ms/epoch - 13ms/step
# Epoch 631/4000
# 67/67 - 1s - loss: 1.7382 - accuracy: 0.3986 - val_loss: 1.7401 - val_accuracy: 0.4098 - 857ms/epoch - 13ms/step
# Epoch 632/4000
# 67/67 - 1s - loss: 1.7387 - accuracy: 0.3985 - val_loss: 1.7398 - val_accuracy: 0.4088 - 864ms/epoch - 13ms/step
# Epoch 633/4000
# 67/67 - 1s - loss: 1.7383 - accuracy: 0.3990 - val_loss: 1.7409 - val_accuracy: 0.4054 - 864ms/epoch - 13ms/step
# Epoch 634/4000
# 67/67 - 1s - loss: 1.7380 - accuracy: 0.3983 - val_loss: 1.7393 - val_accuracy: 0.4100 - 870ms/epoch - 13ms/step
# Epoch 635/4000
# 67/67 - 1s - loss: 1.7384 - accuracy: 0.3987 - val_loss: 1.7394 - val_accuracy: 0.4088 - 862ms/epoch - 13ms/step
# Epoch 636/4000
# 67/67 - 1s - loss: 1.7378 - accuracy: 0.3991 - val_loss: 1.7421 - val_accuracy: 0.4076 - 861ms/epoch - 13ms/step
# Epoch 637/4000
# 67/67 - 1s - loss: 1.7379 - accuracy: 0.3994 - val_loss: 1.7408 - val_accuracy: 0.4078 - 860ms/epoch - 13ms/step
# Epoch 638/4000
# 67/67 - 1s - loss: 1.7382 - accuracy: 0.3986 - val_loss: 1.7394 - val_accuracy: 0.4086 - 860ms/epoch - 13ms/step
# Epoch 639/4000
# 67/67 - 1s - loss: 1.7384 - accuracy: 0.3989 - val_loss: 1.7426 - val_accuracy: 0.4042 - 860ms/epoch - 13ms/step
# Epoch 640/4000
# 67/67 - 1s - loss: 1.7378 - accuracy: 0.3991 - val_loss: 1.7387 - val_accuracy: 0.4100 - 865ms/epoch - 13ms/step
# Epoch 641/4000
# 67/67 - 1s - loss: 1.7375 - accuracy: 0.3982 - val_loss: 1.7392 - val_accuracy: 0.4060 - 861ms/epoch - 13ms/step
# Epoch 642/4000
# 67/67 - 1s - loss: 1.7383 - accuracy: 0.3981 - val_loss: 1.7397 - val_accuracy: 0.4056 - 863ms/epoch - 13ms/step
# Epoch 643/4000
# 67/67 - 1s - loss: 1.7380 - accuracy: 0.3989 - val_loss: 1.7403 - val_accuracy: 0.4040 - 860ms/epoch - 13ms/step
# Epoch 644/4000
# 67/67 - 1s - loss: 1.7376 - accuracy: 0.3987 - val_loss: 1.7413 - val_accuracy: 0.4086 - 858ms/epoch - 13ms/step
# Epoch 645/4000
# 67/67 - 1s - loss: 1.7374 - accuracy: 0.3984 - val_loss: 1.7399 - val_accuracy: 0.4092 - 855ms/epoch - 13ms/step
# Epoch 646/4000
# 67/67 - 1s - loss: 1.7375 - accuracy: 0.3985 - val_loss: 1.7391 - val_accuracy: 0.4088 - 862ms/epoch - 13ms/step
# Epoch 647/4000
# 67/67 - 1s - loss: 1.7373 - accuracy: 0.3990 - val_loss: 1.7397 - val_accuracy: 0.4096 - 861ms/epoch - 13ms/step
# Epoch 648/4000
# 67/67 - 1s - loss: 1.7373 - accuracy: 0.3986 - val_loss: 1.7395 - val_accuracy: 0.4086 - 863ms/epoch - 13ms/step
# Epoch 649/4000
# 67/67 - 1s - loss: 1.7376 - accuracy: 0.3986 - val_loss: 1.7404 - val_accuracy: 0.4068 - 858ms/epoch - 13ms/step
# Epoch 650/4000
# 67/67 - 1s - loss: 1.7373 - accuracy: 0.3987 - val_loss: 1.7392 - val_accuracy: 0.4066 - 861ms/epoch - 13ms/step
# Epoch 651/4000
# 67/67 - 1s - loss: 1.7370 - accuracy: 0.3997 - val_loss: 1.7387 - val_accuracy: 0.4098 - 860ms/epoch - 13ms/step
# Epoch 652/4000
# 67/67 - 1s - loss: 1.7371 - accuracy: 0.3988 - val_loss: 1.7380 - val_accuracy: 0.4084 - 862ms/epoch - 13ms/step
# Epoch 653/4000
# 67/67 - 1s - loss: 1.7375 - accuracy: 0.3984 - val_loss: 1.7388 - val_accuracy: 0.4064 - 857ms/epoch - 13ms/step
# Epoch 654/4000
# 67/67 - 1s - loss: 1.7368 - accuracy: 0.3993 - val_loss: 1.7396 - val_accuracy: 0.4092 - 864ms/epoch - 13ms/step
# Epoch 655/4000
# 67/67 - 1s - loss: 1.7371 - accuracy: 0.3989 - val_loss: 1.7393 - val_accuracy: 0.4102 - 862ms/epoch - 13ms/step
# Epoch 656/4000
# 67/67 - 1s - loss: 1.7368 - accuracy: 0.3996 - val_loss: 1.7396 - val_accuracy: 0.4098 - 858ms/epoch - 13ms/step
# Epoch 657/4000
# 67/67 - 1s - loss: 1.7367 - accuracy: 0.3989 - val_loss: 1.7391 - val_accuracy: 0.4094 - 863ms/epoch - 13ms/step
# Epoch 658/4000
# 67/67 - 1s - loss: 1.7371 - accuracy: 0.3991 - val_loss: 1.7387 - val_accuracy: 0.4080 - 862ms/epoch - 13ms/step
# Epoch 659/4000
# 67/67 - 1s - loss: 1.7360 - accuracy: 0.3992 - val_loss: 1.7393 - val_accuracy: 0.4080 - 862ms/epoch - 13ms/step
# Epoch 660/4000
# 67/67 - 1s - loss: 1.7376 - accuracy: 0.3988 - val_loss: 1.7403 - val_accuracy: 0.4086 - 862ms/epoch - 13ms/step
# Epoch 661/4000
# 67/67 - 1s - loss: 1.7368 - accuracy: 0.3985 - val_loss: 1.7395 - val_accuracy: 0.4086 - 859ms/epoch - 13ms/step
# Epoch 662/4000
# 67/67 - 1s - loss: 1.7366 - accuracy: 0.3989 - val_loss: 1.7383 - val_accuracy: 0.4082 - 859ms/epoch - 13ms/step
# Epoch 663/4000
# 67/67 - 1s - loss: 1.7365 - accuracy: 0.3990 - val_loss: 1.7393 - val_accuracy: 0.4066 - 858ms/epoch - 13ms/step
# Epoch 664/4000
# 67/67 - 1s - loss: 1.7363 - accuracy: 0.3988 - val_loss: 1.7388 - val_accuracy: 0.4100 - 862ms/epoch - 13ms/step
# Epoch 665/4000
# 67/67 - 1s - loss: 1.7370 - accuracy: 0.3987 - val_loss: 1.7388 - val_accuracy: 0.4098 - 859ms/epoch - 13ms/step
# Epoch 666/4000
# 67/67 - 1s - loss: 1.7364 - accuracy: 0.3991 - val_loss: 1.7393 - val_accuracy: 0.4078 - 858ms/epoch - 13ms/step
# Epoch 667/4000
# 67/67 - 1s - loss: 1.7362 - accuracy: 0.3988 - val_loss: 1.7388 - val_accuracy: 0.4086 - 858ms/epoch - 13ms/step
# Epoch 668/4000
# 67/67 - 1s - loss: 1.7364 - accuracy: 0.3990 - val_loss: 1.7386 - val_accuracy: 0.4094 - 859ms/epoch - 13ms/step
# Epoch 669/4000
# 67/67 - 1s - loss: 1.7365 - accuracy: 0.3985 - val_loss: 1.7382 - val_accuracy: 0.4086 - 858ms/epoch - 13ms/step
# Epoch 670/4000
# 67/67 - 1s - loss: 1.7359 - accuracy: 0.3993 - val_loss: 1.7382 - val_accuracy: 0.4096 - 862ms/epoch - 13ms/step
# Epoch 671/4000
# 67/67 - 1s - loss: 1.7359 - accuracy: 0.3995 - val_loss: 1.7392 - val_accuracy: 0.4114 - 864ms/epoch - 13ms/step
# Epoch 672/4000
# 67/67 - 1s - loss: 1.7362 - accuracy: 0.3987 - val_loss: 1.7382 - val_accuracy: 0.4082 - 868ms/epoch - 13ms/step
# 814/814 - 1s - loss: 1.7969 - accuracy: 0.3820 - 1s/epoch - 2ms/step
# Test loss: 1.797
# Test accuracy: 38.203%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 20)        520
#
#  average_pooling2d (AverageP  (None, 14, 14, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 50)        25050
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 10)          12510
#
#  batch_normalization (BatchN  (None, 1, 1, 10)         40
#  ormalization)
#
#  square_activation (SquareAc  (None, 1, 1, 10)         0
#  tivation)
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 38,120
# Trainable params: 38,100
# Non-trainable params: 20
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=20,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 67/67 - 2s - loss: 1.2904 - accuracy: 0.6474 - val_loss: 1.2918 - val_accuracy: 0.6578 - 2s/epoch - 24ms/step
# Epoch 2/4000
# 67/67 - 1s - loss: 1.2523 - accuracy: 0.6550 - val_loss: 1.2789 - val_accuracy: 0.6598 - 857ms/epoch - 13ms/step
# Epoch 3/4000
# 67/67 - 1s - loss: 1.2400 - accuracy: 0.6598 - val_loss: 1.2652 - val_accuracy: 0.6566 - 859ms/epoch - 13ms/step
# Epoch 4/4000
# 67/67 - 1s - loss: 1.2334 - accuracy: 0.6593 - val_loss: 1.2564 - val_accuracy: 0.6582 - 860ms/epoch - 13ms/step
# Epoch 5/4000
# 67/67 - 1s - loss: 1.2294 - accuracy: 0.6622 - val_loss: 1.2462 - val_accuracy: 0.6634 - 863ms/epoch - 13ms/step
# Epoch 6/4000
# 67/67 - 1s - loss: 1.2247 - accuracy: 0.6627 - val_loss: 1.2487 - val_accuracy: 0.6596 - 853ms/epoch - 13ms/step
# Epoch 7/4000
# 67/67 - 1s - loss: 1.2217 - accuracy: 0.6647 - val_loss: 1.2483 - val_accuracy: 0.6554 - 860ms/epoch - 13ms/step
# Epoch 8/4000
# 67/67 - 1s - loss: 1.2178 - accuracy: 0.6659 - val_loss: 1.2503 - val_accuracy: 0.6520 - 858ms/epoch - 13ms/step
# Epoch 9/4000
# 67/67 - 1s - loss: 1.2174 - accuracy: 0.6662 - val_loss: 1.2377 - val_accuracy: 0.6620 - 862ms/epoch - 13ms/step
# Epoch 10/4000
# 67/67 - 1s - loss: 1.2130 - accuracy: 0.6678 - val_loss: 1.2441 - val_accuracy: 0.6582 - 858ms/epoch - 13ms/step
# Epoch 11/4000
# 67/67 - 1s - loss: 1.2130 - accuracy: 0.6677 - val_loss: 1.2300 - val_accuracy: 0.6688 - 860ms/epoch - 13ms/step
# Epoch 12/4000
# 67/67 - 1s - loss: 1.2099 - accuracy: 0.6685 - val_loss: 1.2323 - val_accuracy: 0.6664 - 858ms/epoch - 13ms/step
# Epoch 13/4000
# 67/67 - 1s - loss: 1.2095 - accuracy: 0.6679 - val_loss: 1.2357 - val_accuracy: 0.6616 - 858ms/epoch - 13ms/step
# Epoch 14/4000
# 67/67 - 1s - loss: 1.2065 - accuracy: 0.6698 - val_loss: 1.2290 - val_accuracy: 0.6718 - 862ms/epoch - 13ms/step
# Epoch 15/4000
# 67/67 - 1s - loss: 1.2035 - accuracy: 0.6705 - val_loss: 1.2227 - val_accuracy: 0.6716 - 861ms/epoch - 13ms/step
# Epoch 16/4000
# 67/67 - 1s - loss: 1.2028 - accuracy: 0.6702 - val_loss: 1.2276 - val_accuracy: 0.6658 - 858ms/epoch - 13ms/step
# Epoch 17/4000
# 67/67 - 1s - loss: 1.2020 - accuracy: 0.6717 - val_loss: 1.2231 - val_accuracy: 0.6716 - 859ms/epoch - 13ms/step
# Epoch 18/4000
# 67/67 - 1s - loss: 1.1998 - accuracy: 0.6722 - val_loss: 1.2207 - val_accuracy: 0.6742 - 863ms/epoch - 13ms/step
# Epoch 19/4000
# 67/67 - 1s - loss: 1.1975 - accuracy: 0.6728 - val_loss: 1.2138 - val_accuracy: 0.6780 - 862ms/epoch - 13ms/step
# Epoch 20/4000
# 67/67 - 1s - loss: 1.1968 - accuracy: 0.6739 - val_loss: 1.2182 - val_accuracy: 0.6742 - 861ms/epoch - 13ms/step
# Epoch 21/4000
# 67/67 - 1s - loss: 1.1959 - accuracy: 0.6748 - val_loss: 1.2154 - val_accuracy: 0.6754 - 860ms/epoch - 13ms/step
# Epoch 22/4000
# 67/67 - 1s - loss: 1.1930 - accuracy: 0.6753 - val_loss: 1.2149 - val_accuracy: 0.6738 - 862ms/epoch - 13ms/step
# Epoch 23/4000
# 67/67 - 1s - loss: 1.1915 - accuracy: 0.6770 - val_loss: 1.2132 - val_accuracy: 0.6738 - 863ms/epoch - 13ms/step
# Epoch 24/4000
# 67/67 - 1s - loss: 1.1906 - accuracy: 0.6772 - val_loss: 1.2097 - val_accuracy: 0.6746 - 862ms/epoch - 13ms/step
# Epoch 25/4000
# 67/67 - 1s - loss: 1.1893 - accuracy: 0.6764 - val_loss: 1.2129 - val_accuracy: 0.6746 - 861ms/epoch - 13ms/step
# Epoch 26/4000
# 67/67 - 1s - loss: 1.1882 - accuracy: 0.6774 - val_loss: 1.2127 - val_accuracy: 0.6732 - 860ms/epoch - 13ms/step
# Epoch 27/4000
# 67/67 - 1s - loss: 1.1866 - accuracy: 0.6780 - val_loss: 1.2150 - val_accuracy: 0.6730 - 859ms/epoch - 13ms/step
# Epoch 28/4000
# 67/67 - 1s - loss: 1.1867 - accuracy: 0.6783 - val_loss: 1.2078 - val_accuracy: 0.6764 - 862ms/epoch - 13ms/step
# Epoch 29/4000
# 67/67 - 1s - loss: 1.1842 - accuracy: 0.6792 - val_loss: 1.2139 - val_accuracy: 0.6754 - 858ms/epoch - 13ms/step
# Epoch 30/4000
# 67/67 - 1s - loss: 1.1838 - accuracy: 0.6797 - val_loss: 1.2085 - val_accuracy: 0.6724 - 862ms/epoch - 13ms/step
# Epoch 31/4000
# 67/67 - 1s - loss: 1.1818 - accuracy: 0.6799 - val_loss: 1.2047 - val_accuracy: 0.6790 - 859ms/epoch - 13ms/step
# Epoch 32/4000
# 67/67 - 1s - loss: 1.1797 - accuracy: 0.6805 - val_loss: 1.2025 - val_accuracy: 0.6804 - 862ms/epoch - 13ms/step
# Epoch 33/4000
# 67/67 - 1s - loss: 1.1792 - accuracy: 0.6814 - val_loss: 1.2069 - val_accuracy: 0.6806 - 862ms/epoch - 13ms/step
# Epoch 34/4000
# 67/67 - 1s - loss: 1.1779 - accuracy: 0.6829 - val_loss: 1.2027 - val_accuracy: 0.6788 - 861ms/epoch - 13ms/step
# Epoch 35/4000
# 67/67 - 1s - loss: 1.1769 - accuracy: 0.6819 - val_loss: 1.2033 - val_accuracy: 0.6794 - 858ms/epoch - 13ms/step
# Epoch 36/4000
# 67/67 - 1s - loss: 1.1754 - accuracy: 0.6828 - val_loss: 1.2045 - val_accuracy: 0.6782 - 858ms/epoch - 13ms/step
# Epoch 37/4000
# 67/67 - 1s - loss: 1.1755 - accuracy: 0.6836 - val_loss: 1.2063 - val_accuracy: 0.6790 - 861ms/epoch - 13ms/step
# Epoch 38/4000
# 67/67 - 1s - loss: 1.1758 - accuracy: 0.6829 - val_loss: 1.2018 - val_accuracy: 0.6842 - 862ms/epoch - 13ms/step
# Epoch 39/4000
# 67/67 - 1s - loss: 1.1724 - accuracy: 0.6840 - val_loss: 1.1982 - val_accuracy: 0.6818 - 867ms/epoch - 13ms/step
# Epoch 40/4000
# 67/67 - 1s - loss: 1.1722 - accuracy: 0.6842 - val_loss: 1.2003 - val_accuracy: 0.6812 - 858ms/epoch - 13ms/step
# Epoch 41/4000
# 67/67 - 1s - loss: 1.1717 - accuracy: 0.6838 - val_loss: 1.1974 - val_accuracy: 0.6830 - 865ms/epoch - 13ms/step
# Epoch 42/4000
# 67/67 - 1s - loss: 1.1706 - accuracy: 0.6854 - val_loss: 1.1977 - val_accuracy: 0.6828 - 859ms/epoch - 13ms/step
# Epoch 43/4000
# 67/67 - 1s - loss: 1.1695 - accuracy: 0.6851 - val_loss: 1.1982 - val_accuracy: 0.6858 - 858ms/epoch - 13ms/step
# Epoch 44/4000
# 67/67 - 1s - loss: 1.1693 - accuracy: 0.6857 - val_loss: 1.1963 - val_accuracy: 0.6830 - 868ms/epoch - 13ms/step
# Epoch 45/4000
# 67/67 - 1s - loss: 1.1690 - accuracy: 0.6861 - val_loss: 1.1981 - val_accuracy: 0.6820 - 861ms/epoch - 13ms/step
# Epoch 46/4000
# 67/67 - 1s - loss: 1.1670 - accuracy: 0.6872 - val_loss: 1.1991 - val_accuracy: 0.6804 - 859ms/epoch - 13ms/step
# Epoch 47/4000
# 67/67 - 1s - loss: 1.1671 - accuracy: 0.6877 - val_loss: 1.1995 - val_accuracy: 0.6858 - 862ms/epoch - 13ms/step
# Epoch 48/4000
# 67/67 - 1s - loss: 1.1652 - accuracy: 0.6872 - val_loss: 1.1958 - val_accuracy: 0.6832 - 865ms/epoch - 13ms/step
# Epoch 49/4000
# 67/67 - 1s - loss: 1.1653 - accuracy: 0.6871 - val_loss: 1.1972 - val_accuracy: 0.6834 - 864ms/epoch - 13ms/step
# Epoch 50/4000
# 67/67 - 1s - loss: 1.1648 - accuracy: 0.6884 - val_loss: 1.1925 - val_accuracy: 0.6894 - 866ms/epoch - 13ms/step
# Epoch 51/4000
# 67/67 - 1s - loss: 1.1648 - accuracy: 0.6888 - val_loss: 1.1923 - val_accuracy: 0.6866 - 861ms/epoch - 13ms/step
# Epoch 52/4000
# 67/67 - 1s - loss: 1.1614 - accuracy: 0.6894 - val_loss: 1.1899 - val_accuracy: 0.6884 - 863ms/epoch - 13ms/step
# Epoch 53/4000
# 67/67 - 1s - loss: 1.1627 - accuracy: 0.6886 - val_loss: 1.1935 - val_accuracy: 0.6894 - 861ms/epoch - 13ms/step
# Epoch 54/4000
# 67/67 - 1s - loss: 1.1639 - accuracy: 0.6895 - val_loss: 1.1924 - val_accuracy: 0.6874 - 862ms/epoch - 13ms/step
# Epoch 55/4000
# 67/67 - 1s - loss: 1.1613 - accuracy: 0.6885 - val_loss: 1.1953 - val_accuracy: 0.6850 - 863ms/epoch - 13ms/step
# Epoch 56/4000
# 67/67 - 1s - loss: 1.1591 - accuracy: 0.6902 - val_loss: 1.1902 - val_accuracy: 0.6890 - 861ms/epoch - 13ms/step
# Epoch 57/4000
# 67/67 - 1s - loss: 1.1609 - accuracy: 0.6903 - val_loss: 1.1874 - val_accuracy: 0.6918 - 866ms/epoch - 13ms/step
# Epoch 58/4000
# 67/67 - 1s - loss: 1.1594 - accuracy: 0.6903 - val_loss: 1.1870 - val_accuracy: 0.6880 - 864ms/epoch - 13ms/step
# Epoch 59/4000
# 67/67 - 1s - loss: 1.1593 - accuracy: 0.6901 - val_loss: 1.1848 - val_accuracy: 0.6910 - 865ms/epoch - 13ms/step
# Epoch 60/4000
# 67/67 - 1s - loss: 1.1585 - accuracy: 0.6915 - val_loss: 1.1912 - val_accuracy: 0.6868 - 867ms/epoch - 13ms/step
# Epoch 61/4000
# 67/67 - 1s - loss: 1.1578 - accuracy: 0.6915 - val_loss: 1.1859 - val_accuracy: 0.6912 - 861ms/epoch - 13ms/step
# Epoch 62/4000
# 67/67 - 1s - loss: 1.1572 - accuracy: 0.6917 - val_loss: 1.1876 - val_accuracy: 0.6898 - 869ms/epoch - 13ms/step
# Epoch 63/4000
# 67/67 - 1s - loss: 1.1569 - accuracy: 0.6930 - val_loss: 1.1854 - val_accuracy: 0.6910 - 865ms/epoch - 13ms/step
# Epoch 64/4000
# 67/67 - 1s - loss: 1.1564 - accuracy: 0.6922 - val_loss: 1.1880 - val_accuracy: 0.6902 - 864ms/epoch - 13ms/step
# Epoch 65/4000
# 67/67 - 1s - loss: 1.1564 - accuracy: 0.6927 - val_loss: 1.1840 - val_accuracy: 0.6930 - 866ms/epoch - 13ms/step
# Epoch 66/4000
# 67/67 - 1s - loss: 1.1565 - accuracy: 0.6934 - val_loss: 1.1874 - val_accuracy: 0.6900 - 864ms/epoch - 13ms/step
# Epoch 67/4000
# 67/67 - 1s - loss: 1.1556 - accuracy: 0.6937 - val_loss: 1.1869 - val_accuracy: 0.6894 - 866ms/epoch - 13ms/step
# Epoch 68/4000
# 67/67 - 1s - loss: 1.1546 - accuracy: 0.6931 - val_loss: 1.1917 - val_accuracy: 0.6850 - 862ms/epoch - 13ms/step
# Epoch 69/4000
# 67/67 - 1s - loss: 1.1534 - accuracy: 0.6931 - val_loss: 1.1869 - val_accuracy: 0.6914 - 864ms/epoch - 13ms/step
# Epoch 70/4000
# 67/67 - 1s - loss: 1.1536 - accuracy: 0.6937 - val_loss: 1.1860 - val_accuracy: 0.6910 - 862ms/epoch - 13ms/step
# Epoch 71/4000
# 67/67 - 1s - loss: 1.1521 - accuracy: 0.6951 - val_loss: 1.1857 - val_accuracy: 0.6920 - 867ms/epoch - 13ms/step
# Epoch 72/4000
# 67/67 - 1s - loss: 1.1517 - accuracy: 0.6942 - val_loss: 1.1869 - val_accuracy: 0.6892 - 864ms/epoch - 13ms/step
# Epoch 73/4000
# 67/67 - 1s - loss: 1.1515 - accuracy: 0.6948 - val_loss: 1.1903 - val_accuracy: 0.6858 - 863ms/epoch - 13ms/step
# Epoch 74/4000
# 67/67 - 1s - loss: 1.1508 - accuracy: 0.6954 - val_loss: 1.1800 - val_accuracy: 0.6916 - 867ms/epoch - 13ms/step
# Epoch 75/4000
# 67/67 - 1s - loss: 1.1515 - accuracy: 0.6947 - val_loss: 1.1775 - val_accuracy: 0.6936 - 861ms/epoch - 13ms/step
# Epoch 76/4000
# 67/67 - 1s - loss: 1.1489 - accuracy: 0.6963 - val_loss: 1.1825 - val_accuracy: 0.6914 - 867ms/epoch - 13ms/step
# Epoch 77/4000
# 67/67 - 1s - loss: 1.1491 - accuracy: 0.6963 - val_loss: 1.1804 - val_accuracy: 0.6954 - 865ms/epoch - 13ms/step
# Epoch 78/4000
# 67/67 - 1s - loss: 1.1489 - accuracy: 0.6960 - val_loss: 1.1840 - val_accuracy: 0.6948 - 866ms/epoch - 13ms/step
# Epoch 79/4000
# 67/67 - 1s - loss: 1.1492 - accuracy: 0.6964 - val_loss: 1.1795 - val_accuracy: 0.6942 - 860ms/epoch - 13ms/step
# Epoch 80/4000
# 67/67 - 1s - loss: 1.1492 - accuracy: 0.6963 - val_loss: 1.1815 - val_accuracy: 0.6944 - 860ms/epoch - 13ms/step
# Epoch 81/4000
# 67/67 - 1s - loss: 1.1486 - accuracy: 0.6975 - val_loss: 1.1778 - val_accuracy: 0.6932 - 860ms/epoch - 13ms/step
# Epoch 82/4000
# 67/67 - 1s - loss: 1.1480 - accuracy: 0.6965 - val_loss: 1.1817 - val_accuracy: 0.6912 - 869ms/epoch - 13ms/step
# Epoch 83/4000
# 67/67 - 1s - loss: 1.1472 - accuracy: 0.6966 - val_loss: 1.1824 - val_accuracy: 0.6944 - 860ms/epoch - 13ms/step
# Epoch 84/4000
# 67/67 - 1s - loss: 1.1466 - accuracy: 0.6964 - val_loss: 1.1805 - val_accuracy: 0.6976 - 865ms/epoch - 13ms/step
# Epoch 85/4000
# 67/67 - 1s - loss: 1.1463 - accuracy: 0.6982 - val_loss: 1.1791 - val_accuracy: 0.6936 - 865ms/epoch - 13ms/step
# Epoch 86/4000
# 67/67 - 1s - loss: 1.1457 - accuracy: 0.6976 - val_loss: 1.1764 - val_accuracy: 0.6940 - 865ms/epoch - 13ms/step
# Epoch 87/4000
# 67/67 - 1s - loss: 1.1451 - accuracy: 0.6983 - val_loss: 1.1803 - val_accuracy: 0.6916 - 863ms/epoch - 13ms/step
# Epoch 88/4000
# 67/67 - 1s - loss: 1.1446 - accuracy: 0.6982 - val_loss: 1.1775 - val_accuracy: 0.6962 - 863ms/epoch - 13ms/step
# Epoch 89/4000
# 67/67 - 1s - loss: 1.1447 - accuracy: 0.6982 - val_loss: 1.1772 - val_accuracy: 0.6970 - 867ms/epoch - 13ms/step
# Epoch 90/4000
# 67/67 - 1s - loss: 1.1443 - accuracy: 0.6988 - val_loss: 1.1823 - val_accuracy: 0.6880 - 863ms/epoch - 13ms/step
# Epoch 91/4000
# 67/67 - 1s - loss: 1.1443 - accuracy: 0.6984 - val_loss: 1.1818 - val_accuracy: 0.6946 - 861ms/epoch - 13ms/step
# Epoch 92/4000
# 67/67 - 1s - loss: 1.1446 - accuracy: 0.6984 - val_loss: 1.1762 - val_accuracy: 0.6976 - 868ms/epoch - 13ms/step
# Epoch 93/4000
# 67/67 - 1s - loss: 1.1427 - accuracy: 0.6992 - val_loss: 1.1756 - val_accuracy: 0.6962 - 901ms/epoch - 13ms/step
# Epoch 94/4000
# 67/67 - 1s - loss: 1.1432 - accuracy: 0.6995 - val_loss: 1.1752 - val_accuracy: 0.6980 - 871ms/epoch - 13ms/step
# Epoch 95/4000
# 67/67 - 1s - loss: 1.1426 - accuracy: 0.6993 - val_loss: 1.1751 - val_accuracy: 0.6934 - 870ms/epoch - 13ms/step
# Epoch 96/4000
# 67/67 - 1s - loss: 1.1434 - accuracy: 0.6986 - val_loss: 1.1735 - val_accuracy: 0.6984 - 870ms/epoch - 13ms/step
# Epoch 97/4000
# 67/67 - 1s - loss: 1.1424 - accuracy: 0.6996 - val_loss: 1.1785 - val_accuracy: 0.6960 - 867ms/epoch - 13ms/step
# Epoch 98/4000
# 67/67 - 1s - loss: 1.1418 - accuracy: 0.6990 - val_loss: 1.1761 - val_accuracy: 0.6940 - 866ms/epoch - 13ms/step
# Epoch 99/4000
# 67/67 - 1s - loss: 1.1417 - accuracy: 0.6991 - val_loss: 1.1769 - val_accuracy: 0.6956 - 864ms/epoch - 13ms/step
# Epoch 100/4000
# 67/67 - 1s - loss: 1.1421 - accuracy: 0.6988 - val_loss: 1.1734 - val_accuracy: 0.6982 - 869ms/epoch - 13ms/step
# Epoch 101/4000
# 67/67 - 1s - loss: 1.1411 - accuracy: 0.6997 - val_loss: 1.1726 - val_accuracy: 0.6992 - 867ms/epoch - 13ms/step
# Epoch 102/4000
# 67/67 - 1s - loss: 1.1401 - accuracy: 0.6996 - val_loss: 1.1759 - val_accuracy: 0.6960 - 869ms/epoch - 13ms/step
# Epoch 103/4000
# 67/67 - 1s - loss: 1.1403 - accuracy: 0.7007 - val_loss: 1.1738 - val_accuracy: 0.6980 - 862ms/epoch - 13ms/step
# Epoch 104/4000
# 67/67 - 1s - loss: 1.1410 - accuracy: 0.7004 - val_loss: 1.1720 - val_accuracy: 0.6996 - 870ms/epoch - 13ms/step
# Epoch 105/4000
# 67/67 - 1s - loss: 1.1397 - accuracy: 0.7007 - val_loss: 1.1728 - val_accuracy: 0.6996 - 864ms/epoch - 13ms/step
# Epoch 106/4000
# 67/67 - 1s - loss: 1.1401 - accuracy: 0.7001 - val_loss: 1.1763 - val_accuracy: 0.6970 - 865ms/epoch - 13ms/step
# Epoch 107/4000
# 67/67 - 1s - loss: 1.1395 - accuracy: 0.7020 - val_loss: 1.1713 - val_accuracy: 0.6988 - 869ms/epoch - 13ms/step
# Epoch 108/4000
# 67/67 - 1s - loss: 1.1374 - accuracy: 0.7016 - val_loss: 1.1718 - val_accuracy: 0.6988 - 864ms/epoch - 13ms/step
# Epoch 109/4000
# 67/67 - 1s - loss: 1.1394 - accuracy: 0.7007 - val_loss: 1.1692 - val_accuracy: 0.6986 - 868ms/epoch - 13ms/step
# Epoch 110/4000
# 67/67 - 1s - loss: 1.1381 - accuracy: 0.7017 - val_loss: 1.1727 - val_accuracy: 0.7002 - 865ms/epoch - 13ms/step
# Epoch 111/4000
# 67/67 - 1s - loss: 1.1385 - accuracy: 0.7011 - val_loss: 1.1715 - val_accuracy: 0.6992 - 868ms/epoch - 13ms/step
# Epoch 112/4000
# 67/67 - 1s - loss: 1.1372 - accuracy: 0.7018 - val_loss: 1.1715 - val_accuracy: 0.6990 - 865ms/epoch - 13ms/step
# Epoch 113/4000
# 67/67 - 1s - loss: 1.1366 - accuracy: 0.7021 - val_loss: 1.1724 - val_accuracy: 0.7008 - 866ms/epoch - 13ms/step
# Epoch 114/4000
# 67/67 - 1s - loss: 1.1368 - accuracy: 0.7024 - val_loss: 1.1718 - val_accuracy: 0.7016 - 868ms/epoch - 13ms/step
# Epoch 115/4000
# 67/67 - 1s - loss: 1.1372 - accuracy: 0.7014 - val_loss: 1.1719 - val_accuracy: 0.6996 - 866ms/epoch - 13ms/step
# Epoch 116/4000
# 67/67 - 1s - loss: 1.1373 - accuracy: 0.7011 - val_loss: 1.1718 - val_accuracy: 0.6982 - 867ms/epoch - 13ms/step
# Epoch 117/4000
# 67/67 - 1s - loss: 1.1367 - accuracy: 0.7022 - val_loss: 1.1728 - val_accuracy: 0.7000 - 864ms/epoch - 13ms/step
# Epoch 118/4000
# 67/67 - 1s - loss: 1.1361 - accuracy: 0.7020 - val_loss: 1.1699 - val_accuracy: 0.7006 - 868ms/epoch - 13ms/step
# Epoch 119/4000
# 67/67 - 1s - loss: 1.1361 - accuracy: 0.7019 - val_loss: 1.1721 - val_accuracy: 0.6986 - 865ms/epoch - 13ms/step
# Epoch 120/4000
# 67/67 - 1s - loss: 1.1347 - accuracy: 0.7024 - val_loss: 1.1714 - val_accuracy: 0.7002 - 866ms/epoch - 13ms/step
# Epoch 121/4000
# 67/67 - 1s - loss: 1.1357 - accuracy: 0.7027 - val_loss: 1.1683 - val_accuracy: 0.7014 - 864ms/epoch - 13ms/step
# Epoch 122/4000
# 67/67 - 1s - loss: 1.1356 - accuracy: 0.7024 - val_loss: 1.1708 - val_accuracy: 0.7014 - 862ms/epoch - 13ms/step
# Epoch 123/4000
# 67/67 - 1s - loss: 1.1339 - accuracy: 0.7033 - val_loss: 1.1689 - val_accuracy: 0.7024 - 863ms/epoch - 13ms/step
# Epoch 124/4000
# 67/67 - 1s - loss: 1.1351 - accuracy: 0.7018 - val_loss: 1.1675 - val_accuracy: 0.7010 - 866ms/epoch - 13ms/step
# Epoch 125/4000
# 67/67 - 1s - loss: 1.1341 - accuracy: 0.7019 - val_loss: 1.1688 - val_accuracy: 0.7002 - 864ms/epoch - 13ms/step
# Epoch 126/4000
# 67/67 - 1s - loss: 1.1349 - accuracy: 0.7015 - val_loss: 1.1695 - val_accuracy: 0.7002 - 869ms/epoch - 13ms/step
# Epoch 127/4000
# 67/67 - 1s - loss: 1.1335 - accuracy: 0.7025 - val_loss: 1.1686 - val_accuracy: 0.6998 - 867ms/epoch - 13ms/step
# Epoch 128/4000
# 67/67 - 1s - loss: 1.1340 - accuracy: 0.7029 - val_loss: 1.1721 - val_accuracy: 0.6990 - 866ms/epoch - 13ms/step
# Epoch 129/4000
# 67/67 - 1s - loss: 1.1332 - accuracy: 0.7031 - val_loss: 1.1686 - val_accuracy: 0.6988 - 869ms/epoch - 13ms/step
# Epoch 130/4000
# 67/67 - 1s - loss: 1.1326 - accuracy: 0.7039 - val_loss: 1.1710 - val_accuracy: 0.6984 - 897ms/epoch - 13ms/step
# Epoch 131/4000
# 67/67 - 1s - loss: 1.1338 - accuracy: 0.7028 - val_loss: 1.1710 - val_accuracy: 0.6962 - 868ms/epoch - 13ms/step
# Epoch 132/4000
# 67/67 - 1s - loss: 1.1331 - accuracy: 0.7039 - val_loss: 1.1685 - val_accuracy: 0.7042 - 866ms/epoch - 13ms/step
# Epoch 133/4000
# 67/67 - 1s - loss: 1.1331 - accuracy: 0.7030 - val_loss: 1.1701 - val_accuracy: 0.6996 - 863ms/epoch - 13ms/step
# Epoch 134/4000
# 67/67 - 1s - loss: 1.1332 - accuracy: 0.7025 - val_loss: 1.1698 - val_accuracy: 0.6984 - 866ms/epoch - 13ms/step
# Epoch 135/4000
# 67/67 - 1s - loss: 1.1329 - accuracy: 0.7026 - val_loss: 1.1672 - val_accuracy: 0.7026 - 865ms/epoch - 13ms/step
# Epoch 136/4000
# 67/67 - 1s - loss: 1.1325 - accuracy: 0.7028 - val_loss: 1.1704 - val_accuracy: 0.7002 - 865ms/epoch - 13ms/step
# Epoch 137/4000
# 67/67 - 1s - loss: 1.1319 - accuracy: 0.7051 - val_loss: 1.1725 - val_accuracy: 0.6968 - 864ms/epoch - 13ms/step
# Epoch 138/4000
# 67/67 - 1s - loss: 1.1327 - accuracy: 0.7038 - val_loss: 1.1665 - val_accuracy: 0.7032 - 867ms/epoch - 13ms/step
# Epoch 139/4000
# 67/67 - 1s - loss: 1.1324 - accuracy: 0.7045 - val_loss: 1.1663 - val_accuracy: 0.7038 - 869ms/epoch - 13ms/step
# Epoch 140/4000
# 67/67 - 1s - loss: 1.1306 - accuracy: 0.7041 - val_loss: 1.1669 - val_accuracy: 0.7012 - 861ms/epoch - 13ms/step
# Epoch 141/4000
# 67/67 - 1s - loss: 1.1314 - accuracy: 0.7043 - val_loss: 1.1669 - val_accuracy: 0.7038 - 864ms/epoch - 13ms/step
# Epoch 142/4000
# 67/67 - 1s - loss: 1.1299 - accuracy: 0.7048 - val_loss: 1.1659 - val_accuracy: 0.7014 - 867ms/epoch - 13ms/step
# Epoch 143/4000
# 67/67 - 1s - loss: 1.1315 - accuracy: 0.7041 - val_loss: 1.1640 - val_accuracy: 0.7018 - 863ms/epoch - 13ms/step
# Epoch 144/4000
# 67/67 - 1s - loss: 1.1313 - accuracy: 0.7031 - val_loss: 1.1656 - val_accuracy: 0.7010 - 861ms/epoch - 13ms/step
# Epoch 145/4000
# 67/67 - 1s - loss: 1.1305 - accuracy: 0.7037 - val_loss: 1.1686 - val_accuracy: 0.7002 - 866ms/epoch - 13ms/step
# Epoch 146/4000
# 67/67 - 1s - loss: 1.1308 - accuracy: 0.7045 - val_loss: 1.1679 - val_accuracy: 0.6982 - 864ms/epoch - 13ms/step
# Epoch 147/4000
# 67/67 - 1s - loss: 1.1296 - accuracy: 0.7047 - val_loss: 1.1680 - val_accuracy: 0.6996 - 865ms/epoch - 13ms/step
# Epoch 148/4000
# 67/67 - 1s - loss: 1.1303 - accuracy: 0.7049 - val_loss: 1.1669 - val_accuracy: 0.7002 - 862ms/epoch - 13ms/step
# Epoch 149/4000
# 67/67 - 1s - loss: 1.1297 - accuracy: 0.7045 - val_loss: 1.1671 - val_accuracy: 0.6990 - 865ms/epoch - 13ms/step
# Epoch 150/4000
# 67/67 - 1s - loss: 1.1293 - accuracy: 0.7046 - val_loss: 1.1668 - val_accuracy: 0.7022 - 862ms/epoch - 13ms/step
# Epoch 151/4000
# 67/67 - 1s - loss: 1.1299 - accuracy: 0.7050 - val_loss: 1.1663 - val_accuracy: 0.7004 - 862ms/epoch - 13ms/step
# Epoch 152/4000
# 67/67 - 1s - loss: 1.1300 - accuracy: 0.7041 - val_loss: 1.1716 - val_accuracy: 0.6978 - 860ms/epoch - 13ms/step
# Epoch 153/4000
# 67/67 - 1s - loss: 1.1294 - accuracy: 0.7050 - val_loss: 1.1667 - val_accuracy: 0.6994 - 863ms/epoch - 13ms/step
# Epoch 154/4000
# 67/67 - 1s - loss: 1.1302 - accuracy: 0.7047 - val_loss: 1.1695 - val_accuracy: 0.6992 - 867ms/epoch - 13ms/step
# Epoch 155/4000
# 67/67 - 1s - loss: 1.1293 - accuracy: 0.7055 - val_loss: 1.1683 - val_accuracy: 0.7024 - 863ms/epoch - 13ms/step
# Epoch 156/4000
# 67/67 - 1s - loss: 1.1289 - accuracy: 0.7046 - val_loss: 1.1655 - val_accuracy: 0.7014 - 865ms/epoch - 13ms/step
# Epoch 157/4000
# 67/67 - 1s - loss: 1.1290 - accuracy: 0.7045 - val_loss: 1.1641 - val_accuracy: 0.7016 - 864ms/epoch - 13ms/step
# Epoch 158/4000
# 67/67 - 1s - loss: 1.1289 - accuracy: 0.7048 - val_loss: 1.1661 - val_accuracy: 0.7018 - 863ms/epoch - 13ms/step
# Epoch 159/4000
# 67/67 - 1s - loss: 1.1291 - accuracy: 0.7048 - val_loss: 1.1641 - val_accuracy: 0.7024 - 868ms/epoch - 13ms/step
# Epoch 160/4000
# 67/67 - 1s - loss: 1.1286 - accuracy: 0.7051 - val_loss: 1.1653 - val_accuracy: 0.7002 - 862ms/epoch - 13ms/step
# Epoch 161/4000
# 67/67 - 1s - loss: 1.1288 - accuracy: 0.7052 - val_loss: 1.1660 - val_accuracy: 0.7026 - 864ms/epoch - 13ms/step
# Epoch 162/4000
# 67/67 - 1s - loss: 1.1284 - accuracy: 0.7056 - val_loss: 1.1654 - val_accuracy: 0.7000 - 861ms/epoch - 13ms/step
# Epoch 163/4000
# 67/67 - 1s - loss: 1.1288 - accuracy: 0.7043 - val_loss: 1.1642 - val_accuracy: 0.6976 - 869ms/epoch - 13ms/step
# 814/814 - 1s - loss: 1.3417 - accuracy: 0.6578 - 1s/epoch - 2ms/step
# Test loss: 1.342
# Test accuracy: 65.777%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model520.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model520.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
