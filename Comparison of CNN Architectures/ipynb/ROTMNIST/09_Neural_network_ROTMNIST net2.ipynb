# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-05-30 13:42:04.173245: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
import gzip
import numpy as np
import struct

def load_images(path):
    with gzip.open(path, 'rb') as f:
        # 解析文件头（魔数、图像数、行数、列数）
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        # 读取图像数据并转换为numpy数组
        images = np.frombuffer(f.read(), dtype=np.uint8)
        images = images.reshape(num, rows, cols)  # 维度调整为 [N, 28, 28]
    return images

def load_labels(path):
    with gzip.open(path, 'rb') as f:
        # 解析文件头（魔数、标签数）
        magic, num = struct.unpack('>II', f.read(8))
        # 读取标签数据
        labels = np.frombuffer(f.read(), dtype=np.uint8)
    return labels
x_train = load_images("/workspace/examples/vision_transformer/data/ROTNIST/train-images-idx3-ubyte.gz")
y_train = load_labels("/workspace/examples/vision_transformer/data/ROTNIST/train-labels-idx1-ubyte.gz")
x_test = load_images("/workspace/examples/vision_transformer/data/ROTNIST/t10k-images-idx3-ubyte.gz")
y_test = load_labels("/workspace/examples/vision_transformer/data/ROTNIST/t10k-labels-idx1-ubyte.gz")
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# 添加通道维度（从 [N,28,28] 转为 [N,28,28,1]）
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# %%
# Create validation data
# valsize=16
# valsize=500
valsize=5000
x_train = x_train[:-valsize]
x_val = x_train[-valsize:]
y_train = y_train[:-valsize]
y_val = y_train[-valsize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test17')
# save_data_set(x_train, y_train, data_type='train')
# save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test17 of shape (10000, 28, 28, 1) in data/net_mnist/x_test17.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D,AveragePooling2D,Softmax
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2

# 创建模型
model = Sequential()
# 第一层卷积层（无激活函数）
model.add(Conv2D(20, (3, 3), input_shape=(28, 28, 1),kernel_regularizer=l2(0.0005)))  # 移除activation参数


# AveP-BN操作
model.add(AvgPool2D(pool_size=2))
model.add(BatchNormalization())

# 第二层卷积层（无激活函数）
model.add(Conv2D(50, (3, 3),kernel_regularizer=l2(0.0005)))  # 移除activation参数
model.add(ReLU())  # 显式添加激活层

# BN操作
model.add(BatchNormalization())
model.add(Flatten())
# 全连接层，500个神经元
model.add(Dense(500))

# 输出层，10个神经元（假设是10分类任务）
model.add(Dense(10,kernel_regularizer=l2(0.0005)))


model.summary()
# Out:
# 2025-05-30 13:42:14.738531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:14.778012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:14.780950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:14.784505: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-30 13:42:14.785107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:14.787921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:14.790541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:15.559018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:15.560993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:15.562711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 13:42:15.564380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 20)        200
#
#  average_pooling2d (AverageP  (None, 13, 13, 20)       0
#  ooling2D)
#
#  batch_normalization (BatchN  (None, 13, 13, 20)       80
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 50)        9050
#
#  re_lu (ReLU)                (None, 11, 11, 50)        0
#
#  batch_normalization_1 (Batc  (None, 11, 11, 50)       200
#  hNormalization)
#
#  flatten (Flatten)           (None, 6050)              0
#
#  dense (Dense)               (None, 500)               3025500
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 3,040,040
# Trainable params: 3,039,900
# Non-trainable params: 140
# _________________________________________________________________

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-05-30 13:42:18.526263: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 54/54 - 4s - loss: 0.4852 - accuracy: 0.8665 - val_loss: 1.9620 - val_accuracy: 0.2098 - 4s/epoch - 73ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.1639 - accuracy: 0.9599 - val_loss: 2.0362 - val_accuracy: 0.1986 - 912ms/epoch - 17ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.1180 - accuracy: 0.9731 - val_loss: 2.1567 - val_accuracy: 0.1888 - 909ms/epoch - 17ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.0944 - accuracy: 0.9799 - val_loss: 2.4061 - val_accuracy: 0.1384 - 910ms/epoch - 17ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.0800 - accuracy: 0.9845 - val_loss: 2.2914 - val_accuracy: 0.1798 - 913ms/epoch - 17ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.0713 - accuracy: 0.9874 - val_loss: 1.8446 - val_accuracy: 0.2664 - 922ms/epoch - 17ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.0651 - accuracy: 0.9894 - val_loss: 1.3500 - val_accuracy: 0.4484 - 925ms/epoch - 17ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.0599 - accuracy: 0.9906 - val_loss: 0.6028 - val_accuracy: 0.7276 - 922ms/epoch - 17ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.0551 - accuracy: 0.9922 - val_loss: 0.2763 - val_accuracy: 0.9056 - 924ms/epoch - 17ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.0509 - accuracy: 0.9940 - val_loss: 0.1374 - val_accuracy: 0.9642 - 929ms/epoch - 17ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.0478 - accuracy: 0.9946 - val_loss: 0.0707 - val_accuracy: 0.9898 - 926ms/epoch - 17ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.0454 - accuracy: 0.9953 - val_loss: 0.0558 - val_accuracy: 0.9930 - 926ms/epoch - 17ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.0427 - accuracy: 0.9965 - val_loss: 0.0457 - val_accuracy: 0.9964 - 928ms/epoch - 17ms/step
# Epoch 14/4000
# 54/54 - 1s - loss: 0.0408 - accuracy: 0.9968 - val_loss: 0.0396 - val_accuracy: 0.9982 - 926ms/epoch - 17ms/step
# Epoch 15/4000
# 54/54 - 1s - loss: 0.0391 - accuracy: 0.9974 - val_loss: 0.0378 - val_accuracy: 0.9986 - 928ms/epoch - 17ms/step
# Epoch 16/4000
# 54/54 - 1s - loss: 0.0372 - accuracy: 0.9982 - val_loss: 0.0355 - val_accuracy: 0.9988 - 926ms/epoch - 17ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.0360 - accuracy: 0.9985 - val_loss: 0.0344 - val_accuracy: 0.9990 - 927ms/epoch - 17ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.0346 - accuracy: 0.9986 - val_loss: 0.0358 - val_accuracy: 0.9980 - 919ms/epoch - 17ms/step
# Epoch 19/4000
# 54/54 - 1s - loss: 0.0341 - accuracy: 0.9987 - val_loss: 0.0329 - val_accuracy: 0.9994 - 930ms/epoch - 17ms/step
# Epoch 20/4000
# 54/54 - 1s - loss: 0.0328 - accuracy: 0.9991 - val_loss: 0.0318 - val_accuracy: 0.9996 - 932ms/epoch - 17ms/step
# Epoch 21/4000
# 54/54 - 1s - loss: 0.0321 - accuracy: 0.9992 - val_loss: 0.0309 - val_accuracy: 0.9998 - 941ms/epoch - 17ms/step
# Epoch 22/4000
# 54/54 - 1s - loss: 0.0312 - accuracy: 0.9993 - val_loss: 0.0308 - val_accuracy: 0.9994 - 930ms/epoch - 17ms/step
# Epoch 23/4000
# 54/54 - 1s - loss: 0.0307 - accuracy: 0.9994 - val_loss: 0.0311 - val_accuracy: 0.9994 - 920ms/epoch - 17ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.0299 - accuracy: 0.9996 - val_loss: 0.0295 - val_accuracy: 1.0000 - 938ms/epoch - 17ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.0293 - accuracy: 0.9996 - val_loss: 0.0290 - val_accuracy: 1.0000 - 929ms/epoch - 17ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.0289 - accuracy: 0.9997 - val_loss: 0.0281 - val_accuracy: 1.0000 - 935ms/epoch - 17ms/step
# Epoch 27/4000
# 54/54 - 1s - loss: 0.0285 - accuracy: 0.9998 - val_loss: 0.0279 - val_accuracy: 1.0000 - 931ms/epoch - 17ms/step
# Epoch 28/4000
# 54/54 - 1s - loss: 0.0281 - accuracy: 0.9998 - val_loss: 0.0275 - val_accuracy: 0.9998 - 935ms/epoch - 17ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.0276 - accuracy: 0.9999 - val_loss: 0.0269 - val_accuracy: 1.0000 - 936ms/epoch - 17ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.0273 - accuracy: 0.9999 - val_loss: 0.0269 - val_accuracy: 0.9998 - 934ms/epoch - 17ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.0269 - accuracy: 0.9999 - val_loss: 0.0267 - val_accuracy: 1.0000 - 936ms/epoch - 17ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 1.0000 - 930ms/epoch - 17ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.0263 - accuracy: 0.9999 - val_loss: 0.0259 - val_accuracy: 1.0000 - 934ms/epoch - 17ms/step
# Epoch 34/4000
# 54/54 - 1s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9998 - 924ms/epoch - 17ms/step
# Epoch 35/4000
# 54/54 - 1s - loss: 0.0257 - accuracy: 0.9999 - val_loss: 0.0256 - val_accuracy: 0.9998 - 937ms/epoch - 17ms/step
# Epoch 36/4000
# 54/54 - 1s - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 1.0000 - 935ms/epoch - 17ms/step
# Epoch 37/4000
# 54/54 - 1s - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000 - 938ms/epoch - 17ms/step
# Epoch 38/4000
# 54/54 - 1s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 1.0000 - 936ms/epoch - 17ms/step
# Epoch 39/4000
# 54/54 - 1s - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 1.0000 - 939ms/epoch - 17ms/step
# Epoch 40/4000
# 54/54 - 1s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 1.0000 - 939ms/epoch - 17ms/step
# Epoch 41/4000
# 54/54 - 1s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000 - 941ms/epoch - 17ms/step
# Epoch 42/4000
# 54/54 - 1s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 1.0000 - 943ms/epoch - 17ms/step
# Epoch 43/4000
# 54/54 - 1s - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 1.0000 - 942ms/epoch - 17ms/step
# Epoch 44/4000
# 54/54 - 1s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 1.0000 - 940ms/epoch - 17ms/step
# Epoch 45/4000
# 54/54 - 1s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 1.0000 - 939ms/epoch - 17ms/step
# Epoch 46/4000
# 54/54 - 1s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 1.0000 - 945ms/epoch - 17ms/step
# Epoch 47/4000
# 54/54 - 1s - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 1.0000 - 942ms/epoch - 17ms/step
# Epoch 48/4000
# 54/54 - 1s - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000 - 942ms/epoch - 17ms/step
# Epoch 49/4000
# 54/54 - 1s - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 1.0000 - 943ms/epoch - 17ms/step
# Epoch 50/4000
# 54/54 - 1s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000 - 944ms/epoch - 17ms/step
# Epoch 51/4000
# 54/54 - 1s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 1.0000 - 942ms/epoch - 17ms/step
# Epoch 52/4000
# 54/54 - 1s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000 - 944ms/epoch - 17ms/step
# Epoch 53/4000
# 54/54 - 1s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000 - 942ms/epoch - 17ms/step
# Epoch 54/4000
# 54/54 - 1s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 1.0000 - 944ms/epoch - 17ms/step
# Epoch 55/4000
# 54/54 - 1s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 1.0000 - 941ms/epoch - 17ms/step
# Epoch 56/4000
# 54/54 - 1s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 1.0000 - 942ms/epoch - 17ms/step
# Epoch 57/4000
# 54/54 - 1s - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 1.0000 - 945ms/epoch - 17ms/step
# Epoch 58/4000
# 54/54 - 1s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000 - 945ms/epoch - 17ms/step
# Epoch 59/4000
# 54/54 - 1s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 1.0000 - 944ms/epoch - 17ms/step
# Epoch 60/4000
# 54/54 - 1s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 61/4000
# 54/54 - 1s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 62/4000
# 54/54 - 1s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000 - 943ms/epoch - 17ms/step
# Epoch 63/4000
# 54/54 - 1s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000 - 948ms/epoch - 18ms/step
# Epoch 64/4000
# 54/54 - 1s - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 65/4000
# 54/54 - 1s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000 - 943ms/epoch - 17ms/step
# Epoch 66/4000
# 54/54 - 1s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 1.0000 - 950ms/epoch - 18ms/step
# Epoch 67/4000
# 54/54 - 1s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000 - 948ms/epoch - 18ms/step
# Epoch 68/4000
# 54/54 - 1s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000 - 945ms/epoch - 18ms/step
# Epoch 69/4000
# 54/54 - 1s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000 - 950ms/epoch - 18ms/step
# Epoch 70/4000
# 54/54 - 1s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 1.0000 - 946ms/epoch - 18ms/step
# Epoch 71/4000
# 54/54 - 1s - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000 - 950ms/epoch - 18ms/step
# Epoch 72/4000
# 54/54 - 1s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000 - 950ms/epoch - 18ms/step
# Epoch 73/4000
# 54/54 - 1s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 74/4000
# 54/54 - 1s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000 - 949ms/epoch - 18ms/step
# Epoch 75/4000
# 54/54 - 1s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000 - 950ms/epoch - 18ms/step
# Epoch 76/4000
# 54/54 - 1s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000 - 949ms/epoch - 18ms/step
# Epoch 77/4000
# 54/54 - 1s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 78/4000
# 54/54 - 1s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 79/4000
# 54/54 - 1s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 80/4000
# 54/54 - 1s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 81/4000
# 54/54 - 1s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000 - 949ms/epoch - 18ms/step
# Epoch 82/4000
# 54/54 - 1s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 83/4000
# 54/54 - 1s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 84/4000
# 54/54 - 1s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 85/4000
# 54/54 - 1s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 86/4000
# 54/54 - 1s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 87/4000
# 54/54 - 1s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 88/4000
# 54/54 - 1s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 89/4000
# 54/54 - 1s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000 - 963ms/epoch - 18ms/step
# Epoch 90/4000
# 54/54 - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 91/4000
# 54/54 - 1s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 92/4000
# 54/54 - 1s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 93/4000
# 54/54 - 1s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 94/4000
# 54/54 - 1s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 95/4000
# 54/54 - 1s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 96/4000
# 54/54 - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 97/4000
# 54/54 - 1s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 98/4000
# 54/54 - 1s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 99/4000
# 54/54 - 1s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 100/4000
# 54/54 - 1s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 101/4000
# 54/54 - 1s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 102/4000
# 54/54 - 1s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 103/4000
# 54/54 - 1s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 104/4000
# 54/54 - 1s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 105/4000
# 54/54 - 1s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 106/4000
# 54/54 - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 107/4000
# 54/54 - 1s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 108/4000
# 54/54 - 1s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 109/4000
# 54/54 - 1s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - 966ms/epoch - 18ms/step
# Epoch 110/4000
# 54/54 - 1s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 111/4000
# 54/54 - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 112/4000
# 54/54 - 1s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 113/4000
# 54/54 - 1s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 114/4000
# 54/54 - 1s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 115/4000
# 54/54 - 1s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 116/4000
# 54/54 - 1s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - 963ms/epoch - 18ms/step
# Epoch 117/4000
# 54/54 - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 118/4000
# 54/54 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 119/4000
# 54/54 - 1s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 120/4000
# 54/54 - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 121/4000
# 54/54 - 1s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 122/4000
# 54/54 - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 123/4000
# 54/54 - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 124/4000
# 54/54 - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 125/4000
# 54/54 - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 126/4000
# 54/54 - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - 966ms/epoch - 18ms/step
# Epoch 127/4000
# 54/54 - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 128/4000
# 54/54 - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 129/4000
# 54/54 - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000 - 971ms/epoch - 18ms/step
# Epoch 130/4000
# 54/54 - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000 - 972ms/epoch - 18ms/step
# Epoch 131/4000
# 54/54 - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000 - 968ms/epoch - 18ms/step
# Epoch 132/4000
# 54/54 - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000 - 966ms/epoch - 18ms/step
# Epoch 133/4000
# 54/54 - 1s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000 - 974ms/epoch - 18ms/step
# Epoch 134/4000
# 54/54 - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 135/4000
# 54/54 - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 136/4000
# 54/54 - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 137/4000
# 54/54 - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 138/4000
# 54/54 - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 139/4000
# 54/54 - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 140/4000
# 54/54 - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 141/4000
# 54/54 - 1s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000 - 973ms/epoch - 18ms/step
# Epoch 142/4000
# 54/54 - 1s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 143/4000
# 54/54 - 1s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 144/4000
# 54/54 - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000 - 968ms/epoch - 18ms/step
# Epoch 145/4000
# 54/54 - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 146/4000
# 54/54 - 1s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 147/4000
# 54/54 - 1s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000 - 968ms/epoch - 18ms/step
# Epoch 148/4000
# 54/54 - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000 - 986ms/epoch - 18ms/step
# Epoch 149/4000
# 54/54 - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000 - 976ms/epoch - 18ms/step
# Epoch 150/4000
# 54/54 - 1s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000 - 966ms/epoch - 18ms/step
# Epoch 151/4000
# 54/54 - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 152/4000
# 54/54 - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000 - 971ms/epoch - 18ms/step
# Epoch 153/4000
# 54/54 - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000 - 971ms/epoch - 18ms/step
# Epoch 154/4000
# 54/54 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000 - 968ms/epoch - 18ms/step
# Epoch 155/4000
# 54/54 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 156/4000
# 54/54 - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 157/4000
# 54/54 - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - 972ms/epoch - 18ms/step
# Epoch 158/4000
# 54/54 - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 968ms/epoch - 18ms/step
# Epoch 159/4000
# 54/54 - 1s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 972ms/epoch - 18ms/step
# Epoch 160/4000
# 54/54 - 1s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 161/4000
# 54/54 - 1s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 162/4000
# 54/54 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - 971ms/epoch - 18ms/step
# Epoch 163/4000
# 54/54 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 164/4000
# 54/54 - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 165/4000
# 54/54 - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 166/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 167/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 969ms/epoch - 18ms/step
# Epoch 168/4000
# 54/54 - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 169/4000
# 54/54 - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 170/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 171/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 172/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 970ms/epoch - 18ms/step
# Epoch 173/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 174/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 968ms/epoch - 18ms/step
# Epoch 175/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 176/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 963ms/epoch - 18ms/step
# Epoch 177/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 178/4000
# 54/54 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 967ms/epoch - 18ms/step
# Epoch 179/4000
# 54/54 - 1s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 180/4000
# 54/54 - 1s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 181/4000
# 54/54 - 1s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 182/4000
# 54/54 - 1s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - 965ms/epoch - 18ms/step
# Epoch 183/4000
# 54/54 - 1s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 184/4000
# 54/54 - 1s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 185/4000
# 54/54 - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 186/4000
# 54/54 - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 187/4000
# 54/54 - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 188/4000
# 54/54 - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 189/4000
# 54/54 - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 190/4000
# 54/54 - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 962ms/epoch - 18ms/step
# Epoch 191/4000
# 54/54 - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 950ms/epoch - 18ms/step
# Epoch 192/4000
# 54/54 - 1s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 193/4000
# 54/54 - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - 963ms/epoch - 18ms/step
# Epoch 194/4000
# 54/54 - 1s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 195/4000
# 54/54 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 196/4000
# 54/54 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 197/4000
# 54/54 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 198/4000
# 54/54 - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - 964ms/epoch - 18ms/step
# Epoch 199/4000
# 54/54 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 200/4000
# 54/54 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 201/4000
# 54/54 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 202/4000
# 54/54 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 203/4000
# 54/54 - 1s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 204/4000
# 54/54 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 205/4000
# 54/54 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 206/4000
# 54/54 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 207/4000
# 54/54 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 961ms/epoch - 18ms/step
# Epoch 208/4000
# 54/54 - 1s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 209/4000
# 54/54 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 210/4000
# 54/54 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 211/4000
# 54/54 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 212/4000
# 54/54 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 213/4000
# 54/54 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 214/4000
# 54/54 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 215/4000
# 54/54 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 216/4000
# 54/54 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 217/4000
# 54/54 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 218/4000
# 54/54 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 219/4000
# 54/54 - 1s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 220/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 221/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 222/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 223/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 224/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 225/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 226/4000
# 54/54 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 227/4000
# 54/54 - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 228/4000
# 54/54 - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 229/4000
# 54/54 - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 230/4000
# 54/54 - 1s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.9332e-04 - val_accuracy: 1.0000 - 960ms/epoch - 18ms/step
# Epoch 231/4000
# 54/54 - 1s - loss: 9.8704e-04 - accuracy: 1.0000 - val_loss: 9.8424e-04 - val_accuracy: 1.0000 - 957ms/epoch - 18ms/step
# Epoch 232/4000
# 54/54 - 1s - loss: 9.8399e-04 - accuracy: 1.0000 - val_loss: 9.8150e-04 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 233/4000
# 54/54 - 1s - loss: 9.6463e-04 - accuracy: 1.0000 - val_loss: 9.4508e-04 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 234/4000
# 54/54 - 1s - loss: 9.5131e-04 - accuracy: 1.0000 - val_loss: 9.3503e-04 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 235/4000
# 54/54 - 1s - loss: 9.3864e-04 - accuracy: 1.0000 - val_loss: 9.2777e-04 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 236/4000
# 54/54 - 1s - loss: 9.4051e-04 - accuracy: 1.0000 - val_loss: 9.5882e-04 - val_accuracy: 1.0000 - 945ms/epoch - 18ms/step
# Epoch 237/4000
# 54/54 - 1s - loss: 9.2666e-04 - accuracy: 1.0000 - val_loss: 9.0533e-04 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 238/4000
# 54/54 - 1s - loss: 9.1498e-04 - accuracy: 1.0000 - val_loss: 9.1474e-04 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 239/4000
# 54/54 - 1s - loss: 8.9606e-04 - accuracy: 1.0000 - val_loss: 8.8701e-04 - val_accuracy: 1.0000 - 955ms/epoch - 18ms/step
# Epoch 240/4000
# 54/54 - 1s - loss: 8.8365e-04 - accuracy: 1.0000 - val_loss: 8.6905e-04 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 241/4000
# 54/54 - 1s - loss: 8.7584e-04 - accuracy: 1.0000 - val_loss: 8.6439e-04 - val_accuracy: 1.0000 - 954ms/epoch - 18ms/step
# Epoch 242/4000
# 54/54 - 1s - loss: 8.7746e-04 - accuracy: 1.0000 - val_loss: 8.6534e-04 - val_accuracy: 1.0000 - 943ms/epoch - 17ms/step
# Epoch 243/4000
# 54/54 - 1s - loss: 8.5500e-04 - accuracy: 1.0000 - val_loss: 8.8002e-04 - val_accuracy: 1.0000 - 946ms/epoch - 18ms/step
# Epoch 244/4000
# 54/54 - 1s - loss: 8.6077e-04 - accuracy: 1.0000 - val_loss: 8.4416e-04 - val_accuracy: 1.0000 - 958ms/epoch - 18ms/step
# Epoch 245/4000
# 54/54 - 1s - loss: 8.6258e-04 - accuracy: 1.0000 - val_loss: 8.4300e-04 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 246/4000
# 54/54 - 1s - loss: 8.2869e-04 - accuracy: 1.0000 - val_loss: 8.1932e-04 - val_accuracy: 1.0000 - 948ms/epoch - 18ms/step
# Epoch 247/4000
# 54/54 - 1s - loss: 8.1649e-04 - accuracy: 1.0000 - val_loss: 8.1955e-04 - val_accuracy: 1.0000 - 941ms/epoch - 17ms/step
# Epoch 248/4000
# 54/54 - 1s - loss: 8.0735e-04 - accuracy: 1.0000 - val_loss: 8.1816e-04 - val_accuracy: 1.0000 - 956ms/epoch - 18ms/step
# Epoch 249/4000
# 54/54 - 1s - loss: 8.0988e-04 - accuracy: 1.0000 - val_loss: 8.0504e-04 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 250/4000
# 54/54 - 1s - loss: 7.9850e-04 - accuracy: 1.0000 - val_loss: 8.0005e-04 - val_accuracy: 1.0000 - 959ms/epoch - 18ms/step
# Epoch 251/4000
# 54/54 - 1s - loss: 7.8504e-04 - accuracy: 1.0000 - val_loss: 7.8123e-04 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 252/4000
# 54/54 - 1s - loss: 7.7299e-04 - accuracy: 1.0000 - val_loss: 7.5941e-04 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 253/4000
# 54/54 - 1s - loss: 7.6384e-04 - accuracy: 1.0000 - val_loss: 7.5786e-04 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 254/4000
# 54/54 - 1s - loss: 7.5654e-04 - accuracy: 1.0000 - val_loss: 7.5168e-04 - val_accuracy: 1.0000 - 953ms/epoch - 18ms/step
# Epoch 255/4000
# 54/54 - 1s - loss: 7.5380e-04 - accuracy: 1.0000 - val_loss: 7.4264e-04 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# Epoch 256/4000
# 54/54 - 1s - loss: 7.6611e-04 - accuracy: 1.0000 - val_loss: 9.5744e-04 - val_accuracy: 1.0000 - 949ms/epoch - 18ms/step
# Epoch 257/4000
# 54/54 - 1s - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0493 - val_accuracy: 0.9860 - 941ms/epoch - 17ms/step
# Epoch 258/4000
# 54/54 - 1s - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0078 - val_accuracy: 0.9982 - 944ms/epoch - 17ms/step
# Epoch 259/4000
# 54/54 - 1s - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0018 - val_accuracy: 0.9998 - 947ms/epoch - 18ms/step
# Epoch 260/4000
# 54/54 - 1s - loss: 9.6916e-04 - accuracy: 1.0000 - val_loss: 9.5298e-04 - val_accuracy: 1.0000 - 948ms/epoch - 18ms/step
# Epoch 261/4000
# 54/54 - 1s - loss: 8.9246e-04 - accuracy: 1.0000 - val_loss: 8.9108e-04 - val_accuracy: 1.0000 - 946ms/epoch - 18ms/step
# Epoch 262/4000
# 54/54 - 1s - loss: 8.7646e-04 - accuracy: 1.0000 - val_loss: 8.7534e-04 - val_accuracy: 1.0000 - 943ms/epoch - 17ms/step
# Epoch 263/4000
# 54/54 - 1s - loss: 8.6639e-04 - accuracy: 1.0000 - val_loss: 8.6648e-04 - val_accuracy: 1.0000 - 947ms/epoch - 18ms/step
# Epoch 264/4000
# 54/54 - 1s - loss: 8.5955e-04 - accuracy: 1.0000 - val_loss: 8.5876e-04 - val_accuracy: 1.0000 - 938ms/epoch - 17ms/step
# Epoch 265/4000
# 54/54 - 1s - loss: 8.5226e-04 - accuracy: 1.0000 - val_loss: 8.5269e-04 - val_accuracy: 1.0000 - 952ms/epoch - 18ms/step
# 313/313 - 1s - loss: 0.0473 - accuracy: 0.9886 - 590ms/epoch - 2ms/step
# Test loss: 0.047
# Test accuracy: 98.860%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 20)        200
#
#  average_pooling2d (AverageP  (None, 13, 13, 20)       0
#  ooling2D)
#
#  batch_normalization (BatchN  (None, 13, 13, 20)       80
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 50)        9050
#
#  square_activation (SquareAc  (None, 11, 11, 50)       0
#  tivation)
#
#  batch_normalization_1 (Batc  (None, 11, 11, 50)       200
#  hNormalization)
#
#  flatten (Flatten)           (None, 6050)              0
#
#  dense (Dense)               (None, 500)               3025500
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 3,040,040
# Trainable params: 3,039,900
# Non-trainable params: 140
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 54/54 - 2s - loss: 0.7918 - accuracy: 0.8416 - val_loss: 22.9304 - val_accuracy: 0.2208 - 2s/epoch - 35ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.1887 - accuracy: 0.9436 - val_loss: 9.7901 - val_accuracy: 0.3004 - 1s/epoch - 20ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.1311 - accuracy: 0.9601 - val_loss: 3.2740 - val_accuracy: 0.5314 - 1s/epoch - 20ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.1028 - accuracy: 0.9691 - val_loss: 0.9341 - val_accuracy: 0.7580 - 1s/epoch - 20ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.0847 - accuracy: 0.9759 - val_loss: 0.2314 - val_accuracy: 0.9182 - 1s/epoch - 20ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.0719 - accuracy: 0.9799 - val_loss: 0.0854 - val_accuracy: 0.9748 - 1s/epoch - 20ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.0631 - accuracy: 0.9823 - val_loss: 0.0595 - val_accuracy: 0.9838 - 1s/epoch - 20ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.0559 - accuracy: 0.9849 - val_loss: 0.0473 - val_accuracy: 0.9874 - 1s/epoch - 20ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.0501 - accuracy: 0.9864 - val_loss: 0.0415 - val_accuracy: 0.9892 - 1s/epoch - 20ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.0454 - accuracy: 0.9881 - val_loss: 0.0383 - val_accuracy: 0.9894 - 1s/epoch - 20ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.0416 - accuracy: 0.9891 - val_loss: 0.0381 - val_accuracy: 0.9900 - 1s/epoch - 20ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.0382 - accuracy: 0.9903 - val_loss: 0.0336 - val_accuracy: 0.9908 - 1s/epoch - 20ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.0358 - accuracy: 0.9910 - val_loss: 0.0317 - val_accuracy: 0.9914 - 1s/epoch - 20ms/step
# Epoch 14/4000
# 54/54 - 1s - loss: 0.0332 - accuracy: 0.9913 - val_loss: 0.0294 - val_accuracy: 0.9926 - 1s/epoch - 20ms/step
# Epoch 15/4000
# 54/54 - 1s - loss: 0.0310 - accuracy: 0.9922 - val_loss: 0.0282 - val_accuracy: 0.9928 - 1s/epoch - 20ms/step
# Epoch 16/4000
# 54/54 - 1s - loss: 0.0290 - accuracy: 0.9928 - val_loss: 0.0260 - val_accuracy: 0.9932 - 1s/epoch - 20ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.0276 - accuracy: 0.9932 - val_loss: 0.0257 - val_accuracy: 0.9930 - 1s/epoch - 20ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.0260 - accuracy: 0.9933 - val_loss: 0.0248 - val_accuracy: 0.9940 - 1s/epoch - 20ms/step
# Epoch 19/4000
# 54/54 - 1s - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.0228 - val_accuracy: 0.9946 - 1s/epoch - 20ms/step
# Epoch 20/4000
# 54/54 - 1s - loss: 0.0232 - accuracy: 0.9945 - val_loss: 0.0218 - val_accuracy: 0.9942 - 1s/epoch - 21ms/step
# Epoch 21/4000
# 54/54 - 1s - loss: 0.0220 - accuracy: 0.9948 - val_loss: 0.0207 - val_accuracy: 0.9946 - 1s/epoch - 20ms/step
# Epoch 22/4000
# 54/54 - 1s - loss: 0.0211 - accuracy: 0.9945 - val_loss: 0.0205 - val_accuracy: 0.9938 - 1s/epoch - 20ms/step
# Epoch 23/4000
# 54/54 - 1s - loss: 0.0202 - accuracy: 0.9949 - val_loss: 0.0194 - val_accuracy: 0.9956 - 1s/epoch - 20ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.0191 - accuracy: 0.9956 - val_loss: 0.0180 - val_accuracy: 0.9950 - 1s/epoch - 20ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.0180 - accuracy: 0.9960 - val_loss: 0.0186 - val_accuracy: 0.9950 - 1s/epoch - 20ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.0177 - accuracy: 0.9957 - val_loss: 0.0167 - val_accuracy: 0.9958 - 1s/epoch - 20ms/step
# Epoch 27/4000
# 54/54 - 1s - loss: 0.0167 - accuracy: 0.9961 - val_loss: 0.0150 - val_accuracy: 0.9962 - 1s/epoch - 20ms/step
# Epoch 28/4000
# 54/54 - 1s - loss: 0.0158 - accuracy: 0.9964 - val_loss: 0.0140 - val_accuracy: 0.9970 - 1s/epoch - 20ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.0152 - accuracy: 0.9970 - val_loss: 0.0134 - val_accuracy: 0.9974 - 1s/epoch - 20ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.0146 - accuracy: 0.9970 - val_loss: 0.0134 - val_accuracy: 0.9972 - 1s/epoch - 20ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.0140 - accuracy: 0.9971 - val_loss: 0.0127 - val_accuracy: 0.9968 - 1s/epoch - 20ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.0136 - accuracy: 0.9973 - val_loss: 0.0127 - val_accuracy: 0.9964 - 1s/epoch - 20ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.0118 - val_accuracy: 0.9978 - 1s/epoch - 20ms/step
# Epoch 34/4000
# 54/54 - 1s - loss: 0.0123 - accuracy: 0.9976 - val_loss: 0.0118 - val_accuracy: 0.9974 - 1s/epoch - 20ms/step
# Epoch 35/4000
# 54/54 - 1s - loss: 0.0114 - accuracy: 0.9979 - val_loss: 0.0110 - val_accuracy: 0.9976 - 1s/epoch - 20ms/step
# Epoch 36/4000
# 54/54 - 1s - loss: 0.0110 - accuracy: 0.9981 - val_loss: 0.0099 - val_accuracy: 0.9980 - 1s/epoch - 20ms/step
# Epoch 37/4000
# 54/54 - 1s - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.0099 - val_accuracy: 0.9984 - 1s/epoch - 20ms/step
# Epoch 38/4000
# 54/54 - 1s - loss: 0.0100 - accuracy: 0.9982 - val_loss: 0.0101 - val_accuracy: 0.9980 - 1s/epoch - 20ms/step
# Epoch 39/4000
# 54/54 - 1s - loss: 0.0103 - accuracy: 0.9981 - val_loss: 0.0091 - val_accuracy: 0.9988 - 1s/epoch - 20ms/step
# Epoch 40/4000
# 54/54 - 1s - loss: 0.0092 - accuracy: 0.9986 - val_loss: 0.0089 - val_accuracy: 0.9986 - 1s/epoch - 20ms/step
# Epoch 41/4000
# 54/54 - 1s - loss: 0.0087 - accuracy: 0.9989 - val_loss: 0.0089 - val_accuracy: 0.9982 - 1s/epoch - 20ms/step
# Epoch 42/4000
# 54/54 - 1s - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.0077 - val_accuracy: 0.9992 - 1s/epoch - 20ms/step
# Epoch 43/4000
# 54/54 - 1s - loss: 0.0081 - accuracy: 0.9989 - val_loss: 0.0077 - val_accuracy: 0.9990 - 1s/epoch - 20ms/step
# Epoch 44/4000
# 54/54 - 1s - loss: 0.0080 - accuracy: 0.9989 - val_loss: 0.0073 - val_accuracy: 0.9990 - 1s/epoch - 20ms/step
# Epoch 45/4000
# 54/54 - 1s - loss: 0.0075 - accuracy: 0.9993 - val_loss: 0.0062 - val_accuracy: 0.9992 - 1s/epoch - 20ms/step
# Epoch 46/4000
# 54/54 - 1s - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.0069 - val_accuracy: 0.9994 - 1s/epoch - 20ms/step
# Epoch 47/4000
# 54/54 - 1s - loss: 0.0070 - accuracy: 0.9993 - val_loss: 0.0071 - val_accuracy: 0.9992 - 1s/epoch - 20ms/step
# Epoch 48/4000
# 54/54 - 1s - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.0059 - val_accuracy: 0.9994 - 1s/epoch - 21ms/step
# Epoch 49/4000
# 54/54 - 1s - loss: 0.0065 - accuracy: 0.9993 - val_loss: 0.0059 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 50/4000
# 54/54 - 1s - loss: 0.0062 - accuracy: 0.9995 - val_loss: 0.0057 - val_accuracy: 0.9992 - 1s/epoch - 20ms/step
# Epoch 51/4000
# 54/54 - 1s - loss: 0.0059 - accuracy: 0.9995 - val_loss: 0.0051 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 52/4000
# 54/54 - 1s - loss: 0.0055 - accuracy: 0.9996 - val_loss: 0.0060 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 53/4000
# 54/54 - 1s - loss: 0.0055 - accuracy: 0.9996 - val_loss: 0.0054 - val_accuracy: 0.9994 - 1s/epoch - 20ms/step
# Epoch 54/4000
# 54/54 - 1s - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.0046 - val_accuracy: 0.9998 - 1s/epoch - 20ms/step
# Epoch 55/4000
# 54/54 - 1s - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.0049 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 56/4000
# 54/54 - 1s - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.0048 - val_accuracy: 0.9998 - 1s/epoch - 20ms/step
# Epoch 57/4000
# 54/54 - 1s - loss: 0.0049 - accuracy: 0.9998 - val_loss: 0.0044 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 58/4000
# 54/54 - 1s - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 59/4000
# 54/54 - 1s - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.0042 - val_accuracy: 0.9996 - 1s/epoch - 20ms/step
# Epoch 60/4000
# 54/54 - 1s - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.0048 - val_accuracy: 0.9998 - 1s/epoch - 20ms/step
# Epoch 61/4000
# 54/54 - 1s - loss: 0.0042 - accuracy: 0.9999 - val_loss: 0.0040 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 62/4000
# 54/54 - 1s - loss: 0.0042 - accuracy: 0.9999 - val_loss: 0.0040 - val_accuracy: 0.9998 - 1s/epoch - 20ms/step
# Epoch 63/4000
# 54/54 - 1s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9998 - 1s/epoch - 20ms/step
# Epoch 64/4000
# 54/54 - 1s - loss: 0.0039 - accuracy: 0.9999 - val_loss: 0.0038 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 65/4000
# 54/54 - 1s - loss: 0.0037 - accuracy: 0.9999 - val_loss: 0.0036 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 66/4000
# 54/54 - 1s - loss: 0.0036 - accuracy: 0.9999 - val_loss: 0.0033 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 67/4000
# 54/54 - 1s - loss: 0.0036 - accuracy: 0.9999 - val_loss: 0.0035 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 68/4000
# 54/54 - 1s - loss: 0.0036 - accuracy: 0.9999 - val_loss: 0.0034 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 69/4000
# 54/54 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 70/4000
# 54/54 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9998 - 1s/epoch - 20ms/step
# Epoch 71/4000
# 54/54 - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 72/4000
# 54/54 - 1s - loss: 0.0033 - accuracy: 0.9999 - val_loss: 0.0030 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 73/4000
# 54/54 - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 74/4000
# 54/54 - 1s - loss: 0.0033 - accuracy: 0.9999 - val_loss: 0.0032 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 75/4000
# 54/54 - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 76/4000
# 54/54 - 1s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 77/4000
# 54/54 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 78/4000
# 54/54 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 79/4000
# 54/54 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 80/4000
# 54/54 - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 81/4000
# 54/54 - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 82/4000
# 54/54 - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 83/4000
# 54/54 - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 84/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 85/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 86/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 87/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 88/4000
# 54/54 - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 89/4000
# 54/54 - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 90/4000
# 54/54 - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 91/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 92/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 93/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 94/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 95/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 96/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 97/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 98/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 99/4000
# 54/54 - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 100/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 101/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 102/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 103/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 104/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 105/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 106/4000
# 54/54 - 4s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 4s/epoch - 83ms/step
# Epoch 107/4000
# 54/54 - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 108/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 109/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 110/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 111/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 112/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 113/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 114/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 115/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 116/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 117/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 118/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 119/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 120/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 121/4000
# 54/54 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 122/4000
# 54/54 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 123/4000
# 54/54 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 124/4000
# 54/54 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 125/4000
# 54/54 - 1s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 126/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 127/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 128/4000
# 54/54 - 1s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 129/4000
# 54/54 - 1s - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.0116 - val_accuracy: 0.9968 - 1s/epoch - 20ms/step
# Epoch 130/4000
# 54/54 - 1s - loss: 0.0241 - accuracy: 0.9934 - val_loss: 0.0245 - val_accuracy: 0.9932 - 1s/epoch - 20ms/step
# Epoch 131/4000
# 54/54 - 1s - loss: 0.0179 - accuracy: 0.9952 - val_loss: 0.0078 - val_accuracy: 0.9988 - 1s/epoch - 20ms/step
# Epoch 132/4000
# 54/54 - 1s - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.0105 - val_accuracy: 0.9974 - 1s/epoch - 20ms/step
# 313/313 - 1s - loss: 0.0891 - accuracy: 0.9842 - 569ms/epoch - 2ms/step
# Test loss: 0.089
# Test accuracy: 98.420%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model125.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model125.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
