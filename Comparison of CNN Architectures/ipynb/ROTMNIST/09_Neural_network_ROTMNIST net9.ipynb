# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-06-12 14:39:35.678777: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
import gzip
import numpy as np
import struct

def load_images(path):
    with gzip.open(path, 'rb') as f:
        # 解析文件头（魔数、图像数、行数、列数）
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        # 读取图像数据并转换为numpy数组
        images = np.frombuffer(f.read(), dtype=np.uint8)
        images = images.reshape(num, rows, cols)  # 维度调整为 [N, 28, 28]
    return images

def load_labels(path):
    with gzip.open(path, 'rb') as f:
        # 解析文件头（魔数、标签数）
        magic, num = struct.unpack('>II', f.read(8))
        # 读取标签数据
        labels = np.frombuffer(f.read(), dtype=np.uint8)
    return labels
x_train = load_images("/workspace/examples/vision_transformer/data/ROTNIST/train-images-idx3-ubyte.gz")
y_train = load_labels("/workspace/examples/vision_transformer/data/ROTNIST/train-labels-idx1-ubyte.gz")
x_test = load_images("/workspace/examples/vision_transformer/data/ROTNIST/t10k-images-idx3-ubyte.gz")
y_test = load_labels("/workspace/examples/vision_transformer/data/ROTNIST/t10k-labels-idx1-ubyte.gz")
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# 添加通道维度（从 [N,28,28] 转为 [N,28,28,1]）
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# %%
# Create validation data
# valsize=16
# valsize=500
valsize=5000
x_train = x_train[:-valsize]
x_val = x_train[-valsize:]
y_train = y_train[:-valsize]
y_val = y_train[-valsize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test17')
# save_data_set(x_train, y_train, data_type='train')
# save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test17 of shape (10000, 28, 28, 1) in data/net_mnist/x_test17.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D,AveragePooling2D,Softmax
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2

# 创建模型
model = Sequential()

# 卷积层1（无填充，输入28x28x1）
# 卷积层1（无修改，保持原输入输出维度）
model.add(Conv2D(6, kernel_size=5, input_shape=(28, 28, 1), kernel_regularizer=l2(0.0005)))  # 输出(24,24,6)
model.add(AvgPool2D(pool_size=2, strides=2))  # 输出(12,12,6)

# 卷积层2（无修改，保持原输入输出维度）
model.add(Conv2D(16, kernel_size=5, kernel_regularizer=l2(0.0005)))  # 输出(8,8,16)
model.add(AvgPool2D(pool_size=2, strides=2))  # 输出(4,4,16)

# 核心合并层（无修改，保持原功能和输出维度）
model.add(Conv2D(84, kernel_size=4, kernel_regularizer=l2(0.0005)))  # 输出(1,1,84)，替代原两个卷积层

# 后续层（无修改，保持原结构）
model.add(BatchNormalization())
model.add(ReLU())
# 通道数调整为10（对应分类类别数，输出(1,1,10)）
model.add(Conv2D(10, kernel_size=1, kernel_regularizer=l2(0.0005)))

# 关键修改：替换GlobalAveragePooling2D为 AvgPool2D + Flatten
# 步骤1：添加普通平均池化层（输入(1,1,10)，输出仍为(1,1,10)，保证维度稳定）
# pool_size=1、strides=1：因输入空间尺寸已为1x1，该设置不改变尺寸，仅完成“平均池化”操作
model.add(AvgPool2D(pool_size=1, strides=1))
# 步骤2：添加展平层，将(1,1,10)特征图展平为(10,)向量，与原网络输出维度完全一致
model.add(Flatten())

# 打印模型结构验证
model.summary()
# Out:
# 2025-06-12 14:39:39.065636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.105361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.108281: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.111373: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-12 14:39:39.112044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so ret
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 20)        520
#
#  average_pooling2d (AverageP  (None, 12, 12, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 50)          25050
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 10)          8010
#
#  batch_normalization (BatchN  (None, 1, 1, 10)         40
#  ormalization)
#
#  re_lu (ReLU)                (None, 1, 1, 10)          0
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 33,620
# Trainable params: 33,600
# Non-trainable params: 20
# _________________________________________________________________
# urning NUMA node zero
# 2025-06-12 14:39:39.114852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.117504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.890443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.892331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.893995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:39:39.895596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-06-12 14:39:44.027837: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 54/54 - 3s - loss: 1.6200 - accuracy: 0.5768 - val_loss: 2.1507 - val_accuracy: 0.5752 - 3s/epoch - 64ms/step
# Epoch 2/4000
# 54/54 - 0s - loss: 1.1436 - accuracy: 0.8271 - val_loss: 2.0245 - val_accuracy: 0.8212 - 499ms/epoch - 9ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 1.0682 - accuracy: 0.8478 - val_loss: 1.8822 - val_accuracy: 0.8390 - 502ms/epoch - 9ms/step
# Epoch 4/4000
# 54/54 - 0s - loss: 1.0331 - accuracy: 0.8546 - val_loss: 1.7170 - val_accuracy: 0.8526 - 499ms/epoch - 9ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 1.0117 - accuracy: 0.8589 - val_loss: 1.5306 - val_accuracy: 0.8562 - 505ms/epoch - 9ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.9938 - accuracy: 0.8621 - val_loss: 1.3517 - val_accuracy: 0.8576 - 504ms/epoch - 9ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.9795 - accuracy: 0.8641 - val_loss: 1.1959 - val_accuracy: 0.8652 - 500ms/epoch - 9ms/step
# Epoch 8/4000
# 54/54 - 0s - loss: 0.9676 - accuracy: 0.8659 - val_loss: 1.0728 - val_accuracy: 0.8674 - 500ms/epoch - 9ms/step
# Epoch 9/4000
# 54/54 - 0s - loss: 0.9565 - accuracy: 0.8674 - val_loss: 0.9986 - val_accuracy: 0.8656 - 499ms/epoch - 9ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.9469 - accuracy: 0.8685 - val_loss: 0.9461 - val_accuracy: 0.8718 - 503ms/epoch - 9ms/step
# Epoch 11/4000
# 54/54 - 0s - loss: 0.9373 - accuracy: 0.8688 - val_loss: 0.9209 - val_accuracy: 0.8712 - 495ms/epoch - 9ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.9290 - accuracy: 0.8701 - val_loss: 0.8928 - val_accuracy: 0.8742 - 612ms/epoch - 11ms/step
# Epoch 13/4000
# 54/54 - 0s - loss: 0.9207 - accuracy: 0.8713 - val_loss: 0.8798 - val_accuracy: 0.8724 - 496ms/epoch - 9ms/step
# Epoch 14/4000
# 54/54 - 0s - loss: 0.9131 - accuracy: 0.8720 - val_loss: 0.8718 - val_accuracy: 0.8728 - 499ms/epoch - 9ms/step
# Epoch 15/4000
# 54/54 - 0s - loss: 0.9057 - accuracy: 0.8728 - val_loss: 0.8692 - val_accuracy: 0.8746 - 498ms/epoch - 9ms/step
# Epoch 16/4000
# 54/54 - 0s - loss: 0.8987 - accuracy: 0.8722 - val_loss: 0.8592 - val_accuracy: 0.8754 - 497ms/epoch - 9ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.8920 - accuracy: 0.8733 - val_loss: 0.8530 - val_accuracy: 0.8750 - 500ms/epoch - 9ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.8857 - accuracy: 0.8738 - val_loss: 0.8489 - val_accuracy: 0.8780 - 503ms/epoch - 9ms/step
# Epoch 19/4000
# 54/54 - 0s - loss: 0.8794 - accuracy: 0.8747 - val_loss: 0.8454 - val_accuracy: 0.8760 - 498ms/epoch - 9ms/step
# Epoch 20/4000
# 54/54 - 0s - loss: 0.8727 - accuracy: 0.8746 - val_loss: 0.8394 - val_accuracy: 0.8738 - 500ms/epoch - 9ms/step
# Epoch 21/4000
# 54/54 - 0s - loss: 0.8672 - accuracy: 0.8745 - val_loss: 0.8328 - val_accuracy: 0.8736 - 495ms/epoch - 9ms/step
# Epoch 22/4000
# 54/54 - 0s - loss: 0.8615 - accuracy: 0.8751 - val_loss: 0.8297 - val_accuracy: 0.8758 - 495ms/epoch - 9ms/step
# Epoch 23/4000
# 54/54 - 0s - loss: 0.8557 - accuracy: 0.8760 - val_loss: 0.8251 - val_accuracy: 0.8808 - 497ms/epoch - 9ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.8498 - accuracy: 0.8764 - val_loss: 0.8196 - val_accuracy: 0.8772 - 501ms/epoch - 9ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.8443 - accuracy: 0.8770 - val_loss: 0.8174 - val_accuracy: 0.8772 - 506ms/epoch - 9ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.8388 - accuracy: 0.8759 - val_loss: 0.8143 - val_accuracy: 0.8768 - 501ms/epoch - 9ms/step
# Epoch 27/4000
# 54/54 - 0s - loss: 0.8334 - accuracy: 0.8779 - val_loss: 0.8083 - val_accuracy: 0.8806 - 499ms/epoch - 9ms/step
# Epoch 28/4000
# 54/54 - 0s - loss: 0.8282 - accuracy: 0.8782 - val_loss: 0.8053 - val_accuracy: 0.8790 - 497ms/epoch - 9ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.8235 - accuracy: 0.8783 - val_loss: 0.8026 - val_accuracy: 0.8754 - 503ms/epoch - 9ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.8188 - accuracy: 0.8779 - val_loss: 0.7978 - val_accuracy: 0.8826 - 501ms/epoch - 9ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.8134 - accuracy: 0.8788 - val_loss: 0.7953 - val_accuracy: 0.8814 - 502ms/epoch - 9ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.8090 - accuracy: 0.8787 - val_loss: 0.7872 - val_accuracy: 0.8868 - 512ms/epoch - 9ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.8039 - accuracy: 0.8791 - val_loss: 0.7867 - val_accuracy: 0.8798 - 507ms/epoch - 9ms/step
# Epoch 34/4000
# 54/54 - 1s - loss: 0.7990 - accuracy: 0.8791 - val_loss: 0.7822 - val_accuracy: 0.8848 - 504ms/epoch - 9ms/step
# Epoch 35/4000
# 54/54 - 1s - loss: 0.7951 - accuracy: 0.8795 - val_loss: 0.7741 - val_accuracy: 0.8794 - 503ms/epoch - 9ms/step
# Epoch 36/4000
# 54/54 - 1s - loss: 0.7905 - accuracy: 0.8794 - val_loss: 0.7718 - val_accuracy: 0.8852 - 508ms/epoch - 9ms/step
# Epoch 37/4000
# 54/54 - 1s - loss: 0.7858 - accuracy: 0.8799 - val_loss: 0.7672 - val_accuracy: 0.8870 - 504ms/epoch - 9ms/step
# Epoch 38/4000
# 54/54 - 0s - loss: 0.7816 - accuracy: 0.8801 - val_loss: 0.7636 - val_accuracy: 0.8832 - 498ms/epoch - 9ms/step
# Epoch 39/4000
# 54/54 - 1s - loss: 0.7776 - accuracy: 0.8808 - val_loss: 0.7598 - val_accuracy: 0.8812 - 501ms/epoch - 9ms/step
# Epoch 40/4000
# 54/54 - 1s - loss: 0.7731 - accuracy: 0.8809 - val_loss: 0.7570 - val_accuracy: 0.8832 - 504ms/epoch - 9ms/step
# Epoch 41/4000
# 54/54 - 1s - loss: 0.7690 - accuracy: 0.8809 - val_loss: 0.7525 - val_accuracy: 0.8852 - 509ms/epoch - 9ms/step
# Epoch 42/4000
# 54/54 - 1s - loss: 0.7644 - accuracy: 0.8818 - val_loss: 0.7449 - val_accuracy: 0.8826 - 505ms/epoch - 9ms/step
# Epoch 43/4000
# 54/54 - 1s - loss: 0.7612 - accuracy: 0.8811 - val_loss: 0.7433 - val_accuracy: 0.8856 - 506ms/epoch - 9ms/step
# Epoch 44/4000
# 54/54 - 1s - loss: 0.7575 - accuracy: 0.8813 - val_loss: 0.7398 - val_accuracy: 0.8846 - 523ms/epoch - 10ms/step
# Epoch 45/4000
# 54/54 - 1s - loss: 0.7532 - accuracy: 0.8818 - val_loss: 0.7350 - val_accuracy: 0.8870 - 516ms/epoch - 10ms/step
# Epoch 46/4000
# 54/54 - 1s - loss: 0.7496 - accuracy: 0.8820 - val_loss: 0.7330 - val_accuracy: 0.8824 - 503ms/epoch - 9ms/step
# Epoch 47/4000
# 54/54 - 1s - loss: 0.7450 - accuracy: 0.8828 - val_loss: 0.7289 - val_accuracy: 0.8860 - 508ms/epoch - 9ms/step
# Epoch 48/4000
# 54/54 - 1s - loss: 0.7418 - accuracy: 0.8830 - val_loss: 0.7226 - val_accuracy: 0.8822 - 507ms/epoch - 9ms/step
# Epoch 49/4000
# 54/54 - 1s - loss: 0.7385 - accuracy: 0.8824 - val_loss: 0.7220 - val_accuracy: 0.8826 - 508ms/epoch - 9ms/step
# Epoch 50/4000
# 54/54 - 1s - loss: 0.7346 - accuracy: 0.8825 - val_loss: 0.7220 - val_accuracy: 0.8848 - 507ms/epoch - 9ms/step
# Epoch 51/4000
# 54/54 - 1s - loss: 0.7310 - accuracy: 0.8823 - val_loss: 0.7190 - val_accuracy: 0.8850 - 508ms/epoch - 9ms/step
# Epoch 52/4000
# 54/54 - 1s - loss: 0.7278 - accuracy: 0.8832 - val_loss: 0.7156 - val_accuracy: 0.8842 - 500ms/epoch - 9ms/step
# Epoch 53/4000
# 54/54 - 1s - loss: 0.7240 - accuracy: 0.8836 - val_loss: 0.7115 - val_accuracy: 0.8842 - 501ms/epoch - 9ms/step
# Epoch 54/4000
# 54/54 - 1s - loss: 0.7205 - accuracy: 0.8835 - val_loss: 0.7073 - val_accuracy: 0.8854 - 502ms/epoch - 9ms/step
# Epoch 55/4000
# 54/54 - 1s - loss: 0.7175 - accuracy: 0.8837 - val_loss: 0.6994 - val_accuracy: 0.8878 - 505ms/epoch - 9ms/step
# Epoch 56/4000
# 54/54 - 1s - loss: 0.7137 - accuracy: 0.8835 - val_loss: 0.7004 - val_accuracy: 0.8828 - 511ms/epoch - 9ms/step
# Epoch 57/4000
# 54/54 - 1s - loss: 0.7101 - accuracy: 0.8842 - val_loss: 0.6938 - val_accuracy: 0.8848 - 500ms/epoch - 9ms/step
# Epoch 58/4000
# 54/54 - 1s - loss: 0.7068 - accuracy: 0.8842 - val_loss: 0.6926 - val_accuracy: 0.8830 - 504ms/epoch - 9ms/step
# Epoch 59/4000
# 54/54 - 1s - loss: 0.7039 - accuracy: 0.8847 - val_loss: 0.6904 - val_accuracy: 0.8860 - 504ms/epoch - 9ms/step
# Epoch 60/4000
# 54/54 - 0s - loss: 0.7011 - accuracy: 0.8843 - val_loss: 0.6876 - val_accuracy: 0.8824 - 500ms/epoch - 9ms/step
# Epoch 61/4000
# 54/54 - 1s - loss: 0.6975 - accuracy: 0.8851 - val_loss: 0.6813 - val_accuracy: 0.8848 - 500ms/epoch - 9ms/step
# Epoch 62/4000
# 54/54 - 1s - loss: 0.6944 - accuracy: 0.8847 - val_loss: 0.6810 - val_accuracy: 0.8864 - 502ms/epoch - 9ms/step
# Epoch 63/4000
# 54/54 - 1s - loss: 0.6910 - accuracy: 0.8852 - val_loss: 0.6752 - val_accuracy: 0.8874 - 503ms/epoch - 9ms/step
# Epoch 64/4000
# 54/54 - 1s - loss: 0.6883 - accuracy: 0.8849 - val_loss: 0.6749 - val_accuracy: 0.8892 - 500ms/epoch - 9ms/step
# Epoch 65/4000
# 54/54 - 1s - loss: 0.6848 - accuracy: 0.8852 - val_loss: 0.6724 - val_accuracy: 0.8844 - 502ms/epoch - 9ms/step
# Epoch 66/4000
# 54/54 - 1s - loss: 0.6829 - accuracy: 0.8848 - val_loss: 0.6717 - val_accuracy: 0.8872 - 505ms/epoch - 9ms/step
# Epoch 67/4000
# 54/54 - 1s - loss: 0.6791 - accuracy: 0.8855 - val_loss: 0.6654 - val_accuracy: 0.8894 - 506ms/epoch - 9ms/step
# Epoch 68/4000
# 54/54 - 1s - loss: 0.6764 - accuracy: 0.8854 - val_loss: 0.6646 - val_accuracy: 0.8872 - 500ms/epoch - 9ms/step
# Epoch 69/4000
# 54/54 - 1s - loss: 0.6735 - accuracy: 0.8861 - val_loss: 0.6575 - val_accuracy: 0.8890 - 501ms/epoch - 9ms/step
# Epoch 70/4000
# 54/54 - 0s - loss: 0.6708 - accuracy: 0.8857 - val_loss: 0.6576 - val_accuracy: 0.8900 - 497ms/epoch - 9ms/step
# Epoch 71/4000
# 54/54 - 1s - loss: 0.6681 - accuracy: 0.8857 - val_loss: 0.6564 - val_accuracy: 0.8850 - 500ms/epoch - 9ms/step
# Epoch 72/4000
# 54/54 - 1s - loss: 0.6649 - accuracy: 0.8860 - val_loss: 0.6512 - val_accuracy: 0.8860 - 503ms/epoch - 9ms/step
# Epoch 73/4000
# 54/54 - 1s - loss: 0.6619 - accuracy: 0.8867 - val_loss: 0.6477 - val_accuracy: 0.8896 - 508ms/epoch - 9ms/step
# Epoch 74/4000
# 54/54 - 0s - loss: 0.6593 - accuracy: 0.8869 - val_loss: 0.6499 - val_accuracy: 0.8900 - 495ms/epoch - 9ms/step
# Epoch 75/4000
# 54/54 - 0s - loss: 0.6571 - accuracy: 0.8864 - val_loss: 0.6440 - val_accuracy: 0.8886 - 499ms/epoch - 9ms/step
# Epoch 76/4000
# 54/54 - 1s - loss: 0.6539 - accuracy: 0.8872 - val_loss: 0.6444 - val_accuracy: 0.8892 - 501ms/epoch - 9ms/step
# Epoch 77/4000
# 54/54 - 1s - loss: 0.6511 - accuracy: 0.8868 - val_loss: 0.6409 - val_accuracy: 0.8878 - 504ms/epoch - 9ms/step
# Epoch 78/4000
# 54/54 - 1s - loss: 0.6488 - accuracy: 0.8877 - val_loss: 0.6384 - val_accuracy: 0.8902 - 506ms/epoch - 9ms/step
# Epoch 79/4000
# 54/54 - 1s - loss: 0.6462 - accuracy: 0.8875 - val_loss: 0.6424 - val_accuracy: 0.8850 - 502ms/epoch - 9ms/step
# Epoch 80/4000
# 54/54 - 1s - loss: 0.6436 - accuracy: 0.8885 - val_loss: 0.6305 - val_accuracy: 0.8886 - 503ms/epoch - 9ms/step
# Epoch 81/4000
# 54/54 - 1s - loss: 0.6417 - accuracy: 0.8874 - val_loss: 0.6338 - val_accuracy: 0.8906 - 501ms/epoch - 9ms/step
# Epoch 82/4000
# 54/54 - 1s - loss: 0.6385 - accuracy: 0.8877 - val_loss: 0.6306 - val_accuracy: 0.8872 - 503ms/epoch - 9ms/step
# Epoch 83/4000
# 54/54 - 1s - loss: 0.6366 - accuracy: 0.8875 - val_loss: 0.6212 - val_accuracy: 0.8910 - 502ms/epoch - 9ms/step
# Epoch 84/4000
# 54/54 - 1s - loss: 0.6330 - accuracy: 0.8887 - val_loss: 0.6217 - val_accuracy: 0.8910 - 500ms/epoch - 9ms/step
# Epoch 85/4000
# 54/54 - 1s - loss: 0.6307 - accuracy: 0.8869 - val_loss: 0.6190 - val_accuracy: 0.8914 - 506ms/epoch - 9ms/step
# Epoch 86/4000
# 54/54 - 0s - loss: 0.6286 - accuracy: 0.8882 - val_loss: 0.6205 - val_accuracy: 0.8918 - 500ms/epoch - 9ms/step
# Epoch 87/4000
# 54/54 - 1s - loss: 0.6260 - accuracy: 0.8889 - val_loss: 0.6217 - val_accuracy: 0.8848 - 501ms/epoch - 9ms/step
# Epoch 88/4000
# 54/54 - 1s - loss: 0.6237 - accuracy: 0.8887 - val_loss: 0.6145 - val_accuracy: 0.8876 - 501ms/epoch - 9ms/step
# Epoch 89/4000
# 54/54 - 1s - loss: 0.6214 - accuracy: 0.8898 - val_loss: 0.6088 - val_accuracy: 0.8918 - 504ms/epoch - 9ms/step
# Epoch 90/4000
# 54/54 - 1s - loss: 0.6189 - accuracy: 0.8886 - val_loss: 0.6064 - val_accuracy: 0.8918 - 501ms/epoch - 9ms/step
# Epoch 91/4000
# 54/54 - 1s - loss: 0.6168 - accuracy: 0.8890 - val_loss: 0.6080 - val_accuracy: 0.8882 - 502ms/epoch - 9ms/step
# Epoch 92/4000
# 54/54 - 1s - loss: 0.6144 - accuracy: 0.8886 - val_loss: 0.6007 - val_accuracy: 0.8916 - 505ms/epoch - 9ms/step
# Epoch 93/4000
# 54/54 - 1s - loss: 0.6122 - accuracy: 0.8887 - val_loss: 0.5997 - val_accuracy: 0.8930 - 505ms/epoch - 9ms/step
# Epoch 94/4000
# 54/54 - 1s - loss: 0.6095 - accuracy: 0.8891 - val_loss: 0.6009 - val_accuracy: 0.8886 - 504ms/epoch - 9ms/step
# Epoch 95/4000
# 54/54 - 1s - loss: 0.6078 - accuracy: 0.8895 - val_loss: 0.5929 - val_accuracy: 0.8910 - 504ms/epoch - 9ms/step
# Epoch 96/4000
# 54/54 - 1s - loss: 0.6056 - accuracy: 0.8893 - val_loss: 0.5937 - val_accuracy: 0.8882 - 502ms/epoch - 9ms/step
# Epoch 97/4000
# 54/54 - 1s - loss: 0.6034 - accuracy: 0.8901 - val_loss: 0.5922 - val_accuracy: 0.8918 - 504ms/epoch - 9ms/step
# Epoch 98/4000
# 54/54 - 1s - loss: 0.6008 - accuracy: 0.8899 - val_loss: 0.5972 - val_accuracy: 0.8886 - 503ms/epoch - 9ms/step
# Epoch 99/4000
# 54/54 - 1s - loss: 0.5991 - accuracy: 0.8903 - val_loss: 0.5856 - val_accuracy: 0.8930 - 502ms/epoch - 9ms/step
# Epoch 100/4000
# 54/54 - 1s - loss: 0.5974 - accuracy: 0.8905 - val_loss: 0.5830 - val_accuracy: 0.8932 - 503ms/epoch - 9ms/step
# Epoch 101/4000
# 54/54 - 1s - loss: 0.5944 - accuracy: 0.8902 - val_loss: 0.5850 - val_accuracy: 0.8936 - 503ms/epoch - 9ms/step
# Epoch 102/4000
# 54/54 - 1s - loss: 0.5927 - accuracy: 0.8894 - val_loss: 0.5833 - val_accuracy: 0.8904 - 510ms/epoch - 9ms/step
# Epoch 103/4000
# 54/54 - 1s - loss: 0.5910 - accuracy: 0.8899 - val_loss: 0.5833 - val_accuracy: 0.8926 - 505ms/epoch - 9ms/step
# Epoch 104/4000
# 54/54 - 1s - loss: 0.5887 - accuracy: 0.8902 - val_loss: 0.5777 - val_accuracy: 0.8914 - 502ms/epoch - 9ms/step
# Epoch 105/4000
# 54/54 - 1s - loss: 0.5860 - accuracy: 0.8908 - val_loss: 0.5770 - val_accuracy: 0.8942 - 509ms/epoch - 9ms/step
# Epoch 106/4000
# 54/54 - 1s - loss: 0.5836 - accuracy: 0.8913 - val_loss: 0.5785 - val_accuracy: 0.8910 - 503ms/epoch - 9ms/step
# Epoch 107/4000
# 54/54 - 1s - loss: 0.5822 - accuracy: 0.8911 - val_loss: 0.5762 - val_accuracy: 0.8924 - 503ms/epoch - 9ms/step
# Epoch 108/4000
# 54/54 - 1s - loss: 0.5800 - accuracy: 0.8909 - val_loss: 0.5724 - val_accuracy: 0.8930 - 500ms/epoch - 9ms/step
# Epoch 109/4000
# 54/54 - 1s - loss: 0.5778 - accuracy: 0.8914 - val_loss: 0.5700 - val_accuracy: 0.8928 - 507ms/epoch - 9ms/step
# Epoch 110/4000
# 54/54 - 1s - loss: 0.5758 - accuracy: 0.8911 - val_loss: 0.5692 - val_accuracy: 0.8930 - 503ms/epoch - 9ms/step
# Epoch 111/4000
# 54/54 - 1s - loss: 0.5740 - accuracy: 0.8912 - val_loss: 0.5624 - val_accuracy: 0.8954 - 504ms/epoch - 9ms/step
# Epoch 112/4000
# 54/54 - 1s - loss: 0.5729 - accuracy: 0.8915 - val_loss: 0.5623 - val_accuracy: 0.8914 - 507ms/epoch - 9ms/step
# Epoch 113/4000
# 54/54 - 1s - loss: 0.5705 - accuracy: 0.8919 - val_loss: 0.5577 - val_accuracy: 0.8952 - 503ms/epoch - 9ms/step
# Epoch 114/4000
# 54/54 - 0s - loss: 0.5684 - accuracy: 0.8917 - val_loss: 0.5639 - val_accuracy: 0.8904 - 500ms/epoch - 9ms/step
# Epoch 115/4000
# 54/54 - 1s - loss: 0.5666 - accuracy: 0.8924 - val_loss: 0.5540 - val_accuracy: 0.8954 - 507ms/epoch - 9ms/step
# Epoch 116/4000
# 54/54 - 1s - loss: 0.5645 - accuracy: 0.8914 - val_loss: 0.5585 - val_accuracy: 0.8906 - 502ms/epoch - 9ms/step
# Epoch 117/4000
# 54/54 - 1s - loss: 0.5628 - accuracy: 0.8920 - val_loss: 0.5631 - val_accuracy: 0.8900 - 505ms/epoch - 9ms/step
# Epoch 118/4000
# 54/54 - 1s - loss: 0.5615 - accuracy: 0.8913 - val_loss: 0.5557 - val_accuracy: 0.8942 - 503ms/epoch - 9ms/step
# Epoch 119/4000
# 54/54 - 1s - loss: 0.5594 - accuracy: 0.8927 - val_loss: 0.5473 - val_accuracy: 0.8978 - 504ms/epoch - 9ms/step
# Epoch 120/4000
# 54/54 - 1s - loss: 0.5576 - accuracy: 0.8926 - val_loss: 0.5457 - val_accuracy: 0.8982 - 503ms/epoch - 9ms/step
# Epoch 121/4000
# 54/54 - 1s - loss: 0.5556 - accuracy: 0.8926 - val_loss: 0.5466 - val_accuracy: 0.8968 - 501ms/epoch - 9ms/step
# Epoch 122/4000
# 54/54 - 1s - loss: 0.5540 - accuracy: 0.8930 - val_loss: 0.5458 - val_accuracy: 0.8942 - 500ms/epoch - 9ms/step
# Epoch 123/4000
# 54/54 - 1s - loss: 0.5524 - accuracy: 0.8931 - val_loss: 0.5513 - val_accuracy: 0.8930 - 503ms/epoch - 9ms/step
# Epoch 124/4000
# 54/54 - 1s - loss: 0.5507 - accuracy: 0.8926 - val_loss: 0.5446 - val_accuracy: 0.8944 - 508ms/epoch - 9ms/step
# Epoch 125/4000
# 54/54 - 1s - loss: 0.5490 - accuracy: 0.8933 - val_loss: 0.5356 - val_accuracy: 0.8970 - 502ms/epoch - 9ms/step
# Epoch 126/4000
# 54/54 - 1s - loss: 0.5469 - accuracy: 0.8926 - val_loss: 0.5380 - val_accuracy: 0.8970 - 501ms/epoch - 9ms/step
# Epoch 127/4000
# 54/54 - 1s - loss: 0.5452 - accuracy: 0.8935 - val_loss: 0.5349 - val_accuracy: 0.8992 - 505ms/epoch - 9ms/step
# Epoch 128/4000
# 54/54 - 1s - loss: 0.5440 - accuracy: 0.8942 - val_loss: 0.5369 - val_accuracy: 0.8932 - 502ms/epoch - 9ms/step
# Epoch 129/4000
# 54/54 - 1s - loss: 0.5420 - accuracy: 0.8932 - val_loss: 0.5322 - val_accuracy: 0.8996 - 504ms/epoch - 9ms/step
# Epoch 130/4000
# 54/54 - 1s - loss: 0.5403 - accuracy: 0.8940 - val_loss: 0.5296 - val_accuracy: 0.8960 - 503ms/epoch - 9ms/step
# Epoch 131/4000
# 54/54 - 1s - loss: 0.5390 - accuracy: 0.8934 - val_loss: 0.5321 - val_accuracy: 0.8958 - 535ms/epoch - 10ms/step
# Epoch 132/4000
# 54/54 - 0s - loss: 0.5370 - accuracy: 0.8943 - val_loss: 0.5310 - val_accuracy: 0.8936 - 499ms/epoch - 9ms/step
# Epoch 133/4000
# 54/54 - 1s - loss: 0.5357 - accuracy: 0.8939 - val_loss: 0.5244 - val_accuracy: 0.8958 - 505ms/epoch - 9ms/step
# Epoch 134/4000
# 54/54 - 1s - loss: 0.5332 - accuracy: 0.8943 - val_loss: 0.5286 - val_accuracy: 0.8966 - 505ms/epoch - 9ms/step
# Epoch 135/4000
# 54/54 - 1s - loss: 0.5324 - accuracy: 0.8942 - val_loss: 0.5278 - val_accuracy: 0.8954 - 505ms/epoch - 9ms/step
# Epoch 136/4000
# 54/54 - 1s - loss: 0.5306 - accuracy: 0.8948 - val_loss: 0.5189 - val_accuracy: 0.8992 - 507ms/epoch - 9ms/step
# Epoch 137/4000
# 54/54 - 1s - loss: 0.5292 - accuracy: 0.8946 - val_loss: 0.5194 - val_accuracy: 0.8970 - 504ms/epoch - 9ms/step
# Epoch 138/4000
# 54/54 - 1s - loss: 0.5273 - accuracy: 0.8948 - val_loss: 0.5199 - val_accuracy: 0.8984 - 503ms/epoch - 9ms/step
# Epoch 139/4000
# 54/54 - 1s - loss: 0.5263 - accuracy: 0.8941 - val_loss: 0.5202 - val_accuracy: 0.8948 - 504ms/epoch - 9ms/step
# Epoch 140/4000
# 54/54 - 1s - loss: 0.5247 - accuracy: 0.8951 - val_loss: 0.5177 - val_accuracy: 0.8934 - 504ms/epoch - 9ms/step
# Epoch 141/4000
# 54/54 - 1s - loss: 0.5228 - accuracy: 0.8946 - val_loss: 0.5161 - val_accuracy: 0.8976 - 506ms/epoch - 9ms/step
# Epoch 142/4000
# 54/54 - 1s - loss: 0.5215 - accuracy: 0.8949 - val_loss: 0.5115 - val_accuracy: 0.8994 - 508ms/epoch - 9ms/step
# Epoch 143/4000
# 54/54 - 1s - loss: 0.5200 - accuracy: 0.8947 - val_loss: 0.5115 - val_accuracy: 0.8996 - 509ms/epoch - 9ms/step
# Epoch 144/4000
# 54/54 - 1s - loss: 0.5185 - accuracy: 0.8960 - val_loss: 0.5090 - val_accuracy: 0.8998 - 505ms/epoch - 9ms/step
# Epoch 145/4000
# 54/54 - 1s - loss: 0.5165 - accuracy: 0.8952 - val_loss: 0.5135 - val_accuracy: 0.9008 - 508ms/epoch - 9ms/step
# Epoch 146/4000
# 54/54 - 1s - loss: 0.5152 - accuracy: 0.8962 - val_loss: 0.5062 - val_accuracy: 0.8986 - 508ms/epoch - 9ms/step
# Epoch 147/4000
# 54/54 - 1s - loss: 0.5142 - accuracy: 0.8959 - val_loss: 0.5097 - val_accuracy: 0.8974 - 505ms/epoch - 9ms/step
# Epoch 148/4000
# 54/54 - 1s - loss: 0.5123 - accuracy: 0.8967 - val_loss: 0.5061 - val_accuracy: 0.8940 - 507ms/epoch - 9ms/step
# Epoch 149/4000
# 54/54 - 1s - loss: 0.5115 - accuracy: 0.8958 - val_loss: 0.4991 - val_accuracy: 0.8980 - 509ms/epoch - 9ms/step
# Epoch 150/4000
# 54/54 - 1s - loss: 0.5099 - accuracy: 0.8953 - val_loss: 0.5048 - val_accuracy: 0.8992 - 505ms/epoch - 9ms/step
# Epoch 151/4000
# 54/54 - 1s - loss: 0.5080 - accuracy: 0.8961 - val_loss: 0.5025 - val_accuracy: 0.8962 - 510ms/epoch - 9ms/step
# Epoch 152/4000
# 54/54 - 1s - loss: 0.5071 - accuracy: 0.8960 - val_loss: 0.4993 - val_accuracy: 0.8986 - 508ms/epoch - 9ms/step
# Epoch 153/4000
# 54/54 - 1s - loss: 0.5050 - accuracy: 0.8968 - val_loss: 0.5026 - val_accuracy: 0.9008 - 504ms/epoch - 9ms/step
# Epoch 154/4000
# 54/54 - 1s - loss: 0.5044 - accuracy: 0.8965 - val_loss: 0.4964 - val_accuracy: 0.9002 - 506ms/epoch - 9ms/step
# Epoch 155/4000
# 54/54 - 1s - loss: 0.5028 - accuracy: 0.8967 - val_loss: 0.4991 - val_accuracy: 0.8998 - 506ms/epoch - 9ms/step
# Epoch 156/4000
# 54/54 - 1s - loss: 0.5014 - accuracy: 0.8966 - val_loss: 0.4924 - val_accuracy: 0.9012 - 510ms/epoch - 9ms/step
# Epoch 157/4000
# 54/54 - 1s - loss: 0.4995 - accuracy: 0.8970 - val_loss: 0.4934 - val_accuracy: 0.9014 - 508ms/epoch - 9ms/step
# Epoch 158/4000
# 54/54 - 1s - loss: 0.4981 - accuracy: 0.8968 - val_loss: 0.4936 - val_accuracy: 0.8938 - 507ms/epoch - 9ms/step
# Epoch 159/4000
# 54/54 - 1s - loss: 0.4970 - accuracy: 0.8968 - val_loss: 0.4954 - val_accuracy: 0.8996 - 503ms/epoch - 9ms/step
# Epoch 160/4000
# 54/54 - 1s - loss: 0.4957 - accuracy: 0.8972 - val_loss: 0.4925 - val_accuracy: 0.9008 - 507ms/epoch - 9ms/step
# Epoch 161/4000
# 54/54 - 1s - loss: 0.4949 - accuracy: 0.8968 - val_loss: 0.4839 - val_accuracy: 0.9008 - 506ms/epoch - 9ms/step
# Epoch 162/4000
# 54/54 - 1s - loss: 0.4935 - accuracy: 0.8979 - val_loss: 0.4879 - val_accuracy: 0.8998 - 504ms/epoch - 9ms/step
# Epoch 163/4000
# 54/54 - 1s - loss: 0.4922 - accuracy: 0.8981 - val_loss: 0.4843 - val_accuracy: 0.8988 - 508ms/epoch - 9ms/step
# Epoch 164/4000
# 54/54 - 1s - loss: 0.4908 - accuracy: 0.8981 - val_loss: 0.4836 - val_accuracy: 0.8970 - 511ms/epoch - 9ms/step
# Epoch 165/4000
# 54/54 - 1s - loss: 0.4895 - accuracy: 0.8984 - val_loss: 0.4830 - val_accuracy: 0.9004 - 511ms/epoch - 9ms/step
# Epoch 166/4000
# 54/54 - 1s - loss: 0.4888 - accuracy: 0.8975 - val_loss: 0.4899 - val_accuracy: 0.9010 - 510ms/epoch - 9ms/step
# Epoch 167/4000
# 54/54 - 1s - loss: 0.4873 - accuracy: 0.8980 - val_loss: 0.4810 - val_accuracy: 0.9002 - 515ms/epoch - 10ms/step
# Epoch 168/4000
# 54/54 - 1s - loss: 0.4856 - accuracy: 0.8982 - val_loss: 0.4801 - val_accuracy: 0.8994 - 509ms/epoch - 9ms/step
# Epoch 169/4000
# 54/54 - 1s - loss: 0.4847 - accuracy: 0.8983 - val_loss: 0.4804 - val_accuracy: 0.9006 - 507ms/epoch - 9ms/step
# Epoch 170/4000
# 54/54 - 0s - loss: 0.4836 - accuracy: 0.8982 - val_loss: 0.4836 - val_accuracy: 0.8982 - 498ms/epoch - 9ms/step
# Epoch 171/4000
# 54/54 - 1s - loss: 0.4819 - accuracy: 0.8987 - val_loss: 0.4773 - val_accuracy: 0.9012 - 507ms/epoch - 9ms/step
# Epoch 172/4000
# 54/54 - 1s - loss: 0.4813 - accuracy: 0.8984 - val_loss: 0.4805 - val_accuracy: 0.8962 - 506ms/epoch - 9ms/step
# Epoch 173/4000
# 54/54 - 1s - loss: 0.4796 - accuracy: 0.8983 - val_loss: 0.4745 - val_accuracy: 0.9006 - 507ms/epoch - 9ms/step
# Epoch 174/4000
# 54/54 - 1s - loss: 0.4786 - accuracy: 0.8994 - val_loss: 0.4742 - val_accuracy: 0.9004 - 509ms/epoch - 9ms/step
# Epoch 175/4000
# 54/54 - 1s - loss: 0.4773 - accuracy: 0.8987 - val_loss: 0.4711 - val_accuracy: 0.9044 - 509ms/epoch - 9ms/step
# Epoch 176/4000
# 54/54 - 1s - loss: 0.4764 - accuracy: 0.8983 - val_loss: 0.4714 - val_accuracy: 0.9016 - 509ms/epoch - 9ms/step
# Epoch 177/4000
# 54/54 - 1s - loss: 0.4749 - accuracy: 0.8990 - val_loss: 0.4686 - val_accuracy: 0.9020 - 509ms/epoch - 9ms/step
# Epoch 178/4000
# 54/54 - 1s - loss: 0.4742 - accuracy: 0.8990 - val_loss: 0.4720 - val_accuracy: 0.9008 - 506ms/epoch - 9ms/step
# Epoch 179/4000
# 54/54 - 1s - loss: 0.4728 - accuracy: 0.8992 - val_loss: 0.4720 - val_accuracy: 0.9004 - 505ms/epoch - 9ms/step
# Epoch 180/4000
# 54/54 - 1s - loss: 0.4714 - accuracy: 0.8995 - val_loss: 0.4649 - val_accuracy: 0.9016 - 510ms/epoch - 9ms/step
# Epoch 181/4000
# 54/54 - 1s - loss: 0.4703 - accuracy: 0.8997 - val_loss: 0.4674 - val_accuracy: 0.9022 - 503ms/epoch - 9ms/step
# Epoch 182/4000
# 54/54 - 1s - loss: 0.4693 - accuracy: 0.8997 - val_loss: 0.4615 - val_accuracy: 0.9000 - 505ms/epoch - 9ms/step
# Epoch 183/4000
# 54/54 - 1s - loss: 0.4685 - accuracy: 0.8995 - val_loss: 0.4655 - val_accuracy: 0.9014 - 509ms/epoch - 9ms/step
# Epoch 184/4000
# 54/54 - 1s - loss: 0.4673 - accuracy: 0.8992 - val_loss: 0.4654 - val_accuracy: 0.9012 - 506ms/epoch - 9ms/step
# Epoch 185/4000
# 54/54 - 1s - loss: 0.4664 - accuracy: 0.8998 - val_loss: 0.4557 - val_accuracy: 0.9026 - 507ms/epoch - 9ms/step
# Epoch 186/4000
# 54/54 - 1s - loss: 0.4650 - accuracy: 0.8996 - val_loss: 0.4578 - val_accuracy: 0.9030 - 505ms/epoch - 9ms/step
# Epoch 187/4000
# 54/54 - 1s - loss: 0.4640 - accuracy: 0.8995 - val_loss: 0.4592 - val_accuracy: 0.9010 - 506ms/epoch - 9ms/step
# Epoch 188/4000
# 54/54 - 1s - loss: 0.4631 - accuracy: 0.9001 - val_loss: 0.4523 - val_accuracy: 0.9014 - 510ms/epoch - 9ms/step
# Epoch 189/4000
# 54/54 - 1s - loss: 0.4615 - accuracy: 0.9003 - val_loss: 0.4541 - val_accuracy: 0.9026 - 504ms/epoch - 9ms/step
# Epoch 190/4000
# 54/54 - 1s - loss: 0.4603 - accuracy: 0.9008 - val_loss: 0.4572 - val_accuracy: 0.8978 - 506ms/epoch - 9ms/step
# Epoch 191/4000
# 54/54 - 1s - loss: 0.4595 - accuracy: 0.8998 - val_loss: 0.4583 - val_accuracy: 0.9006 - 504ms/epoch - 9ms/step
# Epoch 192/4000
# 54/54 - 1s - loss: 0.4582 - accuracy: 0.9002 - val_loss: 0.4556 - val_accuracy: 0.9022 - 502ms/epoch - 9ms/step
# Epoch 193/4000
# 54/54 - 1s - loss: 0.4576 - accuracy: 0.9009 - val_loss: 0.4518 - val_accuracy: 0.9012 - 506ms/epoch - 9ms/step
# Epoch 194/4000
# 54/54 - 1s - loss: 0.4568 - accuracy: 0.9002 - val_loss: 0.4500 - val_accuracy: 0.9054 - 509ms/epoch - 9ms/step
# Epoch 195/4000
# 54/54 - 1s - loss: 0.4550 - accuracy: 0.9008 - val_loss: 0.4535 - val_accuracy: 0.9024 - 505ms/epoch - 9ms/step
# Epoch 196/4000
# 54/54 - 1s - loss: 0.4543 - accuracy: 0.9011 - val_loss: 0.4534 - val_accuracy: 0.9034 - 506ms/epoch - 9ms/step
# Epoch 197/4000
# 54/54 - 1s - loss: 0.4538 - accuracy: 0.9005 - val_loss: 0.4463 - val_accuracy: 0.9014 - 509ms/epoch - 9ms/step
# Epoch 198/4000
# 54/54 - 1s - loss: 0.4524 - accuracy: 0.9011 - val_loss: 0.4426 - val_accuracy: 0.9016 - 508ms/epoch - 9ms/step
# Epoch 199/4000
# 54/54 - 1s - loss: 0.4516 - accuracy: 0.9013 - val_loss: 0.4472 - val_accuracy: 0.9038 - 507ms/epoch - 9ms/step
# Epoch 200/4000
# 54/54 - 1s - loss: 0.4506 - accuracy: 0.9015 - val_loss: 0.4519 - val_accuracy: 0.9010 - 505ms/epoch - 9ms/step
# Epoch 201/4000
# 54/54 - 1s - loss: 0.4496 - accuracy: 0.9007 - val_loss: 0.4497 - val_accuracy: 0.9006 - 503ms/epoch - 9ms/step
# Epoch 202/4000
# 54/54 - 1s - loss: 0.4482 - accuracy: 0.9016 - val_loss: 0.4431 - val_accuracy: 0.9014 - 506ms/epoch - 9ms/step
# Epoch 203/4000
# 54/54 - 1s - loss: 0.4471 - accuracy: 0.9020 - val_loss: 0.4480 - val_accuracy: 0.9016 - 504ms/epoch - 9ms/step
# Epoch 204/4000
# 54/54 - 1s - loss: 0.4466 - accuracy: 0.9023 - val_loss: 0.4394 - val_accuracy: 0.9060 - 507ms/epoch - 9ms/step
# Epoch 205/4000
# 54/54 - 1s - loss: 0.4463 - accuracy: 0.9015 - val_loss: 0.4424 - val_accuracy: 0.9016 - 508ms/epoch - 9ms/step
# Epoch 206/4000
# 54/54 - 1s - loss: 0.4452 - accuracy: 0.9021 - val_loss: 0.4419 - val_accuracy: 0.9014 - 504ms/epoch - 9ms/step
# Epoch 207/4000
# 54/54 - 1s - loss: 0.4438 - accuracy: 0.9013 - val_loss: 0.4373 - val_accuracy: 0.9066 - 507ms/epoch - 9ms/step
# Epoch 208/4000
# 54/54 - 1s - loss: 0.4430 - accuracy: 0.9022 - val_loss: 0.4351 - val_accuracy: 0.9054 - 506ms/epoch - 9ms/step
# Epoch 209/4000
# 54/54 - 1s - loss: 0.4417 - accuracy: 0.9020 - val_loss: 0.4370 - val_accuracy: 0.9036 - 514ms/epoch - 10ms/step
# Epoch 210/4000
# 54/54 - 1s - loss: 0.4412 - accuracy: 0.9019 - val_loss: 0.4455 - val_accuracy: 0.8990 - 512ms/epoch - 9ms/step
# Epoch 211/4000
# 54/54 - 1s - loss: 0.4404 - accuracy: 0.9028 - val_loss: 0.4338 - val_accuracy: 0.9050 - 507ms/epoch - 9ms/step
# Epoch 212/4000
# 54/54 - 1s - loss: 0.4388 - accuracy: 0.9020 - val_loss: 0.4371 - val_accuracy: 0.9030 - 506ms/epoch - 9ms/step
# Epoch 213/4000
# 54/54 - 1s - loss: 0.4380 - accuracy: 0.9031 - val_loss: 0.4378 - val_accuracy: 0.9030 - 507ms/epoch - 9ms/step
# Epoch 214/4000
# 54/54 - 1s - loss: 0.4369 - accuracy: 0.9027 - val_loss: 0.4314 - val_accuracy: 0.9040 - 508ms/epoch - 9ms/step
# Epoch 215/4000
# 54/54 - 1s - loss: 0.4364 - accuracy: 0.9022 - val_loss: 0.4311 - val_accuracy: 0.9058 - 509ms/epoch - 9ms/step
# Epoch 216/4000
# 54/54 - 1s - loss: 0.4353 - accuracy: 0.9027 - val_loss: 0.4319 - val_accuracy: 0.9044 - 506ms/epoch - 9ms/step
# Epoch 217/4000
# 54/54 - 1s - loss: 0.4344 - accuracy: 0.9033 - val_loss: 0.4295 - val_accuracy: 0.9046 - 510ms/epoch - 9ms/step
# Epoch 218/4000
# 54/54 - 1s - loss: 0.4336 - accuracy: 0.9035 - val_loss: 0.4284 - val_accuracy: 0.9062 - 507ms/epoch - 9ms/step
# Epoch 219/4000
# 54/54 - 1s - loss: 0.4327 - accuracy: 0.9031 - val_loss: 0.4274 - val_accuracy: 0.9034 - 507ms/epoch - 9ms/step
# Epoch 220/4000
# 54/54 - 1s - loss: 0.4322 - accuracy: 0.9037 - val_loss: 0.4297 - val_accuracy: 0.9030 - 507ms/epoch - 9ms/step
# Epoch 221/4000
# 54/54 - 1s - loss: 0.4311 - accuracy: 0.9025 - val_loss: 0.4270 - val_accuracy: 0.9026 - 508ms/epoch - 9ms/step
# Epoch 222/4000
# 54/54 - 1s - loss: 0.4302 - accuracy: 0.9032 - val_loss: 0.4272 - val_accuracy: 0.9026 - 507ms/epoch - 9ms/step
# Epoch 223/4000
# 54/54 - 1s - loss: 0.4293 - accuracy: 0.9033 - val_loss: 0.4227 - val_accuracy: 0.9058 - 507ms/epoch - 9ms/step
# Epoch 224/4000
# 54/54 - 1s - loss: 0.4286 - accuracy: 0.9033 - val_loss: 0.4243 - val_accuracy: 0.9040 - 502ms/epoch - 9ms/step
# Epoch 225/4000
# 54/54 - 1s - loss: 0.4275 - accuracy: 0.9042 - val_loss: 0.4224 - val_accuracy: 0.9054 - 510ms/epoch - 9ms/step
# Epoch 226/4000
# 54/54 - 1s - loss: 0.4270 - accuracy: 0.9039 - val_loss: 0.4256 - val_accuracy: 0.9060 - 506ms/epoch - 9ms/step
# Epoch 227/4000
# 54/54 - 1s - loss: 0.4258 - accuracy: 0.9033 - val_loss: 0.4209 - val_accuracy: 0.9048 - 507ms/epoch - 9ms/step
# Epoch 228/4000
# 54/54 - 1s - loss: 0.4257 - accuracy: 0.9039 - val_loss: 0.4250 - val_accuracy: 0.9046 - 506ms/epoch - 9ms/step
# Epoch 229/4000
# 54/54 - 1s - loss: 0.4241 - accuracy: 0.9039 - val_loss: 0.4223 - val_accuracy: 0.9026 - 507ms/epoch - 9ms/step
# Epoch 230/4000
# 54/54 - 1s - loss: 0.4236 - accuracy: 0.9041 - val_loss: 0.4194 - val_accuracy: 0.9054 - 511ms/epoch - 9ms/step
# Epoch 231/4000
# 54/54 - 1s - loss: 0.4226 - accuracy: 0.9048 - val_loss: 0.4162 - val_accuracy: 0.9052 - 508ms/epoch - 9ms/step
# Epoch 232/4000
# 54/54 - 1s - loss: 0.4220 - accuracy: 0.9042 - val_loss: 0.4194 - val_accuracy: 0.9042 - 504ms/epoch - 9ms/step
# Epoch 233/4000
# 54/54 - 1s - loss: 0.4212 - accuracy: 0.9046 - val_loss: 0.4201 - val_accuracy: 0.9052 - 508ms/epoch - 9ms/step
# Epoch 234/4000
# 54/54 - 1s - loss: 0.4201 - accuracy: 0.9046 - val_loss: 0.4206 - val_accuracy: 0.9036 - 512ms/epoch - 9ms/step
# Epoch 235/4000
# 54/54 - 1s - loss: 0.4201 - accuracy: 0.9039 - val_loss: 0.4203 - val_accuracy: 0.9024 - 510ms/epoch - 9ms/step
# Epoch 236/4000
# 54/54 - 1s - loss: 0.4187 - accuracy: 0.9049 - val_loss: 0.4157 - val_accuracy: 0.9060 - 514ms/epoch - 10ms/step
# Epoch 237/4000
# 54/54 - 1s - loss: 0.4185 - accuracy: 0.9042 - val_loss: 0.4157 - val_accuracy: 0.9072 - 515ms/epoch - 10ms/step
# Epoch 238/4000
# 54/54 - 1s - loss: 0.4175 - accuracy: 0.9044 - val_loss: 0.4135 - val_accuracy: 0.9052 - 513ms/epoch - 9ms/step
# Epoch 239/4000
# 54/54 - 1s - loss: 0.4167 - accuracy: 0.9045 - val_loss: 0.4143 - val_accuracy: 0.9066 - 512ms/epoch - 9ms/step
# Epoch 240/4000
# 54/54 - 1s - loss: 0.4159 - accuracy: 0.9046 - val_loss: 0.4157 - val_accuracy: 0.9036 - 509ms/epoch - 9ms/step
# Epoch 241/4000
# 54/54 - 1s - loss: 0.4153 - accuracy: 0.9051 - val_loss: 0.4094 - val_accuracy: 0.9070 - 509ms/epoch - 9ms/step
# Epoch 242/4000
# 54/54 - 1s - loss: 0.4142 - accuracy: 0.9050 - val_loss: 0.4108 - val_accuracy: 0.9082 - 508ms/epoch - 9ms/step
# Epoch 243/4000
# 54/54 - 1s - loss: 0.4133 - accuracy: 0.9057 - val_loss: 0.4119 - val_accuracy: 0.9070 - 512ms/epoch - 9ms/step
# Epoch 244/4000
# 54/54 - 1s - loss: 0.4130 - accuracy: 0.9050 - val_loss: 0.4066 - val_accuracy: 0.9058 - 512ms/epoch - 9ms/step
# Epoch 245/4000
# 54/54 - 1s - loss: 0.4125 - accuracy: 0.9048 - val_loss: 0.4129 - val_accuracy: 0.9054 - 510ms/epoch - 9ms/step
# Epoch 246/4000
# 54/54 - 1s - loss: 0.4110 - accuracy: 0.9052 - val_loss: 0.4117 - val_accuracy: 0.9028 - 509ms/epoch - 9ms/step
# Epoch 247/4000
# 54/54 - 1s - loss: 0.4104 - accuracy: 0.9055 - val_loss: 0.4072 - val_accuracy: 0.9072 - 510ms/epoch - 9ms/step
# Epoch 248/4000
# 54/54 - 1s - loss: 0.4102 - accuracy: 0.9049 - val_loss: 0.4094 - val_accuracy: 0.9084 - 509ms/epoch - 9ms/step
# Epoch 249/4000
# 54/54 - 1s - loss: 0.4094 - accuracy: 0.9053 - val_loss: 0.4040 - val_accuracy: 0.9108 - 511ms/epoch - 9ms/step
# Epoch 250/4000
# 54/54 - 1s - loss: 0.4089 - accuracy: 0.9055 - val_loss: 0.4051 - val_accuracy: 0.9056 - 510ms/epoch - 9ms/step
# Epoch 251/4000
# 54/54 - 1s - loss: 0.4083 - accuracy: 0.9055 - val_loss: 0.4053 - val_accuracy: 0.9092 - 509ms/epoch - 9ms/step
# Epoch 252/4000
# 54/54 - 1s - loss: 0.4072 - accuracy: 0.9059 - val_loss: 0.4057 - val_accuracy: 0.9074 - 511ms/epoch - 9ms/step
# Epoch 253/4000
# 54/54 - 1s - loss: 0.4064 - accuracy: 0.9055 - val_loss: 0.4026 - val_accuracy: 0.9092 - 514ms/epoch - 10ms/step
# Epoch 254/4000
# 54/54 - 1s - loss: 0.4064 - accuracy: 0.9057 - val_loss: 0.4028 - val_accuracy: 0.9068 - 511ms/epoch - 9ms/step
# Epoch 255/4000
# 54/54 - 1s - loss: 0.4046 - accuracy: 0.9060 - val_loss: 0.4045 - val_accuracy: 0.9050 - 511ms/epoch - 9ms/step
# Epoch 256/4000
# 54/54 - 1s - loss: 0.4049 - accuracy: 0.9062 - val_loss: 0.3998 - val_accuracy: 0.9062 - 512ms/epoch - 9ms/step
# Epoch 257/4000
# 54/54 - 1s - loss: 0.4038 - accuracy: 0.9062 - val_loss: 0.4052 - val_accuracy: 0.9048 - 507ms/epoch - 9ms/step
# Epoch 258/4000
# 54/54 - 1s - loss: 0.4029 - accuracy: 0.9056 - val_loss: 0.4006 - val_accuracy: 0.9088 - 511ms/epoch - 9ms/step
# Epoch 259/4000
# 54/54 - 1s - loss: 0.4026 - accuracy: 0.9060 - val_loss: 0.3993 - val_accuracy: 0.9058 - 514ms/epoch - 10ms/step
# Epoch 260/4000
# 54/54 - 1s - loss: 0.4013 - accuracy: 0.9071 - val_loss: 0.4044 - val_accuracy: 0.9046 - 512ms/epoch - 9ms/step
# Epoch 261/4000
# 54/54 - 1s - loss: 0.4009 - accuracy: 0.9065 - val_loss: 0.4013 - val_accuracy: 0.9060 - 507ms/epoch - 9ms/step
# Epoch 262/4000
# 54/54 - 1s - loss: 0.4001 - accuracy: 0.9072 - val_loss: 0.3937 - val_accuracy: 0.9096 - 515ms/epoch - 10ms/step
# Epoch 263/4000
# 54/54 - 1s - loss: 0.3998 - accuracy: 0.9065 - val_loss: 0.3991 - val_accuracy: 0.9040 - 516ms/epoch - 10ms/step
# Epoch 264/4000
# 54/54 - 1s - loss: 0.3989 - accuracy: 0.9070 - val_loss: 0.3941 - val_accuracy: 0.9106 - 512ms/epoch - 9ms/step
# Epoch 265/4000
# 54/54 - 1s - loss: 0.3992 - accuracy: 0.9058 - val_loss: 0.3987 - val_accuracy: 0.9060 - 508ms/epoch - 9ms/step
# Epoch 266/4000
# 54/54 - 1s - loss: 0.3985 - accuracy: 0.9066 - val_loss: 0.3930 - val_accuracy: 0.9086 - 506ms/epoch - 9ms/step
# Epoch 267/4000
# 54/54 - 1s - loss: 0.3976 - accuracy: 0.9063 - val_loss: 0.4004 - val_accuracy: 0.9066 - 514ms/epoch - 10ms/step
# Epoch 268/4000
# 54/54 - 1s - loss: 0.3967 - accuracy: 0.9064 - val_loss: 0.3955 - val_accuracy: 0.9078 - 516ms/epoch - 10ms/step
# Epoch 269/4000
# 54/54 - 1s - loss: 0.3955 - accuracy: 0.9067 - val_loss: 0.3916 - val_accuracy: 0.9072 - 521ms/epoch - 10ms/step
# Epoch 270/4000
# 54/54 - 1s - loss: 0.3954 - accuracy: 0.9070 - val_loss: 0.3960 - val_accuracy: 0.9058 - 510ms/epoch - 9ms/step
# Epoch 271/4000
# 54/54 - 1s - loss: 0.3948 - accuracy: 0.9073 - val_loss: 0.3905 - val_accuracy: 0.9080 - 514ms/epoch - 10ms/step
# Epoch 272/4000
# 54/54 - 1s - loss: 0.3946 - accuracy: 0.9070 - val_loss: 0.3928 - val_accuracy: 0.9052 - 511ms/epoch - 9ms/step
# Epoch 273/4000
# 54/54 - 1s - loss: 0.3931 - accuracy: 0.9072 - val_loss: 0.3888 - val_accuracy: 0.9078 - 514ms/epoch - 10ms/step
# Epoch 274/4000
# 54/54 - 1s - loss: 0.3927 - accuracy: 0.9074 - val_loss: 0.3909 - val_accuracy: 0.9084 - 512ms/epoch - 9ms/step
# Epoch 275/4000
# 54/54 - 1s - loss: 0.3921 - accuracy: 0.9072 - val_loss: 0.3873 - val_accuracy: 0.9118 - 517ms/epoch - 10ms/step
# Epoch 276/4000
# 54/54 - 1s - loss: 0.3915 - accuracy: 0.9077 - val_loss: 0.3900 - val_accuracy: 0.9056 - 508ms/epoch - 9ms/step
# Epoch 277/4000
# 54/54 - 1s - loss: 0.3913 - accuracy: 0.9075 - val_loss: 0.3901 - val_accuracy: 0.9058 - 511ms/epoch - 9ms/step
# Epoch 278/4000
# 54/54 - 1s - loss: 0.3911 - accuracy: 0.9073 - val_loss: 0.3873 - val_accuracy: 0.9080 - 507ms/epoch - 9ms/step
# Epoch 279/4000
# 54/54 - 1s - loss: 0.3896 - accuracy: 0.9086 - val_loss: 0.3879 - val_accuracy: 0.9088 - 513ms/epoch - 9ms/step
# Epoch 280/4000
# 54/54 - 1s - loss: 0.3890 - accuracy: 0.9074 - val_loss: 0.3874 - val_accuracy: 0.9072 - 512ms/epoch - 9ms/step
# Epoch 281/4000
# 54/54 - 1s - loss: 0.3890 - accuracy: 0.9079 - val_loss: 0.3898 - val_accuracy: 0.9092 - 515ms/epoch - 10ms/step
# Epoch 282/4000
# 54/54 - 1s - loss: 0.3879 - accuracy: 0.9078 - val_loss: 0.3868 - val_accuracy: 0.9082 - 518ms/epoch - 10ms/step
# Epoch 283/4000
# 54/54 - 1s - loss: 0.3875 - accuracy: 0.9077 - val_loss: 0.3830 - val_accuracy: 0.9116 - 512ms/epoch - 9ms/step
# Epoch 284/4000
# 54/54 - 1s - loss: 0.3867 - accuracy: 0.9077 - val_loss: 0.3841 - val_accuracy: 0.9100 - 517ms/epoch - 10ms/step
# Epoch 285/4000
# 54/54 - 1s - loss: 0.3869 - accuracy: 0.9077 - val_loss: 0.3877 - val_accuracy: 0.9082 - 513ms/epoch - 9ms/step
# Epoch 286/4000
# 54/54 - 1s - loss: 0.3861 - accuracy: 0.9076 - val_loss: 0.3877 - val_accuracy: 0.9062 - 515ms/epoch - 10ms/step
# Epoch 287/4000
# 54/54 - 1s - loss: 0.3850 - accuracy: 0.9085 - val_loss: 0.3818 - val_accuracy: 0.9094 - 509ms/epoch - 9ms/step
# Epoch 288/4000
# 54/54 - 1s - loss: 0.3848 - accuracy: 0.9090 - val_loss: 0.3822 - val_accuracy: 0.9094 - 513ms/epoch - 9ms/step
# Epoch 289/4000
# 54/54 - 1s - loss: 0.3845 - accuracy: 0.9082 - val_loss: 0.3825 - val_accuracy: 0.9072 - 511ms/epoch - 9ms/step
# Epoch 290/4000
# 54/54 - 1s - loss: 0.3835 - accuracy: 0.9089 - val_loss: 0.3830 - val_accuracy: 0.9076 - 509ms/epoch - 9ms/step
# Epoch 291/4000
# 54/54 - 1s - loss: 0.3829 - accuracy: 0.9084 - val_loss: 0.3799 - val_accuracy: 0.9100 - 510ms/epoch - 9ms/step
# Epoch 292/4000
# 54/54 - 1s - loss: 0.3830 - accuracy: 0.9087 - val_loss: 0.3829 - val_accuracy: 0.9060 - 512ms/epoch - 9ms/step
# Epoch 293/4000
# 54/54 - 1s - loss: 0.3821 - accuracy: 0.9084 - val_loss: 0.3850 - val_accuracy: 0.9060 - 512ms/epoch - 9ms/step
# Epoch 294/4000
# 54/54 - 1s - loss: 0.3815 - accuracy: 0.9091 - val_loss: 0.3821 - val_accuracy: 0.9100 - 510ms/epoch - 9ms/step
# Epoch 295/4000
# 54/54 - 1s - loss: 0.3811 - accuracy: 0.9082 - val_loss: 0.3826 - val_accuracy: 0.9098 - 511ms/epoch - 9ms/step
# Epoch 296/4000
# 54/54 - 1s - loss: 0.3807 - accuracy: 0.9083 - val_loss: 0.3856 - val_accuracy: 0.9074 - 510ms/epoch - 9ms/step
# Epoch 297/4000
# 54/54 - 1s - loss: 0.3800 - accuracy: 0.9091 - val_loss: 0.3743 - val_accuracy: 0.9110 - 515ms/epoch - 10ms/step
# Epoch 298/4000
# 54/54 - 1s - loss: 0.3792 - accuracy: 0.9086 - val_loss: 0.3808 - val_accuracy: 0.9064 - 511ms/epoch - 9ms/step
# Epoch 299/4000
# 54/54 - 1s - loss: 0.3794 - accuracy: 0.9081 - val_loss: 0.3836 - val_accuracy: 0.9066 - 510ms/epoch - 9ms/step
# Epoch 300/4000
# 54/54 - 1s - loss: 0.3783 - accuracy: 0.9092 - val_loss: 0.3729 - val_accuracy: 0.9136 - 516ms/epoch - 10ms/step
# Epoch 301/4000
# 54/54 - 1s - loss: 0.3780 - accuracy: 0.9090 - val_loss: 0.3773 - val_accuracy: 0.9096 - 515ms/epoch - 10ms/step
# Epoch 302/4000
# 54/54 - 1s - loss: 0.3773 - accuracy: 0.9088 - val_loss: 0.3747 - val_accuracy: 0.9092 - 509ms/epoch - 9ms/step
# Epoch 303/4000
# 54/54 - 1s - loss: 0.3766 - accuracy: 0.9089 - val_loss: 0.3746 - val_accuracy: 0.9072 - 507ms/epoch - 9ms/step
# Epoch 304/4000
# 54/54 - 1s - loss: 0.3762 - accuracy: 0.9091 - val_loss: 0.3841 - val_accuracy: 0.9056 - 510ms/epoch - 9ms/step
# Epoch 305/4000
# 54/54 - 1s - loss: 0.3762 - accuracy: 0.9097 - val_loss: 0.3731 - val_accuracy: 0.9086 - 512ms/epoch - 9ms/step
# Epoch 306/4000
# 54/54 - 1s - loss: 0.3749 - accuracy: 0.9096 - val_loss: 0.3749 - val_accuracy: 0.9076 - 510ms/epoch - 9ms/step
# Epoch 307/4000
# 54/54 - 1s - loss: 0.3754 - accuracy: 0.9084 - val_loss: 0.3747 - val_accuracy: 0.9086 - 509ms/epoch - 9ms/step
# Epoch 308/4000
# 54/54 - 1s - loss: 0.3746 - accuracy: 0.9085 - val_loss: 0.3786 - val_accuracy: 0.9092 - 511ms/epoch - 9ms/step
# Epoch 309/4000
# 54/54 - 1s - loss: 0.3733 - accuracy: 0.9097 - val_loss: 0.3741 - val_accuracy: 0.9084 - 508ms/epoch - 9ms/step
# Epoch 310/4000
# 54/54 - 1s - loss: 0.3731 - accuracy: 0.9101 - val_loss: 0.3739 - val_accuracy: 0.9088 - 512ms/epoch - 9ms/step
# 313/313 - 1s - loss: 0.3577 - accuracy: 0.9135 - 596ms/epoch - 2ms/step
# Test loss: 0.358
# Test accuracy: 91.350%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 20)        520
#
#  average_pooling2d (AverageP  (None, 12, 12, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 50)          25050
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 10)          8010
#
#  batch_normalization (BatchN  (None, 1, 1, 10)         40
#  ormalization)
#
#  square_activation (SquareAc  (None, 1, 1, 10)         0
#  tivation)
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 33,620
# Trainable params: 33,600
# Non-trainable params: 20
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 54/54 - 1s - loss: 0.3293 - accuracy: 0.9112 - val_loss: 0.3273 - val_accuracy: 0.9080 - 1s/epoch - 23ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.3206 - accuracy: 0.9131 - val_loss: 0.3209 - val_accuracy: 0.9116 - 514ms/epoch - 10ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.3177 - accuracy: 0.9136 - val_loss: 0.3221 - val_accuracy: 0.9138 - 513ms/epoch - 10ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.3158 - accuracy: 0.9145 - val_loss: 0.3234 - val_accuracy: 0.9126 - 508ms/epoch - 9ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.3160 - accuracy: 0.9142 - val_loss: 0.3228 - val_accuracy: 0.9108 - 508ms/epoch - 9ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.3139 - accuracy: 0.9146 - val_loss: 0.3182 - val_accuracy: 0.9100 - 511ms/epoch - 9ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.3140 - accuracy: 0.9154 - val_loss: 0.3139 - val_accuracy: 0.9150 - 516ms/epoch - 10ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.3135 - accuracy: 0.9149 - val_loss: 0.3141 - val_accuracy: 0.9136 - 510ms/epoch - 9ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.3120 - accuracy: 0.9161 - val_loss: 0.3193 - val_accuracy: 0.9120 - 507ms/epoch - 9ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.3120 - accuracy: 0.9153 - val_loss: 0.3146 - val_accuracy: 0.9120 - 508ms/epoch - 9ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.3114 - accuracy: 0.9156 - val_loss: 0.3212 - val_accuracy: 0.9132 - 509ms/epoch - 9ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.3117 - accuracy: 0.9155 - val_loss: 0.3092 - val_accuracy: 0.9140 - 511ms/epoch - 9ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.3114 - accuracy: 0.9156 - val_loss: 0.3106 - val_accuracy: 0.9140 - 509ms/epoch - 9ms/step
# Epoch 14/4000
# 54/54 - 1s - loss: 0.3110 - accuracy: 0.9163 - val_loss: 0.3085 - val_accuracy: 0.9150 - 512ms/epoch - 9ms/step
# Epoch 15/4000
# 54/54 - 1s - loss: 0.3108 - accuracy: 0.9166 - val_loss: 0.3132 - val_accuracy: 0.9126 - 509ms/epoch - 9ms/step
# Epoch 16/4000
# 54/54 - 1s - loss: 0.3095 - accuracy: 0.9157 - val_loss: 0.3129 - val_accuracy: 0.9144 - 513ms/epoch - 9ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.3097 - accuracy: 0.9161 - val_loss: 0.3130 - val_accuracy: 0.9144 - 508ms/epoch - 9ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.3099 - accuracy: 0.9163 - val_loss: 0.3118 - val_accuracy: 0.9150 - 508ms/epoch - 9ms/step
# Epoch 19/4000
# 54/54 - 1s - loss: 0.3089 - accuracy: 0.9165 - val_loss: 0.3092 - val_accuracy: 0.9140 - 510ms/epoch - 9ms/step
# Epoch 20/4000
# 54/54 - 1s - loss: 0.3084 - accuracy: 0.9166 - val_loss: 0.3096 - val_accuracy: 0.9140 - 511ms/epoch - 9ms/step
# Epoch 21/4000
# 54/54 - 1s - loss: 0.3086 - accuracy: 0.9163 - val_loss: 0.3097 - val_accuracy: 0.9146 - 510ms/epoch - 9ms/step
# Epoch 22/4000
# 54/54 - 1s - loss: 0.3082 - accuracy: 0.9174 - val_loss: 0.3085 - val_accuracy: 0.9154 - 517ms/epoch - 10ms/step
# Epoch 23/4000
# 54/54 - 1s - loss: 0.3082 - accuracy: 0.9165 - val_loss: 0.3114 - val_accuracy: 0.9154 - 508ms/epoch - 9ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.3079 - accuracy: 0.9176 - val_loss: 0.3082 - val_accuracy: 0.9150 - 514ms/epoch - 10ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.3076 - accuracy: 0.9166 - val_loss: 0.3088 - val_accuracy: 0.9150 - 514ms/epoch - 10ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.3069 - accuracy: 0.9168 - val_loss: 0.3151 - val_accuracy: 0.9140 - 512ms/epoch - 9ms/step
# Epoch 27/4000
# 54/54 - 1s - loss: 0.3064 - accuracy: 0.9167 - val_loss: 0.3088 - val_accuracy: 0.9156 - 514ms/epoch - 10ms/step
# Epoch 28/4000
# 54/54 - 1s - loss: 0.3060 - accuracy: 0.9173 - val_loss: 0.3084 - val_accuracy: 0.9164 - 511ms/epoch - 9ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.3058 - accuracy: 0.9172 - val_loss: 0.3130 - val_accuracy: 0.9140 - 509ms/epoch - 9ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.3068 - accuracy: 0.9171 - val_loss: 0.3022 - val_accuracy: 0.9170 - 512ms/epoch - 9ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.3055 - accuracy: 0.9181 - val_loss: 0.3028 - val_accuracy: 0.9176 - 516ms/epoch - 10ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.3061 - accuracy: 0.9179 - val_loss: 0.3019 - val_accuracy: 0.9174 - 510ms/epoch - 9ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.3050 - accuracy: 0.9169 - val_loss: 0.3078 - val_accuracy: 0.9172 - 510ms/epoch - 9ms/step
# Epoch 34/4000
# 54/54 - 1s - loss: 0.3052 - accuracy: 0.9178 - val_loss: 0.3119 - val_accuracy: 0.9158 - 512ms/epoch - 9ms/step
# Epoch 35/4000
# 54/54 - 1s - loss: 0.3055 - accuracy: 0.9172 - val_loss: 0.3116 - val_accuracy: 0.9134 - 513ms/epoch - 9ms/step
# Epoch 36/4000
# 54/54 - 1s - loss: 0.3055 - accuracy: 0.9168 - val_loss: 0.3089 - val_accuracy: 0.9166 - 510ms/epoch - 9ms/step
# Epoch 37/4000
# 54/54 - 1s - loss: 0.3040 - accuracy: 0.9188 - val_loss: 0.3092 - val_accuracy: 0.9150 - 514ms/epoch - 10ms/step
# Epoch 38/4000
# 54/54 - 1s - loss: 0.3044 - accuracy: 0.9175 - val_loss: 0.3066 - val_accuracy: 0.9182 - 509ms/epoch - 9ms/step
# Epoch 39/4000
# 54/54 - 1s - loss: 0.3046 - accuracy: 0.9173 - val_loss: 0.3110 - val_accuracy: 0.9140 - 507ms/epoch - 9ms/step
# Epoch 40/4000
# 54/54 - 1s - loss: 0.3041 - accuracy: 0.9171 - val_loss: 0.3097 - val_accuracy: 0.9130 - 507ms/epoch - 9ms/step
# Epoch 41/4000
# 54/54 - 1s - loss: 0.3045 - accuracy: 0.9175 - val_loss: 0.3037 - val_accuracy: 0.9172 - 512ms/epoch - 9ms/step
# Epoch 42/4000
# 54/54 - 1s - loss: 0.3030 - accuracy: 0.9182 - val_loss: 0.3064 - val_accuracy: 0.9154 - 517ms/epoch - 10ms/step
# 313/313 - 1s - loss: 0.2901 - accuracy: 0.9197 - 557ms/epoch - 2ms/step
# Test loss: 0.290
# Test accuracy: 91.970%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model826.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model826.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
