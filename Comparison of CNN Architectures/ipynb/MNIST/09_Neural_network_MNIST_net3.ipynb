# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-05-17 09:01:44.123139: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# # 对图像进行裁剪，以适应新的形状 (24, 24, 1)
# x_train = x_train[:, 2:26, 2:26]
# x_test = x_test[:, 2:26, 2:26]

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

x_train /= 255
x_test /= 255
print('data ready')
# Out:
# data ready

# %%
# Create validation data
# testSize=16
# testSize=500
testSize=10000
x_val = x_test[:-testSize]
x_test = x_test[-testSize:]
y_val = y_test[:-testSize]
y_test = y_test[-testSize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test3')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test3 of shape (10000, 28, 28, 1) in data/net_mnist/x_test3.h5
# Saving x_train of shape (60000, 28, 28, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (0, 28, 28, 1) in data/net_mnist/x_val.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D, Reshape,AveragePooling2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
# 创建模型

model = Sequential()

model = Sequential()

# 1. 卷积层：输入28x28，输出5通道13x13
model.add(Conv2D(filters=5, kernel_size=(5,5), strides=(2,2), 
                padding='same', input_shape=(28,28,1)))

# 2. 平方激活层
model.add(SquareActivation())
model.add()

# 3. 缩放均值池化层
model.add(AveragePooling2D(pool_size=(3,3), strides=1, padding='same'))

# 4. 卷积层：输出50通道5x5
model.add(Conv2D(filters=50, kernel_size=(5,5), strides=(2,2), 
                padding='valid'))

# 5. 缩放均值池化层
model.add(AveragePooling2D(pool_size=(3,3), strides=1, padding='same'))

# 6. 调整通道数至10（对应分类数）
model.add(Conv2D(filters=10, kernel_size=(1, 1), padding='same'))

# 7. 非全局平均池化层：将5x5特征图压缩为1x1（每个通道取均值）
model.add(AveragePooling2D(pool_size=(5, 5), strides=1, padding='valid'))

# 8. 展平并输出
model.add(Flatten())


# 输出模型架构

model.summary()
# Out:
# 2025-05-17 01:35:58.872437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 14, 5)         130
#
#  square_activation (SquareAc  (None, 14, 14, 5)        0
#  tivation)
#
#  average_pooling2d (AverageP  (None, 14, 14, 5)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 50)          6300
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 10)          510
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 6,940
# Trainable params: 6,940
# Non-trainable params: 0
# _________________________________________________________________
# 2025-05-17 01:35:58.993693: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:35:58.996536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:35:59.001442: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-17 01:35:59.003042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:35:59.005774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:35:59.008326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:36:00.945262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:36:00.947357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:36:00.949153: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-17 01:36:00.950844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### 第一阶段

# %%
epochs = 4000
# epochs = 3000
# epochs = 200
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              verbose=2,
            #   validation_data=(x_val, y_val),
              shuffle=True,
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 2025-05-17 01:36:05.801400: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 59/59 - 6s - loss: 2.2974 - accuracy: 0.1028 - 6s/epoch - 94ms/step
# Epoch 2/4000
# 59/59 - 0s - loss: 2.2848 - accuracy: 0.1003 - 232ms/epoch - 4ms/step
# Epoch 3/4000
# 59/59 - 0s - loss: 2.2641 - accuracy: 0.1111 - 230ms/epoch - 4ms/step
# Epoch 4/4000
# 59/59 - 0s - loss: 2.2275 - accuracy: 0.1732 - 229ms/epoch - 4ms/step
# Epoch 5/4000
# 59/59 - 0s - loss: 2.1673 - accuracy: 0.2608 - 231ms/epoch - 4ms/step
# Epoch 6/4000
# 59/59 - 0s - loss: 2.0850 - accuracy: 0.2813 - 233ms/epoch - 4ms/step
# Epoch 7/4000
# 59/59 - 0s - loss: 1.9937 - accuracy: 0.3066 - 232ms/epoch - 4ms/step
# Epoch 8/4000
# 59/59 - 0s - loss: 1.9067 - accuracy: 0.3300 - 231ms/epoch - 4ms/step
# Epoch 9/4000
# 59/59 - 0s - loss: 1.8303 - accuracy: 0.3670 - 231ms/epoch - 4ms/step
# Epoch 10/4000
# 59/59 - 0s - loss: 1.7644 - accuracy: 0.3897 - 232ms/epoch - 4ms/step
# Epoch 11/4000
# 59/59 - 0s - loss: 1.7069 - accuracy: 0.4205 - 229ms/epoch - 4ms/step
# Epoch 12/4000
# 59/59 - 0s - loss: 1.6562 - accuracy: 0.4407 - 227ms/epoch - 4ms/step
# Epoch 13/4000
# 59/59 - 0s - loss: 1.6093 - accuracy: 0.4658 - 231ms/epoch - 4ms/step
# Epoch 14/4000
# 59/59 - 0s - loss: 1.5657 - accuracy: 0.4878 - 231ms/epoch - 4ms/step
# Epoch 15/4000
# 59/59 - 0s - loss: 1.5247 - accuracy: 0.5091 - 229ms/epoch - 4ms/step
# Epoch 16/4000
# 59/59 - 0s - loss: 1.4849 - accuracy: 0.5265 - 232ms/epoch - 4ms/step
# Epoch 17/4000
# 59/59 - 0s - loss: 1.4467 - accuracy: 0.5423 - 228ms/epoch - 4ms/step
# Epoch 18/4000
# 59/59 - 0s - loss: 1.4105 - accuracy: 0.5575 - 230ms/epoch - 4ms/step
# Epoch 19/4000
# 59/59 - 0s - loss: 1.3751 - accuracy: 0.5689 - 231ms/epoch - 4ms/step
# Epoch 20/4000
# 59/59 - 0s - loss: 1.3412 - accuracy: 0.5821 - 231ms/epoch - 4ms/step
# Epoch 21/4000
# 59/59 - 0s - loss: 1.3087 - accuracy: 0.5948 - 230ms/epoch - 4ms/step
# Epoch 22/4000
# 59/59 - 0s - loss: 1.2772 - accuracy: 0.6060 - 231ms/epoch - 4ms/step
# Epoch 23/4000
# 59/59 - 0s - loss: 1.2472 - accuracy: 0.6174 - 229ms/epoch - 4ms/step
# Epoch 24/4000
# 59/59 - 0s - loss: 1.2184 - accuracy: 0.6263 - 234ms/epoch - 4ms/step
# Epoch 25/4000
# 59/59 - 0s - loss: 1.1906 - accuracy: 0.6371 - 230ms/epoch - 4ms/step
# Epoch 26/4000
# 59/59 - 0s - loss: 1.1641 - accuracy: 0.6467 - 230ms/epoch - 4ms/step
# Epoch 27/4000
# 59/59 - 0s - loss: 1.1388 - accuracy: 0.6553 - 233ms/epoch - 4ms/step
# Epoch 28/4000
# 59/59 - 0s - loss: 1.1146 - accuracy: 0.6630 - 231ms/epoch - 4ms/step
# Epoch 29/4000
# 59/59 - 0s - loss: 1.0913 - accuracy: 0.6707 - 231ms/epoch - 4ms/step
# Epoch 30/4000
# 59/59 - 0s - loss: 1.0697 - accuracy: 0.6768 - 229ms/epoch - 4ms/step
# Epoch 31/4000
# 59/59 - 0s - loss: 1.0483 - accuracy: 0.6856 - 230ms/epoch - 4ms/step
# Epoch 32/4000
# 59/59 - 0s - loss: 1.0282 - accuracy: 0.6919 - 229ms/epoch - 4ms/step
# Epoch 33/4000
# 59/59 - 0s - loss: 1.0089 - accuracy: 0.6987 - 231ms/epoch - 4ms/step
# Epoch 34/4000
# 59/59 - 0s - loss: 0.9910 - accuracy: 0.7046 - 232ms/epoch - 4ms/step
# Epoch 35/4000
# 59/59 - 0s - loss: 0.9734 - accuracy: 0.7103 - 234ms/epoch - 4ms/step
# Epoch 36/4000
# 59/59 - 0s - loss: 0.9570 - accuracy: 0.7146 - 232ms/epoch - 4ms/step
# Epoch 37/4000
# 59/59 - 0s - loss: 0.9405 - accuracy: 0.7207 - 230ms/epoch - 4ms/step
# Epoch 38/4000
# 59/59 - 0s - loss: 0.9253 - accuracy: 0.7238 - 232ms/epoch - 4ms/step
# Epoch 39/4000
# 59/59 - 0s - loss: 0.9106 - accuracy: 0.7277 - 233ms/epoch - 4ms/step
# Epoch 40/4000
# 59/59 - 0s - loss: 0.8965 - accuracy: 0.7317 - 233ms/epoch - 4ms/step
# Epoch 41/4000
# 59/59 - 0s - loss: 0.8828 - accuracy: 0.7359 - 230ms/epoch - 4ms/step
# Epoch 42/4000
# 59/59 - 0s - loss: 0.8699 - accuracy: 0.7399 - 231ms/epoch - 4ms/step
# Epoch 43/4000
# 59/59 - 0s - loss: 0.8577 - accuracy: 0.7433 - 230ms/epoch - 4ms/step
# Epoch 44/4000
# 59/59 - 0s - loss: 0.8456 - accuracy: 0.7478 - 230ms/epoch - 4ms/step
# Epoch 45/4000
# 59/59 - 0s - loss: 0.8343 - accuracy: 0.7498 - 230ms/epoch - 4ms/step
# Epoch 46/4000
# 59/59 - 0s - loss: 0.8235 - accuracy: 0.7531 - 231ms/epoch - 4ms/step
# Epoch 47/4000
# 59/59 - 0s - loss: 0.8122 - accuracy: 0.7573 - 233ms/epoch - 4ms/step
# Epoch 48/4000
# 59/59 - 0s - loss: 0.8019 - accuracy: 0.7597 - 228ms/epoch - 4ms/step
# Epoch 49/4000
# 59/59 - 0s - loss: 0.7925 - accuracy: 0.7623 - 234ms/epoch - 4ms/step
# Epoch 50/4000
# 59/59 - 0s - loss: 0.7829 - accuracy: 0.7661 - 231ms/epoch - 4ms/step
# Epoch 51/4000
# 59/59 - 0s - loss: 0.7732 - accuracy: 0.7676 - 229ms/epoch - 4ms/step
# Epoch 52/4000
# 59/59 - 0s - loss: 0.7646 - accuracy: 0.7707 - 232ms/epoch - 4ms/step
# Epoch 53/4000
# 59/59 - 0s - loss: 0.7560 - accuracy: 0.7728 - 231ms/epoch - 4ms/step
# Epoch 54/4000
# 59/59 - 0s - loss: 0.7472 - accuracy: 0.7757 - 233ms/epoch - 4ms/step
# Epoch 55/4000
# 59/59 - 0s - loss: 0.7390 - accuracy: 0.7781 - 233ms/epoch - 4ms/step
# Epoch 56/4000
# 59/59 - 0s - loss: 0.7314 - accuracy: 0.7804 - 232ms/epoch - 4ms/step
# Epoch 57/4000
# 59/59 - 0s - loss: 0.7235 - accuracy: 0.7830 - 230ms/epoch - 4ms/step
# Epoch 58/4000
# 59/59 - 0s - loss: 0.7160 - accuracy: 0.7856 - 233ms/epoch - 4ms/step
# Epoch 59/4000
# 59/59 - 0s - loss: 0.7087 - accuracy: 0.7872 - 230ms/epoch - 4ms/step
# Epoch 60/4000
# 59/59 - 0s - loss: 0.7017 - accuracy: 0.7901 - 232ms/epoch - 4ms/step
# Epoch 61/4000
# 59/59 - 0s - loss: 0.6949 - accuracy: 0.7920 - 231ms/epoch - 4ms/step
# Epoch 62/4000
# 59/59 - 0s - loss: 0.6891 - accuracy: 0.7929 - 231ms/epoch - 4ms/step
# Epoch 63/4000
# 59/59 - 0s - loss: 0.6814 - accuracy: 0.7958 - 229ms/epoch - 4ms/step
# Epoch 64/4000
# 59/59 - 0s - loss: 0.6752 - accuracy: 0.7983 - 229ms/epoch - 4ms/step
# Epoch 65/4000
# 59/59 - 0s - loss: 0.6687 - accuracy: 0.7997 - 233ms/epoch - 4ms/step
# Epoch 66/4000
# 59/59 - 0s - loss: 0.6634 - accuracy: 0.8020 - 230ms/epoch - 4ms/step
# Epoch 67/4000
# 59/59 - 0s - loss: 0.6575 - accuracy: 0.8033 - 234ms/epoch - 4ms/step
# Epoch 68/4000
# 59/59 - 0s - loss: 0.6513 - accuracy: 0.8050 - 232ms/epoch - 4ms/step
# Epoch 69/4000
# 59/59 - 0s - loss: 0.6455 - accuracy: 0.8078 - 230ms/epoch - 4ms/step
# Epoch 70/4000
# 59/59 - 0s - loss: 0.6401 - accuracy: 0.8092 - 231ms/epoch - 4ms/step
# Epoch 71/4000
# 59/59 - 0s - loss: 0.6346 - accuracy: 0.8112 - 235ms/epoch - 4ms/step
# Epoch 72/4000
# 59/59 - 0s - loss: 0.6303 - accuracy: 0.8134 - 232ms/epoch - 4ms/step
# Epoch 73/4000
# 59/59 - 0s - loss: 0.6255 - accuracy: 0.8128 - 230ms/epoch - 4ms/step
# Epoch 74/4000
# 59/59 - 0s - loss: 0.6200 - accuracy: 0.8156 - 231ms/epoch - 4ms/step
# Epoch 75/4000
# 59/59 - 0s - loss: 0.6151 - accuracy: 0.8163 - 233ms/epoch - 4ms/step
# Epoch 76/4000
# 59/59 - 0s - loss: 0.6106 - accuracy: 0.8180 - 232ms/epoch - 4ms/step
# Epoch 77/4000
# 59/59 - 0s - loss: 0.6063 - accuracy: 0.8194 - 234ms/epoch - 4ms/step
# Epoch 78/4000
# 59/59 - 0s - loss: 0.6014 - accuracy: 0.8213 - 231ms/epoch - 4ms/step
# Epoch 79/4000
# 59/59 - 0s - loss: 0.5977 - accuracy: 0.8221 - 233ms/epoch - 4ms/step
# Epoch 80/4000
# 59/59 - 0s - loss: 0.5940 - accuracy: 0.8235 - 232ms/epoch - 4ms/step
# Epoch 81/4000
# 59/59 - 0s - loss: 0.5894 - accuracy: 0.8250 - 233ms/epoch - 4ms/step
# Epoch 82/4000
# 59/59 - 0s - loss: 0.5852 - accuracy: 0.8270 - 229ms/epoch - 4ms/step
# Epoch 83/4000
# 59/59 - 0s - loss: 0.5812 - accuracy: 0.8278 - 232ms/epoch - 4ms/step
# Epoch 84/4000
# 59/59 - 0s - loss: 0.5778 - accuracy: 0.8288 - 231ms/epoch - 4ms/step
# Epoch 85/4000
# 59/59 - 0s - loss: 0.5753 - accuracy: 0.8303 - 231ms/epoch - 4ms/step
# Epoch 86/4000
# 59/59 - 0s - loss: 0.5705 - accuracy: 0.8318 - 232ms/epoch - 4ms/step
# Epoch 87/4000
# 59/59 - 0s - loss: 0.5666 - accuracy: 0.8333 - 229ms/epoch - 4ms/step
# Epoch 88/4000
# 59/59 - 0s - loss: 0.5635 - accuracy: 0.8339 - 233ms/epoch - 4ms/step
# Epoch 89/4000
# 59/59 - 0s - loss: 0.5603 - accuracy: 0.8354 - 231ms/epoch - 4ms/step
# Epoch 90/4000
# 59/59 - 0s - loss: 0.5576 - accuracy: 0.8364 - 232ms/epoch - 4ms/step
# Epoch 91/4000
# 59/59 - 0s - loss: 0.5548 - accuracy: 0.8370 - 229ms/epoch - 4ms/step
# Epoch 92/4000
# 59/59 - 0s - loss: 0.5508 - accuracy: 0.8386 - 235ms/epoch - 4ms/step
# Epoch 93/4000
# 59/59 - 0s - loss: 0.5475 - accuracy: 0.8398 - 234ms/epoch - 4ms/step
# Epoch 94/4000
# 59/59 - 0s - loss: 0.5446 - accuracy: 0.8409 - 234ms/epoch - 4ms/step
# Epoch 95/4000
# 59/59 - 0s - loss: 0.5415 - accuracy: 0.8410 - 230ms/epoch - 4ms/step
# Epoch 96/4000
# 59/59 - 0s - loss: 0.5391 - accuracy: 0.8426 - 232ms/epoch - 4ms/step
# Epoch 97/4000
# 59/59 - 0s - loss: 0.5366 - accuracy: 0.8433 - 235ms/epoch - 4ms/step
# Epoch 98/4000
# 59/59 - 0s - loss: 0.5337 - accuracy: 0.8444 - 232ms/epoch - 4ms/step
# Epoch 99/4000
# 59/59 - 0s - loss: 0.5306 - accuracy: 0.8447 - 235ms/epoch - 4ms/step
# Epoch 100/4000
# 59/59 - 0s - loss: 0.5287 - accuracy: 0.8453 - 234ms/epoch - 4ms/step
# Epoch 101/4000
# 59/59 - 0s - loss: 0.5256 - accuracy: 0.8466 - 231ms/epoch - 4ms/step
# Epoch 102/4000
# 59/59 - 0s - loss: 0.5230 - accuracy: 0.8469 - 230ms/epoch - 4ms/step
# Epoch 103/4000
# 59/59 - 0s - loss: 0.5216 - accuracy: 0.8479 - 233ms/epoch - 4ms/step
# Epoch 104/4000
# 59/59 - 0s - loss: 0.5184 - accuracy: 0.8486 - 230ms/epoch - 4ms/step
# Epoch 105/4000
# 59/59 - 0s - loss: 0.5155 - accuracy: 0.8500 - 231ms/epoch - 4ms/step
# Epoch 106/4000
# 59/59 - 0s - loss: 0.5136 - accuracy: 0.8506 - 234ms/epoch - 4ms/step
# Epoch 107/4000
# 59/59 - 0s - loss: 0.5118 - accuracy: 0.8508 - 231ms/epoch - 4ms/step
# Epoch 108/4000
# 59/59 - 0s - loss: 0.5099 - accuracy: 0.8519 - 234ms/epoch - 4ms/step
# Epoch 109/4000
# 59/59 - 0s - loss: 0.5082 - accuracy: 0.8522 - 232ms/epoch - 4ms/step
# Epoch 110/4000
# 59/59 - 0s - loss: 0.5059 - accuracy: 0.8528 - 231ms/epoch - 4ms/step
# Epoch 111/4000
# 59/59 - 0s - loss: 0.5041 - accuracy: 0.8538 - 232ms/epoch - 4ms/step
# Epoch 112/4000
# 59/59 - 0s - loss: 0.5006 - accuracy: 0.8551 - 231ms/epoch - 4ms/step
# Epoch 113/4000
# 59/59 - 0s - loss: 0.4995 - accuracy: 0.8554 - 231ms/epoch - 4ms/step
# Epoch 114/4000
# 59/59 - 0s - loss: 0.4977 - accuracy: 0.8553 - 264ms/epoch - 4ms/step
# Epoch 115/4000
# 59/59 - 0s - loss: 0.4955 - accuracy: 0.8565 - 235ms/epoch - 4ms/step
# Epoch 116/4000
# 59/59 - 0s - loss: 0.4942 - accuracy: 0.8570 - 233ms/epoch - 4ms/step
# Epoch 117/4000
# 59/59 - 0s - loss: 0.4920 - accuracy: 0.8571 - 241ms/epoch - 4ms/step
# Epoch 118/4000
# 59/59 - 0s - loss: 0.4903 - accuracy: 0.8579 - 232ms/epoch - 4ms/step
# Epoch 119/4000
# 59/59 - 0s - loss: 0.4885 - accuracy: 0.8590 - 231ms/epoch - 4ms/step
# Epoch 120/4000
# 59/59 - 0s - loss: 0.4866 - accuracy: 0.8589 - 249ms/epoch - 4ms/step
# Epoch 121/4000
# 59/59 - 0s - loss: 0.4848 - accuracy: 0.8596 - 230ms/epoch - 4ms/step
# Epoch 122/4000
# 59/59 - 0s - loss: 0.4822 - accuracy: 0.8610 - 234ms/epoch - 4ms/step
# Epoch 123/4000
# 59/59 - 0s - loss: 0.4814 - accuracy: 0.8609 - 230ms/epoch - 4ms/step
# Epoch 124/4000
# 59/59 - 0s - loss: 0.4791 - accuracy: 0.8617 - 231ms/epoch - 4ms/step
# Epoch 125/4000
# 59/59 - 0s - loss: 0.4779 - accuracy: 0.8613 - 230ms/epoch - 4ms/step
# Epoch 126/4000
# 59/59 - 0s - loss: 0.4773 - accuracy: 0.8621 - 231ms/epoch - 4ms/step
# Epoch 127/4000
# 59/59 - 0s - loss: 0.4758 - accuracy: 0.8624 - 232ms/epoch - 4ms/step
# Epoch 128/4000
# 59/59 - 0s - loss: 0.4737 - accuracy: 0.8632 - 230ms/epoch - 4ms/step
# Epoch 129/4000
# 59/59 - 0s - loss: 0.4718 - accuracy: 0.8631 - 229ms/epoch - 4ms/step
# Epoch 130/4000
# 59/59 - 0s - loss: 0.4702 - accuracy: 0.8643 - 230ms/epoch - 4ms/step
# Epoch 131/4000
# 59/59 - 0s - loss: 0.4687 - accuracy: 0.8643 - 233ms/epoch - 4ms/step
# Epoch 132/4000
# 59/59 - 0s - loss: 0.4677 - accuracy: 0.8651 - 231ms/epoch - 4ms/step
# Epoch 133/4000
# 59/59 - 0s - loss: 0.4658 - accuracy: 0.8654 - 232ms/epoch - 4ms/step
# Epoch 134/4000
# 59/59 - 0s - loss: 0.4644 - accuracy: 0.8658 - 232ms/epoch - 4ms/step
# Epoch 135/4000
# 59/59 - 0s - loss: 0.4642 - accuracy: 0.8657 - 238ms/epoch - 4ms/step
# Epoch 136/4000
# 59/59 - 0s - loss: 0.4616 - accuracy: 0.8666 - 231ms/epoch - 4ms/step
# Epoch 137/4000
# 59/59 - 0s - loss: 0.4604 - accuracy: 0.8669 - 232ms/epoch - 4ms/step
# Epoch 138/4000
# 59/59 - 0s - loss: 0.4593 - accuracy: 0.8671 - 231ms/epoch - 4ms/step
# Epoch 139/4000
# 59/59 - 0s - loss: 0.4582 - accuracy: 0.8683 - 234ms/epoch - 4ms/step
# Epoch 140/4000
# 59/59 - 0s - loss: 0.4568 - accuracy: 0.8682 - 233ms/epoch - 4ms/step
# Epoch 141/4000
# 59/59 - 0s - loss: 0.4550 - accuracy: 0.8695 - 231ms/epoch - 4ms/step
# Epoch 142/4000
# 59/59 - 0s - loss: 0.4540 - accuracy: 0.8695 - 232ms/epoch - 4ms/step
# Epoch 143/4000
# 59/59 - 0s - loss: 0.4534 - accuracy: 0.8691 - 233ms/epoch - 4ms/step
# Epoch 144/4000
# 59/59 - 0s - loss: 0.4518 - accuracy: 0.8691 - 234ms/epoch - 4ms/step
# Epoch 145/4000
# 59/59 - 0s - loss: 0.4507 - accuracy: 0.8704 - 232ms/epoch - 4ms/step
# Epoch 146/4000
# 59/59 - 0s - loss: 0.4491 - accuracy: 0.8705 - 232ms/epoch - 4ms/step
# Epoch 147/4000
# 59/59 - 0s - loss: 0.4483 - accuracy: 0.8706 - 230ms/epoch - 4ms/step
# Epoch 148/4000
# 59/59 - 0s - loss: 0.4474 - accuracy: 0.8712 - 233ms/epoch - 4ms/step
# Epoch 149/4000
# 59/59 - 0s - loss: 0.4452 - accuracy: 0.8708 - 228ms/epoch - 4ms/step
# Epoch 150/4000
# 59/59 - 0s - loss: 0.4439 - accuracy: 0.8721 - 232ms/epoch - 4ms/step
# Epoch 151/4000
# 59/59 - 0s - loss: 0.4434 - accuracy: 0.8719 - 229ms/epoch - 4ms/step
# Epoch 152/4000
# 59/59 - 0s - loss: 0.4419 - accuracy: 0.8724 - 231ms/epoch - 4ms/step
# Epoch 153/4000
# 59/59 - 0s - loss: 0.4403 - accuracy: 0.8729 - 229ms/epoch - 4ms/step
# Epoch 154/4000
# 59/59 - 0s - loss: 0.4400 - accuracy: 0.8734 - 234ms/epoch - 4ms/step
# Epoch 155/4000
# 59/59 - 0s - loss: 0.4391 - accuracy: 0.8734 - 234ms/epoch - 4ms/step
# Epoch 156/4000
# 59/59 - 0s - loss: 0.4377 - accuracy: 0.8741 - 233ms/epoch - 4ms/step
# Epoch 157/4000
# 59/59 - 0s - loss: 0.4365 - accuracy: 0.8742 - 234ms/epoch - 4ms/step
# Epoch 158/4000
# 59/59 - 0s - loss: 0.4358 - accuracy: 0.8740 - 232ms/epoch - 4ms/step
# Epoch 159/4000
# 59/59 - 0s - loss: 0.4345 - accuracy: 0.8750 - 234ms/epoch - 4ms/step
# Epoch 160/4000
# 59/59 - 0s - loss: 0.4331 - accuracy: 0.8751 - 234ms/epoch - 4ms/step
# Epoch 161/4000
# 59/59 - 0s - loss: 0.4335 - accuracy: 0.8752 - 231ms/epoch - 4ms/step
# Epoch 162/4000
# 59/59 - 0s - loss: 0.4307 - accuracy: 0.8760 - 233ms/epoch - 4ms/step
# Epoch 163/4000
# 59/59 - 0s - loss: 0.4299 - accuracy: 0.8768 - 231ms/epoch - 4ms/step
# Epoch 164/4000
# 59/59 - 0s - loss: 0.4302 - accuracy: 0.8762 - 231ms/epoch - 4ms/step
# Epoch 165/4000
# 59/59 - 0s - loss: 0.4287 - accuracy: 0.8772 - 233ms/epoch - 4ms/step
# Epoch 166/4000
# 59/59 - 0s - loss: 0.4281 - accuracy: 0.8774 - 232ms/epoch - 4ms/step
# Epoch 167/4000
# 59/59 - 0s - loss: 0.4259 - accuracy: 0.8777 - 232ms/epoch - 4ms/step
# Epoch 168/4000
# 59/59 - 0s - loss: 0.4247 - accuracy: 0.8773 - 233ms/epoch - 4ms/step
# Epoch 169/4000
# 59/59 - 0s - loss: 0.4246 - accuracy: 0.8778 - 233ms/epoch - 4ms/step
# Epoch 170/4000
# 59/59 - 0s - loss: 0.4232 - accuracy: 0.8782 - 230ms/epoch - 4ms/step
# Epoch 171/4000
# 59/59 - 0s - loss: 0.4224 - accuracy: 0.8787 - 231ms/epoch - 4ms/step
# Epoch 172/4000
# 59/59 - 0s - loss: 0.4220 - accuracy: 0.8790 - 233ms/epoch - 4ms/step
# Epoch 173/4000
# 59/59 - 0s - loss: 0.4219 - accuracy: 0.8781 - 232ms/epoch - 4ms/step
# Epoch 174/4000
# 59/59 - 0s - loss: 0.4204 - accuracy: 0.8789 - 231ms/epoch - 4ms/step
# Epoch 175/4000
# 59/59 - 0s - loss: 0.4195 - accuracy: 0.8791 - 232ms/epoch - 4ms/step
# Epoch 176/4000
# 59/59 - 0s - loss: 0.4178 - accuracy: 0.8796 - 232ms/epoch - 4ms/step
# Epoch 177/4000
# 59/59 - 0s - loss: 0.4168 - accuracy: 0.8801 - 232ms/epoch - 4ms/step
# Epoch 178/4000
# 59/59 - 0s - loss: 0.4162 - accuracy: 0.8803 - 236ms/epoch - 4ms/step
# Epoch 179/4000
# 59/59 - 0s - loss: 0.4158 - accuracy: 0.8813 - 231ms/epoch - 4ms/step
# Epoch 180/4000
# 59/59 - 0s - loss: 0.4143 - accuracy: 0.8807 - 233ms/epoch - 4ms/step
# Epoch 181/4000
# 59/59 - 0s - loss: 0.4137 - accuracy: 0.8813 - 231ms/epoch - 4ms/step
# Epoch 182/4000
# 59/59 - 0s - loss: 0.4121 - accuracy: 0.8821 - 234ms/epoch - 4ms/step
# Epoch 183/4000
# 59/59 - 0s - loss: 0.4120 - accuracy: 0.8810 - 234ms/epoch - 4ms/step
# Epoch 184/4000
# 59/59 - 0s - loss: 0.4111 - accuracy: 0.8820 - 232ms/epoch - 4ms/step
# Epoch 185/4000
# 59/59 - 0s - loss: 0.4101 - accuracy: 0.8825 - 231ms/epoch - 4ms/step
# Epoch 186/4000
# 59/59 - 0s - loss: 0.4098 - accuracy: 0.8820 - 233ms/epoch - 4ms/step
# Epoch 187/4000
# 59/59 - 0s - loss: 0.4087 - accuracy: 0.8827 - 236ms/epoch - 4ms/step
# Epoch 188/4000
# 59/59 - 0s - loss: 0.4070 - accuracy: 0.8837 - 230ms/epoch - 4ms/step
# Epoch 189/4000
# 59/59 - 0s - loss: 0.4067 - accuracy: 0.8833 - 233ms/epoch - 4ms/step
# Epoch 190/4000
# 59/59 - 0s - loss: 0.4054 - accuracy: 0.8835 - 231ms/epoch - 4ms/step
# Epoch 191/4000
# 59/59 - 0s - loss: 0.4066 - accuracy: 0.8839 - 233ms/epoch - 4ms/step
# Epoch 192/4000
# 59/59 - 0s - loss: 0.4049 - accuracy: 0.8839 - 231ms/epoch - 4ms/step
# Epoch 193/4000
# 59/59 - 0s - loss: 0.4033 - accuracy: 0.8847 - 232ms/epoch - 4ms/step
# Epoch 194/4000
# 59/59 - 0s - loss: 0.4021 - accuracy: 0.8855 - 237ms/epoch - 4ms/step
# Epoch 195/4000
# 59/59 - 0s - loss: 0.4016 - accuracy: 0.8850 - 232ms/epoch - 4ms/step
# Epoch 196/4000
# 59/59 - 0s - loss: 0.4005 - accuracy: 0.8851 - 231ms/epoch - 4ms/step
# Epoch 197/4000
# 59/59 - 0s - loss: 0.3998 - accuracy: 0.8861 - 233ms/epoch - 4ms/step
# Epoch 198/4000
# 59/59 - 0s - loss: 0.4000 - accuracy: 0.8855 - 231ms/epoch - 4ms/step
# Epoch 199/4000
# 59/59 - 0s - loss: 0.3991 - accuracy: 0.8859 - 233ms/epoch - 4ms/step
# Epoch 200/4000
# 59/59 - 0s - loss: 0.3984 - accuracy: 0.8860 - 233ms/epoch - 4ms/step
# Epoch 201/4000
# 59/59 - 0s - loss: 0.3972 - accuracy: 0.8865 - 235ms/epoch - 4ms/step
# Epoch 202/4000
# 59/59 - 0s - loss: 0.3971 - accuracy: 0.8864 - 230ms/epoch - 4ms/step
# Epoch 203/4000
# 59/59 - 0s - loss: 0.3967 - accuracy: 0.8866 - 233ms/epoch - 4ms/step
# Epoch 204/4000
# 59/59 - 0s - loss: 0.3945 - accuracy: 0.8871 - 233ms/epoch - 4ms/step
# Epoch 205/4000
# 59/59 - 0s - loss: 0.3946 - accuracy: 0.8874 - 233ms/epoch - 4ms/step
# Epoch 206/4000
# 59/59 - 0s - loss: 0.3937 - accuracy: 0.8876 - 232ms/epoch - 4ms/step
# Epoch 207/4000
# 59/59 - 0s - loss: 0.3928 - accuracy: 0.8877 - 234ms/epoch - 4ms/step
# Epoch 208/4000
# 59/59 - 0s - loss: 0.3923 - accuracy: 0.8883 - 235ms/epoch - 4ms/step
# Epoch 209/4000
# 59/59 - 0s - loss: 0.3915 - accuracy: 0.8881 - 232ms/epoch - 4ms/step
# Epoch 210/4000
# 59/59 - 0s - loss: 0.3908 - accuracy: 0.8878 - 232ms/epoch - 4ms/step
# Epoch 211/4000
# 59/59 - 0s - loss: 0.3905 - accuracy: 0.8883 - 234ms/epoch - 4ms/step
# Epoch 212/4000
# 59/59 - 0s - loss: 0.3903 - accuracy: 0.8888 - 233ms/epoch - 4ms/step
# Epoch 213/4000
# 59/59 - 0s - loss: 0.3894 - accuracy: 0.8891 - 233ms/epoch - 4ms/step
# Epoch 214/4000
# 59/59 - 0s - loss: 0.3883 - accuracy: 0.8892 - 231ms/epoch - 4ms/step
# Epoch 215/4000
# 59/59 - 0s - loss: 0.3876 - accuracy: 0.8900 - 229ms/epoch - 4ms/step
# Epoch 216/4000
# 59/59 - 0s - loss: 0.3861 - accuracy: 0.8899 - 231ms/epoch - 4ms/step
# Epoch 217/4000
# 59/59 - 0s - loss: 0.3862 - accuracy: 0.8903 - 233ms/epoch - 4ms/step
# Epoch 218/4000
# 59/59 - 0s - loss: 0.3856 - accuracy: 0.8899 - 231ms/epoch - 4ms/step
# Epoch 219/4000
# 59/59 - 0s - loss: 0.3854 - accuracy: 0.8896 - 232ms/epoch - 4ms/step
# Epoch 220/4000
# 59/59 - 0s - loss: 0.3846 - accuracy: 0.8901 - 236ms/epoch - 4ms/step
# Epoch 221/4000
# 59/59 - 0s - loss: 0.3826 - accuracy: 0.8906 - 232ms/epoch - 4ms/step
# Epoch 222/4000
# 59/59 - 0s - loss: 0.3827 - accuracy: 0.8911 - 235ms/epoch - 4ms/step
# Epoch 223/4000
# 59/59 - 0s - loss: 0.3815 - accuracy: 0.8910 - 231ms/epoch - 4ms/step
# Epoch 224/4000
# 59/59 - 0s - loss: 0.3813 - accuracy: 0.8911 - 232ms/epoch - 4ms/step
# Epoch 225/4000
# 59/59 - 0s - loss: 0.3805 - accuracy: 0.8915 - 233ms/epoch - 4ms/step
# Epoch 226/4000
# 59/59 - 0s - loss: 0.3792 - accuracy: 0.8925 - 235ms/epoch - 4ms/step
# Epoch 227/4000
# 59/59 - 0s - loss: 0.3792 - accuracy: 0.8923 - 233ms/epoch - 4ms/step
# Epoch 228/4000
# 59/59 - 0s - loss: 0.3782 - accuracy: 0.8924 - 235ms/epoch - 4ms/step
# Epoch 229/4000
# 59/59 - 0s - loss: 0.3782 - accuracy: 0.8913 - 235ms/epoch - 4ms/step
# Epoch 230/4000
# 59/59 - 0s - loss: 0.3771 - accuracy: 0.8928 - 233ms/epoch - 4ms/step
# Epoch 231/4000
# 59/59 - 0s - loss: 0.3771 - accuracy: 0.8928 - 234ms/epoch - 4ms/step
# Epoch 232/4000
# 59/59 - 0s - loss: 0.3764 - accuracy: 0.8927 - 231ms/epoch - 4ms/step
# Epoch 233/4000
# 59/59 - 0s - loss: 0.3754 - accuracy: 0.8932 - 232ms/epoch - 4ms/step
# Epoch 234/4000
# 59/59 - 0s - loss: 0.3750 - accuracy: 0.8924 - 233ms/epoch - 4ms/step
# Epoch 235/4000
# 59/59 - 0s - loss: 0.3734 - accuracy: 0.8936 - 233ms/epoch - 4ms/step
# Epoch 236/4000
# 59/59 - 0s - loss: 0.3738 - accuracy: 0.8938 - 237ms/epoch - 4ms/step
# Epoch 237/4000
# 59/59 - 0s - loss: 0.3724 - accuracy: 0.8937 - 235ms/epoch - 4ms/step
# Epoch 238/4000
# 59/59 - 0s - loss: 0.3727 - accuracy: 0.8938 - 234ms/epoch - 4ms/step
# Epoch 239/4000
# 59/59 - 0s - loss: 0.3719 - accuracy: 0.8941 - 233ms/epoch - 4ms/step
# Epoch 240/4000
# 59/59 - 0s - loss: 0.3708 - accuracy: 0.8942 - 234ms/epoch - 4ms/step
# Epoch 241/4000
# 59/59 - 0s - loss: 0.3706 - accuracy: 0.8940 - 234ms/epoch - 4ms/step
# Epoch 242/4000
# 59/59 - 0s - loss: 0.3703 - accuracy: 0.8945 - 232ms/epoch - 4ms/step
# Epoch 243/4000
# 59/59 - 0s - loss: 0.3694 - accuracy: 0.8948 - 233ms/epoch - 4ms/step
# Epoch 244/4000
# 59/59 - 0s - loss: 0.3690 - accuracy: 0.8946 - 233ms/epoch - 4ms/step
# Epoch 245/4000
# 59/59 - 0s - loss: 0.3679 - accuracy: 0.8955 - 237ms/epoch - 4ms/step
# Epoch 246/4000
# 59/59 - 0s - loss: 0.3674 - accuracy: 0.8950 - 235ms/epoch - 4ms/step
# Epoch 247/4000
# 59/59 - 0s - loss: 0.3665 - accuracy: 0.8954 - 233ms/epoch - 4ms/step
# Epoch 248/4000
# 59/59 - 0s - loss: 0.3662 - accuracy: 0.8956 - 234ms/epoch - 4ms/step
# Epoch 249/4000
# 59/59 - 0s - loss: 0.3656 - accuracy: 0.8957 - 236ms/epoch - 4ms/step
# Epoch 250/4000
# 59/59 - 0s - loss: 0.3654 - accuracy: 0.8954 - 234ms/epoch - 4ms/step
# Epoch 251/4000
# 59/59 - 0s - loss: 0.3648 - accuracy: 0.8953 - 232ms/epoch - 4ms/step
# Epoch 252/4000
# 59/59 - 0s - loss: 0.3642 - accuracy: 0.8962 - 232ms/epoch - 4ms/step
# Epoch 253/4000
# 59/59 - 0s - loss: 0.3635 - accuracy: 0.8964 - 230ms/epoch - 4ms/step
# Epoch 254/4000
# 59/59 - 0s - loss: 0.3626 - accuracy: 0.8966 - 234ms/epoch - 4ms/step
# Epoch 255/4000
# 59/59 - 0s - loss: 0.3625 - accuracy: 0.8970 - 233ms/epoch - 4ms/step
# Epoch 256/4000
# 59/59 - 0s - loss: 0.3613 - accuracy: 0.8961 - 235ms/epoch - 4ms/step
# Epoch 257/4000
# 59/59 - 0s - loss: 0.3607 - accuracy: 0.8977 - 233ms/epoch - 4ms/step
# Epoch 258/4000
# 59/59 - 0s - loss: 0.3609 - accuracy: 0.8977 - 232ms/epoch - 4ms/step
# Epoch 259/4000
# 59/59 - 0s - loss: 0.3603 - accuracy: 0.8969 - 234ms/epoch - 4ms/step
# Epoch 260/4000
# 59/59 - 0s - loss: 0.3596 - accuracy: 0.8978 - 231ms/epoch - 4ms/step
# Epoch 261/4000
# 59/59 - 0s - loss: 0.3598 - accuracy: 0.8974 - 233ms/epoch - 4ms/step
# Epoch 262/4000
# 59/59 - 0s - loss: 0.3585 - accuracy: 0.8983 - 234ms/epoch - 4ms/step
# Epoch 263/4000
# 59/59 - 0s - loss: 0.3569 - accuracy: 0.8984 - 236ms/epoch - 4ms/step
# Epoch 264/4000
# 59/59 - 0s - loss: 0.3570 - accuracy: 0.8984 - 232ms/epoch - 4ms/step
# Epoch 265/4000
# 59/59 - 0s - loss: 0.3573 - accuracy: 0.8984 - 237ms/epoch - 4ms/step
# Epoch 266/4000
# 59/59 - 0s - loss: 0.3568 - accuracy: 0.8979 - 232ms/epoch - 4ms/step
# Epoch 267/4000
# 59/59 - 0s - loss: 0.3553 - accuracy: 0.8989 - 232ms/epoch - 4ms/step
# Epoch 268/4000
# 59/59 - 0s - loss: 0.3551 - accuracy: 0.8994 - 231ms/epoch - 4ms/step
# Epoch 269/4000
# 59/59 - 0s - loss: 0.3543 - accuracy: 0.8990 - 233ms/epoch - 4ms/step
# Epoch 270/4000
# 59/59 - 0s - loss: 0.3538 - accuracy: 0.8993 - 234ms/epoch - 4ms/step
# Epoch 271/4000
# 59/59 - 0s - loss: 0.3539 - accuracy: 0.8986 - 234ms/epoch - 4ms/step
# Epoch 272/4000
# 59/59 - 0s - loss: 0.3536 - accuracy: 0.8997 - 231ms/epoch - 4ms/step
# Epoch 273/4000
# 59/59 - 0s - loss: 0.3522 - accuracy: 0.8999 - 235ms/epoch - 4ms/step
# Epoch 274/4000
# 59/59 - 0s - loss: 0.3526 - accuracy: 0.9001 - 235ms/epoch - 4ms/step
# Epoch 275/4000
# 59/59 - 0s - loss: 0.3520 - accuracy: 0.8998 - 232ms/epoch - 4ms/step
# Epoch 276/4000
# 59/59 - 0s - loss: 0.3505 - accuracy: 0.9004 - 235ms/epoch - 4ms/step
# Epoch 277/4000
# 59/59 - 0s - loss: 0.3500 - accuracy: 0.9003 - 233ms/epoch - 4ms/step
# Epoch 278/4000
# 59/59 - 0s - loss: 0.3500 - accuracy: 0.9000 - 230ms/epoch - 4ms/step
# Epoch 279/4000
# 59/59 - 0s - loss: 0.3494 - accuracy: 0.9002 - 233ms/epoch - 4ms/step
# Epoch 280/4000
# 59/59 - 0s - loss: 0.3491 - accuracy: 0.9006 - 231ms/epoch - 4ms/step
# Epoch 281/4000
# 59/59 - 0s - loss: 0.3503 - accuracy: 0.8998 - 232ms/epoch - 4ms/step
# Epoch 282/4000
# 59/59 - 0s - loss: 0.3483 - accuracy: 0.9003 - 234ms/epoch - 4ms/step
# Epoch 283/4000
# 59/59 - 0s - loss: 0.3465 - accuracy: 0.9015 - 236ms/epoch - 4ms/step
# Epoch 284/4000
# 59/59 - 0s - loss: 0.3478 - accuracy: 0.9012 - 237ms/epoch - 4ms/step
# Epoch 285/4000
# 59/59 - 0s - loss: 0.3468 - accuracy: 0.9011 - 233ms/epoch - 4ms/step
# Epoch 286/4000
# 59/59 - 0s - loss: 0.3459 - accuracy: 0.9022 - 235ms/epoch - 4ms/step
# Epoch 287/4000
# 59/59 - 0s - loss: 0.3449 - accuracy: 0.9022 - 233ms/epoch - 4ms/step
# Epoch 288/4000
# 59/59 - 0s - loss: 0.3458 - accuracy: 0.9019 - 235ms/epoch - 4ms/step
# Epoch 289/4000
# 59/59 - 0s - loss: 0.3460 - accuracy: 0.9018 - 233ms/epoch - 4ms/step
# Epoch 290/4000
# 59/59 - 0s - loss: 0.3436 - accuracy: 0.9025 - 235ms/epoch - 4ms/step
# Epoch 291/4000
# 59/59 - 0s - loss: 0.3438 - accuracy: 0.9021 - 234ms/epoch - 4ms/step
# Epoch 292/4000
# 59/59 - 0s - loss: 0.3424 - accuracy: 0.9025 - 235ms/epoch - 4ms/step
# Epoch 293/4000
# 59/59 - 0s - loss: 0.3419 - accuracy: 0.9026 - 236ms/epoch - 4ms/step
# Epoch 294/4000
# 59/59 - 0s - loss: 0.3421 - accuracy: 0.9029 - 234ms/epoch - 4ms/step
# Epoch 295/4000
# 59/59 - 0s - loss: 0.3430 - accuracy: 0.9028 - 234ms/epoch - 4ms/step
# Epoch 296/4000
# 59/59 - 0s - loss: 0.3402 - accuracy: 0.9032 - 238ms/epoch - 4ms/step
# Epoch 297/4000
# 59/59 - 0s - loss: 0.3412 - accuracy: 0.9031 - 233ms/epoch - 4ms/step
# Epoch 298/4000
# 59/59 - 0s - loss: 0.3396 - accuracy: 0.9036 - 233ms/epoch - 4ms/step
# Epoch 299/4000
# 59/59 - 0s - loss: 0.3398 - accuracy: 0.9031 - 233ms/epoch - 4ms/step
# Epoch 300/4000
# 59/59 - 0s - loss: 0.3400 - accuracy: 0.9025 - 233ms/epoch - 4ms/step
# Epoch 301/4000
# 59/59 - 0s - loss: 0.3380 - accuracy: 0.9032 - 232ms/epoch - 4ms/step
# Epoch 302/4000
# 59/59 - 0s - loss: 0.3380 - accuracy: 0.9031 - 233ms/epoch - 4ms/step
# Epoch 303/4000
# 59/59 - 0s - loss: 0.3385 - accuracy: 0.9039 - 234ms/epoch - 4ms/step
# Epoch 304/4000
# 59/59 - 0s - loss: 0.3377 - accuracy: 0.9039 - 237ms/epoch - 4ms/step
# Epoch 305/4000
# 59/59 - 0s - loss: 0.3364 - accuracy: 0.9043 - 237ms/epoch - 4ms/step
# Epoch 306/4000
# 59/59 - 0s - loss: 0.3368 - accuracy: 0.9037 - 234ms/epoch - 4ms/step
# Epoch 307/4000
# 59/59 - 0s - loss: 0.3366 - accuracy: 0.9042 - 237ms/epoch - 4ms/step
# Epoch 308/4000
# 59/59 - 0s - loss: 0.3362 - accuracy: 0.9039 - 233ms/epoch - 4ms/step
# Epoch 309/4000
# 59/59 - 0s - loss: 0.3360 - accuracy: 0.9042 - 234ms/epoch - 4ms/step
# Epoch 310/4000
# 59/59 - 0s - loss: 0.3342 - accuracy: 0.9044 - 235ms/epoch - 4ms/step
# Epoch 311/4000
# 59/59 - 0s - loss: 0.3351 - accuracy: 0.9038 - 236ms/epoch - 4ms/step
# Epoch 312/4000
# 59/59 - 0s - loss: 0.3346 - accuracy: 0.9050 - 234ms/epoch - 4ms/step
# Epoch 313/4000
# 59/59 - 0s - loss: 0.3335 - accuracy: 0.9051 - 234ms/epoch - 4ms/step
# Epoch 314/4000
# 59/59 - 0s - loss: 0.3330 - accuracy: 0.9053 - 234ms/epoch - 4ms/step
# Epoch 315/4000
# 59/59 - 0s - loss: 0.3321 - accuracy: 0.9056 - 232ms/epoch - 4ms/step
# Epoch 316/4000
# 59/59 - 0s - loss: 0.3320 - accuracy: 0.9056 - 234ms/epoch - 4ms/step
# Epoch 317/4000
# 59/59 - 0s - loss: 0.3317 - accuracy: 0.9052 - 233ms/epoch - 4ms/step
# Epoch 318/4000
# 59/59 - 0s - loss: 0.3324 - accuracy: 0.9053 - 233ms/epoch - 4ms/step
# Epoch 319/4000
# 59/59 - 0s - loss: 0.3314 - accuracy: 0.9056 - 234ms/epoch - 4ms/step
# Epoch 320/4000
# 59/59 - 0s - loss: 0.3316 - accuracy: 0.9065 - 235ms/epoch - 4ms/step
# Epoch 321/4000
# 59/59 - 0s - loss: 0.3309 - accuracy: 0.9056 - 233ms/epoch - 4ms/step
# Epoch 322/4000
# 59/59 - 0s - loss: 0.3292 - accuracy: 0.9062 - 233ms/epoch - 4ms/step
# Epoch 323/4000
# 59/59 - 0s - loss: 0.3291 - accuracy: 0.9063 - 235ms/epoch - 4ms/step
# Epoch 324/4000
# 59/59 - 0s - loss: 0.3289 - accuracy: 0.9059 - 233ms/epoch - 4ms/step
# Epoch 325/4000
# 59/59 - 0s - loss: 0.3281 - accuracy: 0.9070 - 232ms/epoch - 4ms/step
# Epoch 326/4000
# 59/59 - 0s - loss: 0.3286 - accuracy: 0.9066 - 237ms/epoch - 4ms/step
# Epoch 327/4000
# 59/59 - 0s - loss: 0.3272 - accuracy: 0.9072 - 232ms/epoch - 4ms/step
# Epoch 328/4000
# 59/59 - 0s - loss: 0.3274 - accuracy: 0.9067 - 233ms/epoch - 4ms/step
# Epoch 329/4000
# 59/59 - 0s - loss: 0.3281 - accuracy: 0.9065 - 233ms/epoch - 4ms/step
# Epoch 330/4000
# 59/59 - 0s - loss: 0.3270 - accuracy: 0.9068 - 233ms/epoch - 4ms/step
# Epoch 331/4000
# 59/59 - 0s - loss: 0.3260 - accuracy: 0.9076 - 232ms/epoch - 4ms/step
# Epoch 332/4000
# 59/59 - 0s - loss: 0.3258 - accuracy: 0.9075 - 236ms/epoch - 4ms/step
# Epoch 333/4000
# 59/59 - 0s - loss: 0.3252 - accuracy: 0.9077 - 234ms/epoch - 4ms/step
# Epoch 334/4000
# 59/59 - 0s - loss: 0.3256 - accuracy: 0.9074 - 236ms/epoch - 4ms/step
# Epoch 335/4000
# 59/59 - 0s - loss: 0.3241 - accuracy: 0.9075 - 235ms/epoch - 4ms/step
# Epoch 336/4000
# 59/59 - 0s - loss: 0.3254 - accuracy: 0.9072 - 235ms/epoch - 4ms/step
# Epoch 337/4000
# 59/59 - 0s - loss: 0.3242 - accuracy: 0.9073 - 233ms/epoch - 4ms/step
# Epoch 338/4000
# 59/59 - 0s - loss: 0.3233 - accuracy: 0.9079 - 235ms/epoch - 4ms/step
# Epoch 339/4000
# 59/59 - 0s - loss: 0.3233 - accuracy: 0.9082 - 233ms/epoch - 4ms/step
# Epoch 340/4000
# 59/59 - 0s - loss: 0.3230 - accuracy: 0.9088 - 233ms/epoch - 4ms/step
# Epoch 341/4000
# 59/59 - 0s - loss: 0.3221 - accuracy: 0.9092 - 233ms/epoch - 4ms/step
# Epoch 342/4000
# 59/59 - 0s - loss: 0.3228 - accuracy: 0.9082 - 233ms/epoch - 4ms/step
# Epoch 343/4000
# 59/59 - 0s - loss: 0.3218 - accuracy: 0.9080 - 235ms/epoch - 4ms/step
# Epoch 344/4000
# 59/59 - 0s - loss: 0.3238 - accuracy: 0.9074 - 233ms/epoch - 4ms/step
# Epoch 345/4000
# 59/59 - 0s - loss: 0.3224 - accuracy: 0.9087 - 236ms/epoch - 4ms/step
# Epoch 346/4000
# 59/59 - 0s - loss: 0.3208 - accuracy: 0.9086 - 235ms/epoch - 4ms/step
# Epoch 347/4000
# 59/59 - 0s - loss: 0.3201 - accuracy: 0.9086 - 236ms/epoch - 4ms/step
# Epoch 348/4000
# 59/59 - 0s - loss: 0.3196 - accuracy: 0.9093 - 234ms/epoch - 4ms/step
# Epoch 349/4000
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9092 - 235ms/epoch - 4ms/step
# Epoch 350/4000
# 59/59 - 0s - loss: 0.3197 - accuracy: 0.9090 - 235ms/epoch - 4ms/step
# Epoch 351/4000
# 59/59 - 0s - loss: 0.3188 - accuracy: 0.9093 - 235ms/epoch - 4ms/step
# Epoch 352/4000
# 59/59 - 0s - loss: 0.3184 - accuracy: 0.9089 - 236ms/epoch - 4ms/step
# Epoch 353/4000
# 59/59 - 0s - loss: 0.3182 - accuracy: 0.9098 - 236ms/epoch - 4ms/step
# Epoch 354/4000
# 59/59 - 0s - loss: 0.3183 - accuracy: 0.9093 - 236ms/epoch - 4ms/step
# Epoch 355/4000
# 59/59 - 0s - loss: 0.3177 - accuracy: 0.9094 - 232ms/epoch - 4ms/step
# Epoch 356/4000
# 59/59 - 0s - loss: 0.3169 - accuracy: 0.9098 - 234ms/epoch - 4ms/step
# Epoch 357/4000
# 59/59 - 0s - loss: 0.3179 - accuracy: 0.9094 - 234ms/epoch - 4ms/step
# Epoch 358/4000
# 59/59 - 0s - loss: 0.3167 - accuracy: 0.9100 - 235ms/epoch - 4ms/step
# Epoch 359/4000
# 59/59 - 0s - loss: 0.3172 - accuracy: 0.9096 - 233ms/epoch - 4ms/step
# Epoch 360/4000
# 59/59 - 0s - loss: 0.3162 - accuracy: 0.9097 - 233ms/epoch - 4ms/step
# Epoch 361/4000
# 59/59 - 0s - loss: 0.3156 - accuracy: 0.9102 - 235ms/epoch - 4ms/step
# Epoch 362/4000
# 59/59 - 0s - loss: 0.3157 - accuracy: 0.9102 - 235ms/epoch - 4ms/step
# Epoch 363/4000
# 59/59 - 0s - loss: 0.3146 - accuracy: 0.9102 - 235ms/epoch - 4ms/step
# Epoch 364/4000
# 59/59 - 0s - loss: 0.3146 - accuracy: 0.9100 - 234ms/epoch - 4ms/step
# Epoch 365/4000
# 59/59 - 0s - loss: 0.3145 - accuracy: 0.9099 - 234ms/epoch - 4ms/step
# Epoch 366/4000
# 59/59 - 0s - loss: 0.3141 - accuracy: 0.9106 - 235ms/epoch - 4ms/step
# Epoch 367/4000
# 59/59 - 0s - loss: 0.3131 - accuracy: 0.9110 - 233ms/epoch - 4ms/step
# Epoch 368/4000
# 59/59 - 0s - loss: 0.3133 - accuracy: 0.9107 - 237ms/epoch - 4ms/step
# Epoch 369/4000
# 59/59 - 0s - loss: 0.3129 - accuracy: 0.9112 - 236ms/epoch - 4ms/step
# Epoch 370/4000
# 59/59 - 0s - loss: 0.3133 - accuracy: 0.9107 - 234ms/epoch - 4ms/step
# Epoch 371/4000
# 59/59 - 0s - loss: 0.3116 - accuracy: 0.9117 - 236ms/epoch - 4ms/step
# Epoch 372/4000
# 59/59 - 0s - loss: 0.3114 - accuracy: 0.9117 - 232ms/epoch - 4ms/step
# Epoch 373/4000
# 59/59 - 0s - loss: 0.3122 - accuracy: 0.9110 - 234ms/epoch - 4ms/step
# Epoch 374/4000
# 59/59 - 0s - loss: 0.3115 - accuracy: 0.9118 - 235ms/epoch - 4ms/step
# Epoch 375/4000
# 59/59 - 0s - loss: 0.3108 - accuracy: 0.9117 - 234ms/epoch - 4ms/step
# Epoch 376/4000
# 59/59 - 0s - loss: 0.3112 - accuracy: 0.9115 - 234ms/epoch - 4ms/step
# Epoch 377/4000
# 59/59 - 0s - loss: 0.3105 - accuracy: 0.9112 - 235ms/epoch - 4ms/step
# Epoch 378/4000
# 59/59 - 0s - loss: 0.3101 - accuracy: 0.9114 - 235ms/epoch - 4ms/step
# Epoch 379/4000
# 59/59 - 0s - loss: 0.3092 - accuracy: 0.9119 - 235ms/epoch - 4ms/step
# Epoch 380/4000
# 59/59 - 0s - loss: 0.3095 - accuracy: 0.9118 - 234ms/epoch - 4ms/step
# Epoch 381/4000
# 59/59 - 0s - loss: 0.3099 - accuracy: 0.9119 - 235ms/epoch - 4ms/step
# Epoch 382/4000
# 59/59 - 0s - loss: 0.3089 - accuracy: 0.9123 - 238ms/epoch - 4ms/step
# Epoch 383/4000
# 59/59 - 0s - loss: 0.3083 - accuracy: 0.9121 - 237ms/epoch - 4ms/step
# Epoch 384/4000
# 59/59 - 0s - loss: 0.3085 - accuracy: 0.9117 - 237ms/epoch - 4ms/step
# Epoch 385/4000
# 59/59 - 0s - loss: 0.3079 - accuracy: 0.9125 - 234ms/epoch - 4ms/step
# Epoch 386/4000
# 59/59 - 0s - loss: 0.3090 - accuracy: 0.9122 - 235ms/epoch - 4ms/step
# Epoch 387/4000
# 59/59 - 0s - loss: 0.3075 - accuracy: 0.9130 - 234ms/epoch - 4ms/step
# Epoch 388/4000
# 59/59 - 0s - loss: 0.3073 - accuracy: 0.9120 - 236ms/epoch - 4ms/step
# Epoch 389/4000
# 59/59 - 0s - loss: 0.3085 - accuracy: 0.9119 - 235ms/epoch - 4ms/step
# Epoch 390/4000
# 59/59 - 0s - loss: 0.3079 - accuracy: 0.9121 - 239ms/epoch - 4ms/step
# Epoch 391/4000
# 59/59 - 0s - loss: 0.3070 - accuracy: 0.9127 - 236ms/epoch - 4ms/step
# Epoch 392/4000
# 59/59 - 0s - loss: 0.3061 - accuracy: 0.9128 - 234ms/epoch - 4ms/step
# Epoch 393/4000
# 59/59 - 0s - loss: 0.3060 - accuracy: 0.9132 - 234ms/epoch - 4ms/step
# Epoch 394/4000
# 59/59 - 0s - loss: 0.3056 - accuracy: 0.9129 - 236ms/epoch - 4ms/step
# Epoch 395/4000
# 59/59 - 0s - loss: 0.3051 - accuracy: 0.9129 - 235ms/epoch - 4ms/step
# Epoch 396/4000
# 59/59 - 0s - loss: 0.3058 - accuracy: 0.9133 - 234ms/epoch - 4ms/step
# Epoch 397/4000
# 59/59 - 0s - loss: 0.3050 - accuracy: 0.9133 - 234ms/epoch - 4ms/step
# Epoch 398/4000
# 59/59 - 0s - loss: 0.3054 - accuracy: 0.9126 - 237ms/epoch - 4ms/step
# Epoch 399/4000
# 59/59 - 0s - loss: 0.3043 - accuracy: 0.9132 - 235ms/epoch - 4ms/step
# Epoch 400/4000
# 59/59 - 0s - loss: 0.3040 - accuracy: 0.9130 - 233ms/epoch - 4ms/step
# Epoch 401/4000
# 59/59 - 0s - loss: 0.3033 - accuracy: 0.9130 - 234ms/epoch - 4ms/step
# Epoch 402/4000
# 59/59 - 0s - loss: 0.3036 - accuracy: 0.9130 - 234ms/epoch - 4ms/step
# Epoch 403/4000
# 59/59 - 0s - loss: 0.3035 - accuracy: 0.9135 - 235ms/epoch - 4ms/step
# Epoch 404/4000
# 59/59 - 0s - loss: 0.3047 - accuracy: 0.9127 - 236ms/epoch - 4ms/step
# Epoch 405/4000
# 59/59 - 0s - loss: 0.3030 - accuracy: 0.9135 - 235ms/epoch - 4ms/step
# Epoch 406/4000
# 59/59 - 0s - loss: 0.3024 - accuracy: 0.9139 - 235ms/epoch - 4ms/step
# Epoch 407/4000
# 59/59 - 0s - loss: 0.3022 - accuracy: 0.9139 - 235ms/epoch - 4ms/step
# Epoch 408/4000
# 59/59 - 0s - loss: 0.3021 - accuracy: 0.9136 - 237ms/epoch - 4ms/step
# Epoch 409/4000
# 59/59 - 0s - loss: 0.3020 - accuracy: 0.9139 - 234ms/epoch - 4ms/step
# Epoch 410/4000
# 59/59 - 0s - loss: 0.3012 - accuracy: 0.9139 - 236ms/epoch - 4ms/step
# Epoch 411/4000
# 59/59 - 0s - loss: 0.3011 - accuracy: 0.9142 - 236ms/epoch - 4ms/step
# Epoch 412/4000
# 59/59 - 0s - loss: 0.3008 - accuracy: 0.9144 - 236ms/epoch - 4ms/step
# Epoch 413/4000
# 59/59 - 0s - loss: 0.3016 - accuracy: 0.9143 - 234ms/epoch - 4ms/step
# Epoch 414/4000
# 59/59 - 0s - loss: 0.3003 - accuracy: 0.9139 - 234ms/epoch - 4ms/step
# Epoch 415/4000
# 59/59 - 0s - loss: 0.3005 - accuracy: 0.9145 - 233ms/epoch - 4ms/step
# Epoch 416/4000
# 59/59 - 0s - loss: 0.3002 - accuracy: 0.9143 - 238ms/epoch - 4ms/step
# Epoch 417/4000
# 59/59 - 0s - loss: 0.2998 - accuracy: 0.9143 - 235ms/epoch - 4ms/step
# Epoch 418/4000
# 59/59 - 0s - loss: 0.2992 - accuracy: 0.9151 - 232ms/epoch - 4ms/step
# Epoch 419/4000
# 59/59 - 0s - loss: 0.2988 - accuracy: 0.9145 - 236ms/epoch - 4ms/step
# Epoch 420/4000
# 59/59 - 0s - loss: 0.2994 - accuracy: 0.9145 - 236ms/epoch - 4ms/step
# Epoch 421/4000
# 59/59 - 0s - loss: 0.2986 - accuracy: 0.9148 - 239ms/epoch - 4ms/step
# Epoch 422/4000
# 59/59 - 0s - loss: 0.2990 - accuracy: 0.9141 - 236ms/epoch - 4ms/step
# Epoch 423/4000
# 59/59 - 0s - loss: 0.2984 - accuracy: 0.9152 - 235ms/epoch - 4ms/step
# Epoch 424/4000
# 59/59 - 0s - loss: 0.2978 - accuracy: 0.9149 - 237ms/epoch - 4ms/step
# Epoch 425/4000
# 59/59 - 0s - loss: 0.2983 - accuracy: 0.9144 - 235ms/epoch - 4ms/step
# Epoch 426/4000
# 59/59 - 0s - loss: 0.2979 - accuracy: 0.9151 - 236ms/epoch - 4ms/step
# Epoch 427/4000
# 59/59 - 0s - loss: 0.2990 - accuracy: 0.9141 - 234ms/epoch - 4ms/step
# Epoch 428/4000
# 59/59 - 0s - loss: 0.2981 - accuracy: 0.9144 - 236ms/epoch - 4ms/step
# Epoch 429/4000
# 59/59 - 0s - loss: 0.2969 - accuracy: 0.9147 - 237ms/epoch - 4ms/step
# Epoch 430/4000
# 59/59 - 0s - loss: 0.2964 - accuracy: 0.9153 - 234ms/epoch - 4ms/step
# Epoch 431/4000
# 59/59 - 0s - loss: 0.2959 - accuracy: 0.9154 - 240ms/epoch - 4ms/step
# Epoch 432/4000
# 59/59 - 0s - loss: 0.2967 - accuracy: 0.9150 - 248ms/epoch - 4ms/step
# Epoch 433/4000
# 59/59 - 0s - loss: 0.2971 - accuracy: 0.9147 - 235ms/epoch - 4ms/step
# Epoch 434/4000
# 59/59 - 0s - loss: 0.2958 - accuracy: 0.9153 - 233ms/epoch - 4ms/step
# Epoch 435/4000
# 59/59 - 0s - loss: 0.2963 - accuracy: 0.9158 - 236ms/epoch - 4ms/step
# Epoch 436/4000
# 59/59 - 0s - loss: 0.2955 - accuracy: 0.9148 - 236ms/epoch - 4ms/step
# Epoch 437/4000
# 59/59 - 0s - loss: 0.2947 - accuracy: 0.9155 - 237ms/epoch - 4ms/step
# Epoch 438/4000
# 59/59 - 0s - loss: 0.2950 - accuracy: 0.9155 - 233ms/epoch - 4ms/step
# Epoch 439/4000
# 59/59 - 0s - loss: 0.2962 - accuracy: 0.9151 - 235ms/epoch - 4ms/step
# Epoch 440/4000
# 59/59 - 0s - loss: 0.2951 - accuracy: 0.9151 - 235ms/epoch - 4ms/step
# Epoch 441/4000
# 59/59 - 0s - loss: 0.2948 - accuracy: 0.9150 - 239ms/epoch - 4ms/step
# Epoch 442/4000
# 59/59 - 0s - loss: 0.2943 - accuracy: 0.9154 - 235ms/epoch - 4ms/step
# Epoch 443/4000
# 59/59 - 0s - loss: 0.2952 - accuracy: 0.9151 - 234ms/epoch - 4ms/step
# Epoch 444/4000
# 59/59 - 0s - loss: 0.2934 - accuracy: 0.9159 - 237ms/epoch - 4ms/step
# Epoch 445/4000
# 59/59 - 0s - loss: 0.2935 - accuracy: 0.9155 - 238ms/epoch - 4ms/step
# Epoch 446/4000
# 59/59 - 0s - loss: 0.2932 - accuracy: 0.9157 - 236ms/epoch - 4ms/step
# Epoch 447/4000
# 59/59 - 0s - loss: 0.2931 - accuracy: 0.9161 - 233ms/epoch - 4ms/step
# Epoch 448/4000
# 59/59 - 0s - loss: 0.2927 - accuracy: 0.9157 - 235ms/epoch - 4ms/step
# Epoch 449/4000
# 59/59 - 0s - loss: 0.2926 - accuracy: 0.9164 - 233ms/epoch - 4ms/step
# Epoch 450/4000
# 59/59 - 0s - loss: 0.2942 - accuracy: 0.9160 - 231ms/epoch - 4ms/step
# Epoch 451/4000
# 59/59 - 0s - loss: 0.2925 - accuracy: 0.9163 - 235ms/epoch - 4ms/step
# Epoch 452/4000
# 59/59 - 0s - loss: 0.2923 - accuracy: 0.9168 - 234ms/epoch - 4ms/step
# Epoch 453/4000
# 59/59 - 0s - loss: 0.2923 - accuracy: 0.9161 - 237ms/epoch - 4ms/step
# Epoch 454/4000
# 59/59 - 0s - loss: 0.2915 - accuracy: 0.9167 - 235ms/epoch - 4ms/step
# Epoch 455/4000
# 59/59 - 0s - loss: 0.2926 - accuracy: 0.9157 - 234ms/epoch - 4ms/step
# Epoch 456/4000
# 59/59 - 0s - loss: 0.2918 - accuracy: 0.9167 - 238ms/epoch - 4ms/step
# Epoch 457/4000
# 59/59 - 0s - loss: 0.2908 - accuracy: 0.9165 - 233ms/epoch - 4ms/step
# Epoch 458/4000
# 59/59 - 0s - loss: 0.2919 - accuracy: 0.9159 - 238ms/epoch - 4ms/step
# Epoch 459/4000
# 59/59 - 0s - loss: 0.2908 - accuracy: 0.9166 - 235ms/epoch - 4ms/step
# Epoch 460/4000
# 59/59 - 0s - loss: 0.2909 - accuracy: 0.9165 - 235ms/epoch - 4ms/step
# Epoch 461/4000
# 59/59 - 0s - loss: 0.2912 - accuracy: 0.9165 - 238ms/epoch - 4ms/step
# Epoch 462/4000
# 59/59 - 0s - loss: 0.2904 - accuracy: 0.9162 - 232ms/epoch - 4ms/step
# Epoch 463/4000
# 59/59 - 0s - loss: 0.2912 - accuracy: 0.9163 - 235ms/epoch - 4ms/step
# Epoch 464/4000
# 59/59 - 0s - loss: 0.2899 - accuracy: 0.9169 - 234ms/epoch - 4ms/step
# Epoch 465/4000
# 59/59 - 0s - loss: 0.2908 - accuracy: 0.9161 - 237ms/epoch - 4ms/step
# Epoch 466/4000
# 59/59 - 0s - loss: 0.2895 - accuracy: 0.9168 - 237ms/epoch - 4ms/step
# Epoch 467/4000
# 59/59 - 0s - loss: 0.2885 - accuracy: 0.9176 - 234ms/epoch - 4ms/step
# Epoch 468/4000
# 59/59 - 0s - loss: 0.2893 - accuracy: 0.9172 - 236ms/epoch - 4ms/step
# Epoch 469/4000
# 59/59 - 0s - loss: 0.2886 - accuracy: 0.9168 - 238ms/epoch - 4ms/step
# Epoch 470/4000
# 59/59 - 0s - loss: 0.2896 - accuracy: 0.9175 - 236ms/epoch - 4ms/step
# Epoch 471/4000
# 59/59 - 0s - loss: 0.2890 - accuracy: 0.9170 - 233ms/epoch - 4ms/step
# Epoch 472/4000
# 59/59 - 0s - loss: 0.2883 - accuracy: 0.9171 - 234ms/epoch - 4ms/step
# Epoch 473/4000
# 59/59 - 0s - loss: 0.2873 - accuracy: 0.9179 - 238ms/epoch - 4ms/step
# Epoch 474/4000
# 59/59 - 0s - loss: 0.2875 - accuracy: 0.9172 - 235ms/epoch - 4ms/step
# Epoch 475/4000
# 59/59 - 0s - loss: 0.2890 - accuracy: 0.9171 - 235ms/epoch - 4ms/step
# Epoch 476/4000
# 59/59 - 0s - loss: 0.2887 - accuracy: 0.9168 - 236ms/epoch - 4ms/step
# Epoch 477/4000
# 59/59 - 0s - loss: 0.2877 - accuracy: 0.9178 - 237ms/epoch - 4ms/step
# Epoch 478/4000
# 59/59 - 0s - loss: 0.2867 - accuracy: 0.9174 - 237ms/epoch - 4ms/step
# Epoch 479/4000
# 59/59 - 0s - loss: 0.2871 - accuracy: 0.9173 - 236ms/epoch - 4ms/step
# Epoch 480/4000
# 59/59 - 0s - loss: 0.2880 - accuracy: 0.9177 - 236ms/epoch - 4ms/step
# Epoch 481/4000
# 59/59 - 0s - loss: 0.2875 - accuracy: 0.9170 - 237ms/epoch - 4ms/step
# Epoch 482/4000
# 59/59 - 0s - loss: 0.2867 - accuracy: 0.9177 - 239ms/epoch - 4ms/step
# Epoch 483/4000
# 59/59 - 0s - loss: 0.2858 - accuracy: 0.9177 - 236ms/epoch - 4ms/step
# Epoch 484/4000
# 59/59 - 0s - loss: 0.2854 - accuracy: 0.9186 - 236ms/epoch - 4ms/step
# Epoch 485/4000
# 59/59 - 0s - loss: 0.2855 - accuracy: 0.9177 - 238ms/epoch - 4ms/step
# Epoch 486/4000
# 59/59 - 0s - loss: 0.2859 - accuracy: 0.9176 - 237ms/epoch - 4ms/step
# Epoch 487/4000
# 59/59 - 0s - loss: 0.2852 - accuracy: 0.9181 - 238ms/epoch - 4ms/step
# Epoch 488/4000
# 59/59 - 0s - loss: 0.2847 - accuracy: 0.9181 - 237ms/epoch - 4ms/step
# Epoch 489/4000
# 59/59 - 0s - loss: 0.2853 - accuracy: 0.9176 - 238ms/epoch - 4ms/step
# Epoch 490/4000
# 59/59 - 0s - loss: 0.2853 - accuracy: 0.9179 - 240ms/epoch - 4ms/step
# Epoch 491/4000
# 59/59 - 0s - loss: 0.2856 - accuracy: 0.9178 - 236ms/epoch - 4ms/step
# Epoch 492/4000
# 59/59 - 0s - loss: 0.2854 - accuracy: 0.9177 - 236ms/epoch - 4ms/step
# Epoch 493/4000
# 59/59 - 0s - loss: 0.2850 - accuracy: 0.9183 - 235ms/epoch - 4ms/step
# Epoch 494/4000
# 59/59 - 0s - loss: 0.2845 - accuracy: 0.9177 - 236ms/epoch - 4ms/step
# Epoch 495/4000
# 59/59 - 0s - loss: 0.2841 - accuracy: 0.9182 - 235ms/epoch - 4ms/step
# Epoch 496/4000
# 59/59 - 0s - loss: 0.2837 - accuracy: 0.9189 - 237ms/epoch - 4ms/step
# Epoch 497/4000
# 59/59 - 0s - loss: 0.2841 - accuracy: 0.9183 - 233ms/epoch - 4ms/step
# Epoch 498/4000
# 59/59 - 0s - loss: 0.2841 - accuracy: 0.9178 - 235ms/epoch - 4ms/step
# Epoch 499/4000
# 59/59 - 0s - loss: 0.2846 - accuracy: 0.9177 - 235ms/epoch - 4ms/step
# Epoch 500/4000
# 59/59 - 0s - loss: 0.2837 - accuracy: 0.9185 - 236ms/epoch - 4ms/step
# Epoch 501/4000
# 59/59 - 0s - loss: 0.2837 - accuracy: 0.9183 - 238ms/epoch - 4ms/step
# Epoch 502/4000
# 59/59 - 0s - loss: 0.2855 - accuracy: 0.9179 - 236ms/epoch - 4ms/step
# Epoch 503/4000
# 59/59 - 0s - loss: 0.2846 - accuracy: 0.9177 - 237ms/epoch - 4ms/step
# Epoch 504/4000
# 59/59 - 0s - loss: 0.2818 - accuracy: 0.9189 - 234ms/epoch - 4ms/step
# Epoch 505/4000
# 59/59 - 0s - loss: 0.2824 - accuracy: 0.9188 - 236ms/epoch - 4ms/step
# Epoch 506/4000
# 59/59 - 0s - loss: 0.2827 - accuracy: 0.9186 - 237ms/epoch - 4ms/step
# Epoch 507/4000
# 59/59 - 0s - loss: 0.2832 - accuracy: 0.9185 - 235ms/epoch - 4ms/step
# Epoch 508/4000
# 59/59 - 0s - loss: 0.2825 - accuracy: 0.9187 - 236ms/epoch - 4ms/step
# Epoch 509/4000
# 59/59 - 0s - loss: 0.2820 - accuracy: 0.9193 - 236ms/epoch - 4ms/step
# Epoch 510/4000
# 59/59 - 0s - loss: 0.2817 - accuracy: 0.9187 - 235ms/epoch - 4ms/step
# Epoch 511/4000
# 59/59 - 0s - loss: 0.2823 - accuracy: 0.9189 - 236ms/epoch - 4ms/step
# Epoch 512/4000
# 59/59 - 0s - loss: 0.2816 - accuracy: 0.9189 - 236ms/epoch - 4ms/step
# Epoch 513/4000
# 59/59 - 0s - loss: 0.2809 - accuracy: 0.9189 - 237ms/epoch - 4ms/step
# Epoch 514/4000
# 59/59 - 0s - loss: 0.2815 - accuracy: 0.9190 - 239ms/epoch - 4ms/step
# Epoch 515/4000
# 59/59 - 0s - loss: 0.2821 - accuracy: 0.9188 - 237ms/epoch - 4ms/step
# Epoch 516/4000
# 59/59 - 0s - loss: 0.2799 - accuracy: 0.9190 - 233ms/epoch - 4ms/step
# Epoch 517/4000
# 59/59 - 0s - loss: 0.2814 - accuracy: 0.9191 - 237ms/epoch - 4ms/step
# Epoch 518/4000
# 59/59 - 0s - loss: 0.2801 - accuracy: 0.9194 - 236ms/epoch - 4ms/step
# Epoch 519/4000
# 59/59 - 0s - loss: 0.2802 - accuracy: 0.9192 - 235ms/epoch - 4ms/step
# Epoch 520/4000
# 59/59 - 0s - loss: 0.2801 - accuracy: 0.9192 - 236ms/epoch - 4ms/step
# Epoch 521/4000
# 59/59 - 0s - loss: 0.2797 - accuracy: 0.9191 - 234ms/epoch - 4ms/step
# Epoch 522/4000
# 59/59 - 0s - loss: 0.2805 - accuracy: 0.9193 - 237ms/epoch - 4ms/step
# Epoch 523/4000
# 59/59 - 0s - loss: 0.2797 - accuracy: 0.9193 - 235ms/epoch - 4ms/step
# Epoch 524/4000
# 59/59 - 0s - loss: 0.2790 - accuracy: 0.9198 - 235ms/epoch - 4ms/step
# Epoch 525/4000
# 59/59 - 0s - loss: 0.2800 - accuracy: 0.9198 - 236ms/epoch - 4ms/step
# Epoch 526/4000
# 59/59 - 0s - loss: 0.2798 - accuracy: 0.9192 - 235ms/epoch - 4ms/step
# Epoch 527/4000
# 59/59 - 0s - loss: 0.2799 - accuracy: 0.9195 - 237ms/epoch - 4ms/step
# Epoch 528/4000
# 59/59 - 0s - loss: 0.2786 - accuracy: 0.9197 - 236ms/epoch - 4ms/step
# Epoch 529/4000
# 59/59 - 0s - loss: 0.2797 - accuracy: 0.9190 - 239ms/epoch - 4ms/step
# Epoch 530/4000
# 59/59 - 0s - loss: 0.2785 - accuracy: 0.9198 - 238ms/epoch - 4ms/step
# Epoch 531/4000
# 59/59 - 0s - loss: 0.2785 - accuracy: 0.9196 - 238ms/epoch - 4ms/step
# Epoch 532/4000
# 59/59 - 0s - loss: 0.2778 - accuracy: 0.9200 - 238ms/epoch - 4ms/step
# Epoch 533/4000
# 59/59 - 0s - loss: 0.2784 - accuracy: 0.9197 - 236ms/epoch - 4ms/step
# Epoch 534/4000
# 59/59 - 0s - loss: 0.2799 - accuracy: 0.9194 - 237ms/epoch - 4ms/step
# Epoch 535/4000
# 59/59 - 0s - loss: 0.2780 - accuracy: 0.9206 - 238ms/epoch - 4ms/step
# Epoch 536/4000
# 59/59 - 0s - loss: 0.2792 - accuracy: 0.9195 - 238ms/epoch - 4ms/step
# Epoch 537/4000
# 59/59 - 0s - loss: 0.2775 - accuracy: 0.9199 - 237ms/epoch - 4ms/step
# Epoch 538/4000
# 59/59 - 0s - loss: 0.2781 - accuracy: 0.9200 - 238ms/epoch - 4ms/step
# Epoch 539/4000
# 59/59 - 0s - loss: 0.2767 - accuracy: 0.9202 - 236ms/epoch - 4ms/step
# Epoch 540/4000
# 59/59 - 0s - loss: 0.2768 - accuracy: 0.9201 - 235ms/epoch - 4ms/step
# Epoch 541/4000
# 59/59 - 0s - loss: 0.2772 - accuracy: 0.9206 - 236ms/epoch - 4ms/step
# Epoch 542/4000
# 59/59 - 0s - loss: 0.2767 - accuracy: 0.9200 - 239ms/epoch - 4ms/step
# Epoch 543/4000
# 59/59 - 0s - loss: 0.2772 - accuracy: 0.9200 - 239ms/epoch - 4ms/step
# Epoch 544/4000
# 59/59 - 0s - loss: 0.2771 - accuracy: 0.9207 - 237ms/epoch - 4ms/step
# Epoch 545/4000
# 59/59 - 0s - loss: 0.2775 - accuracy: 0.9195 - 237ms/epoch - 4ms/step
# Epoch 546/4000
# 59/59 - 0s - loss: 0.2767 - accuracy: 0.9205 - 235ms/epoch - 4ms/step
# Epoch 547/4000
# 59/59 - 0s - loss: 0.2756 - accuracy: 0.9208 - 237ms/epoch - 4ms/step
# Epoch 548/4000
# 59/59 - 0s - loss: 0.2765 - accuracy: 0.9202 - 236ms/epoch - 4ms/step
# Epoch 549/4000
# 59/59 - 0s - loss: 0.2760 - accuracy: 0.9202 - 238ms/epoch - 4ms/step
# Epoch 550/4000
# 59/59 - 0s - loss: 0.2753 - accuracy: 0.9208 - 237ms/epoch - 4ms/step
# Epoch 551/4000
# 59/59 - 0s - loss: 0.2756 - accuracy: 0.9206 - 236ms/epoch - 4ms/step
# Epoch 552/4000
# 59/59 - 0s - loss: 0.2757 - accuracy: 0.9203 - 234ms/epoch - 4ms/step
# Epoch 553/4000
# 59/59 - 0s - loss: 0.2742 - accuracy: 0.9211 - 237ms/epoch - 4ms/step
# Epoch 554/4000
# 59/59 - 0s - loss: 0.2748 - accuracy: 0.9204 - 234ms/epoch - 4ms/step
# Epoch 555/4000
# 59/59 - 0s - loss: 0.2750 - accuracy: 0.9208 - 236ms/epoch - 4ms/step
# Epoch 556/4000
# 59/59 - 0s - loss: 0.2752 - accuracy: 0.9205 - 238ms/epoch - 4ms/step
# Epoch 557/4000
# 59/59 - 0s - loss: 0.2746 - accuracy: 0.9212 - 240ms/epoch - 4ms/step
# Epoch 558/4000
# 59/59 - 0s - loss: 0.2748 - accuracy: 0.9204 - 235ms/epoch - 4ms/step
# Epoch 559/4000
# 59/59 - 0s - loss: 0.2751 - accuracy: 0.9207 - 236ms/epoch - 4ms/step
# Epoch 560/4000
# 59/59 - 0s - loss: 0.2744 - accuracy: 0.9212 - 237ms/epoch - 4ms/step
# Epoch 561/4000
# 59/59 - 0s - loss: 0.2739 - accuracy: 0.9209 - 236ms/epoch - 4ms/step
# Epoch 562/4000
# 59/59 - 0s - loss: 0.2750 - accuracy: 0.9205 - 237ms/epoch - 4ms/step
# Epoch 563/4000
# 59/59 - 0s - loss: 0.2736 - accuracy: 0.9212 - 234ms/epoch - 4ms/step
# Epoch 564/4000
# 59/59 - 0s - loss: 0.2737 - accuracy: 0.9214 - 234ms/epoch - 4ms/step
# Epoch 565/4000
# ...
# Epoch 3817/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9563 - 239ms/epoch - 4ms/step
# Epoch 3818/4000
# 59/59 - 0s - loss: 0.1513 - accuracy: 0.9552 - 237ms/epoch - 4ms/step
# Epoch 3819/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9566 - 239ms/epoch - 4ms/step
# Epoch 3820/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9562 - 237ms/epoch - 4ms/step
# Epoch 3821/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9570 - 238ms/epoch - 4ms/step
# Epoch 3822/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9562 - 237ms/epoch - 4ms/step
# Epoch 3823/4000
# 59/59 - 0s - loss: 0.1511 - accuracy: 0.9555 - 239ms/epoch - 4ms/step
# Epoch 3824/4000
# 59/59 - 0s - loss: 0.1503 - accuracy: 0.9557 - 237ms/epoch - 4ms/step
# Epoch 3825/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9562 - 238ms/epoch - 4ms/step
# Epoch 3826/4000
# 59/59 - 0s - loss: 0.1506 - accuracy: 0.9559 - 239ms/epoch - 4ms/step
# Epoch 3827/4000
# 59/59 - 0s - loss: 0.1514 - accuracy: 0.9559 - 236ms/epoch - 4ms/step
# Epoch 3828/4000
# 59/59 - 0s - loss: 0.1502 - accuracy: 0.9563 - 236ms/epoch - 4ms/step
# Epoch 3829/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9568 - 238ms/epoch - 4ms/step
# Epoch 3830/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9566 - 238ms/epoch - 4ms/step
# Epoch 3831/4000
# 59/59 - 0s - loss: 0.1501 - accuracy: 0.9559 - 247ms/epoch - 4ms/step
# Epoch 3832/4000
# 59/59 - 0s - loss: 0.1504 - accuracy: 0.9557 - 237ms/epoch - 4ms/step
# Epoch 3833/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9563 - 235ms/epoch - 4ms/step
# Epoch 3834/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9562 - 238ms/epoch - 4ms/step
# Epoch 3835/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9568 - 237ms/epoch - 4ms/step
# Epoch 3836/4000
# 59/59 - 0s - loss: 0.1495 - accuracy: 0.9564 - 237ms/epoch - 4ms/step
# Epoch 3837/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9556 - 237ms/epoch - 4ms/step
# Epoch 3838/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9560 - 239ms/epoch - 4ms/step
# Epoch 3839/4000
# 59/59 - 0s - loss: 0.1507 - accuracy: 0.9559 - 238ms/epoch - 4ms/step
# Epoch 3840/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9556 - 235ms/epoch - 4ms/step
# Epoch 3841/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9567 - 239ms/epoch - 4ms/step
# Epoch 3842/4000
# 59/59 - 0s - loss: 0.1503 - accuracy: 0.9562 - 236ms/epoch - 4ms/step
# Epoch 3843/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9564 - 240ms/epoch - 4ms/step
# Epoch 3844/4000
# 59/59 - 0s - loss: 0.1499 - accuracy: 0.9561 - 237ms/epoch - 4ms/step
# Epoch 3845/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9560 - 235ms/epoch - 4ms/step
# Epoch 3846/4000
# 59/59 - 0s - loss: 0.1515 - accuracy: 0.9560 - 240ms/epoch - 4ms/step
# Epoch 3847/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9558 - 240ms/epoch - 4ms/step
# Epoch 3848/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9560 - 237ms/epoch - 4ms/step
# Epoch 3849/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9565 - 237ms/epoch - 4ms/step
# Epoch 3850/4000
# 59/59 - 0s - loss: 0.1507 - accuracy: 0.9561 - 237ms/epoch - 4ms/step
# Epoch 3851/4000
# 59/59 - 0s - loss: 0.1495 - accuracy: 0.9565 - 239ms/epoch - 4ms/step
# Epoch 3852/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9563 - 238ms/epoch - 4ms/step
# Epoch 3853/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9556 - 236ms/epoch - 4ms/step
# Epoch 3854/4000
# 59/59 - 0s - loss: 0.1507 - accuracy: 0.9567 - 237ms/epoch - 4ms/step
# Epoch 3855/4000
# 59/59 - 0s - loss: 0.1511 - accuracy: 0.9562 - 248ms/epoch - 4ms/step
# Epoch 3856/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9562 - 238ms/epoch - 4ms/step
# Epoch 3857/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9563 - 239ms/epoch - 4ms/step
# Epoch 3858/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9563 - 239ms/epoch - 4ms/step
# Epoch 3859/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9564 - 241ms/epoch - 4ms/step
# Epoch 3860/4000
# 59/59 - 0s - loss: 0.1508 - accuracy: 0.9560 - 236ms/epoch - 4ms/step
# Epoch 3861/4000
# 59/59 - 0s - loss: 0.1487 - accuracy: 0.9570 - 236ms/epoch - 4ms/step
# Epoch 3862/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9564 - 236ms/epoch - 4ms/step
# Epoch 3863/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9568 - 238ms/epoch - 4ms/step
# Epoch 3864/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9560 - 237ms/epoch - 4ms/step
# Epoch 3865/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9563 - 237ms/epoch - 4ms/step
# Epoch 3866/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9562 - 237ms/epoch - 4ms/step
# Epoch 3867/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9560 - 239ms/epoch - 4ms/step
# Epoch 3868/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9566 - 238ms/epoch - 4ms/step
# Epoch 3869/4000
# 59/59 - 0s - loss: 0.1509 - accuracy: 0.9556 - 236ms/epoch - 4ms/step
# Epoch 3870/4000
# 59/59 - 0s - loss: 0.1506 - accuracy: 0.9560 - 237ms/epoch - 4ms/step
# Epoch 3871/4000
# 59/59 - 0s - loss: 0.1507 - accuracy: 0.9561 - 239ms/epoch - 4ms/step
# Epoch 3872/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9566 - 242ms/epoch - 4ms/step
# Epoch 3873/4000
# 59/59 - 0s - loss: 0.1493 - accuracy: 0.9562 - 235ms/epoch - 4ms/step
# Epoch 3874/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9561 - 236ms/epoch - 4ms/step
# Epoch 3875/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9559 - 240ms/epoch - 4ms/step
# Epoch 3876/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9565 - 239ms/epoch - 4ms/step
# Epoch 3877/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9564 - 238ms/epoch - 4ms/step
# Epoch 3878/4000
# 59/59 - 0s - loss: 0.1508 - accuracy: 0.9558 - 247ms/epoch - 4ms/step
# Epoch 3879/4000
# 59/59 - 0s - loss: 0.1504 - accuracy: 0.9560 - 239ms/epoch - 4ms/step
# Epoch 3880/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9557 - 238ms/epoch - 4ms/step
# Epoch 3881/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9565 - 240ms/epoch - 4ms/step
# Epoch 3882/4000
# 59/59 - 0s - loss: 0.1503 - accuracy: 0.9559 - 236ms/epoch - 4ms/step
# Epoch 3883/4000
# 59/59 - 0s - loss: 0.1506 - accuracy: 0.9554 - 241ms/epoch - 4ms/step
# Epoch 3884/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9558 - 238ms/epoch - 4ms/step
# Epoch 3885/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9555 - 237ms/epoch - 4ms/step
# Epoch 3886/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9559 - 234ms/epoch - 4ms/step
# Epoch 3887/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9566 - 236ms/epoch - 4ms/step
# Epoch 3888/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9564 - 248ms/epoch - 4ms/step
# Epoch 3889/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9566 - 238ms/epoch - 4ms/step
# Epoch 3890/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9561 - 238ms/epoch - 4ms/step
# Epoch 3891/4000
# 59/59 - 0s - loss: 0.1499 - accuracy: 0.9560 - 242ms/epoch - 4ms/step
# Epoch 3892/4000
# 59/59 - 0s - loss: 0.1484 - accuracy: 0.9568 - 240ms/epoch - 4ms/step
# Epoch 3893/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9567 - 239ms/epoch - 4ms/step
# Epoch 3894/4000
# 59/59 - 0s - loss: 0.1519 - accuracy: 0.9556 - 236ms/epoch - 4ms/step
# Epoch 3895/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9560 - 237ms/epoch - 4ms/step
# Epoch 3896/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9564 - 237ms/epoch - 4ms/step
# Epoch 3897/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9567 - 238ms/epoch - 4ms/step
# Epoch 3898/4000
# 59/59 - 0s - loss: 0.1506 - accuracy: 0.9561 - 238ms/epoch - 4ms/step
# Epoch 3899/4000
# 59/59 - 0s - loss: 0.1496 - accuracy: 0.9570 - 240ms/epoch - 4ms/step
# Epoch 3900/4000
# 59/59 - 0s - loss: 0.1493 - accuracy: 0.9565 - 240ms/epoch - 4ms/step
# Epoch 3901/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9559 - 241ms/epoch - 4ms/step
# Epoch 3902/4000
# 59/59 - 0s - loss: 0.1493 - accuracy: 0.9563 - 239ms/epoch - 4ms/step
# Epoch 3903/4000
# 59/59 - 0s - loss: 0.1516 - accuracy: 0.9550 - 240ms/epoch - 4ms/step
# Epoch 3904/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9561 - 237ms/epoch - 4ms/step
# Epoch 3905/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9566 - 239ms/epoch - 4ms/step
# Epoch 3906/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9560 - 239ms/epoch - 4ms/step
# Epoch 3907/4000
# 59/59 - 0s - loss: 0.1493 - accuracy: 0.9560 - 238ms/epoch - 4ms/step
# Epoch 3908/4000
# 59/59 - 0s - loss: 0.1499 - accuracy: 0.9561 - 240ms/epoch - 4ms/step
# Epoch 3909/4000
# 59/59 - 0s - loss: 0.1505 - accuracy: 0.9554 - 241ms/epoch - 4ms/step
# Epoch 3910/4000
# 59/59 - 0s - loss: 0.1495 - accuracy: 0.9560 - 236ms/epoch - 4ms/step
# Epoch 3911/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9567 - 240ms/epoch - 4ms/step
# Epoch 3912/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9564 - 237ms/epoch - 4ms/step
# Epoch 3913/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9560 - 237ms/epoch - 4ms/step
# Epoch 3914/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9561 - 238ms/epoch - 4ms/step
# Epoch 3915/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9562 - 237ms/epoch - 4ms/step
# Epoch 3916/4000
# 59/59 - 0s - loss: 0.1480 - accuracy: 0.9567 - 238ms/epoch - 4ms/step
# Epoch 3917/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9562 - 240ms/epoch - 4ms/step
# Epoch 3918/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9569 - 237ms/epoch - 4ms/step
# Epoch 3919/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9567 - 236ms/epoch - 4ms/step
# Epoch 3920/4000
# 59/59 - 0s - loss: 0.1480 - accuracy: 0.9570 - 237ms/epoch - 4ms/step
# Epoch 3921/4000
# 59/59 - 0s - loss: 0.1495 - accuracy: 0.9561 - 243ms/epoch - 4ms/step
# Epoch 3922/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9569 - 240ms/epoch - 4ms/step
# Epoch 3923/4000
# 59/59 - 0s - loss: 0.1487 - accuracy: 0.9566 - 236ms/epoch - 4ms/step
# Epoch 3924/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9562 - 238ms/epoch - 4ms/step
# Epoch 3925/4000
# 59/59 - 0s - loss: 0.1483 - accuracy: 0.9565 - 237ms/epoch - 4ms/step
# Epoch 3926/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9561 - 236ms/epoch - 4ms/step
# Epoch 3927/4000
# 59/59 - 0s - loss: 0.1493 - accuracy: 0.9564 - 237ms/epoch - 4ms/step
# Epoch 3928/4000
# 59/59 - 0s - loss: 0.1496 - accuracy: 0.9560 - 239ms/epoch - 4ms/step
# Epoch 3929/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9564 - 237ms/epoch - 4ms/step
# Epoch 3930/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9562 - 239ms/epoch - 4ms/step
# Epoch 3931/4000
# 59/59 - 0s - loss: 0.1502 - accuracy: 0.9558 - 235ms/epoch - 4ms/step
# Epoch 3932/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9561 - 237ms/epoch - 4ms/step
# Epoch 3933/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9562 - 238ms/epoch - 4ms/step
# Epoch 3934/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9570 - 237ms/epoch - 4ms/step
# Epoch 3935/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9562 - 235ms/epoch - 4ms/step
# Epoch 3936/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9560 - 240ms/epoch - 4ms/step
# Epoch 3937/4000
# 59/59 - 0s - loss: 0.1480 - accuracy: 0.9562 - 237ms/epoch - 4ms/step
# Epoch 3938/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9561 - 237ms/epoch - 4ms/step
# Epoch 3939/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9561 - 239ms/epoch - 4ms/step
# Epoch 3940/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9563 - 236ms/epoch - 4ms/step
# Epoch 3941/4000
# 59/59 - 0s - loss: 0.1505 - accuracy: 0.9557 - 236ms/epoch - 4ms/step
# Epoch 3942/4000
# 59/59 - 0s - loss: 0.1485 - accuracy: 0.9566 - 238ms/epoch - 4ms/step
# Epoch 3943/4000
# 59/59 - 0s - loss: 0.1507 - accuracy: 0.9558 - 243ms/epoch - 4ms/step
# Epoch 3944/4000
# 59/59 - 0s - loss: 0.1499 - accuracy: 0.9559 - 239ms/epoch - 4ms/step
# Epoch 3945/4000
# 59/59 - 0s - loss: 0.1485 - accuracy: 0.9567 - 237ms/epoch - 4ms/step
# Epoch 3946/4000
# 59/59 - 0s - loss: 0.1479 - accuracy: 0.9567 - 239ms/epoch - 4ms/step
# Epoch 3947/4000
# 59/59 - 0s - loss: 0.1526 - accuracy: 0.9554 - 240ms/epoch - 4ms/step
# Epoch 3948/4000
# 59/59 - 0s - loss: 0.1484 - accuracy: 0.9566 - 239ms/epoch - 4ms/step
# Epoch 3949/4000
# 59/59 - 0s - loss: 0.1518 - accuracy: 0.9556 - 240ms/epoch - 4ms/step
# Epoch 3950/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9564 - 236ms/epoch - 4ms/step
# Epoch 3951/4000
# 59/59 - 0s - loss: 0.1483 - accuracy: 0.9570 - 237ms/epoch - 4ms/step
# Epoch 3952/4000
# 59/59 - 0s - loss: 0.1479 - accuracy: 0.9567 - 239ms/epoch - 4ms/step
# Epoch 3953/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9566 - 237ms/epoch - 4ms/step
# Epoch 3954/4000
# 59/59 - 0s - loss: 0.1471 - accuracy: 0.9576 - 240ms/epoch - 4ms/step
# Epoch 3955/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9564 - 240ms/epoch - 4ms/step
# Epoch 3956/4000
# 59/59 - 0s - loss: 0.1479 - accuracy: 0.9566 - 237ms/epoch - 4ms/step
# Epoch 3957/4000
# 59/59 - 0s - loss: 0.1487 - accuracy: 0.9566 - 239ms/epoch - 4ms/step
# Epoch 3958/4000
# 59/59 - 0s - loss: 0.1500 - accuracy: 0.9564 - 239ms/epoch - 4ms/step
# Epoch 3959/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9561 - 241ms/epoch - 4ms/step
# Epoch 3960/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9565 - 240ms/epoch - 4ms/step
# Epoch 3961/4000
# 59/59 - 0s - loss: 0.1498 - accuracy: 0.9562 - 238ms/epoch - 4ms/step
# Epoch 3962/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9561 - 245ms/epoch - 4ms/step
# Epoch 3963/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9561 - 236ms/epoch - 4ms/step
# Epoch 3964/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9562 - 237ms/epoch - 4ms/step
# Epoch 3965/4000
# 59/59 - 0s - loss: 0.1490 - accuracy: 0.9560 - 238ms/epoch - 4ms/step
# Epoch 3966/4000
# 59/59 - 0s - loss: 0.1504 - accuracy: 0.9553 - 237ms/epoch - 4ms/step
# Epoch 3967/4000
# 59/59 - 0s - loss: 0.1488 - accuracy: 0.9563 - 239ms/epoch - 4ms/step
# Epoch 3968/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9565 - 239ms/epoch - 4ms/step
# Epoch 3969/4000
# 59/59 - 0s - loss: 0.1478 - accuracy: 0.9572 - 238ms/epoch - 4ms/step
# Epoch 3970/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9564 - 238ms/epoch - 4ms/step
# Epoch 3971/4000
# 59/59 - 0s - loss: 0.1474 - accuracy: 0.9570 - 240ms/epoch - 4ms/step
# Epoch 3972/4000
# 59/59 - 0s - loss: 0.1492 - accuracy: 0.9568 - 240ms/epoch - 4ms/step
# Epoch 3973/4000
# 59/59 - 0s - loss: 0.1486 - accuracy: 0.9568 - 240ms/epoch - 4ms/step
# Epoch 3974/4000
# 59/59 - 0s - loss: 0.1479 - accuracy: 0.9560 - 240ms/epoch - 4ms/step
# Epoch 3975/4000
# 59/59 - 0s - loss: 0.1485 - accuracy: 0.9563 - 238ms/epoch - 4ms/step
# Epoch 3976/4000
# 59/59 - 0s - loss: 0.1485 - accuracy: 0.9564 - 250ms/epoch - 4ms/step
# Epoch 3977/4000
# 59/59 - 0s - loss: 0.1508 - accuracy: 0.9557 - 241ms/epoch - 4ms/step
# Epoch 3978/4000
# 59/59 - 0s - loss: 0.1479 - accuracy: 0.9566 - 239ms/epoch - 4ms/step
# Epoch 3979/4000
# 59/59 - 0s - loss: 0.1472 - accuracy: 0.9568 - 239ms/epoch - 4ms/step
# Epoch 3980/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9562 - 239ms/epoch - 4ms/step
# Epoch 3981/4000
# 59/59 - 0s - loss: 0.1510 - accuracy: 0.9553 - 239ms/epoch - 4ms/step
# Epoch 3982/4000
# 59/59 - 0s - loss: 0.1484 - accuracy: 0.9563 - 236ms/epoch - 4ms/step
# Epoch 3983/4000
# 59/59 - 0s - loss: 0.1475 - accuracy: 0.9571 - 238ms/epoch - 4ms/step
# Epoch 3984/4000
# 59/59 - 0s - loss: 0.1475 - accuracy: 0.9571 - 238ms/epoch - 4ms/step
# Epoch 3985/4000
# 59/59 - 0s - loss: 0.1488 - accuracy: 0.9565 - 237ms/epoch - 4ms/step
# Epoch 3986/4000
# 59/59 - 0s - loss: 0.1514 - accuracy: 0.9554 - 238ms/epoch - 4ms/step
# Epoch 3987/4000
# 59/59 - 0s - loss: 0.1497 - accuracy: 0.9567 - 238ms/epoch - 4ms/step
# Epoch 3988/4000
# 59/59 - 0s - loss: 0.1480 - accuracy: 0.9561 - 240ms/epoch - 4ms/step
# Epoch 3989/4000
# 59/59 - 0s - loss: 0.1480 - accuracy: 0.9567 - 240ms/epoch - 4ms/step
# Epoch 3990/4000
# 59/59 - 0s - loss: 0.1495 - accuracy: 0.9566 - 237ms/epoch - 4ms/step
# Epoch 3991/4000
# 59/59 - 0s - loss: 0.1491 - accuracy: 0.9563 - 236ms/epoch - 4ms/step
# Epoch 3992/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9567 - 242ms/epoch - 4ms/step
# Epoch 3993/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9564 - 241ms/epoch - 4ms/step
# Epoch 3994/4000
# 59/59 - 0s - loss: 0.1482 - accuracy: 0.9565 - 239ms/epoch - 4ms/step
# Epoch 3995/4000
# 59/59 - 0s - loss: 0.1495 - accuracy: 0.9564 - 240ms/epoch - 4ms/step
# Epoch 3996/4000
# 59/59 - 0s - loss: 0.1493 - accuracy: 0.9560 - 235ms/epoch - 4ms/step
# Epoch 3997/4000
# 59/59 - 0s - loss: 0.1478 - accuracy: 0.9570 - 237ms/epoch - 4ms/step
# Epoch 3998/4000
# 59/59 - 0s - loss: 0.1489 - accuracy: 0.9566 - 247ms/epoch - 4ms/step
# Epoch 3999/4000
# 59/59 - 0s - loss: 0.1494 - accuracy: 0.9555 - 240ms/epoch - 4ms/step
# Epoch 4000/4000
# 59/59 - 0s - loss: 0.1480 - accuracy: 0.9570 - 237ms/epoch - 4ms/step
# 313/313 - 1s - loss: 0.1379 - accuracy: 0.9581 - 655ms/epoch - 2ms/step
# Test loss: 0.138
# Test accuracy: 95.810%

# %%
# model.get_weights()

# %% [markdown]
# ### Rebuild Model

# %%
# from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
# from data_gen.activations import SquareActivation
# from tensorflow.keras.regularizers import l2
# new_model = Sequential()
# for layer in model.layers:
#     if isinstance(layer, ReLU):
#         new_model.add(SquareActivation())
#     else:
#         new_layer = layer.__class__.from_config(layer.get_config())
#         new_model.add(new_layer)
#         if layer.weights:
#             new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

# new_model.summary()

# %%
# new_model.get_weights()

# %% [markdown]
# 第二阶段

# %%
# epochs = 4000
# # epochs = 3000
# # epochs = 200
# def sum_squared_error(y_true, y_pred):
#     return K.sum(K.square(y_pred - y_true), axis=-1)
# base_learning_rate=0.01
# class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
#     def __init__(self, base_learning_rate):
#         self.base_learning_rate = base_learning_rate

#     def __call__(self, epoch):
#         return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
#     # 创建自定义的学习率调度器

# # learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# # optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
# loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

# new_model.compile(loss=loss,
#                   optimizer=optimizer,
#                   metrics=['accuracy'])

# new_model.fit(x_train, y_train,
#               batch_size=batch_size,
#               epochs=epochs,
#               verbose=2,
#             #   validation_data=(x_val, y_val),
#               shuffle=True,
#               )

# score = new_model.evaluate(x_test, y_test, verbose=2)

# print(f'Test loss: { score[0]:.3f}')
# print(f'Test accuracy: {score[1] * 100:.3f}%')

# %% [markdown]
# ### Serialize Model and Weights

# %%
# model_json = new_model.to_json()
# with open(os.path.join(PATH, 'model100.json'), "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# new_model.save_weights(os.path.join(PATH, 'model100.h5'))
# print("Saved model to disk")

# %%
model_json = model.to_json()
with open(os.path.join(PATH, 'model101.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(os.path.join(PATH, 'model101.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
