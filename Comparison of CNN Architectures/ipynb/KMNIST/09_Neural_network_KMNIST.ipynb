# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-05-06 07:30:30.164011: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %%
import numpy as np
import gzip

def load_images(path):
    """加载图像文件（idx3-ubyte格式）"""
    with gzip.open(path, 'rb') as f:
        # 图像文件前16字节为幻数（4字节）、图像数量（4字节）、行数（4字节）、列数（4字节）
        data = np.frombuffer(f.read(), np.uint8, offset=16)
    return data.reshape(-1, 28, 28)  # 重塑为（样本数, 28, 28）

def load_labels(path):
    """加载标签文件（idx1-ubyte格式）"""
    with gzip.open(path, 'rb') as f:
        # 标签文件前8字节为幻数（4字节）、标签数量（4字节）
        data = np.frombuffer(f.read(), np.uint8, offset=8)
    return data  # 直接返回一维数组，无需reshape

# 加载训练和测试数据
x_train = load_images('/workspace/examples/vision_transformer/data/KMNIST/train-images-idx3-ubyte.gz')
y_train = load_labels('/workspace/examples/vision_transformer/data/KMNIST/train-labels-idx1-ubyte.gz')
x_test = load_images('/workspace/examples/vision_transformer/data/KMNIST/t10k-images-idx3-ubyte.gz')
y_test = load_labels('/workspace/examples/vision_transformer/data/KMNIST/t10k-labels-idx1-ubyte.gz')

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
# 以下预处理步骤与MNIST完全兼容，无需修改
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# 裁剪部分（根据需求选择性取消注释）
# x_train = x_train[:, 2:26, 2:26]
# x_test = x_test[:, 2:26, 2:26]

# 添加通道维度（Fashion-MNIST为灰度图，需扩展为[28,28,1]）
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# 归一化至[0,1]范围
x_train /= 255
x_test /= 255

print('Fashion-MNIST data ready')
# Out:
# Fashion-MNIST data ready

# %%
# Create validation data
# valsize=16
# valsize=500
valsize=5000
x_train = x_train[:-valsize]
x_val = x_train[-valsize:]
y_train = y_train[:-valsize]
y_val = y_train[-valsize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test9')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test9 of shape (10000, 28, 28, 1) in data/net_mnist/x_test9.h5
# Saving x_train of shape (55000, 28, 28, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (5000, 28, 28, 1) in data/net_mnist/x_val.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
# 创建模型
model = Sequential()

# Conv2D layer equivalent to nn.Conv2d
model.add(Conv2D(20, kernel_size=5,  input_shape=(28, 28, 1),kernel_regularizer=l2(0.0005)))  # Input shape (28x28x1), 20 filters, kernel size 5
model.add(AvgPool2D(pool_size=2))  # AvgPool2d with kernel size 2

# 第二个 Conv2D 层
model.add(Conv2D(50, kernel_size=5,kernel_regularizer=l2(0.0005)))  # 50 filters, kernel size 5
model.add(AvgPool2D(pool_size=2))  # AvgPool2d with kernel size 2

# Flatten the output to feed it into fully connected layers (Dense)
model.add(Flatten())  # Equivalent to x.view(-1, 50 * 4 * 4)

# Fully connected (Dense) layer
model.add(Dense(500,kernel_regularizer=l2(0.0005)))  # fc1 with 500 units

# BatchNormalization layer
model.add(BatchNormalization())

# SquareActivation activation
# model.add(SquareActivation())
model.add(ReLU())

# Final output layer
model.add(Dense(10,kernel_regularizer=l2(0.0005)))  # fc2 with 10 units for classification


# 输出模型架构

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 20)        520
#
#  average_pooling2d (AverageP  (None, 12, 12, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 50)          25050
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 50)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 500)               400500
#
#  batch_normalization (BatchN  (None, 500)              2000
#  ormalization)
#
#  re_lu (ReLU)                (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 433,080
# Trainable params: 432,080
# Non-trainable params: 1,000
# _________________________________________________________________
# 2025-05-06 07:30:33.668366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:33.707688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:33.710627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:33.713694: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-06 07:30:33.714288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:33.717114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:33.719751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:34.466151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:34.467989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:34.469609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-06 07:30:34.471194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-05-06 07:30:37.586492: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 54/54 - 4s - loss: 0.8647 - accuracy: 0.8380 - val_loss: 1.7232 - val_accuracy: 0.8672 - lr: 0.0010 - 4s/epoch - 66ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.5685 - accuracy: 0.9229 - val_loss: 1.3537 - val_accuracy: 0.9244 - lr: 0.0010 - 536ms/epoch - 10ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.4688 - accuracy: 0.9389 - val_loss: 0.9823 - val_accuracy: 0.9450 - lr: 0.0010 - 539ms/epoch - 10ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.4016 - accuracy: 0.9484 - val_loss: 0.7294 - val_accuracy: 0.9446 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.3508 - accuracy: 0.9535 - val_loss: 0.5327 - val_accuracy: 0.9572 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.3081 - accuracy: 0.9597 - val_loss: 0.4143 - val_accuracy: 0.9524 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.2781 - accuracy: 0.9631 - val_loss: 0.3127 - val_accuracy: 0.9690 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.2530 - accuracy: 0.9663 - val_loss: 0.2812 - val_accuracy: 0.9620 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.2334 - accuracy: 0.9685 - val_loss: 0.2542 - val_accuracy: 0.9646 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.2172 - accuracy: 0.9707 - val_loss: 0.2197 - val_accuracy: 0.9684 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.2038 - accuracy: 0.9720 - val_loss: 0.2040 - val_accuracy: 0.9710 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.1926 - accuracy: 0.9739 - val_loss: 0.1809 - val_accuracy: 0.9798 - lr: 0.0010 - 536ms/epoch - 10ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.1837 - accuracy: 0.9751 - val_loss: 0.1692 - val_accuracy: 0.9800 - lr: 0.0010 - 536ms/epoch - 10ms/step
# Epoch 14/4000
# 54/54 - 1s - loss: 0.1773 - accuracy: 0.9758 - val_loss: 0.1713 - val_accuracy: 0.9816 - lr: 0.0010 - 525ms/epoch - 10ms/step
# Epoch 15/4000
# 54/54 - 1s - loss: 0.1699 - accuracy: 0.9771 - val_loss: 0.1609 - val_accuracy: 0.9790 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 16/4000
# 54/54 - 1s - loss: 0.1637 - accuracy: 0.9791 - val_loss: 0.1666 - val_accuracy: 0.9758 - lr: 0.0010 - 523ms/epoch - 10ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.1596 - accuracy: 0.9795 - val_loss: 0.1476 - val_accuracy: 0.9836 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.1556 - accuracy: 0.9802 - val_loss: 0.1498 - val_accuracy: 0.9844 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 19/4000
# 54/54 - 1s - loss: 0.1533 - accuracy: 0.9805 - val_loss: 0.1545 - val_accuracy: 0.9804 - lr: 0.0010 - 526ms/epoch - 10ms/step
# Epoch 20/4000
# 54/54 - 1s - loss: 0.1480 - accuracy: 0.9823 - val_loss: 0.1496 - val_accuracy: 0.9820 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 21/4000
# 54/54 - 1s - loss: 0.1481 - accuracy: 0.9814 - val_loss: 0.1370 - val_accuracy: 0.9860 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 22/4000
# 54/54 - 1s - loss: 0.1441 - accuracy: 0.9831 - val_loss: 0.1439 - val_accuracy: 0.9840 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 23/4000
# 54/54 - 1s - loss: 0.1420 - accuracy: 0.9828 - val_loss: 0.1350 - val_accuracy: 0.9838 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.1391 - accuracy: 0.9837 - val_loss: 0.1278 - val_accuracy: 0.9896 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.1367 - accuracy: 0.9849 - val_loss: 0.1315 - val_accuracy: 0.9850 - lr: 0.0010 - 522ms/epoch - 10ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.1356 - accuracy: 0.9845 - val_loss: 0.1249 - val_accuracy: 0.9888 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 27/4000
# 54/54 - 1s - loss: 0.1337 - accuracy: 0.9853 - val_loss: 0.1256 - val_accuracy: 0.9884 - lr: 0.0010 - 524ms/epoch - 10ms/step
# Epoch 28/4000
# 54/54 - 1s - loss: 0.1326 - accuracy: 0.9850 - val_loss: 0.1260 - val_accuracy: 0.9890 - lr: 0.0010 - 526ms/epoch - 10ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.1316 - accuracy: 0.9849 - val_loss: 0.1324 - val_accuracy: 0.9872 - lr: 0.0010 - 524ms/epoch - 10ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.1269 - accuracy: 0.9878 - val_loss: 0.1224 - val_accuracy: 0.9904 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.1266 - accuracy: 0.9870 - val_loss: 0.1320 - val_accuracy: 0.9860 - lr: 0.0010 - 524ms/epoch - 10ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.1272 - accuracy: 0.9869 - val_loss: 0.1154 - val_accuracy: 0.9912 - lr: 0.0010 - 539ms/epoch - 10ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.1234 - accuracy: 0.9879 - val_loss: 0.1168 - val_accuracy: 0.9910 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 34/4000
# 54/54 - 1s - loss: 0.1205 - accuracy: 0.9891 - val_loss: 0.1210 - val_accuracy: 0.9890 - lr: 0.0010 - 525ms/epoch - 10ms/step
# Epoch 35/4000
# 54/54 - 1s - loss: 0.1206 - accuracy: 0.9883 - val_loss: 0.1154 - val_accuracy: 0.9906 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 36/4000
# 54/54 - 1s - loss: 0.1193 - accuracy: 0.9886 - val_loss: 0.1155 - val_accuracy: 0.9932 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 37/4000
# 54/54 - 1s - loss: 0.1180 - accuracy: 0.9895 - val_loss: 0.1107 - val_accuracy: 0.9910 - lr: 0.0010 - 534ms/epoch - 10ms/step
# Epoch 38/4000
# 54/54 - 1s - loss: 0.1182 - accuracy: 0.9890 - val_loss: 0.1115 - val_accuracy: 0.9932 - lr: 0.0010 - 525ms/epoch - 10ms/step
# Epoch 39/4000
# 54/54 - 1s - loss: 0.1156 - accuracy: 0.9898 - val_loss: 0.1041 - val_accuracy: 0.9960 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 40/4000
# 54/54 - 1s - loss: 0.1138 - accuracy: 0.9899 - val_loss: 0.1121 - val_accuracy: 0.9896 - lr: 0.0010 - 526ms/epoch - 10ms/step
# Epoch 41/4000
# 54/54 - 1s - loss: 0.1137 - accuracy: 0.9900 - val_loss: 0.1112 - val_accuracy: 0.9908 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 42/4000
# 54/54 - 1s - loss: 0.1147 - accuracy: 0.9889 - val_loss: 0.1144 - val_accuracy: 0.9900 - lr: 0.0010 - 535ms/epoch - 10ms/step
# Epoch 43/4000
# 54/54 - 1s - loss: 0.1130 - accuracy: 0.9899 - val_loss: 0.1044 - val_accuracy: 0.9922 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 44/4000
# 54/54 - 1s - loss: 0.1148 - accuracy: 0.9886 - val_loss: 0.1045 - val_accuracy: 0.9926 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 45/4000
# 54/54 - 1s - loss: 0.1109 - accuracy: 0.9911 - val_loss: 0.1067 - val_accuracy: 0.9918 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 46/4000
# 54/54 - 1s - loss: 0.1067 - accuracy: 0.9921 - val_loss: 0.1040 - val_accuracy: 0.9932 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 47/4000
# 54/54 - 1s - loss: 0.1059 - accuracy: 0.9916 - val_loss: 0.1041 - val_accuracy: 0.9946 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 48/4000
# 54/54 - 1s - loss: 0.1028 - accuracy: 0.9930 - val_loss: 0.1064 - val_accuracy: 0.9914 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 49/4000
# 54/54 - 1s - loss: 0.1042 - accuracy: 0.9919 - val_loss: 0.0980 - val_accuracy: 0.9968 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 50/4000
# 54/54 - 1s - loss: 0.1060 - accuracy: 0.9911 - val_loss: 0.1018 - val_accuracy: 0.9936 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 51/4000
# 54/54 - 1s - loss: 0.1061 - accuracy: 0.9912 - val_loss: 0.0992 - val_accuracy: 0.9944 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 52/4000
# 54/54 - 1s - loss: 0.1013 - accuracy: 0.9929 - val_loss: 0.1000 - val_accuracy: 0.9942 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 53/4000
# 54/54 - 1s - loss: 0.0991 - accuracy: 0.9934 - val_loss: 0.0943 - val_accuracy: 0.9948 - lr: 0.0010 - 538ms/epoch - 10ms/step
# Epoch 54/4000
# 54/54 - 1s - loss: 0.0989 - accuracy: 0.9930 - val_loss: 0.0924 - val_accuracy: 0.9960 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 55/4000
# 54/54 - 1s - loss: 0.0999 - accuracy: 0.9926 - val_loss: 0.0944 - val_accuracy: 0.9952 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 56/4000
# 54/54 - 1s - loss: 0.0971 - accuracy: 0.9934 - val_loss: 0.0941 - val_accuracy: 0.9952 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 57/4000
# 54/54 - 1s - loss: 0.0963 - accuracy: 0.9937 - val_loss: 0.0920 - val_accuracy: 0.9962 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 58/4000
# 54/54 - 1s - loss: 0.0986 - accuracy: 0.9927 - val_loss: 0.0949 - val_accuracy: 0.9940 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 59/4000
# 54/54 - 1s - loss: 0.0977 - accuracy: 0.9932 - val_loss: 0.0892 - val_accuracy: 0.9958 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 60/4000
# 54/54 - 1s - loss: 0.0969 - accuracy: 0.9929 - val_loss: 0.0916 - val_accuracy: 0.9964 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 61/4000
# 54/54 - 1s - loss: 0.0983 - accuracy: 0.9928 - val_loss: 0.0914 - val_accuracy: 0.9962 - lr: 0.0010 - 535ms/epoch - 10ms/step
# Epoch 62/4000
# 54/54 - 1s - loss: 0.0942 - accuracy: 0.9946 - val_loss: 0.0930 - val_accuracy: 0.9944 - lr: 0.0010 - 536ms/epoch - 10ms/step
# Epoch 63/4000
# 54/54 - 1s - loss: 0.0913 - accuracy: 0.9952 - val_loss: 0.0887 - val_accuracy: 0.9966 - lr: 0.0010 - 538ms/epoch - 10ms/step
# Epoch 64/4000
# 54/54 - 1s - loss: 0.0928 - accuracy: 0.9939 - val_loss: 0.0888 - val_accuracy: 0.9964 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 65/4000
# 54/54 - 1s - loss: 0.0938 - accuracy: 0.9935 - val_loss: 0.0869 - val_accuracy: 0.9960 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 66/4000
# 54/54 - 1s - loss: 0.0915 - accuracy: 0.9941 - val_loss: 0.0904 - val_accuracy: 0.9958 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 67/4000
# 54/54 - 1s - loss: 0.0924 - accuracy: 0.9939 - val_loss: 0.0897 - val_accuracy: 0.9964 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 68/4000
# 54/54 - 1s - loss: 0.0901 - accuracy: 0.9950 - val_loss: 0.0853 - val_accuracy: 0.9960 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 69/4000
# 54/54 - 1s - loss: 0.0887 - accuracy: 0.9950 - val_loss: 0.0881 - val_accuracy: 0.9958 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 70/4000
# 54/54 - 1s - loss: 0.0889 - accuracy: 0.9948 - val_loss: 0.0824 - val_accuracy: 0.9980 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 71/4000
# 54/54 - 1s - loss: 0.0882 - accuracy: 0.9951 - val_loss: 0.0823 - val_accuracy: 0.9976 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 72/4000
# 54/54 - 1s - loss: 0.0875 - accuracy: 0.9951 - val_loss: 0.0851 - val_accuracy: 0.9970 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 73/4000
# 54/54 - 1s - loss: 0.0866 - accuracy: 0.9952 - val_loss: 0.0807 - val_accuracy: 0.9972 - lr: 0.0010 - 534ms/epoch - 10ms/step
# Epoch 74/4000
# 54/54 - 1s - loss: 0.0859 - accuracy: 0.9957 - val_loss: 0.0822 - val_accuracy: 0.9968 - lr: 0.0010 - 527ms/epoch - 10ms/step
# Epoch 75/4000
# 54/54 - 1s - loss: 0.0875 - accuracy: 0.9946 - val_loss: 0.0861 - val_accuracy: 0.9946 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 76/4000
# 54/54 - 1s - loss: 0.0868 - accuracy: 0.9950 - val_loss: 0.0871 - val_accuracy: 0.9946 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 77/4000
# 54/54 - 1s - loss: 0.0856 - accuracy: 0.9955 - val_loss: 0.0849 - val_accuracy: 0.9966 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 78/4000
# 54/54 - 1s - loss: 0.0859 - accuracy: 0.9948 - val_loss: 0.0877 - val_accuracy: 0.9958 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 79/4000
# 54/54 - 1s - loss: 0.0859 - accuracy: 0.9953 - val_loss: 0.0815 - val_accuracy: 0.9958 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 80/4000
# 54/54 - 1s - loss: 0.0840 - accuracy: 0.9957 - val_loss: 0.0828 - val_accuracy: 0.9956 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 81/4000
# 54/54 - 1s - loss: 0.0847 - accuracy: 0.9950 - val_loss: 0.0809 - val_accuracy: 0.9972 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 82/4000
# 54/54 - 1s - loss: 0.0847 - accuracy: 0.9952 - val_loss: 0.0788 - val_accuracy: 0.9982 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 83/4000
# 54/54 - 1s - loss: 0.0815 - accuracy: 0.9960 - val_loss: 0.0816 - val_accuracy: 0.9968 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 84/4000
# 54/54 - 1s - loss: 0.0814 - accuracy: 0.9960 - val_loss: 0.0786 - val_accuracy: 0.9976 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 85/4000
# 54/54 - 1s - loss: 0.0797 - accuracy: 0.9965 - val_loss: 0.0757 - val_accuracy: 0.9984 - lr: 0.0010 - 539ms/epoch - 10ms/step
# Epoch 86/4000
# 54/54 - 1s - loss: 0.0801 - accuracy: 0.9960 - val_loss: 0.0785 - val_accuracy: 0.9960 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 87/4000
# 54/54 - 1s - loss: 0.0823 - accuracy: 0.9951 - val_loss: 0.0798 - val_accuracy: 0.9962 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 88/4000
# 54/54 - 1s - loss: 0.0845 - accuracy: 0.9947 - val_loss: 0.0783 - val_accuracy: 0.9970 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 89/4000
# 54/54 - 1s - loss: 0.0817 - accuracy: 0.9955 - val_loss: 0.0742 - val_accuracy: 0.9980 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 90/4000
# 54/54 - 1s - loss: 0.0813 - accuracy: 0.9961 - val_loss: 0.0785 - val_accuracy: 0.9964 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 91/4000
# 54/54 - 1s - loss: 0.0795 - accuracy: 0.9963 - val_loss: 0.0763 - val_accuracy: 0.9978 - lr: 0.0010 - 528ms/epoch - 10ms/step
# Epoch 92/4000
# 54/54 - 1s - loss: 0.0783 - accuracy: 0.9964 - val_loss: 0.0819 - val_accuracy: 0.9942 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 93/4000
# 54/54 - 1s - loss: 0.0836 - accuracy: 0.9942 - val_loss: 0.0864 - val_accuracy: 0.9916 - lr: 0.0010 - 535ms/epoch - 10ms/step
# Epoch 94/4000
# 54/54 - 1s - loss: 0.0839 - accuracy: 0.9949 - val_loss: 0.0783 - val_accuracy: 0.9966 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 95/4000
# 54/54 - 1s - loss: 0.0820 - accuracy: 0.9959 - val_loss: 0.0776 - val_accuracy: 0.9972 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 96/4000
# 54/54 - 1s - loss: 0.0771 - accuracy: 0.9969 - val_loss: 0.0726 - val_accuracy: 0.9988 - lr: 0.0010 - 535ms/epoch - 10ms/step
# Epoch 97/4000
# 54/54 - 1s - loss: 0.0751 - accuracy: 0.9971 - val_loss: 0.0746 - val_accuracy: 0.9970 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 98/4000
# 54/54 - 1s - loss: 0.0748 - accuracy: 0.9970 - val_loss: 0.0761 - val_accuracy: 0.9966 - lr: 0.0010 - 530ms/epoch - 10ms/step
# Epoch 99/4000
# 54/54 - 1s - loss: 0.0738 - accuracy: 0.9973 - val_loss: 0.0718 - val_accuracy: 0.9980 - lr: 0.0010 - 535ms/epoch - 10ms/step
# Epoch 100/4000
# 54/54 - 1s - loss: 0.0759 - accuracy: 0.9961 - val_loss: 0.0752 - val_accuracy: 0.9980 - lr: 0.0010 - 529ms/epoch - 10ms/step
# Epoch 101/4000
# 54/54 - 1s - loss: 0.0678 - accuracy: 0.9987 - val_loss: 0.0623 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 533ms/epoch - 10ms/step
# Epoch 102/4000
# 54/54 - 1s - loss: 0.0606 - accuracy: 0.9999 - val_loss: 0.0597 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 532ms/epoch - 10ms/step
# Epoch 103/4000
# 54/54 - 1s - loss: 0.0576 - accuracy: 0.9999 - val_loss: 0.0584 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 533ms/epoch - 10ms/step
# Epoch 104/4000
# 54/54 - 1s - loss: 0.0559 - accuracy: 0.9999 - val_loss: 0.0570 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 533ms/epoch - 10ms/step
# Epoch 105/4000
# 54/54 - 1s - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 534ms/epoch - 10ms/step
# Epoch 106/4000
# 54/54 - 1s - loss: 0.0539 - accuracy: 0.9999 - val_loss: 0.0545 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 531ms/epoch - 10ms/step
# Epoch 107/4000
# 54/54 - 1s - loss: 0.0532 - accuracy: 0.9999 - val_loss: 0.0538 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 531ms/epoch - 10ms/step
# Epoch 108/4000
# 54/54 - 1s - loss: 0.0531 - accuracy: 0.9998 - val_loss: 0.0523 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 533ms/epoch - 10ms/step
# Epoch 109/4000
# 54/54 - 1s - loss: 0.0531 - accuracy: 0.9997 - val_loss: 0.0526 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 530ms/epoch - 10ms/step
# Epoch 110/4000
# 54/54 - 1s - loss: 0.0531 - accuracy: 0.9998 - val_loss: 0.0522 - val_accuracy: 1.0000 - lr: 5.0000e-04 - 536ms/epoch - 10ms/step
# Epoch 111/4000
# 54/54 - 1s - loss: 0.0530 - accuracy: 0.9998 - val_loss: 0.0515 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 535ms/epoch - 10ms/step
# Epoch 112/4000
# 54/54 - 1s - loss: 0.0540 - accuracy: 0.9993 - val_loss: 0.0547 - val_accuracy: 0.9996 - lr: 5.0000e-04 - 532ms/epoch - 10ms/step
# Epoch 113/4000
# 54/54 - 1s - loss: 0.0549 - accuracy: 0.9992 - val_loss: 0.0530 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 531ms/epoch - 10ms/step
# Epoch 114/4000
# 54/54 - 1s - loss: 0.0563 - accuracy: 0.9988 - val_loss: 0.0540 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 531ms/epoch - 10ms/step
# Epoch 115/4000
# 54/54 - 1s - loss: 0.0568 - accuracy: 0.9987 - val_loss: 0.0540 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 531ms/epoch - 10ms/step
# Epoch 116/4000
# 54/54 - 1s - loss: 0.0572 - accuracy: 0.9985 - val_loss: 0.0527 - val_accuracy: 0.9996 - lr: 5.0000e-04 - 530ms/epoch - 10ms/step
# Epoch 117/4000
# 54/54 - 1s - loss: 0.0563 - accuracy: 0.9990 - val_loss: 0.0523 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 531ms/epoch - 10ms/step
# Epoch 118/4000
# 54/54 - 1s - loss: 0.0548 - accuracy: 0.9992 - val_loss: 0.0523 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 530ms/epoch - 10ms/step
# Epoch 119/4000
# 54/54 - 1s - loss: 0.0547 - accuracy: 0.9993 - val_loss: 0.0527 - val_accuracy: 0.9996 - lr: 5.0000e-04 - 534ms/epoch - 10ms/step
# Epoch 120/4000
# 54/54 - 1s - loss: 0.0541 - accuracy: 0.9993 - val_loss: 0.0530 - val_accuracy: 0.9996 - lr: 5.0000e-04 - 529ms/epoch - 10ms/step
# Epoch 121/4000
# 54/54 - 1s - loss: 0.0540 - accuracy: 0.9993 - val_loss: 0.0521 - val_accuracy: 0.9998 - lr: 5.0000e-04 - 534ms/epoch - 10ms/step
# 313/313 - 1s - loss: 0.3388 - accuracy: 0.9163 - 595ms/epoch - 2ms/step
# Test loss: 0.339
# Test accuracy: 91.630%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 20)        520
#
#  average_pooling2d (AverageP  (None, 12, 12, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 50)          25050
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 50)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 500)               400500
#
#  batch_normalization (BatchN  (None, 500)              2000
#  ormalization)
#
#  square_activation (SquareAc  (None, 500)              0
#  tivation)
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 433,080
# Trainable params: 432,080
# Non-trainable params: 1,000
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 54/54 - 1s - loss: 0.1268 - accuracy: 0.9743 - val_loss: 0.0885 - val_accuracy: 0.9870 - lr: 0.0010 - 1s/epoch - 26ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.1010 - accuracy: 0.9849 - val_loss: 0.0846 - val_accuracy: 0.9882 - lr: 0.0010 - 534ms/epoch - 10ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.0925 - accuracy: 0.9884 - val_loss: 0.0730 - val_accuracy: 0.9938 - lr: 0.0010 - 539ms/epoch - 10ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.0903 - accuracy: 0.9897 - val_loss: 0.0777 - val_accuracy: 0.9930 - lr: 0.0010 - 538ms/epoch - 10ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.0900 - accuracy: 0.9899 - val_loss: 0.0819 - val_accuracy: 0.9930 - lr: 0.0010 - 535ms/epoch - 10ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.0871 - accuracy: 0.9916 - val_loss: 0.0770 - val_accuracy: 0.9954 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.0869 - accuracy: 0.9914 - val_loss: 0.0811 - val_accuracy: 0.9948 - lr: 0.0010 - 534ms/epoch - 10ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.0850 - accuracy: 0.9927 - val_loss: 0.0839 - val_accuracy: 0.9910 - lr: 0.0010 - 532ms/epoch - 10ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.0838 - accuracy: 0.9926 - val_loss: 0.0788 - val_accuracy: 0.9942 - lr: 0.0010 - 534ms/epoch - 10ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.0851 - accuracy: 0.9921 - val_loss: 0.0795 - val_accuracy: 0.9944 - lr: 0.0010 - 531ms/epoch - 10ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.0864 - accuracy: 0.9922 - val_loss: 0.0824 - val_accuracy: 0.9936 - lr: 0.0010 - 536ms/epoch - 10ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.0853 - accuracy: 0.9924 - val_loss: 0.0790 - val_accuracy: 0.9948 - lr: 0.0010 - 533ms/epoch - 10ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.0853 - accuracy: 0.9926 - val_loss: 0.0782 - val_accuracy: 0.9956 - lr: 0.0010 - 540ms/epoch - 10ms/step
# 313/313 - 1s - loss: 0.4427 - accuracy: 0.9087 - 566ms/epoch - 2ms/step
# Test loss: 0.443
# Test accuracy: 90.870%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model25.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model25.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
