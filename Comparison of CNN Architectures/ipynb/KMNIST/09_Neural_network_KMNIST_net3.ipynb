# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-06-08 09:07:01.577548: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %%
import numpy as np
import gzip

def load_images(path):
    """加载图像文件（idx3-ubyte格式）"""
    with gzip.open(path, 'rb') as f:
        # 图像文件前16字节为幻数（4字节）、图像数量（4字节）、行数（4字节）、列数（4字节）
        data = np.frombuffer(f.read(), np.uint8, offset=16)
    return data.reshape(-1, 28, 28)  # 重塑为（样本数, 28, 28）

def load_labels(path):
    """加载标签文件（idx1-ubyte格式）"""
    with gzip.open(path, 'rb') as f:
        # 标签文件前8字节为幻数（4字节）、标签数量（4字节）
        data = np.frombuffer(f.read(), np.uint8, offset=8)
    return data  # 直接返回一维数组，无需reshape

# 加载训练和测试数据
x_train = load_images('/workspace/examples/vision_transformer/data/KMNIST/train-images-idx3-ubyte.gz')
y_train = load_labels('/workspace/examples/vision_transformer/data/KMNIST/train-labels-idx1-ubyte.gz')
x_test = load_images('/workspace/examples/vision_transformer/data/KMNIST/t10k-images-idx3-ubyte.gz')
y_test = load_labels('/workspace/examples/vision_transformer/data/KMNIST/t10k-labels-idx1-ubyte.gz')

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
# 以下预处理步骤与MNIST完全兼容，无需修改
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# 裁剪部分（根据需求选择性取消注释）
# x_train = x_train[:, 2:26, 2:26]
# x_test = x_test[:, 2:26, 2:26]

# 添加通道维度（Fashion-MNIST为灰度图，需扩展为[28,28,1]）
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# 归一化至[0,1]范围
x_train /= 255
x_test /= 255

print('Fashion-MNIST data ready')
# Out:
# Fashion-MNIST data ready

# %%
# Create validation data
# valsize=16
# valsize=500
valsize=5000
x_train = x_train[:-valsize]
x_val = x_train[-valsize:]
y_train = y_train[:-valsize]
y_val = y_train[-valsize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test9')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test9 of shape (10000, 28, 28, 1) in data/net_mnist/x_test9.h5
# Saving x_train of shape (55000, 28, 28, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (5000, 28, 28, 1) in data/net_mnist/x_val.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D,AveragePooling2D,Softmax
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2

# 创建模型
model = Sequential()

# 卷积层1（无填充，直接输入28x28）
model.add(Conv2D(6, kernel_size=5, input_shape=(28, 28, 1),kernel_regularizer=l2(0.0005)))  # 输出24x24x6
# model.add(ReLU())  # 分离的激活层[8](@ref)
model.add(AvgPool2D(pool_size=2, strides=2))  # 输出12x12x6

# 卷积层2
model.add(Conv2D(16, kernel_size=5,kernel_regularizer=l2(0.0005)))  # 输出8x8x16
# model.add(ReLU())  # 分离的激活层[8](@ref)
model.add(AvgPool2D(pool_size=2, strides=2))  # 输出4x4x16

# 全连接部分
model.add(Flatten())  # 展平为256维[4](@ref)
model.add(Dense(120,kernel_regularizer=l2(0.0005)))  # 全连接层1
# model.add(ReLU())  # 分离的激活层[8](@ref)
model.add(Dense(84,kernel_regularizer=l2(0.0005)))   # 全连接层2
model.add(BatchNormalization())
model.add(ReLU())  # 分离的激活层[8](@ref)
model.add(Dense(10,kernel_regularizer=l2(0.0005)))   # 输出层（无激活）[3](@ref)


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  average_pooling2d (AverageP  (None, 12, 12, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2416
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 120)               30840
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  batch_normalization (BatchN  (None, 84)               336
#  ormalization)
#
#  re_lu (ReLU)                (None, 84)                0
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44,762
# Trainable params: 44,594
# Non-trainable params: 168
# _________________________________________________________________
# 2025-06-08 09:07:05.817374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:05.857068: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:05.859870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:05.862791: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-08 09:07:05.863400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:05.866231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:05.868824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:06.615904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:06.617790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:06.619461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-08 09:07:06.621055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-06-08 09:07:10.347704: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 54/54 - 3s - loss: 1.1566 - accuracy: 0.7031 - val_loss: 1.6571 - val_accuracy: 0.7610 - 3s/epoch - 60ms/step
# Epoch 2/4000
# 54/54 - 0s - loss: 0.7234 - accuracy: 0.8439 - val_loss: 1.2866 - val_accuracy: 0.8556 - 317ms/epoch - 6ms/step
# Epoch 3/4000
# 54/54 - 0s - loss: 0.6112 - accuracy: 0.8724 - val_loss: 0.9841 - val_accuracy: 0.8788 - 309ms/epoch - 6ms/step
# Epoch 4/4000
# 54/54 - 0s - loss: 0.5444 - accuracy: 0.8892 - val_loss: 0.7869 - val_accuracy: 0.8916 - 322ms/epoch - 6ms/step
# Epoch 5/4000
# 54/54 - 0s - loss: 0.4959 - accuracy: 0.9015 - val_loss: 0.6311 - val_accuracy: 0.8996 - 311ms/epoch - 6ms/step
# Epoch 6/4000
# 54/54 - 0s - loss: 0.4590 - accuracy: 0.9103 - val_loss: 0.5626 - val_accuracy: 0.9008 - 296ms/epoch - 5ms/step
# Epoch 7/4000
# 54/54 - 0s - loss: 0.4305 - accuracy: 0.9169 - val_loss: 0.4875 - val_accuracy: 0.9106 - 308ms/epoch - 6ms/step
# Epoch 8/4000
# 54/54 - 0s - loss: 0.4074 - accuracy: 0.9218 - val_loss: 0.4329 - val_accuracy: 0.9248 - 302ms/epoch - 6ms/step
# Epoch 9/4000
# 54/54 - 0s - loss: 0.3885 - accuracy: 0.9267 - val_loss: 0.4020 - val_accuracy: 0.9230 - 304ms/epoch - 6ms/step
# Epoch 10/4000
# 54/54 - 0s - loss: 0.3707 - accuracy: 0.9298 - val_loss: 0.3814 - val_accuracy: 0.9276 - 303ms/epoch - 6ms/step
# Epoch 11/4000
# 54/54 - 0s - loss: 0.3558 - accuracy: 0.9329 - val_loss: 0.3611 - val_accuracy: 0.9328 - 303ms/epoch - 6ms/step
# Epoch 12/4000
# 54/54 - 0s - loss: 0.3417 - accuracy: 0.9365 - val_loss: 0.3524 - val_accuracy: 0.9306 - 302ms/epoch - 6ms/step
# Epoch 13/4000
# 54/54 - 0s - loss: 0.3315 - accuracy: 0.9384 - val_loss: 0.3449 - val_accuracy: 0.9340 - 306ms/epoch - 6ms/step
# Epoch 14/4000
# 54/54 - 0s - loss: 0.3211 - accuracy: 0.9407 - val_loss: 0.3408 - val_accuracy: 0.9268 - 306ms/epoch - 6ms/step
# Epoch 15/4000
# 54/54 - 0s - loss: 0.3093 - accuracy: 0.9430 - val_loss: 0.3137 - val_accuracy: 0.9386 - 304ms/epoch - 6ms/step
# Epoch 16/4000
# 54/54 - 0s - loss: 0.3025 - accuracy: 0.9441 - val_loss: 0.2983 - val_accuracy: 0.9466 - 304ms/epoch - 6ms/step
# Epoch 17/4000
# 54/54 - 0s - loss: 0.2933 - accuracy: 0.9461 - val_loss: 0.2969 - val_accuracy: 0.9440 - 303ms/epoch - 6ms/step
# Epoch 18/4000
# 54/54 - 0s - loss: 0.2855 - accuracy: 0.9485 - val_loss: 0.2914 - val_accuracy: 0.9422 - 304ms/epoch - 6ms/step
# Epoch 19/4000
# 54/54 - 0s - loss: 0.2791 - accuracy: 0.9498 - val_loss: 0.2862 - val_accuracy: 0.9442 - 309ms/epoch - 6ms/step
# Epoch 20/4000
# 54/54 - 0s - loss: 0.2739 - accuracy: 0.9498 - val_loss: 0.2789 - val_accuracy: 0.9474 - 316ms/epoch - 6ms/step
# Epoch 21/4000
# 54/54 - 0s - loss: 0.2679 - accuracy: 0.9522 - val_loss: 0.2694 - val_accuracy: 0.9546 - 324ms/epoch - 6ms/step
# Epoch 22/4000
# 54/54 - 0s - loss: 0.2624 - accuracy: 0.9521 - val_loss: 0.2651 - val_accuracy: 0.9538 - 309ms/epoch - 6ms/step
# Epoch 23/4000
# 54/54 - 0s - loss: 0.2564 - accuracy: 0.9544 - val_loss: 0.2538 - val_accuracy: 0.9536 - 303ms/epoch - 6ms/step
# Epoch 24/4000
# 54/54 - 0s - loss: 0.2507 - accuracy: 0.9561 - val_loss: 0.2471 - val_accuracy: 0.9558 - 305ms/epoch - 6ms/step
# Epoch 25/4000
# 54/54 - 0s - loss: 0.2470 - accuracy: 0.9561 - val_loss: 0.2547 - val_accuracy: 0.9486 - 305ms/epoch - 6ms/step
# Epoch 26/4000
# 54/54 - 0s - loss: 0.2434 - accuracy: 0.9566 - val_loss: 0.2357 - val_accuracy: 0.9620 - 304ms/epoch - 6ms/step
# Epoch 27/4000
# 54/54 - 0s - loss: 0.2418 - accuracy: 0.9579 - val_loss: 0.2383 - val_accuracy: 0.9562 - 302ms/epoch - 6ms/step
# Epoch 28/4000
# 54/54 - 0s - loss: 0.2371 - accuracy: 0.9582 - val_loss: 0.2332 - val_accuracy: 0.9604 - 305ms/epoch - 6ms/step
# Epoch 29/4000
# 54/54 - 0s - loss: 0.2329 - accuracy: 0.9595 - val_loss: 0.2272 - val_accuracy: 0.9614 - 304ms/epoch - 6ms/step
# Epoch 30/4000
# 54/54 - 0s - loss: 0.2295 - accuracy: 0.9612 - val_loss: 0.2232 - val_accuracy: 0.9622 - 302ms/epoch - 6ms/step
# Epoch 31/4000
# 54/54 - 0s - loss: 0.2262 - accuracy: 0.9612 - val_loss: 0.2183 - val_accuracy: 0.9652 - 300ms/epoch - 6ms/step
# Epoch 32/4000
# 54/54 - 0s - loss: 0.2247 - accuracy: 0.9616 - val_loss: 0.2169 - val_accuracy: 0.9614 - 306ms/epoch - 6ms/step
# Epoch 33/4000
# 54/54 - 0s - loss: 0.2209 - accuracy: 0.9623 - val_loss: 0.2114 - val_accuracy: 0.9636 - 304ms/epoch - 6ms/step
# Epoch 34/4000
# 54/54 - 0s - loss: 0.2185 - accuracy: 0.9632 - val_loss: 0.2179 - val_accuracy: 0.9626 - 302ms/epoch - 6ms/step
# Epoch 35/4000
# 54/54 - 0s - loss: 0.2160 - accuracy: 0.9635 - val_loss: 0.2092 - val_accuracy: 0.9662 - 309ms/epoch - 6ms/step
# Epoch 36/4000
# 54/54 - 0s - loss: 0.2137 - accuracy: 0.9639 - val_loss: 0.2111 - val_accuracy: 0.9642 - 315ms/epoch - 6ms/step
# Epoch 37/4000
# 54/54 - 0s - loss: 0.2110 - accuracy: 0.9642 - val_loss: 0.2066 - val_accuracy: 0.9632 - 320ms/epoch - 6ms/step
# Epoch 38/4000
# 54/54 - 0s - loss: 0.2093 - accuracy: 0.9646 - val_loss: 0.2061 - val_accuracy: 0.9646 - 318ms/epoch - 6ms/step
# Epoch 39/4000
# 54/54 - 0s - loss: 0.2066 - accuracy: 0.9656 - val_loss: 0.2046 - val_accuracy: 0.9646 - 316ms/epoch - 6ms/step
# Epoch 40/4000
# 54/54 - 0s - loss: 0.2062 - accuracy: 0.9655 - val_loss: 0.1958 - val_accuracy: 0.9672 - 303ms/epoch - 6ms/step
# Epoch 41/4000
# 54/54 - 0s - loss: 0.2030 - accuracy: 0.9660 - val_loss: 0.1990 - val_accuracy: 0.9666 - 299ms/epoch - 6ms/step
# Epoch 42/4000
# 54/54 - 0s - loss: 0.2033 - accuracy: 0.9654 - val_loss: 0.1943 - val_accuracy: 0.9674 - 306ms/epoch - 6ms/step
# Epoch 43/4000
# 54/54 - 0s - loss: 0.1988 - accuracy: 0.9677 - val_loss: 0.1956 - val_accuracy: 0.9654 - 306ms/epoch - 6ms/step
# Epoch 44/4000
# 54/54 - 0s - loss: 0.1986 - accuracy: 0.9674 - val_loss: 0.1882 - val_accuracy: 0.9706 - 303ms/epoch - 6ms/step
# Epoch 45/4000
# 54/54 - 0s - loss: 0.1954 - accuracy: 0.9676 - val_loss: 0.1901 - val_accuracy: 0.9680 - 300ms/epoch - 6ms/step
# Epoch 46/4000
# 54/54 - 0s - loss: 0.1946 - accuracy: 0.9681 - val_loss: 0.1912 - val_accuracy: 0.9672 - 301ms/epoch - 6ms/step
# Epoch 47/4000
# 54/54 - 0s - loss: 0.1938 - accuracy: 0.9687 - val_loss: 0.1855 - val_accuracy: 0.9726 - 301ms/epoch - 6ms/step
# Epoch 48/4000
# 54/54 - 0s - loss: 0.1922 - accuracy: 0.9681 - val_loss: 0.1807 - val_accuracy: 0.9704 - 305ms/epoch - 6ms/step
# Epoch 49/4000
# 54/54 - 0s - loss: 0.1911 - accuracy: 0.9690 - val_loss: 0.1831 - val_accuracy: 0.9674 - 300ms/epoch - 6ms/step
# Epoch 50/4000
# 54/54 - 0s - loss: 0.1885 - accuracy: 0.9693 - val_loss: 0.1828 - val_accuracy: 0.9692 - 301ms/epoch - 6ms/step
# Epoch 51/4000
# 54/54 - 0s - loss: 0.1880 - accuracy: 0.9695 - val_loss: 0.1794 - val_accuracy: 0.9720 - 304ms/epoch - 6ms/step
# Epoch 52/4000
# 54/54 - 0s - loss: 0.1862 - accuracy: 0.9697 - val_loss: 0.1865 - val_accuracy: 0.9686 - 305ms/epoch - 6ms/step
# Epoch 53/4000
# 54/54 - 0s - loss: 0.1850 - accuracy: 0.9703 - val_loss: 0.1853 - val_accuracy: 0.9658 - 312ms/epoch - 6ms/step
# Epoch 54/4000
# 54/54 - 0s - loss: 0.1848 - accuracy: 0.9702 - val_loss: 0.1790 - val_accuracy: 0.9706 - 325ms/epoch - 6ms/step
# Epoch 55/4000
# 54/54 - 0s - loss: 0.1817 - accuracy: 0.9707 - val_loss: 0.1784 - val_accuracy: 0.9720 - 314ms/epoch - 6ms/step
# Epoch 56/4000
# 54/54 - 0s - loss: 0.1819 - accuracy: 0.9710 - val_loss: 0.1780 - val_accuracy: 0.9736 - 310ms/epoch - 6ms/step
# Epoch 57/4000
# 54/54 - 0s - loss: 0.1810 - accuracy: 0.9705 - val_loss: 0.1737 - val_accuracy: 0.9726 - 299ms/epoch - 6ms/step
# Epoch 58/4000
# 54/54 - 0s - loss: 0.1797 - accuracy: 0.9714 - val_loss: 0.1758 - val_accuracy: 0.9738 - 302ms/epoch - 6ms/step
# Epoch 59/4000
# 54/54 - 0s - loss: 0.1785 - accuracy: 0.9719 - val_loss: 0.1705 - val_accuracy: 0.9740 - 303ms/epoch - 6ms/step
# Epoch 60/4000
# 54/54 - 0s - loss: 0.1778 - accuracy: 0.9715 - val_loss: 0.1770 - val_accuracy: 0.9706 - 301ms/epoch - 6ms/step
# Epoch 61/4000
# 54/54 - 0s - loss: 0.1762 - accuracy: 0.9725 - val_loss: 0.1741 - val_accuracy: 0.9724 - 300ms/epoch - 6ms/step
# Epoch 62/4000
# 54/54 - 0s - loss: 0.1742 - accuracy: 0.9730 - val_loss: 0.1652 - val_accuracy: 0.9770 - 304ms/epoch - 6ms/step
# Epoch 63/4000
# 54/54 - 0s - loss: 0.1745 - accuracy: 0.9729 - val_loss: 0.1684 - val_accuracy: 0.9734 - 299ms/epoch - 6ms/step
# Epoch 64/4000
# 54/54 - 0s - loss: 0.1738 - accuracy: 0.9725 - val_loss: 0.1681 - val_accuracy: 0.9750 - 298ms/epoch - 6ms/step
# Epoch 65/4000
# 54/54 - 0s - loss: 0.1723 - accuracy: 0.9734 - val_loss: 0.1711 - val_accuracy: 0.9708 - 302ms/epoch - 6ms/step
# Epoch 66/4000
# 54/54 - 0s - loss: 0.1721 - accuracy: 0.9729 - val_loss: 0.1717 - val_accuracy: 0.9738 - 301ms/epoch - 6ms/step
# Epoch 67/4000
# 54/54 - 0s - loss: 0.1711 - accuracy: 0.9735 - val_loss: 0.1636 - val_accuracy: 0.9758 - 302ms/epoch - 6ms/step
# Epoch 68/4000
# 54/54 - 0s - loss: 0.1690 - accuracy: 0.9741 - val_loss: 0.1653 - val_accuracy: 0.9768 - 300ms/epoch - 6ms/step
# Epoch 69/4000
# 54/54 - 0s - loss: 0.1682 - accuracy: 0.9742 - val_loss: 0.1591 - val_accuracy: 0.9772 - 306ms/epoch - 6ms/step
# Epoch 70/4000
# 54/54 - 0s - loss: 0.1672 - accuracy: 0.9749 - val_loss: 0.1635 - val_accuracy: 0.9752 - 306ms/epoch - 6ms/step
# Epoch 71/4000
# 54/54 - 0s - loss: 0.1666 - accuracy: 0.9750 - val_loss: 0.1532 - val_accuracy: 0.9796 - 313ms/epoch - 6ms/step
# Epoch 72/4000
# 54/54 - 0s - loss: 0.1660 - accuracy: 0.9749 - val_loss: 0.1605 - val_accuracy: 0.9748 - 309ms/epoch - 6ms/step
# Epoch 73/4000
# 54/54 - 0s - loss: 0.1652 - accuracy: 0.9752 - val_loss: 0.1552 - val_accuracy: 0.9802 - 311ms/epoch - 6ms/step
# Epoch 74/4000
# 54/54 - 0s - loss: 0.1640 - accuracy: 0.9749 - val_loss: 0.1558 - val_accuracy: 0.9770 - 302ms/epoch - 6ms/step
# Epoch 75/4000
# 54/54 - 0s - loss: 0.1652 - accuracy: 0.9743 - val_loss: 0.1555 - val_accuracy: 0.9768 - 302ms/epoch - 6ms/step
# Epoch 76/4000
# 54/54 - 0s - loss: 0.1624 - accuracy: 0.9752 - val_loss: 0.1561 - val_accuracy: 0.9784 - 303ms/epoch - 6ms/step
# Epoch 77/4000
# 54/54 - 0s - loss: 0.1626 - accuracy: 0.9757 - val_loss: 0.1609 - val_accuracy: 0.9762 - 292ms/epoch - 5ms/step
# Epoch 78/4000
# 54/54 - 0s - loss: 0.1622 - accuracy: 0.9752 - val_loss: 0.1572 - val_accuracy: 0.9776 - 302ms/epoch - 6ms/step
# Epoch 79/4000
# 54/54 - 0s - loss: 0.1621 - accuracy: 0.9751 - val_loss: 0.1644 - val_accuracy: 0.9754 - 301ms/epoch - 6ms/step
# Epoch 80/4000
# 54/54 - 0s - loss: 0.1600 - accuracy: 0.9768 - val_loss: 0.1533 - val_accuracy: 0.9776 - 299ms/epoch - 6ms/step
# Epoch 81/4000
# 54/54 - 0s - loss: 0.1600 - accuracy: 0.9765 - val_loss: 0.1571 - val_accuracy: 0.9760 - 306ms/epoch - 6ms/step
# 313/313 - 1s - loss: 0.4531 - accuracy: 0.8887 - 574ms/epoch - 2ms/step
# Test loss: 0.453
# Test accuracy: 88.870%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 6)         156
#
#  average_pooling2d (AverageP  (None, 12, 12, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2416
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 120)               30840
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  batch_normalization (BatchN  (None, 84)               336
#  ormalization)
#
#  square_activation (SquareAc  (None, 84)               0
#  tivation)
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44,762
# Trainable params: 44,594
# Non-trainable params: 168
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 54/54 - 1s - loss: 0.1987 - accuracy: 0.9632 - val_loss: 0.1769 - val_accuracy: 0.9684 - 1s/epoch - 23ms/step
# Epoch 2/4000
# 54/54 - 0s - loss: 0.1696 - accuracy: 0.9699 - val_loss: 0.1567 - val_accuracy: 0.9752 - 312ms/epoch - 6ms/step
# Epoch 3/4000
# 54/54 - 0s - loss: 0.1637 - accuracy: 0.9721 - val_loss: 0.1589 - val_accuracy: 0.9728 - 305ms/epoch - 6ms/step
# Epoch 4/4000
# 54/54 - 0s - loss: 0.1629 - accuracy: 0.9731 - val_loss: 0.1499 - val_accuracy: 0.9762 - 309ms/epoch - 6ms/step
# Epoch 5/4000
# 54/54 - 0s - loss: 0.1587 - accuracy: 0.9727 - val_loss: 0.1528 - val_accuracy: 0.9748 - 304ms/epoch - 6ms/step
# Epoch 6/4000
# 54/54 - 0s - loss: 0.1569 - accuracy: 0.9739 - val_loss: 0.1401 - val_accuracy: 0.9794 - 306ms/epoch - 6ms/step
# Epoch 7/4000
# 54/54 - 0s - loss: 0.1541 - accuracy: 0.9748 - val_loss: 0.1465 - val_accuracy: 0.9784 - 301ms/epoch - 6ms/step
# Epoch 8/4000
# 54/54 - 0s - loss: 0.1510 - accuracy: 0.9756 - val_loss: 0.1442 - val_accuracy: 0.9770 - 302ms/epoch - 6ms/step
# Epoch 9/4000
# 54/54 - 0s - loss: 0.1510 - accuracy: 0.9756 - val_loss: 0.1416 - val_accuracy: 0.9778 - 300ms/epoch - 6ms/step
# Epoch 10/4000
# 54/54 - 0s - loss: 0.1504 - accuracy: 0.9745 - val_loss: 0.1445 - val_accuracy: 0.9764 - 306ms/epoch - 6ms/step
# Epoch 11/4000
# 54/54 - 0s - loss: 0.1487 - accuracy: 0.9764 - val_loss: 0.1372 - val_accuracy: 0.9808 - 307ms/epoch - 6ms/step
# Epoch 12/4000
# 54/54 - 0s - loss: 0.1463 - accuracy: 0.9771 - val_loss: 0.1336 - val_accuracy: 0.9822 - 309ms/epoch - 6ms/step
# Epoch 13/4000
# 54/54 - 0s - loss: 0.1447 - accuracy: 0.9773 - val_loss: 0.1308 - val_accuracy: 0.9822 - 308ms/epoch - 6ms/step
# Epoch 14/4000
# 54/54 - 0s - loss: 0.1438 - accuracy: 0.9775 - val_loss: 0.1332 - val_accuracy: 0.9796 - 305ms/epoch - 6ms/step
# Epoch 15/4000
# 54/54 - 0s - loss: 0.1422 - accuracy: 0.9773 - val_loss: 0.1298 - val_accuracy: 0.9826 - 313ms/epoch - 6ms/step
# Epoch 16/4000
# 54/54 - 0s - loss: 0.1420 - accuracy: 0.9781 - val_loss: 0.1266 - val_accuracy: 0.9836 - 321ms/epoch - 6ms/step
# Epoch 17/4000
# 54/54 - 0s - loss: 0.1405 - accuracy: 0.9782 - val_loss: 0.1271 - val_accuracy: 0.9848 - 317ms/epoch - 6ms/step
# Epoch 18/4000
# 54/54 - 0s - loss: 0.1380 - accuracy: 0.9792 - val_loss: 0.1252 - val_accuracy: 0.9822 - 314ms/epoch - 6ms/step
# Epoch 19/4000
# 54/54 - 0s - loss: 0.1383 - accuracy: 0.9783 - val_loss: 0.1284 - val_accuracy: 0.9836 - 313ms/epoch - 6ms/step
# Epoch 20/4000
# 54/54 - 0s - loss: 0.1381 - accuracy: 0.9788 - val_loss: 0.1367 - val_accuracy: 0.9780 - 304ms/epoch - 6ms/step
# Epoch 21/4000
# 54/54 - 0s - loss: 0.1370 - accuracy: 0.9786 - val_loss: 0.1249 - val_accuracy: 0.9832 - 307ms/epoch - 6ms/step
# Epoch 22/4000
# 54/54 - 0s - loss: 0.1364 - accuracy: 0.9788 - val_loss: 0.1245 - val_accuracy: 0.9842 - 304ms/epoch - 6ms/step
# Epoch 23/4000
# 54/54 - 0s - loss: 0.1350 - accuracy: 0.9792 - val_loss: 0.1248 - val_accuracy: 0.9826 - 305ms/epoch - 6ms/step
# Epoch 24/4000
# 54/54 - 0s - loss: 0.1335 - accuracy: 0.9801 - val_loss: 0.1208 - val_accuracy: 0.9850 - 306ms/epoch - 6ms/step
# Epoch 25/4000
# 54/54 - 0s - loss: 0.1325 - accuracy: 0.9800 - val_loss: 0.1234 - val_accuracy: 0.9850 - 299ms/epoch - 6ms/step
# Epoch 26/4000
# 54/54 - 0s - loss: 0.1309 - accuracy: 0.9802 - val_loss: 0.1248 - val_accuracy: 0.9812 - 305ms/epoch - 6ms/step
# Epoch 27/4000
# 54/54 - 0s - loss: 0.1324 - accuracy: 0.9795 - val_loss: 0.1174 - val_accuracy: 0.9856 - 300ms/epoch - 6ms/step
# Epoch 28/4000
# 54/54 - 0s - loss: 0.1297 - accuracy: 0.9812 - val_loss: 0.1255 - val_accuracy: 0.9840 - 306ms/epoch - 6ms/step
# Epoch 29/4000
# 54/54 - 0s - loss: 0.1293 - accuracy: 0.9808 - val_loss: 0.1228 - val_accuracy: 0.9828 - 305ms/epoch - 6ms/step
# Epoch 30/4000
# 54/54 - 0s - loss: 0.1298 - accuracy: 0.9811 - val_loss: 0.1234 - val_accuracy: 0.9818 - 304ms/epoch - 6ms/step
# Epoch 31/4000
# 54/54 - 0s - loss: 0.1302 - accuracy: 0.9804 - val_loss: 0.1204 - val_accuracy: 0.9828 - 305ms/epoch - 6ms/step
# Epoch 32/4000
# 54/54 - 0s - loss: 0.1295 - accuracy: 0.9803 - val_loss: 0.1181 - val_accuracy: 0.9842 - 315ms/epoch - 6ms/step
# Epoch 33/4000
# 54/54 - 0s - loss: 0.1276 - accuracy: 0.9811 - val_loss: 0.1171 - val_accuracy: 0.9856 - 319ms/epoch - 6ms/step
# Epoch 34/4000
# 54/54 - 0s - loss: 0.1276 - accuracy: 0.9810 - val_loss: 0.1171 - val_accuracy: 0.9852 - 315ms/epoch - 6ms/step
# Epoch 35/4000
# 54/54 - 0s - loss: 0.1254 - accuracy: 0.9816 - val_loss: 0.1175 - val_accuracy: 0.9854 - 313ms/epoch - 6ms/step
# Epoch 36/4000
# 54/54 - 0s - loss: 0.1245 - accuracy: 0.9821 - val_loss: 0.1206 - val_accuracy: 0.9836 - 308ms/epoch - 6ms/step
# Epoch 37/4000
# 54/54 - 0s - loss: 0.1261 - accuracy: 0.9811 - val_loss: 0.1125 - val_accuracy: 0.9864 - 307ms/epoch - 6ms/step
# Epoch 38/4000
# 54/54 - 0s - loss: 0.1241 - accuracy: 0.9823 - val_loss: 0.1147 - val_accuracy: 0.9856 - 308ms/epoch - 6ms/step
# Epoch 39/4000
# 54/54 - 0s - loss: 0.1231 - accuracy: 0.9819 - val_loss: 0.1111 - val_accuracy: 0.9882 - 307ms/epoch - 6ms/step
# Epoch 40/4000
# 54/54 - 0s - loss: 0.1241 - accuracy: 0.9816 - val_loss: 0.1172 - val_accuracy: 0.9846 - 302ms/epoch - 6ms/step
# Epoch 41/4000
# 54/54 - 0s - loss: 0.1224 - accuracy: 0.9825 - val_loss: 0.1150 - val_accuracy: 0.9852 - 304ms/epoch - 6ms/step
# Epoch 42/4000
# 54/54 - 0s - loss: 0.1215 - accuracy: 0.9827 - val_loss: 0.1124 - val_accuracy: 0.9846 - 306ms/epoch - 6ms/step
# Epoch 43/4000
# 54/54 - 0s - loss: 0.1221 - accuracy: 0.9824 - val_loss: 0.1106 - val_accuracy: 0.9878 - 311ms/epoch - 6ms/step
# Epoch 44/4000
# 54/54 - 0s - loss: 0.1228 - accuracy: 0.9814 - val_loss: 0.1127 - val_accuracy: 0.9868 - 305ms/epoch - 6ms/step
# Epoch 45/4000
# 54/54 - 0s - loss: 0.1212 - accuracy: 0.9826 - val_loss: 0.1096 - val_accuracy: 0.9872 - 304ms/epoch - 6ms/step
# Epoch 46/4000
# 54/54 - 0s - loss: 0.1201 - accuracy: 0.9826 - val_loss: 0.1124 - val_accuracy: 0.9868 - 301ms/epoch - 6ms/step
# Epoch 47/4000
# 54/54 - 0s - loss: 0.1193 - accuracy: 0.9833 - val_loss: 0.1087 - val_accuracy: 0.9880 - 305ms/epoch - 6ms/step
# Epoch 48/4000
# 54/54 - 0s - loss: 0.1186 - accuracy: 0.9832 - val_loss: 0.1062 - val_accuracy: 0.9874 - 308ms/epoch - 6ms/step
# Epoch 49/4000
# 54/54 - 0s - loss: 0.1186 - accuracy: 0.9829 - val_loss: 0.1100 - val_accuracy: 0.9884 - 310ms/epoch - 6ms/step
# Epoch 50/4000
# 54/54 - 0s - loss: 0.1184 - accuracy: 0.9831 - val_loss: 0.1068 - val_accuracy: 0.9874 - 314ms/epoch - 6ms/step
# Epoch 51/4000
# 54/54 - 0s - loss: 0.1183 - accuracy: 0.9824 - val_loss: 0.1098 - val_accuracy: 0.9880 - 319ms/epoch - 6ms/step
# Epoch 52/4000
# 54/54 - 0s - loss: 0.1153 - accuracy: 0.9845 - val_loss: 0.1158 - val_accuracy: 0.9842 - 313ms/epoch - 6ms/step
# Epoch 53/4000
# 54/54 - 0s - loss: 0.1161 - accuracy: 0.9838 - val_loss: 0.1064 - val_accuracy: 0.9898 - 306ms/epoch - 6ms/step
# Epoch 54/4000
# 54/54 - 0s - loss: 0.1155 - accuracy: 0.9843 - val_loss: 0.1094 - val_accuracy: 0.9858 - 306ms/epoch - 6ms/step
# Epoch 55/4000
# 54/54 - 0s - loss: 0.1140 - accuracy: 0.9846 - val_loss: 0.1064 - val_accuracy: 0.9894 - 303ms/epoch - 6ms/step
# Epoch 56/4000
# 54/54 - 0s - loss: 0.1142 - accuracy: 0.9843 - val_loss: 0.1035 - val_accuracy: 0.9900 - 303ms/epoch - 6ms/step
# Epoch 57/4000
# 54/54 - 0s - loss: 0.1134 - accuracy: 0.9847 - val_loss: 0.1055 - val_accuracy: 0.9886 - 299ms/epoch - 6ms/step
# Epoch 58/4000
# 54/54 - 0s - loss: 0.1152 - accuracy: 0.9839 - val_loss: 0.1122 - val_accuracy: 0.9858 - 304ms/epoch - 6ms/step
# Epoch 59/4000
# 54/54 - 0s - loss: 0.1146 - accuracy: 0.9838 - val_loss: 0.1099 - val_accuracy: 0.9862 - 299ms/epoch - 6ms/step
# Epoch 60/4000
# 54/54 - 0s - loss: 0.1133 - accuracy: 0.9842 - val_loss: 0.1042 - val_accuracy: 0.9880 - 302ms/epoch - 6ms/step
# Epoch 61/4000
# 54/54 - 0s - loss: 0.1121 - accuracy: 0.9847 - val_loss: 0.1072 - val_accuracy: 0.9872 - 306ms/epoch - 6ms/step
# Epoch 62/4000
# 54/54 - 0s - loss: 0.1111 - accuracy: 0.9853 - val_loss: 0.1036 - val_accuracy: 0.9884 - 307ms/epoch - 6ms/step
# Epoch 63/4000
# 54/54 - 0s - loss: 0.1106 - accuracy: 0.9852 - val_loss: 0.1005 - val_accuracy: 0.9914 - 307ms/epoch - 6ms/step
# Epoch 64/4000
# 54/54 - 0s - loss: 0.1115 - accuracy: 0.9846 - val_loss: 0.1072 - val_accuracy: 0.9874 - 303ms/epoch - 6ms/step
# Epoch 65/4000
# 54/54 - 0s - loss: 0.1108 - accuracy: 0.9847 - val_loss: 0.1039 - val_accuracy: 0.9872 - 305ms/epoch - 6ms/step
# Epoch 66/4000
# 54/54 - 0s - loss: 0.1092 - accuracy: 0.9859 - val_loss: 0.1028 - val_accuracy: 0.9892 - 315ms/epoch - 6ms/step
# Epoch 67/4000
# 54/54 - 0s - loss: 0.1109 - accuracy: 0.9847 - val_loss: 0.1079 - val_accuracy: 0.9866 - 314ms/epoch - 6ms/step
# Epoch 68/4000
# 54/54 - 0s - loss: 0.1112 - accuracy: 0.9847 - val_loss: 0.1020 - val_accuracy: 0.9898 - 314ms/epoch - 6ms/step
# Epoch 69/4000
# 54/54 - 0s - loss: 0.1093 - accuracy: 0.9857 - val_loss: 0.1082 - val_accuracy: 0.9866 - 323ms/epoch - 6ms/step
# Epoch 70/4000
# 54/54 - 0s - loss: 0.1099 - accuracy: 0.9851 - val_loss: 0.1067 - val_accuracy: 0.9872 - 312ms/epoch - 6ms/step
# Epoch 71/4000
# 54/54 - 0s - loss: 0.1093 - accuracy: 0.9851 - val_loss: 0.1013 - val_accuracy: 0.9894 - 307ms/epoch - 6ms/step
# Epoch 72/4000
# 54/54 - 0s - loss: 0.1078 - accuracy: 0.9856 - val_loss: 0.1011 - val_accuracy: 0.9902 - 310ms/epoch - 6ms/step
# Epoch 73/4000
# 54/54 - 0s - loss: 0.1047 - accuracy: 0.9872 - val_loss: 0.0968 - val_accuracy: 0.9916 - 312ms/epoch - 6ms/step
# Epoch 74/4000
# 54/54 - 0s - loss: 0.1062 - accuracy: 0.9859 - val_loss: 0.1008 - val_accuracy: 0.9898 - 306ms/epoch - 6ms/step
# Epoch 75/4000
# 54/54 - 0s - loss: 0.1082 - accuracy: 0.9851 - val_loss: 0.0997 - val_accuracy: 0.9888 - 309ms/epoch - 6ms/step
# Epoch 76/4000
# 54/54 - 0s - loss: 0.1066 - accuracy: 0.9858 - val_loss: 0.1004 - val_accuracy: 0.9906 - 303ms/epoch - 6ms/step
# Epoch 77/4000
# 54/54 - 0s - loss: 0.1064 - accuracy: 0.9864 - val_loss: 0.0991 - val_accuracy: 0.9908 - 304ms/epoch - 6ms/step
# Epoch 78/4000
# 54/54 - 0s - loss: 0.1050 - accuracy: 0.9861 - val_loss: 0.0973 - val_accuracy: 0.9908 - 306ms/epoch - 6ms/step
# Epoch 79/4000
# 54/54 - 0s - loss: 0.1076 - accuracy: 0.9848 - val_loss: 0.0995 - val_accuracy: 0.9874 - 303ms/epoch - 6ms/step
# Epoch 80/4000
# 54/54 - 0s - loss: 0.1082 - accuracy: 0.9851 - val_loss: 0.1068 - val_accuracy: 0.9866 - 307ms/epoch - 6ms/step
# Epoch 81/4000
# 54/54 - 0s - loss: 0.1072 - accuracy: 0.9858 - val_loss: 0.1007 - val_accuracy: 0.9894 - 305ms/epoch - 6ms/step
# Epoch 82/4000
# 54/54 - 0s - loss: 0.1046 - accuracy: 0.9865 - val_loss: 0.0999 - val_accuracy: 0.9890 - 305ms/epoch - 6ms/step
# Epoch 83/4000
# 54/54 - 0s - loss: 0.1034 - accuracy: 0.9867 - val_loss: 0.0980 - val_accuracy: 0.9888 - 319ms/epoch - 6ms/step
# 313/313 - 1s - loss: 0.5228 - accuracy: 0.8885 - 585ms/epoch - 2ms/step
# Test loss: 0.523
# Test accuracy: 88.850%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model213.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model213.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
