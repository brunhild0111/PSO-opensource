# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-06-12 14:21:52.591871: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %%
import numpy as np
import gzip

def load_images(path):
    """加载图像文件（idx3-ubyte格式）"""
    with gzip.open(path, 'rb') as f:
        # 图像文件前16字节为幻数（4字节）、图像数量（4字节）、行数（4字节）、列数（4字节）
        data = np.frombuffer(f.read(), np.uint8, offset=16)
    return data.reshape(-1, 28, 28)  # 重塑为（样本数, 28, 28）

def load_labels(path):
    """加载标签文件（idx1-ubyte格式）"""
    with gzip.open(path, 'rb') as f:
        # 标签文件前8字节为幻数（4字节）、标签数量（4字节）
        data = np.frombuffer(f.read(), np.uint8, offset=8)
    return data  # 直接返回一维数组，无需reshape

# 加载训练和测试数据
x_train = load_images('/workspace/examples/vision_transformer/data/KMNIST/train-images-idx3-ubyte.gz')
y_train = load_labels('/workspace/examples/vision_transformer/data/KMNIST/train-labels-idx1-ubyte.gz')
x_test = load_images('/workspace/examples/vision_transformer/data/KMNIST/t10k-images-idx3-ubyte.gz')
y_test = load_labels('/workspace/examples/vision_transformer/data/KMNIST/t10k-labels-idx1-ubyte.gz')

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
# 以下预处理步骤与MNIST完全兼容，无需修改
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# 裁剪部分（根据需求选择性取消注释）
# x_train = x_train[:, 2:26, 2:26]
# x_test = x_test[:, 2:26, 2:26]

# 添加通道维度（Fashion-MNIST为灰度图，需扩展为[28,28,1]）
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# 归一化至[0,1]范围
x_train /= 255
x_test /= 255

print('Fashion-MNIST data ready')
# Out:
# Fashion-MNIST data ready

# %%
# Create validation data
# valsize=16
# valsize=500
valsize=5000
x_train = x_train[:-valsize]
x_val = x_train[-valsize:]
y_train = y_train[:-valsize]
y_val = y_train[-valsize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test9')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test9 of shape (10000, 28, 28, 1) in data/net_mnist/x_test9.h5
# Saving x_train of shape (55000, 28, 28, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (5000, 28, 28, 1) in data/net_mnist/x_val.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D,AveragePooling2D,Softmax
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2

#创建模型
model = Sequential()

# 第一层卷积层（无激活函数）
model.add(Conv2D(20, (3, 3), input_shape=(28, 28, 1), kernel_regularizer=l2(0.0005)))

# AveP-BN操作
model.add(AvgPool2D(pool_size=2))
model.add(BatchNormalization())

# 第二层卷积层（无激活函数）
model.add(Conv2D(50, (3, 3), kernel_regularizer=l2(0.0005)))

# 调整后的BN + ReLU顺序
model.add(ReLU())  # 激活函数前置
model.add(BatchNormalization())  # BN后置

# 新增：1x1卷积调整通道数到10
model.add(Conv2D(10, (1, 1), kernel_regularizer=l2(0.0005)))

# 特征降维方案
model.add(AvgPool2D(pool_size=(11, 11)))  # 池化窗口覆盖整个空间维度
model.add(Flatten())  # 展平为10维向量


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 20)        520
#
#  average_pooling2d (AverageP  (None, 12, 12, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 50)          25050
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 10)          8010
#
#  batch_normalization (BatchN  (None, 1, 1, 10)         40
#  ormalization)
#
#  re_lu (ReLU)                (None, 1, 1, 10)          0
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 33,620
# Trainable params: 33,600
# Non-trainable params: 20
# _________________________________________________________________
# 2025-06-12 14:21:55.994251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:56.116879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:56.119525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:56.123351: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-12 14:21:56.124983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:56.127594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:56.129997: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:57.838200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:57.840131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:57.841895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-12 14:21:57.843458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-06-12 14:22:03.759231: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 54/54 - 8s - loss: 1.3345 - accuracy: 0.6885 - val_loss: 1.8129 - val_accuracy: 0.6914 - 8s/epoch - 151ms/step
# Epoch 2/4000
# 54/54 - 0s - loss: 1.1417 - accuracy: 0.7623 - val_loss: 1.6344 - val_accuracy: 0.7572 - 482ms/epoch - 9ms/step
# Epoch 3/4000
# 54/54 - 0s - loss: 1.0848 - accuracy: 0.7722 - val_loss: 1.4366 - val_accuracy: 0.7694 - 488ms/epoch - 9ms/step
# Epoch 4/4000
# 54/54 - 0s - loss: 1.0423 - accuracy: 0.7776 - val_loss: 1.2639 - val_accuracy: 0.7858 - 488ms/epoch - 9ms/step
# Epoch 5/4000
# 54/54 - 0s - loss: 1.0064 - accuracy: 0.7811 - val_loss: 1.1100 - val_accuracy: 0.7842 - 486ms/epoch - 9ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.9756 - accuracy: 0.7839 - val_loss: 1.0338 - val_accuracy: 0.7826 - 583ms/epoch - 11ms/step
# Epoch 7/4000
# 54/54 - 0s - loss: 0.9498 - accuracy: 0.7867 - val_loss: 0.9625 - val_accuracy: 0.7970 - 487ms/epoch - 9ms/step
# Epoch 8/4000
# 54/54 - 0s - loss: 0.9261 - accuracy: 0.7883 - val_loss: 0.9219 - val_accuracy: 0.8006 - 488ms/epoch - 9ms/step
# Epoch 9/4000
# 54/54 - 0s - loss: 0.9043 - accuracy: 0.7908 - val_loss: 0.8747 - val_accuracy: 0.7980 - 487ms/epoch - 9ms/step
# Epoch 10/4000
# 54/54 - 0s - loss: 0.8847 - accuracy: 0.7917 - val_loss: 0.8670 - val_accuracy: 0.8004 - 490ms/epoch - 9ms/step
# Epoch 11/4000
# 54/54 - 0s - loss: 0.8685 - accuracy: 0.7943 - val_loss: 0.8525 - val_accuracy: 0.8008 - 489ms/epoch - 9ms/step
# Epoch 12/4000
# 54/54 - 0s - loss: 0.8526 - accuracy: 0.7956 - val_loss: 0.8237 - val_accuracy: 0.8050 - 486ms/epoch - 9ms/step
# Epoch 13/4000
# 54/54 - 0s - loss: 0.8387 - accuracy: 0.7964 - val_loss: 0.8238 - val_accuracy: 0.8002 - 485ms/epoch - 9ms/step
# Epoch 14/4000
# 54/54 - 0s - loss: 0.8252 - accuracy: 0.7975 - val_loss: 0.8147 - val_accuracy: 0.8070 - 490ms/epoch - 9ms/step
# Epoch 15/4000
# 54/54 - 0s - loss: 0.8129 - accuracy: 0.7985 - val_loss: 0.8096 - val_accuracy: 0.8028 - 486ms/epoch - 9ms/step
# Epoch 16/4000
# 54/54 - 0s - loss: 0.8024 - accuracy: 0.8000 - val_loss: 0.7925 - val_accuracy: 0.8052 - 488ms/epoch - 9ms/step
# Epoch 17/4000
# 54/54 - 0s - loss: 0.7920 - accuracy: 0.8016 - val_loss: 0.7748 - val_accuracy: 0.8016 - 485ms/epoch - 9ms/step
# Epoch 18/4000
# 54/54 - 0s - loss: 0.7824 - accuracy: 0.8016 - val_loss: 0.7766 - val_accuracy: 0.8070 - 484ms/epoch - 9ms/step
# Epoch 19/4000
# 54/54 - 0s - loss: 0.7741 - accuracy: 0.8035 - val_loss: 0.7595 - val_accuracy: 0.8064 - 485ms/epoch - 9ms/step
# Epoch 20/4000
# 54/54 - 0s - loss: 0.7650 - accuracy: 0.8036 - val_loss: 0.7514 - val_accuracy: 0.8088 - 488ms/epoch - 9ms/step
# Epoch 21/4000
# 54/54 - 0s - loss: 0.7573 - accuracy: 0.8049 - val_loss: 0.7524 - val_accuracy: 0.8104 - 485ms/epoch - 9ms/step
# Epoch 22/4000
# 54/54 - 0s - loss: 0.7503 - accuracy: 0.8055 - val_loss: 0.7367 - val_accuracy: 0.8126 - 488ms/epoch - 9ms/step
# Epoch 23/4000
# 54/54 - 0s - loss: 0.7429 - accuracy: 0.8063 - val_loss: 0.7315 - val_accuracy: 0.8030 - 489ms/epoch - 9ms/step
# Epoch 24/4000
# 54/54 - 0s - loss: 0.7372 - accuracy: 0.8065 - val_loss: 0.7250 - val_accuracy: 0.8056 - 486ms/epoch - 9ms/step
# Epoch 25/4000
# 54/54 - 0s - loss: 0.7310 - accuracy: 0.8078 - val_loss: 0.7177 - val_accuracy: 0.8106 - 486ms/epoch - 9ms/step
# Epoch 26/4000
# 54/54 - 0s - loss: 0.7240 - accuracy: 0.8077 - val_loss: 0.7157 - val_accuracy: 0.8136 - 488ms/epoch - 9ms/step
# Epoch 27/4000
# 54/54 - 0s - loss: 0.7204 - accuracy: 0.8080 - val_loss: 0.7062 - val_accuracy: 0.8136 - 488ms/epoch - 9ms/step
# Epoch 28/4000
# 54/54 - 0s - loss: 0.7162 - accuracy: 0.8081 - val_loss: 0.7091 - val_accuracy: 0.8100 - 483ms/epoch - 9ms/step
# Epoch 29/4000
# 54/54 - 0s - loss: 0.7098 - accuracy: 0.8091 - val_loss: 0.7175 - val_accuracy: 0.8150 - 489ms/epoch - 9ms/step
# Epoch 30/4000
# 54/54 - 0s - loss: 0.7055 - accuracy: 0.8089 - val_loss: 0.7009 - val_accuracy: 0.8132 - 488ms/epoch - 9ms/step
# Epoch 31/4000
# 54/54 - 0s - loss: 0.7013 - accuracy: 0.8095 - val_loss: 0.7101 - val_accuracy: 0.8120 - 485ms/epoch - 9ms/step
# Epoch 32/4000
# 54/54 - 0s - loss: 0.6964 - accuracy: 0.8107 - val_loss: 0.7116 - val_accuracy: 0.8070 - 487ms/epoch - 9ms/step
# Epoch 33/4000
# 54/54 - 0s - loss: 0.6942 - accuracy: 0.8103 - val_loss: 0.6816 - val_accuracy: 0.8160 - 490ms/epoch - 9ms/step
# Epoch 34/4000
# 54/54 - 0s - loss: 0.6900 - accuracy: 0.8105 - val_loss: 0.6788 - val_accuracy: 0.8176 - 485ms/epoch - 9ms/step
# Epoch 35/4000
# 54/54 - 0s - loss: 0.6853 - accuracy: 0.8111 - val_loss: 0.6913 - val_accuracy: 0.8114 - 488ms/epoch - 9ms/step
# Epoch 36/4000
# 54/54 - 0s - loss: 0.6832 - accuracy: 0.8114 - val_loss: 0.6727 - val_accuracy: 0.8134 - 487ms/epoch - 9ms/step
# Epoch 37/4000
# 54/54 - 0s - loss: 0.6786 - accuracy: 0.8124 - val_loss: 0.6762 - val_accuracy: 0.8134 - 488ms/epoch - 9ms/step
# Epoch 38/4000
# 54/54 - 0s - loss: 0.6754 - accuracy: 0.8125 - val_loss: 0.6713 - val_accuracy: 0.8160 - 488ms/epoch - 9ms/step
# Epoch 39/4000
# 54/54 - 0s - loss: 0.6717 - accuracy: 0.8145 - val_loss: 0.6690 - val_accuracy: 0.8160 - 489ms/epoch - 9ms/step
# Epoch 40/4000
# 54/54 - 0s - loss: 0.6710 - accuracy: 0.8143 - val_loss: 0.6650 - val_accuracy: 0.8188 - 487ms/epoch - 9ms/step
# Epoch 41/4000
# 54/54 - 0s - loss: 0.6668 - accuracy: 0.8142 - val_loss: 0.6697 - val_accuracy: 0.8190 - 489ms/epoch - 9ms/step
# Epoch 42/4000
# 54/54 - 0s - loss: 0.6651 - accuracy: 0.8145 - val_loss: 0.6706 - val_accuracy: 0.8146 - 484ms/epoch - 9ms/step
# Epoch 43/4000
# 54/54 - 0s - loss: 0.6622 - accuracy: 0.8146 - val_loss: 0.6678 - val_accuracy: 0.8176 - 496ms/epoch - 9ms/step
# Epoch 44/4000
# 54/54 - 0s - loss: 0.6590 - accuracy: 0.8163 - val_loss: 0.6721 - val_accuracy: 0.8136 - 490ms/epoch - 9ms/step
# Epoch 45/4000
# 54/54 - 0s - loss: 0.6574 - accuracy: 0.8154 - val_loss: 0.6684 - val_accuracy: 0.8106 - 487ms/epoch - 9ms/step
# Epoch 46/4000
# 54/54 - 0s - loss: 0.6543 - accuracy: 0.8159 - val_loss: 0.6554 - val_accuracy: 0.8190 - 488ms/epoch - 9ms/step
# Epoch 47/4000
# 54/54 - 0s - loss: 0.6548 - accuracy: 0.8144 - val_loss: 0.6539 - val_accuracy: 0.8218 - 489ms/epoch - 9ms/step
# Epoch 48/4000
# 54/54 - 0s - loss: 0.6516 - accuracy: 0.8164 - val_loss: 0.6529 - val_accuracy: 0.8174 - 488ms/epoch - 9ms/step
# Epoch 49/4000
# 54/54 - 0s - loss: 0.6499 - accuracy: 0.8158 - val_loss: 0.6425 - val_accuracy: 0.8194 - 490ms/epoch - 9ms/step
# Epoch 50/4000
# 54/54 - 0s - loss: 0.6481 - accuracy: 0.8161 - val_loss: 0.6410 - val_accuracy: 0.8210 - 488ms/epoch - 9ms/step
# Epoch 51/4000
# 54/54 - 0s - loss: 0.6450 - accuracy: 0.8173 - val_loss: 0.6670 - val_accuracy: 0.8064 - 489ms/epoch - 9ms/step
# Epoch 52/4000
# 54/54 - 0s - loss: 0.6428 - accuracy: 0.8174 - val_loss: 0.6468 - val_accuracy: 0.8220 - 487ms/epoch - 9ms/step
# Epoch 53/4000
# 54/54 - 0s - loss: 0.6417 - accuracy: 0.8168 - val_loss: 0.6480 - val_accuracy: 0.8178 - 485ms/epoch - 9ms/step
# Epoch 54/4000
# 54/54 - 0s - loss: 0.6412 - accuracy: 0.8168 - val_loss: 0.6466 - val_accuracy: 0.8200 - 487ms/epoch - 9ms/step
# Epoch 55/4000
# 54/54 - 0s - loss: 0.6387 - accuracy: 0.8173 - val_loss: 0.6500 - val_accuracy: 0.8166 - 488ms/epoch - 9ms/step
# Epoch 56/4000
# 54/54 - 0s - loss: 0.6381 - accuracy: 0.8170 - val_loss: 0.6720 - val_accuracy: 0.8058 - 488ms/epoch - 9ms/step
# Epoch 57/4000
# 54/54 - 0s - loss: 0.6372 - accuracy: 0.8174 - val_loss: 0.6409 - val_accuracy: 0.8190 - 487ms/epoch - 9ms/step
# Epoch 58/4000
# 54/54 - 0s - loss: 0.6349 - accuracy: 0.8184 - val_loss: 0.6387 - val_accuracy: 0.8188 - 489ms/epoch - 9ms/step
# Epoch 59/4000
# 54/54 - 0s - loss: 0.6327 - accuracy: 0.8176 - val_loss: 0.6406 - val_accuracy: 0.8188 - 487ms/epoch - 9ms/step
# Epoch 60/4000
# 54/54 - 0s - loss: 0.6321 - accuracy: 0.8187 - val_loss: 0.6271 - val_accuracy: 0.8196 - 496ms/epoch - 9ms/step
# Epoch 61/4000
# 54/54 - 1s - loss: 0.6306 - accuracy: 0.8184 - val_loss: 0.6423 - val_accuracy: 0.8202 - 503ms/epoch - 9ms/step
# Epoch 62/4000
# 54/54 - 0s - loss: 0.6293 - accuracy: 0.8198 - val_loss: 0.6298 - val_accuracy: 0.8252 - 489ms/epoch - 9ms/step
# Epoch 63/4000
# 54/54 - 0s - loss: 0.6280 - accuracy: 0.8181 - val_loss: 0.6371 - val_accuracy: 0.8180 - 486ms/epoch - 9ms/step
# Epoch 64/4000
# 54/54 - 0s - loss: 0.6284 - accuracy: 0.8196 - val_loss: 0.6358 - val_accuracy: 0.8194 - 490ms/epoch - 9ms/step
# Epoch 65/4000
# 54/54 - 0s - loss: 0.6270 - accuracy: 0.8195 - val_loss: 0.6261 - val_accuracy: 0.8206 - 490ms/epoch - 9ms/step
# Epoch 66/4000
# 54/54 - 0s - loss: 0.6240 - accuracy: 0.8201 - val_loss: 0.6267 - val_accuracy: 0.8206 - 489ms/epoch - 9ms/step
# Epoch 67/4000
# 54/54 - 0s - loss: 0.6232 - accuracy: 0.8185 - val_loss: 0.6305 - val_accuracy: 0.8196 - 487ms/epoch - 9ms/step
# Epoch 68/4000
# 54/54 - 0s - loss: 0.6221 - accuracy: 0.8197 - val_loss: 0.6250 - val_accuracy: 0.8192 - 489ms/epoch - 9ms/step
# Epoch 69/4000
# 54/54 - 0s - loss: 0.6204 - accuracy: 0.8205 - val_loss: 0.6173 - val_accuracy: 0.8266 - 489ms/epoch - 9ms/step
# Epoch 70/4000
# 54/54 - 0s - loss: 0.6206 - accuracy: 0.8196 - val_loss: 0.6258 - val_accuracy: 0.8220 - 488ms/epoch - 9ms/step
# Epoch 71/4000
# 54/54 - 0s - loss: 0.6198 - accuracy: 0.8200 - val_loss: 0.6327 - val_accuracy: 0.8200 - 488ms/epoch - 9ms/step
# Epoch 72/4000
# 54/54 - 0s - loss: 0.6200 - accuracy: 0.8210 - val_loss: 0.6609 - val_accuracy: 0.8054 - 486ms/epoch - 9ms/step
# Epoch 73/4000
# 54/54 - 0s - loss: 0.6189 - accuracy: 0.8208 - val_loss: 0.6105 - val_accuracy: 0.8250 - 491ms/epoch - 9ms/step
# Epoch 74/4000
# 54/54 - 0s - loss: 0.6170 - accuracy: 0.8204 - val_loss: 0.6311 - val_accuracy: 0.8200 - 489ms/epoch - 9ms/step
# Epoch 75/4000
# 54/54 - 0s - loss: 0.6149 - accuracy: 0.8217 - val_loss: 0.6333 - val_accuracy: 0.8138 - 498ms/epoch - 9ms/step
# Epoch 76/4000
# 54/54 - 0s - loss: 0.6160 - accuracy: 0.8210 - val_loss: 0.6243 - val_accuracy: 0.8184 - 490ms/epoch - 9ms/step
# Epoch 77/4000
# 54/54 - 0s - loss: 0.6140 - accuracy: 0.8210 - val_loss: 0.6226 - val_accuracy: 0.8192 - 487ms/epoch - 9ms/step
# Epoch 78/4000
# 54/54 - 0s - loss: 0.6135 - accuracy: 0.8219 - val_loss: 0.6200 - val_accuracy: 0.8192 - 487ms/epoch - 9ms/step
# Epoch 79/4000
# 54/54 - 0s - loss: 0.6121 - accuracy: 0.8216 - val_loss: 0.6116 - val_accuracy: 0.8228 - 493ms/epoch - 9ms/step
# Epoch 80/4000
# 54/54 - 0s - loss: 0.6121 - accuracy: 0.8211 - val_loss: 0.6219 - val_accuracy: 0.8212 - 489ms/epoch - 9ms/step
# Epoch 81/4000
# 54/54 - 0s - loss: 0.6120 - accuracy: 0.8214 - val_loss: 0.6202 - val_accuracy: 0.8192 - 489ms/epoch - 9ms/step
# Epoch 82/4000
# 54/54 - 0s - loss: 0.6104 - accuracy: 0.8222 - val_loss: 0.6243 - val_accuracy: 0.8208 - 489ms/epoch - 9ms/step
# Epoch 83/4000
# 54/54 - 0s - loss: 0.6103 - accuracy: 0.8215 - val_loss: 0.6046 - val_accuracy: 0.8222 - 491ms/epoch - 9ms/step
# Epoch 84/4000
# 54/54 - 0s - loss: 0.6107 - accuracy: 0.8224 - val_loss: 0.6125 - val_accuracy: 0.8264 - 488ms/epoch - 9ms/step
# Epoch 85/4000
# 54/54 - 0s - loss: 0.6093 - accuracy: 0.8214 - val_loss: 0.6234 - val_accuracy: 0.8182 - 489ms/epoch - 9ms/step
# Epoch 86/4000
# 54/54 - 0s - loss: 0.6085 - accuracy: 0.8228 - val_loss: 0.6196 - val_accuracy: 0.8172 - 488ms/epoch - 9ms/step
# Epoch 87/4000
# 54/54 - 0s - loss: 0.6074 - accuracy: 0.8237 - val_loss: 0.6227 - val_accuracy: 0.8224 - 490ms/epoch - 9ms/step
# Epoch 88/4000
# 54/54 - 0s - loss: 0.6082 - accuracy: 0.8225 - val_loss: 0.6096 - val_accuracy: 0.8228 - 488ms/epoch - 9ms/step
# Epoch 89/4000
# 54/54 - 0s - loss: 0.6046 - accuracy: 0.8238 - val_loss: 0.6053 - val_accuracy: 0.8236 - 488ms/epoch - 9ms/step
# Epoch 90/4000
# 54/54 - 0s - loss: 0.6043 - accuracy: 0.8230 - val_loss: 0.6021 - val_accuracy: 0.8244 - 491ms/epoch - 9ms/step
# Epoch 91/4000
# 54/54 - 0s - loss: 0.6060 - accuracy: 0.8234 - val_loss: 0.6079 - val_accuracy: 0.8254 - 489ms/epoch - 9ms/step
# Epoch 92/4000
# 54/54 - 0s - loss: 0.6043 - accuracy: 0.8234 - val_loss: 0.6116 - val_accuracy: 0.8248 - 488ms/epoch - 9ms/step
# Epoch 93/4000
# 54/54 - 0s - loss: 0.6044 - accuracy: 0.8221 - val_loss: 0.6003 - val_accuracy: 0.8268 - 489ms/epoch - 9ms/step
# Epoch 94/4000
# 54/54 - 0s - loss: 0.6026 - accuracy: 0.8239 - val_loss: 0.6062 - val_accuracy: 0.8208 - 491ms/epoch - 9ms/step
# Epoch 95/4000
# 54/54 - 0s - loss: 0.6036 - accuracy: 0.8229 - val_loss: 0.6068 - val_accuracy: 0.8252 - 489ms/epoch - 9ms/step
# Epoch 96/4000
# 54/54 - 0s - loss: 0.6021 - accuracy: 0.8235 - val_loss: 0.6017 - val_accuracy: 0.8248 - 491ms/epoch - 9ms/step
# Epoch 97/4000
# 54/54 - 0s - loss: 0.6007 - accuracy: 0.8237 - val_loss: 0.6069 - val_accuracy: 0.8250 - 490ms/epoch - 9ms/step
# Epoch 98/4000
# 54/54 - 0s - loss: 0.6017 - accuracy: 0.8221 - val_loss: 0.6062 - val_accuracy: 0.8232 - 490ms/epoch - 9ms/step
# Epoch 99/4000
# 54/54 - 0s - loss: 0.6002 - accuracy: 0.8233 - val_loss: 0.5975 - val_accuracy: 0.8278 - 491ms/epoch - 9ms/step
# Epoch 100/4000
# 54/54 - 0s - loss: 0.5997 - accuracy: 0.8241 - val_loss: 0.6010 - val_accuracy: 0.8252 - 490ms/epoch - 9ms/step
# Epoch 101/4000
# 54/54 - 0s - loss: 0.6001 - accuracy: 0.8224 - val_loss: 0.5990 - val_accuracy: 0.8232 - 489ms/epoch - 9ms/step
# Epoch 102/4000
# 54/54 - 0s - loss: 0.5999 - accuracy: 0.8241 - val_loss: 0.6007 - val_accuracy: 0.8254 - 492ms/epoch - 9ms/step
# Epoch 103/4000
# 54/54 - 0s - loss: 0.5985 - accuracy: 0.8252 - val_loss: 0.6071 - val_accuracy: 0.8220 - 487ms/epoch - 9ms/step
# Epoch 104/4000
# 54/54 - 0s - loss: 0.5986 - accuracy: 0.8230 - val_loss: 0.6041 - val_accuracy: 0.8262 - 493ms/epoch - 9ms/step
# Epoch 105/4000
# 54/54 - 0s - loss: 0.5972 - accuracy: 0.8256 - val_loss: 0.6177 - val_accuracy: 0.8180 - 491ms/epoch - 9ms/step
# Epoch 106/4000
# 54/54 - 0s - loss: 0.5982 - accuracy: 0.8243 - val_loss: 0.5963 - val_accuracy: 0.8272 - 494ms/epoch - 9ms/step
# Epoch 107/4000
# 54/54 - 0s - loss: 0.5969 - accuracy: 0.8244 - val_loss: 0.6021 - val_accuracy: 0.8256 - 493ms/epoch - 9ms/step
# Epoch 108/4000
# 54/54 - 0s - loss: 0.5973 - accuracy: 0.8238 - val_loss: 0.6007 - val_accuracy: 0.8248 - 491ms/epoch - 9ms/step
# Epoch 109/4000
# 54/54 - 0s - loss: 0.5971 - accuracy: 0.8245 - val_loss: 0.6034 - val_accuracy: 0.8210 - 490ms/epoch - 9ms/step
# Epoch 110/4000
# 54/54 - 0s - loss: 0.5965 - accuracy: 0.8256 - val_loss: 0.6015 - val_accuracy: 0.8266 - 491ms/epoch - 9ms/step
# Epoch 111/4000
# 54/54 - 0s - loss: 0.5960 - accuracy: 0.8251 - val_loss: 0.6109 - val_accuracy: 0.8154 - 491ms/epoch - 9ms/step
# Epoch 112/4000
# 54/54 - 0s - loss: 0.5956 - accuracy: 0.8241 - val_loss: 0.6034 - val_accuracy: 0.8228 - 491ms/epoch - 9ms/step
# Epoch 113/4000
# 54/54 - 0s - loss: 0.5953 - accuracy: 0.8256 - val_loss: 0.6025 - val_accuracy: 0.8222 - 492ms/epoch - 9ms/step
# Epoch 114/4000
# 54/54 - 0s - loss: 0.5941 - accuracy: 0.8251 - val_loss: 0.6060 - val_accuracy: 0.8212 - 490ms/epoch - 9ms/step
# Epoch 115/4000
# 54/54 - 0s - loss: 0.5947 - accuracy: 0.8241 - val_loss: 0.6026 - val_accuracy: 0.8254 - 492ms/epoch - 9ms/step
# Epoch 116/4000
# 54/54 - 0s - loss: 0.5936 - accuracy: 0.8261 - val_loss: 0.5949 - val_accuracy: 0.8300 - 497ms/epoch - 9ms/step
# Epoch 117/4000
# 54/54 - 0s - loss: 0.5931 - accuracy: 0.8249 - val_loss: 0.6017 - val_accuracy: 0.8262 - 493ms/epoch - 9ms/step
# Epoch 118/4000
# 54/54 - 0s - loss: 0.5911 - accuracy: 0.8269 - val_loss: 0.5991 - val_accuracy: 0.8246 - 494ms/epoch - 9ms/step
# Epoch 119/4000
# 54/54 - 0s - loss: 0.5925 - accuracy: 0.8251 - val_loss: 0.6053 - val_accuracy: 0.8258 - 493ms/epoch - 9ms/step
# Epoch 120/4000
# 54/54 - 0s - loss: 0.5922 - accuracy: 0.8249 - val_loss: 0.5953 - val_accuracy: 0.8294 - 491ms/epoch - 9ms/step
# Epoch 121/4000
# 54/54 - 0s - loss: 0.5924 - accuracy: 0.8254 - val_loss: 0.6018 - val_accuracy: 0.8226 - 494ms/epoch - 9ms/step
# Epoch 122/4000
# 54/54 - 0s - loss: 0.5927 - accuracy: 0.8254 - val_loss: 0.5954 - val_accuracy: 0.8276 - 492ms/epoch - 9ms/step
# Epoch 123/4000
# 54/54 - 0s - loss: 0.5920 - accuracy: 0.8252 - val_loss: 0.5933 - val_accuracy: 0.8246 - 492ms/epoch - 9ms/step
# Epoch 124/4000
# 54/54 - 0s - loss: 0.5908 - accuracy: 0.8264 - val_loss: 0.6081 - val_accuracy: 0.8196 - 485ms/epoch - 9ms/step
# Epoch 125/4000
# 54/54 - 0s - loss: 0.5912 - accuracy: 0.8258 - val_loss: 0.6207 - val_accuracy: 0.8136 - 493ms/epoch - 9ms/step
# Epoch 126/4000
# 54/54 - 0s - loss: 0.5903 - accuracy: 0.8258 - val_loss: 0.5817 - val_accuracy: 0.8288 - 493ms/epoch - 9ms/step
# Epoch 127/4000
# 54/54 - 0s - loss: 0.5899 - accuracy: 0.8256 - val_loss: 0.5923 - val_accuracy: 0.8302 - 491ms/epoch - 9ms/step
# Epoch 128/4000
# 54/54 - 0s - loss: 0.5885 - accuracy: 0.8267 - val_loss: 0.5981 - val_accuracy: 0.8230 - 488ms/epoch - 9ms/step
# Epoch 129/4000
# 54/54 - 0s - loss: 0.5899 - accuracy: 0.8263 - val_loss: 0.6065 - val_accuracy: 0.8222 - 491ms/epoch - 9ms/step
# Epoch 130/4000
# 54/54 - 0s - loss: 0.5894 - accuracy: 0.8268 - val_loss: 0.6015 - val_accuracy: 0.8284 - 492ms/epoch - 9ms/step
# Epoch 131/4000
# 54/54 - 0s - loss: 0.5877 - accuracy: 0.8267 - val_loss: 0.6010 - val_accuracy: 0.8234 - 488ms/epoch - 9ms/step
# Epoch 132/4000
# 54/54 - 0s - loss: 0.5881 - accuracy: 0.8259 - val_loss: 0.5974 - val_accuracy: 0.8260 - 491ms/epoch - 9ms/step
# Epoch 133/4000
# 54/54 - 0s - loss: 0.5874 - accuracy: 0.8264 - val_loss: 0.6066 - val_accuracy: 0.8210 - 492ms/epoch - 9ms/step
# Epoch 134/4000
# 54/54 - 0s - loss: 0.5883 - accuracy: 0.8259 - val_loss: 0.5941 - val_accuracy: 0.8220 - 493ms/epoch - 9ms/step
# Epoch 135/4000
# 54/54 - 0s - loss: 0.5900 - accuracy: 0.8260 - val_loss: 0.5880 - val_accuracy: 0.8244 - 489ms/epoch - 9ms/step
# Epoch 136/4000
# 54/54 - 0s - loss: 0.5866 - accuracy: 0.8263 - val_loss: 0.5996 - val_accuracy: 0.8250 - 496ms/epoch - 9ms/step
# 313/313 - 1s - loss: 1.0349 - accuracy: 0.6950 - 576ms/epoch - 2ms/step
# Test loss: 1.035
# Test accuracy: 69.500%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 20)        520
#
#  average_pooling2d (AverageP  (None, 12, 12, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 50)          25050
#
#  average_pooling2d_1 (Averag  (None, 4, 4, 50)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 10)          8010
#
#  batch_normalization (BatchN  (None, 1, 1, 10)         40
#  ormalization)
#
#  square_activation (SquareAc  (None, 1, 1, 10)         0
#  tivation)
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 10)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 10)                0
#
# =================================================================
# Total params: 33,620
# Trainable params: 33,600
# Non-trainable params: 20
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 54/54 - 1s - loss: 0.6948 - accuracy: 0.8175 - val_loss: 0.8019 - val_accuracy: 0.8120 - 1s/epoch - 22ms/step
# Epoch 2/4000
# 54/54 - 0s - loss: 0.6448 - accuracy: 0.8232 - val_loss: 0.7018 - val_accuracy: 0.8134 - 492ms/epoch - 9ms/step
# Epoch 3/4000
# 54/54 - 0s - loss: 0.6392 - accuracy: 0.8228 - val_loss: 0.6869 - val_accuracy: 0.8152 - 493ms/epoch - 9ms/step
# Epoch 4/4000
# 54/54 - 0s - loss: 0.6353 - accuracy: 0.8248 - val_loss: 0.6885 - val_accuracy: 0.8158 - 492ms/epoch - 9ms/step
# Epoch 5/4000
# 54/54 - 0s - loss: 0.6323 - accuracy: 0.8244 - val_loss: 0.6487 - val_accuracy: 0.8224 - 493ms/epoch - 9ms/step
# Epoch 6/4000
# 54/54 - 0s - loss: 0.6283 - accuracy: 0.8235 - val_loss: 0.6790 - val_accuracy: 0.8176 - 489ms/epoch - 9ms/step
# Epoch 7/4000
# 54/54 - 0s - loss: 0.6254 - accuracy: 0.8241 - val_loss: 0.6408 - val_accuracy: 0.8216 - 494ms/epoch - 9ms/step
# Epoch 8/4000
# 54/54 - 0s - loss: 0.6247 - accuracy: 0.8253 - val_loss: 0.6352 - val_accuracy: 0.8218 - 491ms/epoch - 9ms/step
# Epoch 9/4000
# 54/54 - 0s - loss: 0.6219 - accuracy: 0.8243 - val_loss: 0.6337 - val_accuracy: 0.8246 - 492ms/epoch - 9ms/step
# Epoch 10/4000
# 54/54 - 0s - loss: 0.6190 - accuracy: 0.8254 - val_loss: 0.6341 - val_accuracy: 0.8288 - 490ms/epoch - 9ms/step
# Epoch 11/4000
# 54/54 - 0s - loss: 0.6184 - accuracy: 0.8260 - val_loss: 0.6354 - val_accuracy: 0.8242 - 492ms/epoch - 9ms/step
# Epoch 12/4000
# 54/54 - 0s - loss: 0.6155 - accuracy: 0.8256 - val_loss: 0.6304 - val_accuracy: 0.8210 - 493ms/epoch - 9ms/step
# Epoch 13/4000
# 54/54 - 0s - loss: 0.6156 - accuracy: 0.8251 - val_loss: 0.6309 - val_accuracy: 0.8222 - 489ms/epoch - 9ms/step
# Epoch 14/4000
# 54/54 - 0s - loss: 0.6107 - accuracy: 0.8261 - val_loss: 0.6243 - val_accuracy: 0.8268 - 495ms/epoch - 9ms/step
# Epoch 15/4000
# 54/54 - 0s - loss: 0.6124 - accuracy: 0.8259 - val_loss: 0.6330 - val_accuracy: 0.8238 - 490ms/epoch - 9ms/step
# Epoch 16/4000
# 54/54 - 0s - loss: 0.6125 - accuracy: 0.8256 - val_loss: 0.6138 - val_accuracy: 0.8272 - 491ms/epoch - 9ms/step
# Epoch 17/4000
# 54/54 - 0s - loss: 0.6092 - accuracy: 0.8259 - val_loss: 0.6333 - val_accuracy: 0.8184 - 490ms/epoch - 9ms/step
# Epoch 18/4000
# 54/54 - 0s - loss: 0.6068 - accuracy: 0.8272 - val_loss: 0.6212 - val_accuracy: 0.8244 - 491ms/epoch - 9ms/step
# Epoch 19/4000
# 54/54 - 0s - loss: 0.6060 - accuracy: 0.8276 - val_loss: 0.6346 - val_accuracy: 0.8228 - 490ms/epoch - 9ms/step
# Epoch 20/4000
# 54/54 - 0s - loss: 0.6044 - accuracy: 0.8272 - val_loss: 0.6119 - val_accuracy: 0.8298 - 494ms/epoch - 9ms/step
# Epoch 21/4000
# 54/54 - 0s - loss: 0.6028 - accuracy: 0.8276 - val_loss: 0.6121 - val_accuracy: 0.8252 - 489ms/epoch - 9ms/step
# Epoch 22/4000
# 54/54 - 0s - loss: 0.6027 - accuracy: 0.8273 - val_loss: 0.6234 - val_accuracy: 0.8252 - 495ms/epoch - 9ms/step
# Epoch 23/4000
# 54/54 - 0s - loss: 0.5993 - accuracy: 0.8278 - val_loss: 0.6157 - val_accuracy: 0.8218 - 491ms/epoch - 9ms/step
# Epoch 24/4000
# 54/54 - 0s - loss: 0.5994 - accuracy: 0.8273 - val_loss: 0.6249 - val_accuracy: 0.8226 - 491ms/epoch - 9ms/step
# Epoch 25/4000
# 54/54 - 0s - loss: 0.5991 - accuracy: 0.8277 - val_loss: 0.6078 - val_accuracy: 0.8240 - 493ms/epoch - 9ms/step
# Epoch 26/4000
# 54/54 - 0s - loss: 0.5976 - accuracy: 0.8281 - val_loss: 0.6141 - val_accuracy: 0.8236 - 491ms/epoch - 9ms/step
# Epoch 27/4000
# 54/54 - 0s - loss: 0.5977 - accuracy: 0.8279 - val_loss: 0.6157 - val_accuracy: 0.8266 - 492ms/epoch - 9ms/step
# Epoch 28/4000
# 54/54 - 0s - loss: 0.5983 - accuracy: 0.8273 - val_loss: 0.6065 - val_accuracy: 0.8272 - 495ms/epoch - 9ms/step
# Epoch 29/4000
# 54/54 - 0s - loss: 0.5966 - accuracy: 0.8280 - val_loss: 0.6112 - val_accuracy: 0.8234 - 492ms/epoch - 9ms/step
# Epoch 30/4000
# 54/54 - 0s - loss: 0.5932 - accuracy: 0.8290 - val_loss: 0.6233 - val_accuracy: 0.8206 - 493ms/epoch - 9ms/step
# Epoch 31/4000
# 54/54 - 0s - loss: 0.5928 - accuracy: 0.8276 - val_loss: 0.6080 - val_accuracy: 0.8230 - 494ms/epoch - 9ms/step
# Epoch 32/4000
# 54/54 - 0s - loss: 0.5918 - accuracy: 0.8294 - val_loss: 0.6059 - val_accuracy: 0.8252 - 491ms/epoch - 9ms/step
# Epoch 33/4000
# 54/54 - 0s - loss: 0.5943 - accuracy: 0.8282 - val_loss: 0.5962 - val_accuracy: 0.8300 - 494ms/epoch - 9ms/step
# Epoch 34/4000
# 54/54 - 0s - loss: 0.5924 - accuracy: 0.8281 - val_loss: 0.6082 - val_accuracy: 0.8256 - 493ms/epoch - 9ms/step
# Epoch 35/4000
# 54/54 - 0s - loss: 0.5919 - accuracy: 0.8275 - val_loss: 0.6047 - val_accuracy: 0.8270 - 495ms/epoch - 9ms/step
# Epoch 36/4000
# 54/54 - 0s - loss: 0.5904 - accuracy: 0.8291 - val_loss: 0.6050 - val_accuracy: 0.8260 - 491ms/epoch - 9ms/step
# Epoch 37/4000
# 54/54 - 0s - loss: 0.5904 - accuracy: 0.8283 - val_loss: 0.5992 - val_accuracy: 0.8340 - 492ms/epoch - 9ms/step
# Epoch 38/4000
# 54/54 - 0s - loss: 0.5881 - accuracy: 0.8291 - val_loss: 0.6040 - val_accuracy: 0.8250 - 492ms/epoch - 9ms/step
# Epoch 39/4000
# 54/54 - 0s - loss: 0.5878 - accuracy: 0.8289 - val_loss: 0.6028 - val_accuracy: 0.8286 - 492ms/epoch - 9ms/step
# Epoch 40/4000
# 54/54 - 0s - loss: 0.5875 - accuracy: 0.8283 - val_loss: 0.5958 - val_accuracy: 0.8278 - 496ms/epoch - 9ms/step
# Epoch 41/4000
# 54/54 - 0s - loss: 0.5868 - accuracy: 0.8298 - val_loss: 0.5899 - val_accuracy: 0.8274 - 495ms/epoch - 9ms/step
# Epoch 42/4000
# 54/54 - 0s - loss: 0.5871 - accuracy: 0.8294 - val_loss: 0.5981 - val_accuracy: 0.8270 - 495ms/epoch - 9ms/step
# Epoch 43/4000
# 54/54 - 0s - loss: 0.5866 - accuracy: 0.8297 - val_loss: 0.6015 - val_accuracy: 0.8258 - 492ms/epoch - 9ms/step
# Epoch 44/4000
# 54/54 - 0s - loss: 0.5852 - accuracy: 0.8299 - val_loss: 0.5996 - val_accuracy: 0.8262 - 492ms/epoch - 9ms/step
# Epoch 45/4000
# 54/54 - 0s - loss: 0.5845 - accuracy: 0.8293 - val_loss: 0.5931 - val_accuracy: 0.8254 - 494ms/epoch - 9ms/step
# Epoch 46/4000
# 54/54 - 0s - loss: 0.5837 - accuracy: 0.8281 - val_loss: 0.5932 - val_accuracy: 0.8278 - 494ms/epoch - 9ms/step
# Epoch 47/4000
# 54/54 - 0s - loss: 0.5858 - accuracy: 0.8283 - val_loss: 0.5982 - val_accuracy: 0.8254 - 493ms/epoch - 9ms/step
# Epoch 48/4000
# 54/54 - 0s - loss: 0.5844 - accuracy: 0.8291 - val_loss: 0.5935 - val_accuracy: 0.8278 - 493ms/epoch - 9ms/step
# Epoch 49/4000
# 54/54 - 0s - loss: 0.5835 - accuracy: 0.8280 - val_loss: 0.5916 - val_accuracy: 0.8308 - 494ms/epoch - 9ms/step
# Epoch 50/4000
# 54/54 - 0s - loss: 0.5834 - accuracy: 0.8294 - val_loss: 0.6024 - val_accuracy: 0.8266 - 494ms/epoch - 9ms/step
# Epoch 51/4000
# 54/54 - 0s - loss: 0.5827 - accuracy: 0.8287 - val_loss: 0.6097 - val_accuracy: 0.8214 - 496ms/epoch - 9ms/step
# 313/313 - 1s - loss: 1.0925 - accuracy: 0.6831 - 534ms/epoch - 2ms/step
# Test loss: 1.093
# Test accuracy: 68.310%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model414.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model414.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
