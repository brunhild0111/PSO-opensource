# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

# batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-05-30 02:32:39.704374: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
# 修改导入模块（原MNIST模块替换为Fashion-MNIST模块）
from tensorflow.keras.datasets import fashion_mnist

# 加载Fashion-MNIST数据集（原mnist.load_data()替换为fashion_mnist.load_data()）
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# 以下预处理步骤与MNIST完全兼容，无需修改
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# 裁剪部分（根据需求选择性取消注释）
# x_train = x_train[:, 2:26, 2:26]
# x_test = x_test[:, 2:26, 2:26]

# 添加通道维度（Fashion-MNIST为灰度图，需扩展为[28,28,1]）
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# 归一化至[0,1]范围
x_train /= 255
x_test /= 255

print('Fashion-MNIST data ready')
# Out:
# Fashion-MNIST data ready

# %%
# Create validation data
# valsize=16
# valsize=500
valsize=5000
x_train = x_train[:-valsize]
x_val = x_train[-valsize:]
y_train = y_train[:-valsize]
y_val = y_train[-valsize:]
print('Validation and test data ready')

# Convert class vector to binary class matrices
# num_classes = 10
# y_train = utils.to_categorical(y_train, num_classes)
# y_test = utils.to_categorical(y_test, num_classes)
# y_val = utils.to_categorical(y_val, num_classes)

input_shape = x_train[0].shape
print(f'input shape: {input_shape}')
# Out:
# Validation and test data ready
# input shape: (28, 28, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test5')
# save_data_set(x_train, y_train, data_type='train')
# save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test5 of shape (10000, 28, 28, 1) in data/net_mnist/x_test5.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D,AveragePooling2D,Softmax
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2

#创建模型
model = Sequential()

# 第一层卷积层（无激活函数）
model.add(Conv2D(20, (3, 3), input_shape=(28, 28, 1), kernel_regularizer=l2(0.0005)))

# AveP-BN操作
model.add(AvgPool2D(pool_size=2))
model.add(BatchNormalization())

# 第二层卷积层（无激活函数）
model.add(Conv2D(50, (3, 3), kernel_regularizer=l2(0.0005)))

# 调整后的BN + ReLU顺序
model.add(ReLU())  # 激活函数前置
model.add(BatchNormalization())  # BN后置

# 新增：1x1卷积调整通道数到10
model.add(Conv2D(10, (1, 1), kernel_regularizer=l2(0.0005)))

# 特征降维方案
model.add(AvgPool2D(pool_size=(11, 11)))  # 池化窗口覆盖整个空间维度
model.add(Flatten())  # 展平为10维向量


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 20)        200
#
#  average_pooling2d (AverageP  (None, 13, 13, 20)       0
#  ooling2D)
#
#  batch_normalization (BatchN  (None, 13, 13, 20)       80
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 50)        9050
#
#  re_lu (ReLU)                (None, 11, 11, 50)        0
#
#  batch_normalization_1 (Batc  (None, 11, 11, 50)       200
#  hNormalization)
#
#  flatten (Flatten)           (None, 6050)              0
#
#  dense (Dense)               (None, 500)               3025500
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 3,040,040
# Trainable params: 3,039,900
# Non-trainable params: 140
# _________________________________________________________________
# 2025-05-30 02:32:42.596678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:42.636457: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:42.638608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:42.641004: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-30 02:32:42.641613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:42.643763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:42.645849: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:43.395555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:43.397465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:43.399158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-30 02:32:43.400793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Epoch 1/4000
# 2025-05-30 02:32:45.863796: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 54/54 - 4s - loss: 0.7361 - accuracy: 0.7739 - val_loss: 2.1347 - val_accuracy: 0.3066 - 4s/epoch - 72ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.4163 - accuracy: 0.8627 - val_loss: 2.2564 - val_accuracy: 0.3076 - 894ms/epoch - 17ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.3720 - accuracy: 0.8753 - val_loss: 2.2038 - val_accuracy: 0.4176 - 886ms/epoch - 16ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.3389 - accuracy: 0.8872 - val_loss: 1.9706 - val_accuracy: 0.4556 - 900ms/epoch - 17ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.3225 - accuracy: 0.8921 - val_loss: 1.6662 - val_accuracy: 0.5566 - 895ms/epoch - 17ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.3084 - accuracy: 0.8978 - val_loss: 1.2661 - val_accuracy: 0.6348 - 898ms/epoch - 17ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.2926 - accuracy: 0.9033 - val_loss: 0.8790 - val_accuracy: 0.7318 - 913ms/epoch - 17ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.2791 - accuracy: 0.9087 - val_loss: 0.6670 - val_accuracy: 0.7578 - 910ms/epoch - 17ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.2671 - accuracy: 0.9128 - val_loss: 0.5338 - val_accuracy: 0.8014 - 907ms/epoch - 17ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.2598 - accuracy: 0.9169 - val_loss: 0.3865 - val_accuracy: 0.8638 - 911ms/epoch - 17ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.2497 - accuracy: 0.9197 - val_loss: 0.3308 - val_accuracy: 0.8856 - 911ms/epoch - 17ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.2464 - accuracy: 0.9197 - val_loss: 0.2783 - val_accuracy: 0.9110 - 916ms/epoch - 17ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.2355 - accuracy: 0.9261 - val_loss: 0.2497 - val_accuracy: 0.9192 - 938ms/epoch - 17ms/step
# Epoch 14/4000
# 54/54 - 1s - loss: 0.2292 - accuracy: 0.9276 - val_loss: 0.2366 - val_accuracy: 0.9232 - 916ms/epoch - 17ms/step
# Epoch 15/4000
# 54/54 - 1s - loss: 0.2228 - accuracy: 0.9304 - val_loss: 0.2269 - val_accuracy: 0.9302 - 908ms/epoch - 17ms/step
# Epoch 16/4000
# 54/54 - 1s - loss: 0.2217 - accuracy: 0.9297 - val_loss: 0.2156 - val_accuracy: 0.9308 - 905ms/epoch - 17ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.2168 - accuracy: 0.9321 - val_loss: 0.2054 - val_accuracy: 0.9342 - 902ms/epoch - 17ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.2090 - accuracy: 0.9349 - val_loss: 0.2099 - val_accuracy: 0.9318 - 899ms/epoch - 17ms/step
# Epoch 19/4000
# 54/54 - 1s - loss: 0.2044 - accuracy: 0.9370 - val_loss: 0.2040 - val_accuracy: 0.9340 - 909ms/epoch - 17ms/step
# Epoch 20/4000
# 54/54 - 1s - loss: 0.1988 - accuracy: 0.9384 - val_loss: 0.1971 - val_accuracy: 0.9396 - 906ms/epoch - 17ms/step
# Epoch 21/4000
# 54/54 - 1s - loss: 0.1964 - accuracy: 0.9394 - val_loss: 0.1924 - val_accuracy: 0.9398 - 906ms/epoch - 17ms/step
# Epoch 22/4000
# 54/54 - 1s - loss: 0.1901 - accuracy: 0.9425 - val_loss: 0.1959 - val_accuracy: 0.9366 - 897ms/epoch - 17ms/step
# Epoch 23/4000
# 54/54 - 1s - loss: 0.1842 - accuracy: 0.9436 - val_loss: 0.1734 - val_accuracy: 0.9496 - 899ms/epoch - 17ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.1854 - accuracy: 0.9441 - val_loss: 0.1883 - val_accuracy: 0.9400 - 905ms/epoch - 17ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.1804 - accuracy: 0.9459 - val_loss: 0.1810 - val_accuracy: 0.9456 - 896ms/epoch - 17ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.1763 - accuracy: 0.9476 - val_loss: 0.1749 - val_accuracy: 0.9466 - 899ms/epoch - 17ms/step
# Epoch 27/4000
# 54/54 - 1s - loss: 0.1777 - accuracy: 0.9465 - val_loss: 0.1692 - val_accuracy: 0.9530 - 909ms/epoch - 17ms/step
# Epoch 28/4000
# 54/54 - 1s - loss: 0.1707 - accuracy: 0.9487 - val_loss: 0.1873 - val_accuracy: 0.9438 - 898ms/epoch - 17ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.1712 - accuracy: 0.9484 - val_loss: 0.1839 - val_accuracy: 0.9436 - 894ms/epoch - 17ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.1700 - accuracy: 0.9492 - val_loss: 0.1550 - val_accuracy: 0.9548 - 912ms/epoch - 17ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.1629 - accuracy: 0.9520 - val_loss: 0.1803 - val_accuracy: 0.9426 - 898ms/epoch - 17ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.1676 - accuracy: 0.9494 - val_loss: 0.1619 - val_accuracy: 0.9544 - 896ms/epoch - 17ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.1571 - accuracy: 0.9542 - val_loss: 0.1717 - val_accuracy: 0.9490 - 900ms/epoch - 17ms/step
# Epoch 34/4000
# 54/54 - 1s - loss: 0.1528 - accuracy: 0.9561 - val_loss: 0.1421 - val_accuracy: 0.9604 - 912ms/epoch - 17ms/step
# Epoch 35/4000
# 54/54 - 1s - loss: 0.1490 - accuracy: 0.9578 - val_loss: 0.1448 - val_accuracy: 0.9592 - 902ms/epoch - 17ms/step
# Epoch 36/4000
# 54/54 - 1s - loss: 0.1478 - accuracy: 0.9581 - val_loss: 0.1548 - val_accuracy: 0.9552 - 905ms/epoch - 17ms/step
# Epoch 37/4000
# 54/54 - 1s - loss: 0.1454 - accuracy: 0.9585 - val_loss: 0.1539 - val_accuracy: 0.9534 - 903ms/epoch - 17ms/step
# Epoch 38/4000
# 54/54 - 1s - loss: 0.1441 - accuracy: 0.9590 - val_loss: 0.1414 - val_accuracy: 0.9608 - 910ms/epoch - 17ms/step
# Epoch 39/4000
# 54/54 - 1s - loss: 0.1398 - accuracy: 0.9612 - val_loss: 0.1321 - val_accuracy: 0.9668 - 910ms/epoch - 17ms/step
# Epoch 40/4000
# 54/54 - 1s - loss: 0.1387 - accuracy: 0.9611 - val_loss: 0.1375 - val_accuracy: 0.9620 - 897ms/epoch - 17ms/step
# Epoch 41/4000
# 54/54 - 1s - loss: 0.1441 - accuracy: 0.9585 - val_loss: 0.1345 - val_accuracy: 0.9632 - 904ms/epoch - 17ms/step
# Epoch 42/4000
# 54/54 - 1s - loss: 0.1337 - accuracy: 0.9633 - val_loss: 0.1306 - val_accuracy: 0.9622 - 938ms/epoch - 17ms/step
# Epoch 43/4000
# 54/54 - 1s - loss: 0.1325 - accuracy: 0.9635 - val_loss: 0.1278 - val_accuracy: 0.9662 - 916ms/epoch - 17ms/step
# Epoch 44/4000
# 54/54 - 1s - loss: 0.1306 - accuracy: 0.9641 - val_loss: 0.1378 - val_accuracy: 0.9584 - 903ms/epoch - 17ms/step
# Epoch 45/4000
# 54/54 - 1s - loss: 0.1361 - accuracy: 0.9616 - val_loss: 0.1443 - val_accuracy: 0.9558 - 902ms/epoch - 17ms/step
# Epoch 46/4000
# 54/54 - 1s - loss: 0.1286 - accuracy: 0.9650 - val_loss: 0.1354 - val_accuracy: 0.9604 - 912ms/epoch - 17ms/step
# Epoch 47/4000
# 54/54 - 1s - loss: 0.1303 - accuracy: 0.9649 - val_loss: 0.1270 - val_accuracy: 0.9684 - 919ms/epoch - 17ms/step
# Epoch 48/4000
# 54/54 - 1s - loss: 0.1241 - accuracy: 0.9672 - val_loss: 0.1258 - val_accuracy: 0.9630 - 915ms/epoch - 17ms/step
# Epoch 49/4000
# 54/54 - 1s - loss: 0.1195 - accuracy: 0.9687 - val_loss: 0.1191 - val_accuracy: 0.9688 - 913ms/epoch - 17ms/step
# Epoch 50/4000
# 54/54 - 1s - loss: 0.1197 - accuracy: 0.9684 - val_loss: 0.1159 - val_accuracy: 0.9702 - 913ms/epoch - 17ms/step
# Epoch 51/4000
# 54/54 - 1s - loss: 0.1220 - accuracy: 0.9662 - val_loss: 0.1307 - val_accuracy: 0.9650 - 903ms/epoch - 17ms/step
# Epoch 52/4000
# 54/54 - 1s - loss: 0.1203 - accuracy: 0.9673 - val_loss: 0.1219 - val_accuracy: 0.9654 - 906ms/epoch - 17ms/step
# Epoch 53/4000
# 54/54 - 1s - loss: 0.1168 - accuracy: 0.9701 - val_loss: 0.1298 - val_accuracy: 0.9620 - 913ms/epoch - 17ms/step
# Epoch 54/4000
# 54/54 - 1s - loss: 0.1141 - accuracy: 0.9713 - val_loss: 0.1143 - val_accuracy: 0.9688 - 916ms/epoch - 17ms/step
# Epoch 55/4000
# 54/54 - 1s - loss: 0.1154 - accuracy: 0.9701 - val_loss: 0.1257 - val_accuracy: 0.9608 - 903ms/epoch - 17ms/step
# Epoch 56/4000
# 54/54 - 1s - loss: 0.1113 - accuracy: 0.9718 - val_loss: 0.1078 - val_accuracy: 0.9752 - 917ms/epoch - 17ms/step
# Epoch 57/4000
# 54/54 - 1s - loss: 0.1082 - accuracy: 0.9725 - val_loss: 0.1062 - val_accuracy: 0.9734 - 915ms/epoch - 17ms/step
# Epoch 58/4000
# 54/54 - 1s - loss: 0.1074 - accuracy: 0.9734 - val_loss: 0.1088 - val_accuracy: 0.9728 - 912ms/epoch - 17ms/step
# Epoch 59/4000
# 54/54 - 1s - loss: 0.1074 - accuracy: 0.9724 - val_loss: 0.1230 - val_accuracy: 0.9668 - 913ms/epoch - 17ms/step
# Epoch 60/4000
# 54/54 - 1s - loss: 0.1078 - accuracy: 0.9727 - val_loss: 0.1066 - val_accuracy: 0.9726 - 910ms/epoch - 17ms/step
# Epoch 61/4000
# 54/54 - 1s - loss: 0.1033 - accuracy: 0.9749 - val_loss: 0.0995 - val_accuracy: 0.9748 - 916ms/epoch - 17ms/step
# Epoch 62/4000
# 54/54 - 1s - loss: 0.1060 - accuracy: 0.9733 - val_loss: 0.1026 - val_accuracy: 0.9722 - 908ms/epoch - 17ms/step
# Epoch 63/4000
# 54/54 - 1s - loss: 0.1013 - accuracy: 0.9757 - val_loss: 0.0970 - val_accuracy: 0.9766 - 919ms/epoch - 17ms/step
# Epoch 64/4000
# 54/54 - 1s - loss: 0.0990 - accuracy: 0.9767 - val_loss: 0.1077 - val_accuracy: 0.9716 - 913ms/epoch - 17ms/step
# Epoch 65/4000
# 54/54 - 1s - loss: 0.0994 - accuracy: 0.9762 - val_loss: 0.1008 - val_accuracy: 0.9750 - 915ms/epoch - 17ms/step
# Epoch 66/4000
# 54/54 - 1s - loss: 0.0977 - accuracy: 0.9768 - val_loss: 0.0910 - val_accuracy: 0.9804 - 917ms/epoch - 17ms/step
# Epoch 67/4000
# 54/54 - 1s - loss: 0.0974 - accuracy: 0.9770 - val_loss: 0.1120 - val_accuracy: 0.9722 - 908ms/epoch - 17ms/step
# Epoch 68/4000
# 54/54 - 1s - loss: 0.0995 - accuracy: 0.9753 - val_loss: 0.0966 - val_accuracy: 0.9772 - 911ms/epoch - 17ms/step
# Epoch 69/4000
# 54/54 - 1s - loss: 0.0948 - accuracy: 0.9773 - val_loss: 0.1050 - val_accuracy: 0.9724 - 912ms/epoch - 17ms/step
# Epoch 70/4000
# 54/54 - 1s - loss: 0.0955 - accuracy: 0.9769 - val_loss: 0.0887 - val_accuracy: 0.9806 - 926ms/epoch - 17ms/step
# Epoch 71/4000
# 54/54 - 1s - loss: 0.0957 - accuracy: 0.9771 - val_loss: 0.0936 - val_accuracy: 0.9754 - 914ms/epoch - 17ms/step
# Epoch 72/4000
# 54/54 - 1s - loss: 0.0915 - accuracy: 0.9792 - val_loss: 0.0877 - val_accuracy: 0.9830 - 923ms/epoch - 17ms/step
# Epoch 73/4000
# 54/54 - 1s - loss: 0.0903 - accuracy: 0.9791 - val_loss: 0.0941 - val_accuracy: 0.9768 - 910ms/epoch - 17ms/step
# Epoch 74/4000
# 54/54 - 1s - loss: 0.0895 - accuracy: 0.9794 - val_loss: 0.0921 - val_accuracy: 0.9768 - 913ms/epoch - 17ms/step
# Epoch 75/4000
# 54/54 - 1s - loss: 0.0939 - accuracy: 0.9767 - val_loss: 0.0868 - val_accuracy: 0.9812 - 922ms/epoch - 17ms/step
# Epoch 76/4000
# 54/54 - 1s - loss: 0.0891 - accuracy: 0.9793 - val_loss: 0.0815 - val_accuracy: 0.9828 - 930ms/epoch - 17ms/step
# Epoch 77/4000
# 54/54 - 1s - loss: 0.0857 - accuracy: 0.9815 - val_loss: 0.0814 - val_accuracy: 0.9832 - 922ms/epoch - 17ms/step
# Epoch 78/4000
# 54/54 - 1s - loss: 0.0844 - accuracy: 0.9812 - val_loss: 0.0785 - val_accuracy: 0.9850 - 924ms/epoch - 17ms/step
# Epoch 79/4000
# 54/54 - 1s - loss: 0.0851 - accuracy: 0.9809 - val_loss: 0.0834 - val_accuracy: 0.9804 - 921ms/epoch - 17ms/step
# Epoch 80/4000
# 54/54 - 1s - loss: 0.0873 - accuracy: 0.9800 - val_loss: 0.0854 - val_accuracy: 0.9812 - 920ms/epoch - 17ms/step
# Epoch 81/4000
# 54/54 - 1s - loss: 0.0808 - accuracy: 0.9827 - val_loss: 0.0767 - val_accuracy: 0.9850 - 933ms/epoch - 17ms/step
# Epoch 82/4000
# 54/54 - 1s - loss: 0.0804 - accuracy: 0.9833 - val_loss: 0.0808 - val_accuracy: 0.9824 - 927ms/epoch - 17ms/step
# Epoch 83/4000
# 54/54 - 1s - loss: 0.0790 - accuracy: 0.9833 - val_loss: 0.0755 - val_accuracy: 0.9866 - 928ms/epoch - 17ms/step
# Epoch 84/4000
# 54/54 - 1s - loss: 0.0799 - accuracy: 0.9831 - val_loss: 0.0815 - val_accuracy: 0.9828 - 916ms/epoch - 17ms/step
# Epoch 85/4000
# 54/54 - 1s - loss: 0.0789 - accuracy: 0.9829 - val_loss: 0.0888 - val_accuracy: 0.9772 - 916ms/epoch - 17ms/step
# Epoch 86/4000
# 54/54 - 1s - loss: 0.0787 - accuracy: 0.9833 - val_loss: 0.0881 - val_accuracy: 0.9768 - 920ms/epoch - 17ms/step
# Epoch 87/4000
# 54/54 - 1s - loss: 0.0819 - accuracy: 0.9821 - val_loss: 0.0726 - val_accuracy: 0.9854 - 936ms/epoch - 17ms/step
# Epoch 88/4000
# 54/54 - 1s - loss: 0.0755 - accuracy: 0.9850 - val_loss: 0.0745 - val_accuracy: 0.9850 - 924ms/epoch - 17ms/step
# Epoch 89/4000
# 54/54 - 1s - loss: 0.0760 - accuracy: 0.9843 - val_loss: 0.0773 - val_accuracy: 0.9844 - 916ms/epoch - 17ms/step
# Epoch 90/4000
# 54/54 - 1s - loss: 0.0775 - accuracy: 0.9837 - val_loss: 0.0700 - val_accuracy: 0.9856 - 928ms/epoch - 17ms/step
# Epoch 91/4000
# 54/54 - 1s - loss: 0.0721 - accuracy: 0.9869 - val_loss: 0.0673 - val_accuracy: 0.9886 - 922ms/epoch - 17ms/step
# Epoch 92/4000
# 54/54 - 1s - loss: 0.0774 - accuracy: 0.9828 - val_loss: 0.0735 - val_accuracy: 0.9850 - 916ms/epoch - 17ms/step
# Epoch 93/4000
# 54/54 - 1s - loss: 0.0765 - accuracy: 0.9840 - val_loss: 0.0659 - val_accuracy: 0.9884 - 928ms/epoch - 17ms/step
# Epoch 94/4000
# 54/54 - 1s - loss: 0.0711 - accuracy: 0.9856 - val_loss: 0.0705 - val_accuracy: 0.9852 - 930ms/epoch - 17ms/step
# Epoch 95/4000
# 54/54 - 1s - loss: 0.0689 - accuracy: 0.9872 - val_loss: 0.0643 - val_accuracy: 0.9902 - 925ms/epoch - 17ms/step
# Epoch 96/4000
# 54/54 - 1s - loss: 0.0676 - accuracy: 0.9886 - val_loss: 0.0708 - val_accuracy: 0.9844 - 915ms/epoch - 17ms/step
# Epoch 97/4000
# 54/54 - 1s - loss: 0.0666 - accuracy: 0.9881 - val_loss: 0.0644 - val_accuracy: 0.9900 - 916ms/epoch - 17ms/step
# Epoch 98/4000
# 54/54 - 1s - loss: 0.0684 - accuracy: 0.9870 - val_loss: 0.0636 - val_accuracy: 0.9898 - 931ms/epoch - 17ms/step
# Epoch 99/4000
# 54/54 - 1s - loss: 0.0679 - accuracy: 0.9871 - val_loss: 0.0728 - val_accuracy: 0.9840 - 928ms/epoch - 17ms/step
# Epoch 100/4000
# 54/54 - 1s - loss: 0.0657 - accuracy: 0.9886 - val_loss: 0.0720 - val_accuracy: 0.9838 - 921ms/epoch - 17ms/step
# Epoch 101/4000
# 54/54 - 1s - loss: 0.0699 - accuracy: 0.9859 - val_loss: 0.0666 - val_accuracy: 0.9882 - 917ms/epoch - 17ms/step
# Epoch 102/4000
# 54/54 - 1s - loss: 0.0674 - accuracy: 0.9872 - val_loss: 0.0626 - val_accuracy: 0.9888 - 929ms/epoch - 17ms/step
# Epoch 103/4000
# 54/54 - 1s - loss: 0.0669 - accuracy: 0.9871 - val_loss: 0.0669 - val_accuracy: 0.9878 - 922ms/epoch - 17ms/step
# Epoch 104/4000
# 54/54 - 1s - loss: 0.0646 - accuracy: 0.9883 - val_loss: 0.0649 - val_accuracy: 0.9886 - 925ms/epoch - 17ms/step
# Epoch 105/4000
# 54/54 - 1s - loss: 0.0635 - accuracy: 0.9888 - val_loss: 0.0674 - val_accuracy: 0.9878 - 927ms/epoch - 17ms/step
# Epoch 106/4000
# 54/54 - 1s - loss: 0.0620 - accuracy: 0.9894 - val_loss: 0.0610 - val_accuracy: 0.9896 - 927ms/epoch - 17ms/step
# Epoch 107/4000
# 54/54 - 1s - loss: 0.0652 - accuracy: 0.9878 - val_loss: 0.0597 - val_accuracy: 0.9894 - 934ms/epoch - 17ms/step
# Epoch 108/4000
# 54/54 - 1s - loss: 0.0614 - accuracy: 0.9897 - val_loss: 0.0651 - val_accuracy: 0.9876 - 925ms/epoch - 17ms/step
# Epoch 109/4000
# 54/54 - 1s - loss: 0.0622 - accuracy: 0.9891 - val_loss: 0.0604 - val_accuracy: 0.9908 - 920ms/epoch - 17ms/step
# Epoch 110/4000
# 54/54 - 1s - loss: 0.0619 - accuracy: 0.9892 - val_loss: 0.0645 - val_accuracy: 0.9884 - 924ms/epoch - 17ms/step
# Epoch 111/4000
# 54/54 - 1s - loss: 0.0593 - accuracy: 0.9908 - val_loss: 0.0682 - val_accuracy: 0.9860 - 921ms/epoch - 17ms/step
# Epoch 112/4000
# 54/54 - 1s - loss: 0.0604 - accuracy: 0.9899 - val_loss: 0.0564 - val_accuracy: 0.9930 - 928ms/epoch - 17ms/step
# Epoch 113/4000
# 54/54 - 1s - loss: 0.0609 - accuracy: 0.9897 - val_loss: 0.0626 - val_accuracy: 0.9876 - 924ms/epoch - 17ms/step
# Epoch 114/4000
# 54/54 - 1s - loss: 0.0623 - accuracy: 0.9887 - val_loss: 0.0526 - val_accuracy: 0.9930 - 930ms/epoch - 17ms/step
# Epoch 115/4000
# 54/54 - 1s - loss: 0.0568 - accuracy: 0.9913 - val_loss: 0.0570 - val_accuracy: 0.9926 - 923ms/epoch - 17ms/step
# Epoch 116/4000
# 54/54 - 1s - loss: 0.0596 - accuracy: 0.9902 - val_loss: 0.0616 - val_accuracy: 0.9888 - 927ms/epoch - 17ms/step
# Epoch 117/4000
# 54/54 - 1s - loss: 0.0574 - accuracy: 0.9912 - val_loss: 0.0536 - val_accuracy: 0.9938 - 923ms/epoch - 17ms/step
# Epoch 118/4000
# 54/54 - 1s - loss: 0.0574 - accuracy: 0.9909 - val_loss: 0.0730 - val_accuracy: 0.9836 - 923ms/epoch - 17ms/step
# Epoch 119/4000
# 54/54 - 1s - loss: 0.0595 - accuracy: 0.9895 - val_loss: 0.0529 - val_accuracy: 0.9942 - 924ms/epoch - 17ms/step
# Epoch 120/4000
# 54/54 - 1s - loss: 0.0528 - accuracy: 0.9930 - val_loss: 0.0517 - val_accuracy: 0.9932 - 934ms/epoch - 17ms/step
# Epoch 121/4000
# 54/54 - 1s - loss: 0.0608 - accuracy: 0.9887 - val_loss: 0.0631 - val_accuracy: 0.9888 - 924ms/epoch - 17ms/step
# Epoch 122/4000
# 54/54 - 1s - loss: 0.0572 - accuracy: 0.9902 - val_loss: 0.0577 - val_accuracy: 0.9886 - 927ms/epoch - 17ms/step
# Epoch 123/4000
# 54/54 - 1s - loss: 0.0593 - accuracy: 0.9896 - val_loss: 0.0642 - val_accuracy: 0.9880 - 926ms/epoch - 17ms/step
# Epoch 124/4000
# 54/54 - 1s - loss: 0.0573 - accuracy: 0.9902 - val_loss: 0.0523 - val_accuracy: 0.9936 - 922ms/epoch - 17ms/step
# Epoch 125/4000
# 54/54 - 1s - loss: 0.0548 - accuracy: 0.9912 - val_loss: 0.0534 - val_accuracy: 0.9928 - 924ms/epoch - 17ms/step
# Epoch 126/4000
# 54/54 - 1s - loss: 0.0518 - accuracy: 0.9931 - val_loss: 0.0497 - val_accuracy: 0.9942 - 935ms/epoch - 17ms/step
# Epoch 127/4000
# 54/54 - 1s - loss: 0.0499 - accuracy: 0.9940 - val_loss: 0.0480 - val_accuracy: 0.9948 - 942ms/epoch - 17ms/step
# Epoch 128/4000
# 54/54 - 1s - loss: 0.0520 - accuracy: 0.9926 - val_loss: 0.0478 - val_accuracy: 0.9942 - 932ms/epoch - 17ms/step
# Epoch 129/4000
# 54/54 - 1s - loss: 0.0540 - accuracy: 0.9916 - val_loss: 0.0511 - val_accuracy: 0.9926 - 924ms/epoch - 17ms/step
# Epoch 130/4000
# 54/54 - 1s - loss: 0.0521 - accuracy: 0.9926 - val_loss: 0.0520 - val_accuracy: 0.9928 - 925ms/epoch - 17ms/step
# Epoch 131/4000
# 54/54 - 1s - loss: 0.0483 - accuracy: 0.9943 - val_loss: 0.0483 - val_accuracy: 0.9944 - 926ms/epoch - 17ms/step
# Epoch 132/4000
# 54/54 - 1s - loss: 0.0490 - accuracy: 0.9938 - val_loss: 0.0536 - val_accuracy: 0.9912 - 932ms/epoch - 17ms/step
# Epoch 133/4000
# 54/54 - 1s - loss: 0.0520 - accuracy: 0.9926 - val_loss: 0.0474 - val_accuracy: 0.9946 - 942ms/epoch - 17ms/step
# Epoch 134/4000
# 54/54 - 1s - loss: 0.0492 - accuracy: 0.9938 - val_loss: 0.0491 - val_accuracy: 0.9938 - 928ms/epoch - 17ms/step
# Epoch 135/4000
# 54/54 - 1s - loss: 0.0467 - accuracy: 0.9950 - val_loss: 0.0440 - val_accuracy: 0.9962 - 932ms/epoch - 17ms/step
# Epoch 136/4000
# 54/54 - 1s - loss: 0.0467 - accuracy: 0.9949 - val_loss: 0.0458 - val_accuracy: 0.9960 - 928ms/epoch - 17ms/step
# Epoch 137/4000
# 54/54 - 1s - loss: 0.0479 - accuracy: 0.9938 - val_loss: 0.0454 - val_accuracy: 0.9962 - 925ms/epoch - 17ms/step
# Epoch 138/4000
# 54/54 - 1s - loss: 0.0472 - accuracy: 0.9944 - val_loss: 0.0451 - val_accuracy: 0.9944 - 931ms/epoch - 17ms/step
# Epoch 139/4000
# 54/54 - 1s - loss: 0.0462 - accuracy: 0.9949 - val_loss: 0.0446 - val_accuracy: 0.9966 - 930ms/epoch - 17ms/step
# Epoch 140/4000
# 54/54 - 1s - loss: 0.0464 - accuracy: 0.9949 - val_loss: 0.0455 - val_accuracy: 0.9956 - 928ms/epoch - 17ms/step
# Epoch 141/4000
# 54/54 - 1s - loss: 0.0471 - accuracy: 0.9942 - val_loss: 0.0490 - val_accuracy: 0.9932 - 930ms/epoch - 17ms/step
# Epoch 142/4000
# 54/54 - 1s - loss: 0.0448 - accuracy: 0.9955 - val_loss: 0.0446 - val_accuracy: 0.9962 - 931ms/epoch - 17ms/step
# Epoch 143/4000
# 54/54 - 1s - loss: 0.0443 - accuracy: 0.9955 - val_loss: 0.0408 - val_accuracy: 0.9974 - 945ms/epoch - 17ms/step
# Epoch 144/4000
# 54/54 - 1s - loss: 0.0427 - accuracy: 0.9964 - val_loss: 0.0401 - val_accuracy: 0.9978 - 949ms/epoch - 18ms/step
# Epoch 145/4000
# 54/54 - 1s - loss: 0.0443 - accuracy: 0.9958 - val_loss: 0.0418 - val_accuracy: 0.9968 - 932ms/epoch - 17ms/step
# Epoch 146/4000
# 54/54 - 1s - loss: 0.0428 - accuracy: 0.9963 - val_loss: 0.0542 - val_accuracy: 0.9914 - 934ms/epoch - 17ms/step
# Epoch 147/4000
# 54/54 - 1s - loss: 0.0426 - accuracy: 0.9963 - val_loss: 0.0394 - val_accuracy: 0.9986 - 947ms/epoch - 18ms/step
# Epoch 148/4000
# 54/54 - 1s - loss: 0.0409 - accuracy: 0.9969 - val_loss: 0.0427 - val_accuracy: 0.9960 - 931ms/epoch - 17ms/step
# Epoch 149/4000
# 54/54 - 1s - loss: 0.0425 - accuracy: 0.9961 - val_loss: 0.0468 - val_accuracy: 0.9940 - 951ms/epoch - 18ms/step
# Epoch 150/4000
# 54/54 - 1s - loss: 0.0468 - accuracy: 0.9939 - val_loss: 0.0479 - val_accuracy: 0.9942 - 935ms/epoch - 17ms/step
# Epoch 151/4000
# 54/54 - 1s - loss: 0.0480 - accuracy: 0.9931 - val_loss: 0.0430 - val_accuracy: 0.9960 - 933ms/epoch - 17ms/step
# Epoch 152/4000
# 54/54 - 1s - loss: 0.0505 - accuracy: 0.9922 - val_loss: 0.0464 - val_accuracy: 0.9942 - 936ms/epoch - 17ms/step
# Epoch 153/4000
# 54/54 - 1s - loss: 0.0543 - accuracy: 0.9901 - val_loss: 0.0528 - val_accuracy: 0.9916 - 929ms/epoch - 17ms/step
# Epoch 154/4000
# 54/54 - 1s - loss: 0.0445 - accuracy: 0.9951 - val_loss: 0.0441 - val_accuracy: 0.9950 - 936ms/epoch - 17ms/step
# Epoch 155/4000
# 54/54 - 1s - loss: 0.0444 - accuracy: 0.9947 - val_loss: 0.0672 - val_accuracy: 0.9832 - 935ms/epoch - 17ms/step
# Epoch 156/4000
# 54/54 - 1s - loss: 0.0487 - accuracy: 0.9924 - val_loss: 0.0474 - val_accuracy: 0.9926 - 936ms/epoch - 17ms/step
# Epoch 157/4000
# 54/54 - 1s - loss: 0.0437 - accuracy: 0.9947 - val_loss: 0.0389 - val_accuracy: 0.9982 - 942ms/epoch - 17ms/step
# Epoch 158/4000
# 54/54 - 1s - loss: 0.0424 - accuracy: 0.9958 - val_loss: 0.0416 - val_accuracy: 0.9964 - 930ms/epoch - 17ms/step
# Epoch 159/4000
# 54/54 - 1s - loss: 0.0397 - accuracy: 0.9970 - val_loss: 0.0408 - val_accuracy: 0.9964 - 932ms/epoch - 17ms/step
# Epoch 160/4000
# 54/54 - 1s - loss: 0.0386 - accuracy: 0.9971 - val_loss: 0.0408 - val_accuracy: 0.9960 - 939ms/epoch - 17ms/step
# Epoch 161/4000
# 54/54 - 1s - loss: 0.0404 - accuracy: 0.9960 - val_loss: 0.0386 - val_accuracy: 0.9974 - 960ms/epoch - 18ms/step
# Epoch 162/4000
# 54/54 - 1s - loss: 0.0412 - accuracy: 0.9957 - val_loss: 0.0375 - val_accuracy: 0.9986 - 940ms/epoch - 17ms/step
# Epoch 163/4000
# 54/54 - 1s - loss: 0.0375 - accuracy: 0.9977 - val_loss: 0.0403 - val_accuracy: 0.9968 - 929ms/epoch - 17ms/step
# Epoch 164/4000
# 54/54 - 1s - loss: 0.0385 - accuracy: 0.9971 - val_loss: 0.0371 - val_accuracy: 0.9984 - 939ms/epoch - 17ms/step
# Epoch 165/4000
# 54/54 - 1s - loss: 0.0373 - accuracy: 0.9977 - val_loss: 0.0406 - val_accuracy: 0.9950 - 931ms/epoch - 17ms/step
# Epoch 166/4000
# 54/54 - 1s - loss: 0.0424 - accuracy: 0.9953 - val_loss: 0.0420 - val_accuracy: 0.9958 - 936ms/epoch - 17ms/step
# Epoch 167/4000
# 54/54 - 1s - loss: 0.0423 - accuracy: 0.9953 - val_loss: 0.0411 - val_accuracy: 0.9966 - 936ms/epoch - 17ms/step
# Epoch 168/4000
# 54/54 - 1s - loss: 0.0363 - accuracy: 0.9983 - val_loss: 0.0350 - val_accuracy: 0.9990 - 943ms/epoch - 17ms/step
# Epoch 169/4000
# 54/54 - 1s - loss: 0.0348 - accuracy: 0.9988 - val_loss: 0.0343 - val_accuracy: 0.9982 - 935ms/epoch - 17ms/step
# Epoch 170/4000
# 54/54 - 1s - loss: 0.0372 - accuracy: 0.9977 - val_loss: 0.0373 - val_accuracy: 0.9978 - 936ms/epoch - 17ms/step
# Epoch 171/4000
# 54/54 - 1s - loss: 0.0373 - accuracy: 0.9975 - val_loss: 0.0393 - val_accuracy: 0.9964 - 933ms/epoch - 17ms/step
# Epoch 172/4000
# 54/54 - 1s - loss: 0.0398 - accuracy: 0.9961 - val_loss: 0.0385 - val_accuracy: 0.9970 - 938ms/epoch - 17ms/step
# Epoch 173/4000
# 54/54 - 1s - loss: 0.0402 - accuracy: 0.9957 - val_loss: 0.0365 - val_accuracy: 0.9980 - 937ms/epoch - 17ms/step
# Epoch 174/4000
# 54/54 - 1s - loss: 0.0366 - accuracy: 0.9975 - val_loss: 0.0363 - val_accuracy: 0.9970 - 934ms/epoch - 17ms/step
# Epoch 175/4000
# 54/54 - 1s - loss: 0.0388 - accuracy: 0.9965 - val_loss: 0.0460 - val_accuracy: 0.9942 - 933ms/epoch - 17ms/step
# Epoch 176/4000
# 54/54 - 1s - loss: 0.0400 - accuracy: 0.9958 - val_loss: 0.0442 - val_accuracy: 0.9948 - 933ms/epoch - 17ms/step
# Epoch 177/4000
# 54/54 - 1s - loss: 0.0408 - accuracy: 0.9955 - val_loss: 0.0353 - val_accuracy: 0.9974 - 938ms/epoch - 17ms/step
# Epoch 178/4000
# 54/54 - 1s - loss: 0.0381 - accuracy: 0.9968 - val_loss: 0.0433 - val_accuracy: 0.9946 - 939ms/epoch - 17ms/step
# Epoch 179/4000
# 54/54 - 1s - loss: 0.0371 - accuracy: 0.9970 - val_loss: 0.0392 - val_accuracy: 0.9964 - 944ms/epoch - 17ms/step
# 313/313 - 1s - loss: 0.7382 - accuracy: 0.8869 - 574ms/epoch - 2ms/step
# Test loss: 0.738
# Test accuracy: 88.690%

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 20)        200
#
#  average_pooling2d (AverageP  (None, 13, 13, 20)       0
#  ooling2D)
#
#  batch_normalization (BatchN  (None, 13, 13, 20)       80
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 50)        9050
#
#  square_activation (SquareAc  (None, 11, 11, 50)       0
#  tivation)
#
#  batch_normalization_1 (Batc  (None, 11, 11, 50)       200
#  hNormalization)
#
#  flatten (Flatten)           (None, 6050)              0
#
#  dense (Dense)               (None, 500)               3025500
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 3,040,040
# Trainable params: 3,039,900
# Non-trainable params: 140
# _________________________________________________________________

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=10,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 54/54 - 2s - loss: 0.4705 - accuracy: 0.8814 - val_loss: 4.1063 - val_accuracy: 0.5448 - 2s/epoch - 34ms/step
# Epoch 2/4000
# 54/54 - 1s - loss: 0.2802 - accuracy: 0.9115 - val_loss: 1.7875 - val_accuracy: 0.6542 - 1s/epoch - 20ms/step
# Epoch 3/4000
# 54/54 - 1s - loss: 0.2389 - accuracy: 0.9204 - val_loss: 0.7317 - val_accuracy: 0.7982 - 1s/epoch - 20ms/step
# Epoch 4/4000
# 54/54 - 1s - loss: 0.2288 - accuracy: 0.9240 - val_loss: 0.3977 - val_accuracy: 0.8664 - 1s/epoch - 20ms/step
# Epoch 5/4000
# 54/54 - 1s - loss: 0.2206 - accuracy: 0.9255 - val_loss: 0.2405 - val_accuracy: 0.9178 - 1s/epoch - 20ms/step
# Epoch 6/4000
# 54/54 - 1s - loss: 0.2084 - accuracy: 0.9308 - val_loss: 0.2270 - val_accuracy: 0.9252 - 1s/epoch - 20ms/step
# Epoch 7/4000
# 54/54 - 1s - loss: 0.2063 - accuracy: 0.9312 - val_loss: 0.1901 - val_accuracy: 0.9368 - 1s/epoch - 20ms/step
# Epoch 8/4000
# 54/54 - 1s - loss: 0.1992 - accuracy: 0.9331 - val_loss: 0.2201 - val_accuracy: 0.9300 - 1s/epoch - 20ms/step
# Epoch 9/4000
# 54/54 - 1s - loss: 0.1969 - accuracy: 0.9345 - val_loss: 0.1907 - val_accuracy: 0.9332 - 1s/epoch - 20ms/step
# Epoch 10/4000
# 54/54 - 1s - loss: 0.1920 - accuracy: 0.9357 - val_loss: 0.1978 - val_accuracy: 0.9366 - 1s/epoch - 20ms/step
# Epoch 11/4000
# 54/54 - 1s - loss: 0.1880 - accuracy: 0.9380 - val_loss: 0.1940 - val_accuracy: 0.9368 - 1s/epoch - 20ms/step
# Epoch 12/4000
# 54/54 - 1s - loss: 0.1850 - accuracy: 0.9393 - val_loss: 0.1857 - val_accuracy: 0.9400 - 1s/epoch - 20ms/step
# Epoch 13/4000
# 54/54 - 1s - loss: 0.1765 - accuracy: 0.9434 - val_loss: 0.1787 - val_accuracy: 0.9416 - 1s/epoch - 20ms/step
# Epoch 14/4000
# 54/54 - 1s - loss: 0.1816 - accuracy: 0.9396 - val_loss: 0.2204 - val_accuracy: 0.9262 - 1s/epoch - 20ms/step
# Epoch 15/4000
# 54/54 - 1s - loss: 0.1759 - accuracy: 0.9428 - val_loss: 0.1799 - val_accuracy: 0.9426 - 1s/epoch - 20ms/step
# Epoch 16/4000
# 54/54 - 1s - loss: 0.1762 - accuracy: 0.9427 - val_loss: 0.1746 - val_accuracy: 0.9430 - 1s/epoch - 20ms/step
# Epoch 17/4000
# 54/54 - 1s - loss: 0.1716 - accuracy: 0.9441 - val_loss: 0.1786 - val_accuracy: 0.9424 - 1s/epoch - 20ms/step
# Epoch 18/4000
# 54/54 - 1s - loss: 0.1719 - accuracy: 0.9449 - val_loss: 0.1980 - val_accuracy: 0.9350 - 1s/epoch - 20ms/step
# Epoch 19/4000
# 54/54 - 1s - loss: 0.1695 - accuracy: 0.9441 - val_loss: 0.1588 - val_accuracy: 0.9512 - 1s/epoch - 20ms/step
# Epoch 20/4000
# 54/54 - 1s - loss: 0.1664 - accuracy: 0.9469 - val_loss: 0.1681 - val_accuracy: 0.9466 - 1s/epoch - 20ms/step
# Epoch 21/4000
# 54/54 - 1s - loss: 0.1661 - accuracy: 0.9464 - val_loss: 0.1723 - val_accuracy: 0.9450 - 1s/epoch - 20ms/step
# Epoch 22/4000
# 54/54 - 1s - loss: 0.1659 - accuracy: 0.9475 - val_loss: 0.1666 - val_accuracy: 0.9462 - 1s/epoch - 20ms/step
# Epoch 23/4000
# 54/54 - 1s - loss: 0.1608 - accuracy: 0.9490 - val_loss: 0.1530 - val_accuracy: 0.9522 - 1s/epoch - 20ms/step
# Epoch 24/4000
# 54/54 - 1s - loss: 0.1687 - accuracy: 0.9461 - val_loss: 0.1861 - val_accuracy: 0.9408 - 1s/epoch - 20ms/step
# Epoch 25/4000
# 54/54 - 1s - loss: 0.1678 - accuracy: 0.9457 - val_loss: 0.1662 - val_accuracy: 0.9502 - 1s/epoch - 20ms/step
# Epoch 26/4000
# 54/54 - 1s - loss: 0.1573 - accuracy: 0.9500 - val_loss: 0.1719 - val_accuracy: 0.9462 - 1s/epoch - 20ms/step
# Epoch 27/4000
# 54/54 - 1s - loss: 0.1588 - accuracy: 0.9499 - val_loss: 0.1718 - val_accuracy: 0.9470 - 1s/epoch - 20ms/step
# Epoch 28/4000
# 54/54 - 1s - loss: 0.1556 - accuracy: 0.9506 - val_loss: 0.1811 - val_accuracy: 0.9424 - 1s/epoch - 20ms/step
# Epoch 29/4000
# 54/54 - 1s - loss: 0.1610 - accuracy: 0.9488 - val_loss: 0.1883 - val_accuracy: 0.9402 - 1s/epoch - 20ms/step
# Epoch 30/4000
# 54/54 - 1s - loss: 0.1632 - accuracy: 0.9479 - val_loss: 0.1549 - val_accuracy: 0.9516 - 1s/epoch - 20ms/step
# Epoch 31/4000
# 54/54 - 1s - loss: 0.1553 - accuracy: 0.9503 - val_loss: 0.1754 - val_accuracy: 0.9460 - 1s/epoch - 20ms/step
# Epoch 32/4000
# 54/54 - 1s - loss: 0.1646 - accuracy: 0.9469 - val_loss: 0.1575 - val_accuracy: 0.9516 - 1s/epoch - 20ms/step
# Epoch 33/4000
# 54/54 - 1s - loss: 0.1501 - accuracy: 0.9535 - val_loss: 0.1544 - val_accuracy: 0.9544 - 1s/epoch - 20ms/step
# 313/313 - 1s - loss: 0.4709 - accuracy: 0.8847 - 555ms/epoch - 2ms/step
# Test loss: 0.471
# Test accuracy: 88.470%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model708.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model708.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
