# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
# batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-06-09 03:01:47.237628: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
# # 数据加载
# (x_train, y_train), (x_test, y_test) = octid.load_data()  # 假设已加载OCTID数据集

# # 预处理流水线
# x_train = preprocess_pipeline(x_train)  # 包含裁剪、去噪、增强等
# x_test = preprocess_pipeline(x_test)

# # 维度扩展
# x_train = np.expand_dims(x_train, -1)
# x_test = np.expand_dims(x_test, -1)

# # 标准化
# x_train = zscore_normalize(x_train)
# x_test = zscore_normalize(x_test)

# %%
# # 验证集构建
# x_train, x_val, y_train, y_val = stratified_split(x_train, y_train)

# print('Validation and test data ready')

# # Convert class vector to binary class matrices
# # num_classes = 10
# # y_train = utils.to_categorical(y_train, num_classes)
# # y_test = utils.to_categorical(y_test, num_classes)
# # y_val = utils.to_categorical(y_val, num_classes)

# input_shape = x_train[0].shape
# print(f'input shape: {input_shape}')

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import cv2
import os

CLASS_MAP = {
    'CSR': 0,
    'DR': 1,
    'MH': 2,
    'NORMAL': 3
}

def load_octid_dataset(dataset_path, target_size=(24, 24)):
    images, labels = [], []
    
    for class_name, class_idx in CLASS_MAP.items():
        class_dir = os.path.join(dataset_path, class_name)
        
        if not os.path.isdir(class_dir):
            raise ValueError(f"Missing class directory: {class_name}")
            
        for filename in os.listdir(class_dir):
            if not filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                continue
                
            img_path = os.path.join(class_dir, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                print(f"Warning: Failed to read {img_path}, skipping...")
                continue
                
            img = cv2.resize(img, target_size)
            img = cv2.medianBlur(img, 3)
            img = img.astype(np.float32)
            
            images.append(img)
            labels.append(class_idx)
    
    images = np.expand_dims(np.array(images), axis=-1)  # (N, 24, 24, 1)
    labels = np.array(labels, dtype=np.int32)  # 直接返回整数标签
    return images, labels

# 加载数据
dataset_path = "/workspace/examples/vision_transformer/data/OCTID"
x_all, y_all = load_octid_dataset(dataset_path)

# 分层分割函数（无需修改，但需确保stratify使用整数标签）
def stratified_split(data, labels, test_size=0.2, val_size=0.1, random_state=42):
    x_train_val, x_test, y_train_val, y_test = train_test_split(
        data, labels, test_size=test_size, stratify=labels, random_state=random_state
    )
    x_train, x_val, y_train, y_val = train_test_split(
        x_train_val, y_train_val,
        test_size=val_size/(1-test_size), stratify=y_train_val, random_state=random_state
    )
    return (x_train, y_train), (x_val, y_val), (x_test, y_test)

# 执行分割
(x_train, y_train), (x_val, y_val), (x_test, y_test) = stratified_split(x_all, y_all)

# 标签格式验证
assert y_train.ndim == 1, "训练集标签应为整数格式"
assert y_val.ndim == 1, "验证集标签应为整数格式"
assert y_test.ndim == 1, "测试集标签应为整数格式"

# 标准化处理（原有代码不变）
train_mean = np.mean(x_train, axis=(0,1,2))
train_std = np.std(x_train, axis=(0,1,2))

def zscore_normalize(images, mean, std):
    return (images - mean) / (std + 1e-7)

x_train = zscore_normalize(x_train, train_mean, train_std)
x_val = zscore_normalize(x_val, train_mean, train_std)
x_test = zscore_normalize(x_test, train_mean, train_std)

# 输出验证
print(f"Input shape: {x_train[0].shape}")  # (24, 24, 1)
print(f"y_train shape: {y_train.shape}")  # 应为 (样本数,)
print(f"标签示例: {y_train[:5]}")  # 如 [0, 1, 3, 2, ...]
# Out:
# Input shape: (24, 24, 1)
# y_train shape: (361,)
# 标签示例: [1 3 3 3 2]

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test7')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test7 of shape (104, 24, 24, 1) in data/net_mnist/x_test7.h5
# Saving x_train of shape (361, 24, 24, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (52, 24, 24, 1) in data/net_mnist/x_val.h5

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# datagen = ImageDataGenerator(
#     rotation_range=10,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     zoom_range=0.1
# )

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D,Softmax
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2

# 创建模型
model = Sequential()

# 卷积层1（输入调整为24x24x1）
model.add(Conv2D(6, kernel_size=5, input_shape=(24, 24, 1), kernel_regularizer=l2(0.0005)))  # 输出20x20x6
model.add(AvgPool2D(pool_size=2, strides=2))  # 输出10x10x6

# 卷积层2
model.add(Conv2D(16, kernel_size=5, kernel_regularizer=l2(0.0005)))  # 输出6x6x16
model.add(AvgPool2D(pool_size=2, strides=2))  # 输出3x3x16

# 全连接部分
model.add(Flatten())  # 展平为144维
model.add(Dense(120, kernel_regularizer=l2(0.0005)))  # 全连接层1
model.add(Dense(84, kernel_regularizer=l2(0.0005)))   # 全连接层2
model.add(BatchNormalization())
model.add(ReLU())
model.add(Dense(4))   # 输出层调整为4个单元


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 20, 20, 6)         156
#
#  average_pooling2d (AverageP  (None, 10, 10, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 6, 6, 16)          2416
#
#  average_pooling2d_1 (Averag  (None, 3, 3, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 144)               0
#
#  dense (Dense)               (None, 120)               17400
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  batch_normalization (BatchN  (None, 84)               336
#  ormalization)
#
#  re_lu (ReLU)                (None, 84)                0
#
#  dense_2 (Dense)             (None, 4)                 340
#
# =================================================================
# Total params: 30,812
# Trainable params: 30,644
# Non-trainable params: 168
# _________________________________________________________________
# 2025-06-09 03:01:52.609588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:52.650045: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:52.653359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:52.656100: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-09 03:01:52.656722: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:52.659311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:52.661823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:53.418637: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:53.420280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:53.421721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-06-09 03:01:53.423113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5

# %% [markdown]
# ### 第一阶段

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=20,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2025-06-09 03:01:56.097696: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 23/23 - 3s - loss: 1.3374 - accuracy: 0.4598 - val_loss: 1.2321 - val_accuracy: 0.5192 - lr: 0.0010 - 3s/epoch - 122ms/step
# Epoch 2/4000
# 23/23 - 0s - loss: 1.0544 - accuracy: 0.5845 - val_loss: 1.1676 - val_accuracy: 0.5577 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 3/4000
# 23/23 - 0s - loss: 0.9601 - accuracy: 0.6316 - val_loss: 1.1296 - val_accuracy: 0.5000 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 4/4000
# 23/23 - 0s - loss: 0.8934 - accuracy: 0.6565 - val_loss: 1.0530 - val_accuracy: 0.6538 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 5/4000
# 23/23 - 0s - loss: 0.8776 - accuracy: 0.6898 - val_loss: 1.0948 - val_accuracy: 0.6346 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 6/4000
# 23/23 - 0s - loss: 0.8079 - accuracy: 0.6953 - val_loss: 0.9531 - val_accuracy: 0.6731 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 7/4000
# 23/23 - 0s - loss: 0.7827 - accuracy: 0.7452 - val_loss: 1.0183 - val_accuracy: 0.6538 - lr: 0.0010 - 93ms/epoch - 4ms/step
# Epoch 8/4000
# 23/23 - 0s - loss: 0.8007 - accuracy: 0.7285 - val_loss: 1.0416 - val_accuracy: 0.6346 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 9/4000
# 23/23 - 0s - loss: 0.7603 - accuracy: 0.7618 - val_loss: 0.9198 - val_accuracy: 0.7308 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 10/4000
# 23/23 - 0s - loss: 0.7722 - accuracy: 0.7452 - val_loss: 0.9635 - val_accuracy: 0.6731 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 11/4000
# 23/23 - 0s - loss: 0.7198 - accuracy: 0.7756 - val_loss: 0.9724 - val_accuracy: 0.7500 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 12/4000
# 23/23 - 0s - loss: 0.7109 - accuracy: 0.7645 - val_loss: 0.8737 - val_accuracy: 0.7500 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 13/4000
# 23/23 - 0s - loss: 0.6828 - accuracy: 0.7729 - val_loss: 1.0199 - val_accuracy: 0.7308 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 14/4000
# 23/23 - 0s - loss: 0.6910 - accuracy: 0.7812 - val_loss: 0.9836 - val_accuracy: 0.7500 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 15/4000
# 23/23 - 0s - loss: 0.6554 - accuracy: 0.8255 - val_loss: 0.9208 - val_accuracy: 0.7500 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 16/4000
# 23/23 - 0s - loss: 0.5941 - accuracy: 0.8310 - val_loss: 0.8770 - val_accuracy: 0.7500 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 17/4000
# 23/23 - 0s - loss: 0.5965 - accuracy: 0.8283 - val_loss: 0.8829 - val_accuracy: 0.7115 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 18/4000
# 23/23 - 0s - loss: 0.5783 - accuracy: 0.8587 - val_loss: 0.9570 - val_accuracy: 0.8077 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 19/4000
# 23/23 - 0s - loss: 0.5859 - accuracy: 0.8338 - val_loss: 0.9893 - val_accuracy: 0.7692 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 20/4000
# 23/23 - 0s - loss: 0.5492 - accuracy: 0.8670 - val_loss: 0.7306 - val_accuracy: 0.7500 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 21/4000
# 23/23 - 0s - loss: 0.5274 - accuracy: 0.8809 - val_loss: 0.8056 - val_accuracy: 0.7692 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 22/4000
# 23/23 - 0s - loss: 0.5086 - accuracy: 0.8837 - val_loss: 0.9334 - val_accuracy: 0.7692 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 23/4000
# 23/23 - 0s - loss: 0.5445 - accuracy: 0.8504 - val_loss: 0.9038 - val_accuracy: 0.7692 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 24/4000
# 23/23 - 0s - loss: 0.4903 - accuracy: 0.8781 - val_loss: 0.9767 - val_accuracy: 0.7115 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 25/4000
# 23/23 - 0s - loss: 0.4592 - accuracy: 0.9086 - val_loss: 0.8847 - val_accuracy: 0.7692 - lr: 0.0010 - 93ms/epoch - 4ms/step
# Epoch 26/4000
# 23/23 - 0s - loss: 0.4671 - accuracy: 0.9003 - val_loss: 1.0601 - val_accuracy: 0.7692 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 27/4000
# 23/23 - 0s - loss: 0.4399 - accuracy: 0.9197 - val_loss: 0.9729 - val_accuracy: 0.7692 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 28/4000
# 23/23 - 0s - loss: 0.4224 - accuracy: 0.9141 - val_loss: 1.0065 - val_accuracy: 0.6923 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 29/4000
# 23/23 - 0s - loss: 0.4052 - accuracy: 0.9224 - val_loss: 1.0830 - val_accuracy: 0.6923 - lr: 0.0010 - 93ms/epoch - 4ms/step
# Epoch 30/4000
# 23/23 - 0s - loss: 0.4049 - accuracy: 0.9114 - val_loss: 1.1933 - val_accuracy: 0.6346 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 31/4000
# 23/23 - 0s - loss: 0.4009 - accuracy: 0.9058 - val_loss: 0.9493 - val_accuracy: 0.7692 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 32/4000
# 23/23 - 0s - loss: 0.3844 - accuracy: 0.9141 - val_loss: 1.0020 - val_accuracy: 0.7500 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 33/4000
# 23/23 - 0s - loss: 0.4044 - accuracy: 0.9114 - val_loss: 0.9406 - val_accuracy: 0.7500 - lr: 0.0010 - 93ms/epoch - 4ms/step
# Epoch 34/4000
# 23/23 - 0s - loss: 0.3814 - accuracy: 0.9197 - val_loss: 1.0268 - val_accuracy: 0.7308 - lr: 0.0010 - 93ms/epoch - 4ms/step
# Epoch 35/4000
# 23/23 - 0s - loss: 0.3585 - accuracy: 0.9252 - val_loss: 0.9403 - val_accuracy: 0.7885 - lr: 0.0010 - 92ms/epoch - 4ms/step
# Epoch 36/4000
# 23/23 - 0s - loss: 0.3477 - accuracy: 0.9474 - val_loss: 1.1579 - val_accuracy: 0.7308 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 37/4000
# 23/23 - 0s - loss: 0.3447 - accuracy: 0.9252 - val_loss: 1.0807 - val_accuracy: 0.7115 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 38/4000
# 23/23 - 0s - loss: 0.3679 - accuracy: 0.9252 - val_loss: 1.1300 - val_accuracy: 0.6923 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 39/4000
# 23/23 - 0s - loss: 0.3251 - accuracy: 0.9418 - val_loss: 1.0594 - val_accuracy: 0.7308 - lr: 0.0010 - 109ms/epoch - 5ms/step
# Epoch 40/4000
# 23/23 - 0s - loss: 0.3222 - accuracy: 0.9529 - val_loss: 1.0837 - val_accuracy: 0.7692 - lr: 0.0010 - 108ms/epoch - 5ms/step
# 4/4 - 0s - loss: 1.0712 - accuracy: 0.6442 - 87ms/epoch - 22ms/step
# Test loss: 1.071
# Test accuracy: 64.423%

# %%
# model.get_weights()

# %% [markdown]
# ### Rebuild Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from tensorflow.keras.layers import GlobalAvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
new_model = Sequential()
for layer in model.layers:
    
    if isinstance(layer, ReLU):
        new_model.add(SquareActivation())
    else:
        new_layer = layer.__class__.from_config(layer.get_config())
        new_model.add(new_layer)
        if layer.weights:
            new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 20, 20, 6)         156
#
#  average_pooling2d (AverageP  (None, 10, 10, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 6, 6, 16)          2416
#
#  average_pooling2d_1 (Averag  (None, 3, 3, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 144)               0
#
#  dense (Dense)               (None, 120)               17400
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  batch_normalization (BatchN  (None, 84)               336
#  ormalization)
#
#  square_activation (SquareAc  (None, 84)               0
#  tivation)
#
#  dense_2 (Dense)             (None, 4)                 340
#
# =================================================================
# Total params: 30,812
# Trainable params: 30,644
# Non-trainable params: 168
# _________________________________________________________________

# %%
# new_model.get_weights()

# %% [markdown]
# 第二阶段

# %%
#二阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=20,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
def lr_scheduler(epoch):
    if epoch < 100:
        return 0.001
    elif epoch < 200:
        return 0.0005
    else:
        return 0.0001
callbacks = [
    tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

new_model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

new_model.fit(
    x_train, y_train, batch_size=batch_size,
   
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True,
              callbacks=callbacks
              )

score = new_model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# 23/23 - 1s - loss: 0.6197 - accuracy: 0.8033 - val_loss: 0.7956 - val_accuracy: 0.6923 - lr: 0.0010 - 892ms/epoch - 39ms/step
# Epoch 2/4000
# 23/23 - 0s - loss: 0.5852 - accuracy: 0.8255 - val_loss: 0.7548 - val_accuracy: 0.7692 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 3/4000
# 23/23 - 0s - loss: 0.5649 - accuracy: 0.8476 - val_loss: 0.7478 - val_accuracy: 0.8077 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 4/4000
# 23/23 - 0s - loss: 0.5271 - accuracy: 0.8670 - val_loss: 0.7336 - val_accuracy: 0.7885 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 5/4000
# 23/23 - 0s - loss: 0.5094 - accuracy: 0.8698 - val_loss: 0.7552 - val_accuracy: 0.7885 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 6/4000
# 23/23 - 0s - loss: 0.4996 - accuracy: 0.8698 - val_loss: 0.7555 - val_accuracy: 0.7692 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 7/4000
# 23/23 - 0s - loss: 0.4742 - accuracy: 0.8920 - val_loss: 0.7382 - val_accuracy: 0.7885 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 8/4000
# 23/23 - 0s - loss: 0.4909 - accuracy: 0.8670 - val_loss: 0.7641 - val_accuracy: 0.7500 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 9/4000
# 23/23 - 0s - loss: 0.4684 - accuracy: 0.8892 - val_loss: 0.7593 - val_accuracy: 0.7885 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 10/4000
# 23/23 - 0s - loss: 0.4724 - accuracy: 0.8947 - val_loss: 0.7576 - val_accuracy: 0.7115 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 11/4000
# 23/23 - 0s - loss: 0.4468 - accuracy: 0.8809 - val_loss: 0.7784 - val_accuracy: 0.7500 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 12/4000
# 23/23 - 0s - loss: 0.4481 - accuracy: 0.9058 - val_loss: 0.7895 - val_accuracy: 0.7692 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 13/4000
# 23/23 - 0s - loss: 0.4336 - accuracy: 0.8892 - val_loss: 0.7575 - val_accuracy: 0.6923 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 14/4000
# 23/23 - 0s - loss: 0.4321 - accuracy: 0.9280 - val_loss: 0.7416 - val_accuracy: 0.7885 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 15/4000
# 23/23 - 0s - loss: 0.4362 - accuracy: 0.9224 - val_loss: 0.6861 - val_accuracy: 0.7885 - lr: 0.0010 - 104ms/epoch - 5ms/step
# Epoch 16/4000
# 23/23 - 0s - loss: 0.3898 - accuracy: 0.9224 - val_loss: 0.7431 - val_accuracy: 0.8077 - lr: 0.0010 - 113ms/epoch - 5ms/step
# Epoch 17/4000
# 23/23 - 0s - loss: 0.3936 - accuracy: 0.9141 - val_loss: 0.7275 - val_accuracy: 0.7692 - lr: 0.0010 - 101ms/epoch - 4ms/step
# Epoch 18/4000
# 23/23 - 0s - loss: 0.3706 - accuracy: 0.9197 - val_loss: 0.7807 - val_accuracy: 0.7115 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 19/4000
# 23/23 - 0s - loss: 0.3639 - accuracy: 0.9197 - val_loss: 0.7917 - val_accuracy: 0.7500 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 20/4000
# 23/23 - 0s - loss: 0.3439 - accuracy: 0.9557 - val_loss: 0.7385 - val_accuracy: 0.7500 - lr: 0.0010 - 102ms/epoch - 4ms/step
# Epoch 21/4000
# 23/23 - 0s - loss: 0.3674 - accuracy: 0.9363 - val_loss: 0.6654 - val_accuracy: 0.7885 - lr: 0.0010 - 115ms/epoch - 5ms/step
# Epoch 22/4000
# 23/23 - 0s - loss: 0.3703 - accuracy: 0.9141 - val_loss: 0.7445 - val_accuracy: 0.6923 - lr: 0.0010 - 110ms/epoch - 5ms/step
# Epoch 23/4000
# 23/23 - 0s - loss: 0.4025 - accuracy: 0.8864 - val_loss: 0.6764 - val_accuracy: 0.7885 - lr: 0.0010 - 100ms/epoch - 4ms/step
# Epoch 24/4000
# 23/23 - 0s - loss: 0.3364 - accuracy: 0.9307 - val_loss: 0.7775 - val_accuracy: 0.7500 - lr: 0.0010 - 103ms/epoch - 4ms/step
# Epoch 25/4000
# 23/23 - 0s - loss: 0.3326 - accuracy: 0.9307 - val_loss: 0.6805 - val_accuracy: 0.8077 - lr: 0.0010 - 106ms/epoch - 5ms/step
# Epoch 26/4000
# 23/23 - 0s - loss: 0.3613 - accuracy: 0.9307 - val_loss: 0.8485 - val_accuracy: 0.7885 - lr: 0.0010 - 103ms/epoch - 4ms/step
# Epoch 27/4000
# 23/23 - 0s - loss: 0.3166 - accuracy: 0.9529 - val_loss: 0.7695 - val_accuracy: 0.7692 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 28/4000
# 23/23 - 0s - loss: 0.3035 - accuracy: 0.9529 - val_loss: 0.6742 - val_accuracy: 0.8462 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 29/4000
# 23/23 - 0s - loss: 0.2838 - accuracy: 0.9612 - val_loss: 0.7048 - val_accuracy: 0.7692 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 30/4000
# 23/23 - 0s - loss: 0.2838 - accuracy: 0.9529 - val_loss: 0.7110 - val_accuracy: 0.7308 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 31/4000
# 23/23 - 0s - loss: 0.2953 - accuracy: 0.9529 - val_loss: 0.6556 - val_accuracy: 0.7308 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 32/4000
# 23/23 - 0s - loss: 0.2782 - accuracy: 0.9668 - val_loss: 0.6291 - val_accuracy: 0.7885 - lr: 0.0010 - 100ms/epoch - 4ms/step
# Epoch 33/4000
# 23/23 - 0s - loss: 0.2787 - accuracy: 0.9557 - val_loss: 0.6807 - val_accuracy: 0.7692 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 34/4000
# 23/23 - 0s - loss: 0.2958 - accuracy: 0.9474 - val_loss: 0.6100 - val_accuracy: 0.8462 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 35/4000
# 23/23 - 0s - loss: 0.2608 - accuracy: 0.9529 - val_loss: 0.5702 - val_accuracy: 0.8269 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 36/4000
# 23/23 - 0s - loss: 0.2430 - accuracy: 0.9640 - val_loss: 0.7146 - val_accuracy: 0.8077 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 37/4000
# 23/23 - 0s - loss: 0.2422 - accuracy: 0.9751 - val_loss: 0.7578 - val_accuracy: 0.7115 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 38/4000
# 23/23 - 0s - loss: 0.2682 - accuracy: 0.9501 - val_loss: 0.7966 - val_accuracy: 0.7692 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 39/4000
# 23/23 - 0s - loss: 0.2673 - accuracy: 0.9418 - val_loss: 0.6310 - val_accuracy: 0.8077 - lr: 0.0010 - 98ms/epoch - 4ms/step
# Epoch 40/4000
# 23/23 - 0s - loss: 0.2510 - accuracy: 0.9668 - val_loss: 0.6796 - val_accuracy: 0.8077 - lr: 0.0010 - 99ms/epoch - 4ms/step
# Epoch 41/4000
# 23/23 - 0s - loss: 0.2305 - accuracy: 0.9612 - val_loss: 0.7902 - val_accuracy: 0.7500 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 42/4000
# 23/23 - 0s - loss: 0.2383 - accuracy: 0.9695 - val_loss: 0.7807 - val_accuracy: 0.7692 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 43/4000
# 23/23 - 0s - loss: 0.2576 - accuracy: 0.9695 - val_loss: 0.9602 - val_accuracy: 0.7115 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 44/4000
# 23/23 - 0s - loss: 0.2794 - accuracy: 0.9529 - val_loss: 0.9793 - val_accuracy: 0.7308 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 45/4000
# 23/23 - 0s - loss: 0.2537 - accuracy: 0.9529 - val_loss: 0.9480 - val_accuracy: 0.7692 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 46/4000
# 23/23 - 0s - loss: 0.2649 - accuracy: 0.9612 - val_loss: 0.8198 - val_accuracy: 0.8077 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 47/4000
# 23/23 - 0s - loss: 0.2176 - accuracy: 0.9778 - val_loss: 0.7497 - val_accuracy: 0.7500 - lr: 0.0010 - 94ms/epoch - 4ms/step
# Epoch 48/4000
# 23/23 - 0s - loss: 0.2283 - accuracy: 0.9695 - val_loss: 0.7503 - val_accuracy: 0.8269 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 49/4000
# 23/23 - 0s - loss: 0.2333 - accuracy: 0.9723 - val_loss: 0.6382 - val_accuracy: 0.7885 - lr: 0.0010 - 95ms/epoch - 4ms/step
# Epoch 50/4000
# 23/23 - 0s - loss: 0.2255 - accuracy: 0.9751 - val_loss: 0.6231 - val_accuracy: 0.8846 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 51/4000
# 23/23 - 0s - loss: 0.2327 - accuracy: 0.9695 - val_loss: 0.7937 - val_accuracy: 0.7692 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 52/4000
# 23/23 - 0s - loss: 0.2502 - accuracy: 0.9612 - val_loss: 0.9605 - val_accuracy: 0.7500 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 53/4000
# 23/23 - 0s - loss: 0.2096 - accuracy: 0.9861 - val_loss: 0.7922 - val_accuracy: 0.7115 - lr: 0.0010 - 97ms/epoch - 4ms/step
# Epoch 54/4000
# 23/23 - 0s - loss: 0.2430 - accuracy: 0.9584 - val_loss: 0.7172 - val_accuracy: 0.7692 - lr: 0.0010 - 96ms/epoch - 4ms/step
# Epoch 55/4000
# 23/23 - 0s - loss: 0.2458 - accuracy: 0.9557 - val_loss: 0.7465 - val_accuracy: 0.8077 - lr: 0.0010 - 99ms/epoch - 4ms/step
# 4/4 - 0s - loss: 1.2647 - accuracy: 0.6635 - 28ms/epoch - 7ms/step
# Test loss: 1.265
# Test accuracy: 66.346%

# %% [markdown]
# ### Serialize Model and Weights

# %%
model_json = new_model.to_json()
with open(os.path.join(PATH, 'model210.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
new_model.save_weights(os.path.join(PATH, 'model210.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ******************************************************************************************
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
