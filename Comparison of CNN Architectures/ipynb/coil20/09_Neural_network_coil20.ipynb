# %% [markdown]
# ## Inference under FHE for the MNIST Dataset using helayers
#
# In this demo, we'll deal with a classification problem for the MNIST dataset [1], trying to correctly classify a batch of samples using a neural network model that will be created and trained using the Keras library (with architecture similar to reference [2]).
# First, we'll build a plain neural network for the MNIST model. Then, we'll encrypt the trained network and run inference over it using FHE.

# %%
import os

##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.random.set_seed(seed_value)
from tensorflow.keras import backend as K

from tensorflow.keras import utils, losses
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
import h5py

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)

batch_size = 16
# batch_size = 32
# batch_size = 64
# batch_size = 128
# batch_size = 256
# batch_size = 512
# batch_size = 1024
# batch_size = 2048
# batch_size = 4096
# batch_size=8192
print("Misc. initializations")
# Out:
# 2025-05-21 01:13:07.887816: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Misc. initializations

# %% [markdown]
# ### Load and Preprocess the MNIST Dataset.

# %%
import scipy.io
import numpy as np
from sklearn.model_selection import train_test_split

# 步骤1：生成测试集文件（适配变量名）
def generate_test_set():
    # 加载原始数据集
    data = scipy.io.loadmat('/workspace/examples/vision_transformer/data/coil20/coil20.mat')
    
    # 根据实际变量名调整
    fea = data['X']  # 原'fea'替换为实际变量名
    gnd = data['Y']  # 原'gnd'替换为实际变量名
    # 在generate_test_set中：
    print("原始数据集样本数:", fea.shape[0])  # 应为1440

    
    # 分层划分训练集和测试集
    x_train, x_test, y_train, y_test = train_test_split(
        fea, gnd, 
        test_size=0.2,
        stratify=gnd,
        random_state=42
    )
    # 划分训练测试后：
    print("划分后训练集样本数:", len(x_train))  # 应为1440 * 0.8=1152
    print("划分后测试集样本数:", len(x_test))   # 应为288
    print("打印形状:", x_train.shape)  
    print("打印形状:", x_test.shape)   
    
    # 保存时使用一致的变量名
    scipy.io.savemat('/workspace/examples/vision_transformer/data/coil20/coil20_train.mat',
                    {'X': x_train, 'Y': y_train})
    scipy.io.savemat('/workspace/examples/vision_transformer/data/coil20/coil20_test.mat',
                    {'X': x_test, 'Y': y_test})  # 键名与原始数据对齐

# 步骤2：数据加载函数同步更新
def load_coil20(path):
    data = scipy.io.loadmat(path)
    images = data['X'].reshape(-1, 32, 32)  # 变量名同步修改
    labels = data['Y'].flatten() - 1
    return images, labels

# 执行生成测试集
generate_test_set()

# 加载数据（适配新变量名）
x_train, y_train = load_coil20('/workspace/examples/vision_transformer/data/coil20/coil20.mat')
x_test, y_test = load_coil20('/workspace/examples/vision_transformer/data/coil20/coil20_test.mat')
print("划分后训练集样本数:", len(x_train))  # 应为1440 * 0.8=1152
print("划分后测试集样本数:", len(x_test))   # 应为288

# 预处理流程（保持分辨率）
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# 验证输入形状
print(f"输入形状: {x_train[0].shape}")  # 应为(32,32,1)
# Out:
# 原始数据集样本数: 1440
# 划分后训练集样本数: 1152
# 划分后测试集样本数: 288
# 打印形状: (1152, 1024)
# 打印形状: (288, 1024)
# 划分后训练集样本数: 1440
# 划分后测试集样本数: 288
# 输入形状: (32, 32, 1)

# %%
# 划分验证集（从训练集中取200个样本）
val_size = 200
x_train = x_train[:-val_size]
x_val = x_train[-val_size:]
y_train = y_train[:-val_size]
y_val = y_train[-val_size:]

# 输出最终数据集信息
print(f"训练集形状: {x_train.shape}, 样本数: {len(y_train)}")
print(f"验证集形状: {x_val.shape}, 样本数: {len(y_val)}")
print(f"测试集形状: {x_test.shape}, 样本数: {len(y_test)}")
print(f"输入形状: {x_train[0].shape}")
# Out:
# 训练集形状: (1240, 32, 32, 1), 样本数: 1240
# 验证集形状: (200, 32, 32, 1), 样本数: 200
# 测试集形状: (288, 32, 32, 1), 样本数: 288
# 输入形状: (32, 32, 1)

# %% [markdown]
# ### Save Dataset

# %%
def save_data_set(x, y, data_type, s=''):
    fname=os.path.join(PATH, f'x_{data_type}{s}.h5')
    print("Saving x_{} of shape {} in {}".format(data_type, x.shape,fname))
    xf = h5py.File(fname, 'w')
    xf.create_dataset('x_{}'.format(data_type), data=x)
    xf.close()

    yf = h5py.File(os.path.join(PATH, f'y_{data_type}{s}.h5'), 'w')
    yf.create_dataset(f'y_{data_type}', data=y)
    yf.close()

save_data_set(x_test, y_test, data_type='test10')
save_data_set(x_train, y_train, data_type='train')
save_data_set(x_val, y_val, data_type='val')
# Out:
# Saving x_test10 of shape (288, 32, 32, 1) in data/net_mnist/x_test10.h5
# Saving x_train of shape (1240, 32, 32, 1) in data/net_mnist/x_train.h5
# Saving x_val of shape (200, 32, 32, 1) in data/net_mnist/x_val.h5

# %% [markdown]
# ### Build a Plain Neural Network for the MNIST Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
from data_gen.activations import SquareActivation
from tensorflow.keras.regularizers import l2
# 创建模型
model = Sequential()

# 输入层调整为32x32
model.add(Conv2D(20, kernel_size=5, input_shape=(32,32,1), kernel_regularizer=l2(0.0005)))
model.add(AvgPool2D(pool_size=2))

# 第二卷积层（维度自动计算）
model.add(Conv2D(50, kernel_size=5, kernel_regularizer=l2(0.0005)))
model.add(AvgPool2D(pool_size=2))

# 展平层（输出维度1250）
model.add(Flatten())

# 全连接层（输入维度自动适配）
model.add(Dense(500, kernel_regularizer=l2(0.0005)))
model.add(BatchNormalization())
model.add(SquareActivation())

# 输出层调整为20类
model.add(Dense(20, kernel_regularizer=l2(0.0005)))


# 输出模型架构

model.summary()
# Out:
# 2025-05-21 01:13:11.045146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 20)        520
#
#  average_pooling2d (AverageP  (None, 14, 14, 20)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 50)        25050
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 50)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 1250)              0
#
#  dense (Dense)               (None, 500)               625500
#
#  batch_normalization (BatchN  (None, 500)              2000
#  ormalization)
#
#  square_activation (SquareAc  (None, 500)              0
#  tivation)
#
#  dense_1 (Dense)             (None, 20)                10020
# 2025-05-21 01:13:11.085043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.088225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.091407: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-21 01:13:11.091965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.094695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.097281: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.856362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.858360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.860108: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-05-21 01:13:11.861769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:09.0, compute capability: 7.5
# =================================================================
# Total params: 663,090
# Trainable params: 662,090
# Non-trainable params: 1,000
# _________________________________________________________________

# %% [markdown]
# ### Train the Neural Network

# %%
#一阶段
epochs = 4000
# epochs =1
# epochs = 3000
# epochs = 500
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow_addons as tfa

# 添加早停回调
early_stopping = EarlyStopping(
    monitor='val_loss',  # 监控验证准确率
    
    patience=20,         # 如果20个epoch没有改善则停止
    restore_best_weights=True  # 恢复最佳模型权重
)
def sum_squared_error(y_true, y_pred):
    return K.sum(K.square(y_pred - y_true), axis=-1)
base_learning_rate=0.01
class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_learning_rate):
        self.base_learning_rate = base_learning_rate

    def __call__(self, epoch):
        return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
    # 创建自定义的学习率调度器

# learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# 阶梯式学习率衰减
# def lr_scheduler(epoch):
#     if epoch < 100:
#         return 0.001
#     elif epoch < 200:
#         return 0.0005
#     else:
#         return 0.0001
callbacks = [
    # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    early_stopping
]
loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

model.fit(
    x_train, y_train, batch_size=batch_size,
    
              epochs=epochs,
              verbose=2,
              validation_data=(x_val, y_val),
              shuffle=True
              ,
              callbacks=callbacks
              )

score = model.evaluate(x_test, y_test, verbose=2)

print(f'Test loss: { score[0]:.3f}')
print(f'Test accuracy: {score[1] * 100:.3f}%')
# Out:
# Epoch 1/4000
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /root/miniforge3/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2025-05-21 01:13:14.286278: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8500
# 78/78 - 3s - loss: 3.3624 - accuracy: 0.1121 - val_loss: 3.2692 - val_accuracy: 0.0000e+00 - 3s/epoch - 39ms/step
# Epoch 2/4000
# 78/78 - 0s - loss: 2.2256 - accuracy: 0.4806 - val_loss: 2.8758 - val_accuracy: 0.2950 - 280ms/epoch - 4ms/step
# Epoch 3/4000
# 78/78 - 0s - loss: 1.5063 - accuracy: 0.7395 - val_loss: 2.5467 - val_accuracy: 0.2000 - 282ms/epoch - 4ms/step
# Epoch 4/4000
# 78/78 - 0s - loss: 1.2300 - accuracy: 0.8056 - val_loss: 2.9519 - val_accuracy: 0.0450 - 273ms/epoch - 4ms/step
# Epoch 5/4000
# 78/78 - 0s - loss: 1.0675 - accuracy: 0.8371 - val_loss: 1.7821 - val_accuracy: 0.9200 - 277ms/epoch - 4ms/step
# Epoch 6/4000
# 78/78 - 0s - loss: 0.9632 - accuracy: 0.8694 - val_loss: 1.2986 - val_accuracy: 0.9200 - 278ms/epoch - 4ms/step
# Epoch 7/4000
# 78/78 - 0s - loss: 0.8953 - accuracy: 0.8798 - val_loss: 1.3353 - val_accuracy: 0.8650 - 277ms/epoch - 4ms/step
# Epoch 8/4000
# 78/78 - 0s - loss: 0.7909 - accuracy: 0.9169 - val_loss: 1.0063 - val_accuracy: 0.9200 - 277ms/epoch - 4ms/step
# Epoch 9/4000
# 78/78 - 0s - loss: 0.7568 - accuracy: 0.9097 - val_loss: 1.0771 - val_accuracy: 0.9150 - 275ms/epoch - 4ms/step
# Epoch 10/4000
# 78/78 - 0s - loss: 0.6938 - accuracy: 0.9250 - val_loss: 0.7269 - val_accuracy: 0.9200 - 289ms/epoch - 4ms/step
# Epoch 11/4000
# 78/78 - 0s - loss: 0.6578 - accuracy: 0.9290 - val_loss: 0.5161 - val_accuracy: 0.9200 - 301ms/epoch - 4ms/step
# Epoch 12/4000
# 78/78 - 0s - loss: 0.6194 - accuracy: 0.9411 - val_loss: 0.5011 - val_accuracy: 0.9200 - 295ms/epoch - 4ms/step
# Epoch 13/4000
# 78/78 - 0s - loss: 0.5886 - accuracy: 0.9444 - val_loss: 0.4558 - val_accuracy: 0.9350 - 290ms/epoch - 4ms/step
# Epoch 14/4000
# 78/78 - 0s - loss: 0.5621 - accuracy: 0.9532 - val_loss: 0.4343 - val_accuracy: 0.9650 - 306ms/epoch - 4ms/step
# Epoch 15/4000
# 78/78 - 0s - loss: 0.5438 - accuracy: 0.9540 - val_loss: 0.5033 - val_accuracy: 0.9950 - 272ms/epoch - 3ms/step
# Epoch 16/4000
# 78/78 - 0s - loss: 0.5233 - accuracy: 0.9573 - val_loss: 0.3902 - val_accuracy: 0.9750 - 278ms/epoch - 4ms/step
# Epoch 17/4000
# 78/78 - 0s - loss: 0.4974 - accuracy: 0.9597 - val_loss: 0.3748 - val_accuracy: 0.9750 - 280ms/epoch - 4ms/step
# Epoch 18/4000
# 78/78 - 0s - loss: 0.4848 - accuracy: 0.9669 - val_loss: 0.3623 - val_accuracy: 0.9750 - 279ms/epoch - 4ms/step
# Epoch 19/4000
# 78/78 - 0s - loss: 0.4516 - accuracy: 0.9766 - val_loss: 0.3705 - val_accuracy: 0.9650 - 273ms/epoch - 4ms/step
# Epoch 20/4000
# 78/78 - 0s - loss: 0.4558 - accuracy: 0.9702 - val_loss: 0.3379 - val_accuracy: 0.9850 - 278ms/epoch - 4ms/step
# Epoch 21/4000
# 78/78 - 0s - loss: 0.4368 - accuracy: 0.9750 - val_loss: 0.3289 - val_accuracy: 0.9950 - 279ms/epoch - 4ms/step
# Epoch 22/4000
# 78/78 - 0s - loss: 0.4150 - accuracy: 0.9798 - val_loss: 0.3195 - val_accuracy: 0.9950 - 277ms/epoch - 4ms/step
# Epoch 23/4000
# 78/78 - 0s - loss: 0.4058 - accuracy: 0.9839 - val_loss: 0.3100 - val_accuracy: 0.9950 - 276ms/epoch - 4ms/step
# Epoch 24/4000
# 78/78 - 0s - loss: 0.3944 - accuracy: 0.9790 - val_loss: 0.2999 - val_accuracy: 0.9950 - 276ms/epoch - 4ms/step
# Epoch 25/4000
# 78/78 - 0s - loss: 0.3892 - accuracy: 0.9831 - val_loss: 0.2997 - val_accuracy: 0.9950 - 278ms/epoch - 4ms/step
# Epoch 26/4000
# 78/78 - 0s - loss: 0.3820 - accuracy: 0.9798 - val_loss: 0.2864 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 27/4000
# 78/78 - 0s - loss: 0.3613 - accuracy: 0.9863 - val_loss: 0.2768 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 28/4000
# 78/78 - 0s - loss: 0.3544 - accuracy: 0.9895 - val_loss: 0.2715 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 29/4000
# 78/78 - 0s - loss: 0.3423 - accuracy: 0.9887 - val_loss: 0.2652 - val_accuracy: 1.0000 - 289ms/epoch - 4ms/step
# Epoch
- val_accuracy: 1.0000 - 295ms/epoch - 4ms/step
# Epoch 198/4000
# 78/78 - 0s - loss: 0.0804 - accuracy: 0.9992 - val_loss: 0.0669 - val_accuracy: 1.0000 - 300ms/epoch - 4ms/step
# Epoch 199/4000
# 78/78 - 0s - loss: 0.0756 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 1.0000 - 298ms/epoch - 4ms/step
# Epoch 200/4000
# 78/78 - 0s - loss: 0.0764 - accuracy: 0.9992 - val_loss: 0.0664 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 201/4000
# 78/78 - 0s - loss: 0.0750 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 202/4000
# 78/78 - 0s - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 203/4000
# 78/78 - 0s - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 204/4000
# 78/78 - 0s - loss: 0.0740 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 205/4000
# 78/78 - 0s - loss: 0.0763 - accuracy: 0.9984 - val_loss: 0.0649 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 206/4000
# 78/78 - 0s - loss: 0.0775 - accuracy: 0.9984 - val_loss: 0.0655 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 207/4000
# 78/78 - 0s - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 208/4000
# 78/78 - 0s - loss: 0.0736 - accuracy: 0.9992 - val_loss: 0.0643 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 209/4000
# 78/78 - 0s - loss: 0.0748 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 210/4000
# 78/78 - 0s - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 1.0000 - 273ms/epoch - 4ms/step
# Epoch 211/4000
# 78/78 - 0s - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 1.0000 - 295ms/epoch - 4ms/step
# Epoch 212/4000
# 78/78 - 0s - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 213/4000
# 78/78 - 0s - loss: 0.0721 - accuracy: 0.9992 - val_loss: 0.0641 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 214/4000
# 78/78 - 0s - loss: 0.0740 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 1.0000 - 296ms/epoch - 4ms/step
# Epoch 215/4000
# 78/78 - 0s - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 1.0000 - 294ms/epoch - 4ms/step
# Epoch 216/4000
# 78/78 - 0s - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 1.0000 - 307ms/epoch - 4ms/step
# Epoch 217/4000
# 78/78 - 0s - loss: 0.0757 - accuracy: 0.9992 - val_loss: 0.0642 - val_accuracy: 1.0000 - 308ms/epoch - 4ms/step
# Epoch 218/4000
# 78/78 - 0s - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 1.0000 - 293ms/epoch - 4ms/step
# Epoch 219/4000
# 78/78 - 0s - loss: 0.0755 - accuracy: 0.9984 - val_loss: 0.0642 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 220/4000
# 78/78 - 0s - loss: 0.0843 - accuracy: 0.9968 - val_loss: 0.0645 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 221/4000
# 78/78 - 0s - loss: 0.0732 - accuracy: 0.9992 - val_loss: 0.0641 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 222/4000
# 78/78 - 0s - loss: 0.0715 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 223/4000
# 78/78 - 0s - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 1.0000 - 273ms/epoch - 4ms/step
# Epoch 224/4000
# 78/78 - 0s - loss: 0.0704 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 225/4000
# 78/78 - 0s - loss: 0.0702 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 226/4000
# 78/78 - 0s - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 227/4000
# 78/78 - 0s - loss: 0.0700 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 228/4000
# 78/78 - 0s - loss: 0.0705 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 229/4000
# 78/78 - 0s - loss: 0.0693 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 230/4000
# 78/78 - 0s - loss: 0.0694 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 231/4000
# 78/78 - 0s - loss: 0.0712 - accuracy: 0.9992 - val_loss: 0.0623 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 232/4000
# 78/78 - 0s - loss: 0.0771 - accuracy: 0.9968 - val_loss: 0.0624 - val_accuracy: 1.0000 - 292ms/epoch - 4ms/step
# Epoch 233/4000
# 78/78 - 0s - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 1.0000 - 301ms/epoch - 4ms/step
# Epoch 234/4000
# 78/78 - 0s - loss: 0.0694 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 1.0000 - 294ms/epoch - 4ms/step
# Epoch 235/4000
# 78/78 - 0s - loss: 0.0680 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 1.0000 - 308ms/epoch - 4ms/step
# Epoch 236/4000
# 78/78 - 0s - loss: 0.0681 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 1.0000 - 289ms/epoch - 4ms/step
# Epoch 237/4000
# 78/78 - 0s - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 238/4000
# 78/78 - 0s - loss: 0.0726 - accuracy: 0.9992 - val_loss: 0.0619 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 239/4000
# 78/78 - 0s - loss: 0.0707 - accuracy: 0.9992 - val_loss: 0.0619 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 240/4000
# 78/78 - 0s - loss: 0.0713 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 241/4000
# 78/78 - 0s - loss: 0.0697 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 242/4000
# 78/78 - 0s - loss: 0.0673 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 1.0000 - 282ms/epoch - 4ms/step
# Epoch 243/4000
# 78/78 - 0s - loss: 0.0688 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 244/4000
# 78/78 - 0s - loss: 0.0680 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 245/4000
# 78/78 - 0s - loss: 0.0702 - accuracy: 0.9992 - val_loss: 0.0611 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch
loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 300/4000
# 78/78 - 0s - loss: 0.0661 - accuracy: 0.9992 - val_loss: 0.0581 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 301/4000
# 78/78 - 0s - loss: 0.0650 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 302/4000
# 78/78 - 0s - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 303/4000
# 78/78 - 0s - loss: 0.0674 - accuracy: 0.9992 - val_loss: 0.0575 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 304/4000
# 78/78 - 0s - loss: 0.0739 - accuracy: 0.9968 - val_loss: 0.0571 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 305/4000
# 78/78 - 0s - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 1.0000 - 286ms/epoch - 4ms/step
# Epoch 306/4000
# 78/78 - 0s - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 1.0000 - 292ms/epoch - 4ms/step
# Epoch 307/4000
# 78/78 - 0s - loss: 0.0638 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 1.0000 - 294ms/epoch - 4ms/step
# Epoch 308/4000
# 78/78 - 0s - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 1.0000 - 298ms/epoch - 4ms/step
# Epoch 309/4000
# 78/78 - 0s - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 1.0000 - 305ms/epoch - 4ms/step
# Epoch 310/4000
# 78/78 - 0s - loss: 0.0619 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 1.0000 - 282ms/epoch - 4ms/step
# Epoch 311/4000
# 78/78 - 0s - loss: 0.0642 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 312/4000
# 78/78 - 0s - loss: 0.0665 - accuracy: 0.9984 - val_loss: 0.0578 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 313/4000
# 78/78 - 0s - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 314/4000
# 78/78 - 0s - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 315/4000
# 78/78 - 0s - loss: 0.0722 - accuracy: 0.9960 - val_loss: 0.0569 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 316/4000
# 78/78 - 0s - loss: 0.0650 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 317/4000
# 78/78 - 0s - loss: 0.0644 - accuracy: 0.9992 - val_loss: 0.0562 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 318/4000
# 78/78 - 0s - loss: 0.0648 - accuracy: 0.9992 - val_loss: 0.0564 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 319/4000
# 78/78 - 0s - loss: 0.0626 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 320/4000
# 78/78 - 0s - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 321/4000
# 78/78 - 0s - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 322/4000
# 78/78 - 0s - loss: 0.0670 - accuracy: 0.9992 - val_loss: 0.0567 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 323/4000
# 78/78 - 0s - loss: 0.0659 - accuracy: 0.9992 - val_loss: 0.0556 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 324/4000
# 78/78 - 0s - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 1.0000 - 287ms/epoch - 4ms/step
# Epoch 325/4000
# 78/78 - 0s - loss: 0.0633 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 1.0000 - 299ms/epoch - 4ms/step
# Epoch 326/4000
# 78/78 - 0s - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 1.0000 - 307ms/epoch - 4ms/step
# Epoch 327/4000
# 78/78 - 0s - loss: 0.0651 - accuracy: 0.9984 - val_loss: 0.0569 - val_accuracy: 1.0000 - 301ms/epoch - 4ms/step
# Epoch 328/4000
# 78/78 - 0s - loss: 0.0642 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 1.0000 - 289ms/epoch - 4ms/step
# Epoch 329/4000
# 78/78 - 0s - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 330/4000
# 78/78 - 0s - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 331/4000
# 78/78 - 0s - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 332/4000
# 78/78 - 0s - loss: 0.0627 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 333/4000
# 78/78 - 0s - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 334/4000
# 78/78 - 0s - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 335/4000
# 78/78 - 0s - loss: 0.0618 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 336/4000
# 78/78 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 337/4000
# 78/78 - 0s - loss: 0.0617 - accuracy: 0.9992 - val_loss: 0.0544 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 338/4000
# 78/78 - 0s - loss: 0.0606 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 339/4000
# 78/78 - 0s - loss: 0.0602 - accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 340/4000
# 78/78 - 0s - loss: 0.0607 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 341/4000
# 78/78 - 0s - loss: 0.0644 - accuracy: 0.9976 - val_loss: 0.0548 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 342/4000
# 78/78 - 0s - loss: 0.0646 - accuracy: 0.9976 - val_loss: 0.0544 - val_accuracy: 1.0000 - 284ms/epoch - 4ms/step
# Epoch 343/4000
# 78/78 - 0s - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 1.0000 - 300ms/epoch - 4ms/step
# Epoch 344/4000
# 78/78 - 0s - loss: 0.0646 - accuracy: 0.9984 - val_loss: 0.0543 - val_accuracy: 1.0000 - 313ms/epoch - 4ms/step
# Epoch 345/4000
# 78/78 - 0s - loss: 0.0612 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 1.0000 - 292ms/epoch - 4ms/step
# Epoch 346/4000
# 78/78 - 0s - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 1.0000 - 295ms/epoch - 4ms/step
# Epoch 347/4000
# 78/78 - 0s - loss: 0.0636 - accuracy: 0.9984 - val_loss: 0.0551 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 348/4000
# 78/78 - 0s - loss: 0.0651 - accuracy: 0.9984 - val_loss: 0.0546 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 349/4000
# 78/78 - 0s - loss: 0.0608 - accuracy: 0.9992 - val_loss: 0.0541 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 350/4000
# 78/78 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0537 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 351/4000
# 78/78 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 352/4000
# 78/78 - 0s - loss: 0.0619 - accuracy: 0.9984 - val_loss: 0.0543 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 353/4000
# 78/78 - 0s - loss: 0.0644 - accuracy: 0.9984 - val_loss: 0.0541 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 354/4000
# 78/78 - 0s - loss: 0.0652 - accuracy: 0.9984 - val_loss: 0.0538 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 355/4000
# 78/78 - 0s - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 356/4000
# 78/78 - 0s - loss: 0.0614 - accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 357/4000
# 78/78 - 0s - loss: 0.0614 - accuracy: 0.9992 - val_loss: 0.0538 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 358/4000
# 78/78 - 0s - loss: 0.0650 - accuracy: 0.9992 - val_loss: 0.0555 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 359/4000
# 78/78 - 0s - loss: 0.0623 - accuracy: 0.9984 - val_loss: 0.0543 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 360/4000
# 78/78 - 0s - loss: 0.0612 - accuracy: 0.9992 - val_loss: 0.0541 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 361/4000
# 78/78 - 0s - loss: 0.0633 - accuracy: 0.9984 - val_loss: 0.0537 - val_accuracy: 1.0000 - 303ms/epoch - 4ms/step
# Epoch 362/4000
# 78/78 - 0s - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 1.0000 - 300ms/epoch - 4ms/step
# Epoch 363/4000
# 78/78 - 0s - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 1.0000 - 305ms/epoch - 4ms/step
# Epoch 364/4000
# 78/78 - 0s - loss: 0.0656 - accuracy: 0.9976 - val_loss: 0.0549 - val_accuracy: 1.0000 - 315ms/epoch - 4ms/step
# Epoch 365/4000
# 78/78 - 0s - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 1.0000 - 289ms/epoch - 4ms/step
# Epoch 366/4000
# 78/78 - 0s - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.0536 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 367/4000
# 78/78 - 0s - loss: 0.0587 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 368/4000
# 78/78 - 0s - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 369/4000
# ...
# Epoch 463/4000
# 78/78 - 0s - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 464/4000
# 78/78 - 0s - loss: 0.0535 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 465/4000
# 78/78 - 0s - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 466/4000
# 78/78 - 0s - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 1.0000 - 286ms/epoch - 4ms/step
# Epoch 467/4000
# 78/78 - 0s - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 468/4000
# 78/78 - 0s - loss: 0.0573 - accuracy: 0.9992 - val_loss: 0.0494 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 469/4000
# 78/78 - 0s - loss: 0.0551 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 470/4000
# 78/78 - 0s - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 471/4000
# 78/78 - 0s - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 1.0000 - 289ms/epoch - 4ms/step
# Epoch 472/4000
# 78/78 - 0s - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 1.0000 - 303ms/epoch - 4ms/step
# Epoch 473/4000
# 78/78 - 0s - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 1.0000 - 299ms/epoch - 4ms/step
# Epoch 474/4000
# 78/78 - 0s - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 1.0000 - 295ms/epoch - 4ms/step
# Epoch 475/4000
# 78/78 - 0s - loss: 0.0592 - accuracy: 0.9976 - val_loss: 0.0483 - val_accuracy: 1.0000 - 301ms/epoch - 4ms/step
# Epoch 476/4000
# 78/78 - 0s - loss: 0.0606 - accuracy: 0.9976 - val_loss: 0.0488 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 477/4000
# 78/78 - 0s - loss: 0.0550 - accuracy: 0.9992 - val_loss: 0.0496 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 478/4000
# 78/78 - 0s - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 479/4000
# 78/78 - 0s - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 480/4000
# 78/78 - 0s - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 481/4000
# 78/78 - 0s - loss: 0.0554 - accuracy: 0.9992 - val_loss: 0.0482 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 482/4000
# 78/78 - 0s - loss: 0.0535 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 483/4000
# 78/78 - 0s - loss: 0.0571 - accuracy: 0.9984 - val_loss: 0.0482 - val_accuracy: 1.0000 - 274ms/epoch - 4ms/step
# Epoch 484/4000
# 78/78 - 0s - loss: 0.0553 - accuracy: 0.9992 - val_loss: 0.0480 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 485/4000
# 78/78 - 0s - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 486/4000
# 78/78 - 0s - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 487/4000
# 78/78 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 488/4000
# 78/78 - 0s - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000 - 282ms/epoch - 4ms/step
# Epoch 489/4000
# 78/78 - 0s - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 490/4000
# 78/78 - 0s - loss: 0.0550 - accuracy: 0.9992 - val_loss: 0.0475 - val_accuracy: 1.0000 - 304ms/epoch - 4ms/step
# Epoch 491/4000
# 78/78 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 1.0000 - 296ms/epoch - 4ms/step
# Epoch 492/4000
# 78/78 - 0s - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 1.0000 - 308ms/epoch - 4ms/step
# Epoch 493/4000
# 78/78 - 0s - loss: 0.0538 - accuracy: 0.9992 - val_loss: 0.0473 - val_accuracy: 1.0000 - 310ms/epoch - 4ms/step
# Epoch 494/4000
# 78/78 - 0s - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 1.0000 - 290ms/epoch - 4ms/step
# Epoch 495/4000
# 78/78 - 0s - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 496/4000
# 78/78 - 0s - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 497/4000
# 78/78 - 0s - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 498/4000
# 78/78 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000 - 282ms/epoch - 4ms/step
# Epoch 499/4000
# 78/78 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 500/4000
# 78/78 - 0s - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 501/4000
# 78/78 - 0s - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 1.0000 - 283ms/epoch - 4ms/step
# Epoch 502/4000
# 78/78 - 0s - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 503/4000
# 78/78 - 0s - loss: 0.0566 - accuracy: 0.9968 - val_loss: 0.0477 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 504/4000
# 78/78 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 505/4000
# 78/78 - 0s - loss: 0.0617 - accuracy: 0.9960 - val_loss: 0.0498 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 506/4000
# 78/78 - 0s - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 507/4000
# 78/78 - 0s - loss: 0.0558 - accuracy: 0.9984 - val_loss: 0.0474 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 508/4000
# 78/78 - 0s - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 1.0000 - 285ms/epoch - 4ms/step
# Epoch 509/4000
# 78/78 - 0s - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000 - 298ms/epoch - 4ms/step
# Epoch 510/4000
# 78/78 - 0s - loss: 0.0549 - accuracy: 0.9992 - val_loss: 0.0474 - val_accuracy: 1.0000 - 306ms/epoch - 4ms/step
# Epoch 511/4000
# 78/78 - 0s - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 1.0000 - 312ms/epoch - 4ms/step
# Epoch 512/4000
# 78/78 - 0s - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 1.0000 - 302ms/epoch - 4ms/step
# Epoch 513/4000
# 78/78 - 0s - loss: 0.0554 - accuracy: 0.9984 - val_loss: 0.0488 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 514/4000
# 78/78 - 0s - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 1.0000 - 286ms/epoch - 4ms/step
# Epoch 515/4000
# 78/78 - 0s - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 1.0000 - 284ms/epoch - 4ms/step
# Epoch 516/4000
# 78/78 - 0s - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 517/4000
# 78/78 - 0s - loss: 0.0592 - accuracy: 0.9968 - val_loss: 0.0466 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 518/4000
# 78/78 - 0s - loss: 0.0542 - accuracy: 0.9992 - val_loss: 0.0469 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 519/4000
# 78/78 - 0s - loss: 0.0534 - accuracy: 0.9992 - val_loss: 0.0470 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 520/4000
# 78/78 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 521/4000
# 78/78 - 0s - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 522/4000
# 78/78 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 523/4000
# 78/78 - 0s - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 524/4000
# 78/78 - 0s - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 525/4000
# 78/78 - 0s - loss: 0.0517 - accuracy: 0.9992 - val_loss: 0.0465 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 526/4000
# 78/78 - 0s - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 1.0000 - 289ms/epoch - 4ms/step
# Epoch 527/4000
# 78/78 - 0s - loss: 0.0554 - accuracy: 0.9984 - val_loss: 0.0466 - val_accuracy: 1.0000 - 292ms/epoch - 4ms/step
# Epoch 528/4000
# 78/78 - 0s - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 1.0000 - 286ms/epoch - 4ms/step
# Epoch 529/4000
# 78/78 - 0s - loss: 0.0536 - accuracy: 0.9992 - val_loss: 0.0471 - val_accuracy: 1.0000 - 297ms/epoch - 4ms/step
# Epoch 530/4000
# 78/78 - 0s - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 1.0000 - 295ms/epoch - 4ms/step
# Epoch 531/4000
# 78/78 - 0s - loss: 0.0550 - accuracy: 0.9992 - val_loss: 0.0469 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 532/4000
# 78/78 - 0s - loss: 0.0530 - accuracy: 0.9992 - val_loss: 0.0478 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 533/4000
# 78/78 - 0s - loss: 0.0518 - accuracy: 1.0000 - val_loss: 0.0464 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 534/4000
# 78/78 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 535/4000
# 78/78 - 0s - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 536/4000
# 78/78 - 0s - loss: 0.0519 - accuracy: 0.9992 - val_loss: 0.0461 - val_accuracy: 1.0000 - 285ms/epoch - 4ms/step
# Epoch 537/4000
# 78/78 - 0s - loss: 0.0524 - accuracy: 0.9984 - val_loss: 0.0456 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 538/4000
# 78/78 - 0s - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 539/4000
# 78/78 - 0s - loss: 0.0539 - accuracy: 0.9992 - val_loss: 0.0462 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 540/4000
# 78/78 - 0s - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 541/4000
# 78/78 - 0s - loss: 0.0554 - accuracy: 0.9992 - val_loss: 0.0464 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 542/4000
# 78/78 - 0s - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 543/4000
# 78/78 - 0s - loss: 0.0535 - accuracy: 0.9984 - val_loss: 0.0461 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 544/4000
# 78/78 - 0s - loss: 0.0514 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 545/4000
# 78/78 - 0s - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 1.0000 - 285ms/epoch - 4ms/step
# Epoch 546/4000
# 78/78 - 0s - loss: 0.0508 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 1.0000 - 290ms/epoch - 4ms/step
# Epoch 547/4000
# 78/78 - 0s - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 1.0000 - 291ms/epoch - 4ms/step
# Epoch 548/4000
# 78/78 - 0s - loss: 0.0499 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000 - 308ms/epoch - 4ms/step
# Epoch 549/4000
# 78/78 - 0s - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 1.0000 - 294ms/epoch - 4ms/step
# Epoch 550/4000
# 78/78 - 0s - loss: 0.0607 - accuracy: 0.9976 - val_loss: 0.1580 - val_accuracy: 0.9550 - 278ms/epoch - 4ms/step
# Epoch 551/4000
# 78/78 - 0s - loss: 0.0835 - accuracy: 0.9927 - val_loss: 0.0497 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 552/4000
# 78/78 - 0s - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 553/4000
# 78/78 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.0464 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 554/4000
# 78/78 - 0s - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 555/4000
# 78/78 - 0s - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 556/4000
# 78/78 - 0s - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 557/4000
# 78/78 - 0s - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000 - 280ms/epoch - 4ms/step
# Epoch 558/4000
# 78/78 - 0s - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 559/4000
# 78/78 - 0s - loss: 0.0518 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 1.0000 - 275ms/epoch - 4ms/step
# Epoch 560/4000
# 78/78 - 0s - loss: 0.0525 - accuracy: 0.9992 - val_loss: 0.0456 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 561/4000
# 78/78 - 0s - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 562/4000
# 78/78 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 563/4000
# 78/78 - 0s - loss: 0.0510 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000 - 287ms/epoch - 4ms/step
# Epoch 564/4000
# 78/78 - 0s - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000 - 298ms/epoch - 4ms/step
# Epoch 565/4000
# 78/78 - 0s - loss: 0.0522 - accuracy: 0.9984 - val_loss: 0.0453 - val_accuracy: 1.0000 - 301ms/epoch - 4ms/step
# Epoch 566/4000
# 78/78 - 0s - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 1.0000 - 301ms/epoch - 4ms/step
# Epoch 567/4000
# 78/78 - 0s - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 1.0000 - 295ms/epoch - 4ms/step
# Epoch 568/4000
# 78/78 - 0s - loss: 0.0517 - accuracy: 0.9992 - val_loss: 0.0453 - val_accuracy: 1.0000 - 291ms/epoch - 4ms/step
# Epoch 569/4000
# 78/78 - 0s - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 570/4000
# 78/78 - 0s - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 571/4000
# 78/78 - 0s - loss: 0.0544 - accuracy: 0.9984 - val_loss: 0.0454 - val_accuracy: 1.0000 - 291ms/epoch - 4ms/step
# Epoch 572/4000
# 78/78 - 0s - loss: 0.0570 - accuracy: 0.9976 - val_loss: 0.0468 - val_accuracy: 1.0000 - 279ms/epoch - 4ms/step
# Epoch 573/4000
# 78/78 - 0s - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 574/4000
# 78/78 - 0s - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 575/4000
# 78/78 - 0s - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000 - 281ms/epoch - 4ms/step
# Epoch 576/4000
# 78/78 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 577/4000
# 78/78 - 0s - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 1.0000 - 276ms/epoch - 4ms/step
# Epoch 578/4000
# 78/78 - 0s - loss: 0.0510 - accuracy: 0.9992 - val_loss: 0.0451 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 579/4000
# 78/78 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 580/4000
# 78/78 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 1.0000 - 278ms/epoch - 4ms/step
# Epoch 581/4000
# 78/78 - 0s - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 1.0000 - 277ms/epoch - 4ms/step
# Epoch 582/4000
# 78/78 - 0s - loss: 0.0518 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 1.0000 - 294ms/epoch - 4ms/step
# Epoch 583/4000
# 78/78 - 0s - loss: 0.0530 - accuracy: 0.9976 - val_loss: 0.0450 - val_accuracy: 1.0000 - 290ms/epoch - 4ms/step
# Epoch 584/4000
# 78/78 - 0s - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 1.0000 - 297ms/epoch - 4ms/step
# Epoch 585/4000
# 78/78 - 0s - loss: 0.0509 - accuracy: 0.9992 - val_loss: 0.0450 - val_accuracy: 1.0000 - 309ms/epoch - 4ms/step
# Epoch 586/4000
# 78/78 - 0s - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 1.0000 - 285ms/epoch - 4ms/step
# Epoch 587/4000
# 78/78 - 0s - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000 - 282ms/epoch - 4ms/step
# 9/9 - 0s - loss: 1.3319 - accuracy: 0.8958 - 63ms/epoch - 7ms/step
# Test loss: 1.332
# Test accuracy: 89.583%

# %% [markdown]
# ### Rebuild Model

# %%
# from tensorflow.keras.layers import Dense, Flatten, Conv2D, Activation, BatchNormalization, ReLU, AvgPool2D
# from tensorflow.keras.layers import GlobalAvgPool2D
# from data_gen.activations import SquareActivation
# from tensorflow.keras.regularizers import l2
# new_model = Sequential()
# for layer in model.layers:
    
#     if isinstance(layer, ReLU):
#         new_model.add(SquareActivation())
#     else:
#         new_layer = layer.__class__.from_config(layer.get_config())
#         new_model.add(new_layer)
#         if layer.weights:
#             new_layer.set_weights(layer.get_weights())  # 自动复制权重和偏置

# new_model.summary()

# %%
# #二阶段
# epochs = 4000
# # epochs =1
# # epochs = 3000
# # epochs = 500
# from tensorflow.keras.callbacks import EarlyStopping

# # 添加早停回调
# early_stopping = EarlyStopping(
#     monitor='val_loss',  # 监控验证准确率
    
#     patience=20,         # 如果20个epoch没有改善则停止
#     restore_best_weights=True  # 恢复最佳模型权重
# )
# def sum_squared_error(y_true, y_pred):
#     return K.sum(K.square(y_pred - y_true), axis=-1)
# base_learning_rate=0.01
# class CustomLearningRateSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
#     def __init__(self, base_learning_rate):
#         self.base_learning_rate = base_learning_rate

#     def __call__(self, epoch):
#         return self.base_learning_rate *(1+(1e-4) * (epoch)) ** (-0.75)
#     # 创建自定义的学习率调度器

# # learning_rate_schedule = CustomLearningRateSchedule(base_learning_rate)
# # optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_schedule, momentum=0.9)
# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

# # optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# # 阶梯式学习率衰减
# # def lr_scheduler(epoch):
# #     if epoch < 100:
# #         return 0.001
# #     elif epoch < 200:
# #         return 0.0005
# #     else:
# #         return 0.0001
# callbacks = [
#     # tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
#     early_stopping
# ]
# loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),

# new_model.compile(loss=loss,
#                   optimizer=optimizer,
#                   metrics=['accuracy'])

# new_model.fit(
#     x_train, y_train, batch_size=batch_size,
   
#               epochs=epochs,
#               verbose=2,
#               validation_data=(x_val, y_val),
#               shuffle=True
#             #   ,
#             #   callbacks=callbacks
#               )

# score = new_model.evaluate(x_test, y_test, verbose=2)

# print(f'Test loss: { score[0]:.3f}')
# print(f'Test accuracy: {score[1] * 100:.3f}%')

# %% [markdown]
# ### Serialize Model and Weights

# %%
# model_json = new_model.to_json()
# with open(os.path.join(PATH, 'model26.json'), "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# new_model.save_weights(os.path.join(PATH, 'model26.h5'))
# print("Saved model to disk")

# %%
model_json = model.to_json()
with open(os.path.join(PATH, 'model28.json'), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(os.path.join(PATH, 'model28.h5'))
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# We are all done training the plain network. Next we will encrypt the network and run inference over it using FHE. Let's start with some initializations.

# %%
import pyhelayers
import utils

utils.verify_memory()

print('Misc. initializations')

# %%
import pyhelayers
import utils
import h5py
import os
import numpy as np
##### For reproducibility
seed_value= 1
os.environ['PYTHONHASHSEED']=str(seed_value)

# import activations
import sys
sys.path.append(os.path.join('.', 'data_gen'))
# from activations import SquareActivation

PATH = os.path.join('data', 'net_mnist')
if not os.path.exists(PATH):
    os.makedirs(PATH)



utils.verify_memory()

print('Misc. initializations')

batch_size=500

# %% [markdown]
# The following is a general outline of the next steps.
#
# We encode and encrypt a neural network model, using the files that were created and saved before. An automated optimizer, that occurs during the call to encode_encrypt, will examine our network and will determine various configuration details that will allow running inference under encryption efficiently.
#
# Next, we will demonstrate how we can encrypt data, run inference on our encrypted network, and compare the results against the expected labels.
# Now let's dive in . . .

# %%
he_run_req = pyhelayers.HeRunRequirements()
he_run_req.set_he_context_options([pyhelayers.DefaultContext()])
he_run_req.optimize_for_batch_size(16)

nn = pyhelayers.NeuralNet()
nn.encode_encrypt([os.path.join(PATH, "model.json"), os.path.join(PATH, "model.h5")], he_run_req)

# %% [markdown]
# The encode_encrypt method also initialized an HeContext object containing the keys. We obtain it now from the model so we can encrypt the input data.

# %%
context = nn.get_created_he_context()

# %% [markdown]
# We will now load real samples of the MNIST dataset to classify. We will load the samples and the corresponding true labels from HDF5 files. We will also extract the first batch of samples and labels.

# %%
with h5py.File(os.path.join(PATH, "x_test.h5")) as f:
    x_test = np.array(f["x_test"])
with h5py.File(os.path.join(PATH, "y_test.h5")) as f:
    y_test = np.array(f["y_test"])
    
# plain_samples, labels = utils.extract_batch(x_test, y_test, batch_size, 0)

plain_samples, labels = utils.extract_batch(x_test, y_test, 100, 0)
print('Batch of size',batch_size,'loaded')

# %% [markdown]
# To populate the input, we need to encode and then encrypt the values of the plain input under HE.

# %%
model_io_encoder = pyhelayers.ModelIoEncoder(nn)
samples = pyhelayers.EncryptedData(context)
model_io_encoder.encode_encrypt(samples, [plain_samples])
print('Test data encrypted')

# %% [markdown]
# We now go ahead with the inference itself. We run the encrypted input through the encrypted NN to obtain encrypted results. This computation does not use the secret key and acts on completely encrypted values. Running the inference is done using the "predict" method of the NN, that receives the destination 3D structure to put the result of the computation in, and the input for the inference.

# %%
utils.start_timer()

predictions = pyhelayers.EncryptedData(context)
nn.predict(predictions, samples)

duration=utils.end_timer('predict')
utils.report_duration('predict per sample',duration/batch_size)

# %% [markdown]
# In order to assess the results of the computation, we first need to decrypt them. This is done by an IO processor that has the secret key and is capable of decrypting the ciphertext and decoding it into plaintext version of the HE computation result.

# %%
plain_predictions = model_io_encoder.decrypt_decode_output(predictions)
print('predictions',plain_predictions)

# %% [markdown]
# Now we compare the results against the expected labels and compute the confusion matrix and the accuracy.

# %%
utils.assess_results(labels, plain_predictions)

# %% [markdown]
# <br>
#
# References:
#
# <sub><sup> 1.	LeCun, Yann and Cortes, Corinna. "MNIST handwritten digit database." (2010): </sup></sub>
#
# <sub><sup> 2.	Gilad-Bachrach, R., Dowlin, N., Laine, K., Lauter, K., Naehrig, M. &amp; Wernsing, J.. (2016). CryptoNets: Applying Neural Networks to Encrypted Data with High Throughput and Accuracy. Proceedings of The 33rd International Conference on Machine Learning, in Proceedings of Machine Learning Research 48:201-210 Available from https://proceedings.mlr.press/v48/gilad-bachrach16.html.
# </sup></sub>
